# %% [markdown]
# # Create Function

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
import pandas as pd
import string

def preprocessing(file_path):
  file = pd.read_csv(file_path)
  
  #Stemming and Lowercase
  factory = StemmerFactory()
  stemmer = factory.create_stemmer()

  file["kalimat"] = file["kalimat"].apply(
      lambda kalimat: stemmer.stem(kalimat)
  )
  
  #Remove Stop Words
  factory = StopWordRemoverFactory()
  stopword = factory.create_stop_word_remover()

  file["kalimat"] = file["kalimat"].apply(
      lambda kalimat: stopword.remove(kalimat)
  )
  
  #Remove Punctuation
  for p in string.punctuation:
    file["kalimat"] = file["kalimat"].str.replace(p, '')
    
  #create dictionary
  d = {}

  for index, row in file.iterrows():
    d[str(row["kalimat_id"])] = row["kalimat"].split()
  
  
  return d

# %% [markdown]
# # double_annotator_agree.csv

# %%
file_path = "../data/training_set/double_annotator_agree.csv"

double_annotator_agree = preprocessing(file_path)

double_annotator_agree
# Out:
# {'1000527': ['cara',
#   'anatomi',
#   'hidung',
#   'tonjol',
#   'vertebrata',
#   'kandung',
#   'nostril',
#   'nyaring',
#   'udara',
#   'napas'],
#  '1000651': ['mandi', 'air', 'kandung', 'belerang', 'obat', 'sakit', 'kulit'],
#  '1000770': ['ikat',
#   'klathrin',
#   'membrane',
#   'sel',
#   'bentuk',
#   'vesikel',
#   'kandung',
#   'molekul',
#   'ligan'],
#  '1001199': ['tapak',
#   'karier',
#   'gedung',
#   'parlemen',
#   'totok',
#   'milik',
#   'ambisi',
#   'politik',
#   'kejar',
#   'karier',
#   'puncak'],
#  '1001330': ['juga',
#   'beri',
#   'emc',
#   'alam',
#   'wawas',
#   'masa',
#   'depan',
#   'kejar',
#   'tuju',
#   'utama',
#   'layan',
#   'kereta',
#   'barang'],
#  '1001386': ['injak',
#   'usia',
#   '17',
#   'tahun',
#   'bagas',
#   'putus',
#   'fokus',
#   'kejar',
#   'impi',
#   'cari',
#   'jalan',
#   'bisa',
#   'jadi',
#   'musisi',
#   'sukses'],
#  '1001455': ['kejar',
#   'harry',
#   'ron',
#   'hermione',
#   'pikir',
#   'mereka',
#   'sedang',
#   'kejar',
#   'snape'],
#  '1001469': ['program',
#   'senjata',
#   'kimia',
#   'mesir',
#   'yang',
#   'paling',
#   'maju',
#   'kejar',
#   'kembang',
#   'senjata',
#   'musnah',
#   'massal',
#   'meski',
#   'kira',
#   'capai',
#   'puncak',
#   'tahun',
#   '1960an'],
#  '1001582': ['pasu',
#   'voc',
#   'sendiri',
#   'kejar',
#   'pasu',
#   'mataram',
#   'wilayah',
#   'jatinegara'],
#  '1001682': ['buang',
#   'waktu',
#   'guwarsa',
#   'guwarsi',
#   'kejar',
#   'mana',
#   'cupu',
#   'pergi'],
#  '1001699': ['amerika',
#   'utara',
#   'basenji',
#   'anggap',
#   'bagai',
#   'anjing',
#   'ras',
#   'sighthound',
#   'kejar',
#   'serang',
#   'segala',
#   'mangsa',
#   'cara',
#   'diam'],
#  '1001752': ['dapat',
#   'kerja',
#   'ancang',
#   'di',
#   'lingkup',
#   'giat',
#   'profesional',
#   'konsultan',
#   'cakup',
#   'tanggung',
#   'jawab',
#   'moral',
#   'hormat',
#   'orang',
#   'libat',
#   'itu',
#   'sematamata',
#   'orientasi',
#   'bagai',
#   'usaha',
#   'kejar',
#   'laba',
#   'profit',
#   'oriented'],
#  '1001801': ['sadar',
#   'ancam',
#   'imhotep',
#   'pun',
#   'ke',
#   'kairo',
#   'imhotep',
#   'hasil',
#   'kejar'],
#  '1001863': ['pada',
#   'januari',
#   '2012',
#   'wentz',
#   'umum',
#   'rexha',
#   'tinggal',
#   'band',
#   'kejar',
#   'usaha'],
#  '1001900': ['lee',
#   'sebut',
#   'jika',
#   'tidak',
#   'kejar',
#   'karier',
#   'bidang',
#   'musik',
#   'akan',
#   'pasuk',
#   'bidang',
#   'mana',
#   'bisa',
#   'bantu',
#   'orang',
#   'utama',
#   'anak',
#   'siksa'],
#  '1001923': ['deklarasi',
#   'tekan',
#   'hak',
#   'masyarakat',
#   'adat',
#   'pelihara',
#   'kuat',
#   'institusi',
#   'budaya',
#   'tradisi',
#   'sendiri',
#   'untuk',
#   'kejar',
#   'kembang',
#   'sesuai',
#   'butuh',
#   'aspirasi',
#   'sendiri'],
#  '1002091': ['moldavia', 'kejar', 'unta', 'uang'],
#  '1002169': ['harry',
#   'kejar',
#   'atas',
#   'sapu',
#   'tangkap',
#   'remembrall',
#   'atas',
#   'tanah'],
#  '1002365': ['kemudian',
#   'pihak',
#   'stunticons',
#   'curi',
#   'mobil',
#   'sebut',
#   'tendang',
#   'cara',
#   'paksa',
#   'cahnay',
#   'tak',
#   'lama',
#   'selang',
#   'cahnay',
#   'akhir',
#   'pilih',
#   'kemudi',
#   'bluestreak',
#   'kejar',
#   'mobil',
#   'hilang'],
#  '1002692': ['sangkuriang',
#   'suruh',
#   'si',
#   'tumang',
#   'kejar',
#   'babi',
#   'hutan',
#   'nyata',
#   'celeng',
#   'wayung',
#   'hyang'],
#  '1002916': ['cynoscephalae',
#   'magnesia',
#   'gagal',
#   'tahan',
#   'sayap',
#   'phalanx',
#   'kalah',
#   'di',
#   'pydna',
#   'hilang',
#   'rapat',
#   'baris',
#   'phalanx',
#   'kejar',
#   'tentara',
#   'romawi',
#   'mundur',
#   'mungkin',
#   'roma',
#   'tembus',
#   'formasi',
#   'di',
#   'mana',
#   'terampil',
#   'tarung',
#   'jarak',
#   'dekat',
#   'romawi',
#   'bukti'],
#  '1003018': ['kemudian',
#   'firaun',
#   'kejar',
#   'bani',
#   'israel',
#   'dengan',
#   'kereta',
#   'hingga',
#   'laut',
#   'merah'],
#  '1003170': ['juga',
#   'keluar',
#   'lapang',
#   'akhir',
#   'babak',
#   'pertama',
#   'cedera',
#   'kemudian',
#   'tuan',
#   'rumah',
#   'datang',
#   'kejar',
#   'hasil',
#   'akhir',
#   '22'],
#  '1003184': ['tsunku',
#   'tambah',
#   'ingin',
#   'lihat',
#   'kejar',
#   'mimpi',
#   'baru',
#   'minta',
#   'dukung',
#   'seluruh',
#   'sisa',
#   'waktu'],
#  '1003536': ['produsen',
#   'keluar',
#   'ponsel',
#   'dengan',
#   'warna',
#   'hitam',
#   'putih'],
#  '1003697': ['subgenre',
#   'rpg',
#   'hasil',
#   'campur',
#   'rpg',
#   'genre',
#   'game',
#   'mulai',
#   'lihat',
#   'nintendo',
#   'keluar',
#   'franchise',
#   'kenal',
#   'the',
#   'legend',
#   'of',
#   'zelda',
#   'tahun',
#   '1986',
#   'sebut',
#   'bagai',
#   'main',
#   'peranaksi',
#   'action',
#   'roleplaying',
#   'game',
#   'guna',
#   'sistem',
#   'rpg',
#   'health',
#   'stamina',
#   'guna',
#   'elemen',
#   'genre',
#   'main',
#   'aksi'],
#  '1004619': ['batang', 'daun', 'merah', 'bila', 'patah', 'keluar', 'getah'],
#  '1005735': ['operasi',
#   'di',
#   'tajikistan',
#   'ekstrak',
#   'proses',
#   'emas',
#   'antimoni',
#   'tungsten',
#   'merkuri',
#   'molibdenum',
#   'semua',
#   'kenal',
#   'keluar',
#   'limbah',
#   'racun'],
#  '1006436': ['gunung', 'meru', 'terus', 'keluar', 'letus', 'sejak', '1967'],
#  '1006803': ['lambung', 'sel', 'utama', 'keluar', 'pepsinogen'],
#  '1007624': ['akhir',
#   'tahun',
#   '2003',
#   'netral',
#   'keluar',
#   'klip',
#   'judul',
#   'nama',
#   'netral'],
#  '1007978': ['guangxu',
#   'keluar',
#   'dekret',
#   'boleh',
#   'diri',
#   'universitas',
#   'modern',
#   'beijing',
#   'bangun',
#   'rel',
#   'kereta',
#   'api',
#   'luhan',
#   'sistem',
#   'anggar',
#   'mirip',
#   'negara',
#   'barat'],
#  '1008670': ['beberapa',
#   'detik',
#   'aktif',
#   'ponsel',
#   'keluar',
#   'nada',
#   'dering',
#   'beri',
#   'tampil',
#   'layar',
#   'olah',
#   'telepon',
#   'masuk',
#   'nomor',
#   'kenal'],
#  '1009565': ['bulan',
#   'januari',
#   '2011',
#   'badan',
#   'lindung',
#   'lingkung',
#   'amerika',
#   'serikat',
#   'keluar',
#   'surat',
#   'nyata',
#   'campur',
#   'etanol',
#   'bensin',
#   '15',
#   'e15'],
#  '1009778': ['gambar',
#   'lembu',
#   'jantan',
#   'pohon',
#   'cemara',
#   'orang',
#   'sedang',
#   'tunggang',
#   'kuda',
#   'orang',
#   'sedang',
#   'ikat',
#   'kerbau'],
#  '1010064': ['beda',
#   'wanita',
#   'tionghoa',
#   'kelompok',
#   'wanita',
#   'hakka',
#   'tolak',
#   'ikat',
#   'kaki',
#   'tidak',
#   'sesuai',
#   'peran',
#   'kerja'],
#  '1010160': ['antonio',
#   'pigafetta',
#   'tulis',
#   'kronik',
#   'magellan',
#   'catat',
#   'suku',
#   'tagbanwa',
#   'praktik',
#   'ritual',
#   'satu',
#   'darah',
#   'budi',
#   'daya',
#   'tani',
#   'buru',
#   'sumpit',
#   'panah',
#   'kayu',
#   'simpan',
#   'pakai',
#   'cincin',
#   'rantai',
#   'kuningan',
#   'lonceng',
#   'pisau',
#   'kawat',
#   'tembaga',
#   'ikat',
#   'kait',
#   'ikan',
#   'adu',
#   'ayam',
#   'suling',
#   'minum',
#   'alkohol',
#   'beras'],
#  '1010470': ['ikat',
#   'bulu',
#   'appa',
#   'lengan',
#   'momo',
#   'tinggal',
#   'rumah',
#   'aang',
#   'cari',
#   'appa'],
#  '1010608': ['suatu',
#   'hari',
#   'ryan',
#   'semenamena',
#   'ikat',
#   'orang',
#   'nenek',
#   'renta',
#   'aming',
#   'atas',
#   'tiang',
#   'listrik',
#   'lucu'],
#  '1010686': ['lima',
#   'orang',
#   'pakai',
#   'tugas',
#   'polisi',
#   'ikat',
#   'tutup',
#   'mulut',
#   'lalu',
#   'curi',
#   'hias',
#   'harga',
#   '10',
#   'juta'],
#  '1010848': ['benar',
#   'nama',
#   'gyptian',
#   'rupa',
#   'juluk',
#   'ia',
#   'dari',
#   'kebiasaanya',
#   'suka',
#   'ikat',
#   'kaos',
#   'kepala',
#   'putar',
#   'jenggot',
#   'layak',
#   'firaun',
#   'mesir'],
#  '1010909': ['anchoring',
#   'junctions',
#   '4',
#   'bentuk',
#   'beda',
#   'cara',
#   'fungsional',
#   'adherens',
#   'junctions',
#   'desmosom',
#   'pegang',
#   'sel',
#   'sama',
#   'bentuk',
#   'transmembrane',
#   'adhesion',
#   'proteins',
#   'masuk',
#   'dalam',
#   'famili',
#   'cadherin',
#   'focal',
#   'adhesions',
#   'hemidesmosom',
#   'ikat',
#   'sel',
#   'matriks',
#   'ekstraseluler',
#   'bentuk',
#   'transmembrane',
#   'adhesion',
#   'proteins',
#   'famili',
#   'integrin'],
#  '1011033': ['tahun',
#   '2006',
#   'mls',
#   'pecah',
#   'semuacatatan',
#   'waktu',
#   'jumlah',
#   'hadir',
#   'tanding',
#   'musim',
#   'reguler',
#   'saat',
#   '92',
#   '650',
#   'tonton',
#   'isi',
#   'los',
#   'angeles',
#   'coliseum',
#   'hari',
#   'minggu',
#   'bulan',
#   'agustus'],
#  '1011373': ['bentuk',
#   'energi',
#   'gelap',
#   'usul',
#   'konstanta',
#   'kosmologi',
#   'suatu',
#   'energi',
#   'rapat',
#   'tetap',
#   'cara',
#   'homogen',
#   'isi',
#   'ruang',
#   'quintessence',
#   'suatu',
#   'medan',
#   'dinamis',
#   'padat',
#   'energi',
#   'ubah',
#   'ruang',
#   'waktu'],
#  '1012225': ['jumlah',
#   'pihak',
#   'pandang',
#   'seks',
#   'orang',
#   'pasang',
#   'sebab',
#   'ini',
#   'dua',
#   'saling',
#   'isi',
#   'qi',
#   'masingmasing'],
#  '1012687': ['shinchan',
#   'ony',
#   'pernah',
#   'isi',
#   'suara',
#   'tokoh',
#   'anime',
#   'lain',
#   'lee',
#   'shaoran',
#   'cardcaptor',
#   'sakura',
#   '1',
#   'kuro',
#   'cyborg',
#   'kurochan',
#   'bakabon',
#   'si',
#   'jenius',
#   'bakabon',
#   'tensai',
#   'bakabon',
#   'ikyu',
#   'ikyu',
#   'san',
#   'krishna',
#   'little',
#   'krishna'],
#  '1014103': ['jenis',
#   'anjing',
#   'kini',
#   'punah',
#   'nama',
#   'terus',
#   'jenis',
#   'anjing',
#   'spanyol',
#   'sebut',
#   'alano',
#   'cara',
#   'tradisional',
#   'untuk',
#   'buru',
#   'babi',
#   'hutan',
#   'jaga',
#   'ternak'],
#  '1015092': ['wayang',
#   'kulit',
#   'cirebon',
#   'masih',
#   'pegang',
#   'sinambung',
#   'masa',
#   'praislam',
#   'masa',
#   'islam',
#   'bentuk',
#   'ukir',
#   'pasu',
#   'unsur',
#   'kaligrafi',
#   'jaga',
#   'harmonisasi',
#   'dua',
#   'jadi',
#   'wayang',
#   'kulit',
#   'cirebon',
#   'tetap',
#   'jadi',
#   'duta',
#   'diplomasi',
#   'hingga',
#   'kini',
#   'diplomasi',
#   'temu',
#   'satu',
#   'waris',
#   'leluhur',
#   'aneka',
#   'budaya',
#   'kisah',
#   'epik',
#   'hindu',
#   'budha',
#   'india',
#   'ajar',
#   'islam',
#   'bahkan',
#   'isu',
#   'kontemporer',
#   'hibur',
#   'modern',
#   'media',
#   'teknologi',
#   'seni',
#   'rajin',
#   'tradisional'],
#  '1015644': ['telah',
#   'meni',
#   'paksa',
#   'tunda',
#   'mimpi',
#   'jadi',
#   'nyanyi',
#   'jaga',
#   'urus',
#   'anak',
#   'pertama',
#   'rumah'],
#  '1015820': ['waktu',
#   'lama',
#   'ada',
#   'tanda',
#   'muncul',
#   'culik',
#   'semua',
#   'orang',
#   'biar',
#   'tebak',
#   'apa',
#   'benar',
#   'jadi',
#   'pada',
#   'yang',
#   'sama',
#   'lidi',
#   'buat',
#   'sangat',
#   'rahasia',
#   'tahu',
#   'publik',
#   'jaga',
#   'culik',
#   'tidak',
#   'panik'],
#  '1017600': ['kronos',
#   'kuasa',
#   'tempat',
#   'drakaina',
#   'kampe',
#   'jaga',
#   'makhluk',
#   'kurung',
#   'tartaros'],
#  '1017783': ['jaga',
#   'langgeng',
#   'hubung',
#   'baik',
#   'kampung',
#   'imam',
#   'kampung',
#   'raja',
#   'tetap',
#   'buah',
#   'etika',
#   'sultan',
#   'badarruddin',
#   'sya',
#   'ban',
#   'bin',
#   'sanga',
#   'hingga',
#   'kini',
#   'masih',
#   'lihat',
#   'laksana',
#   'ritual',
#   'agama',
#   'dua',
#   'kampung',
#   'islam',
#   'tua',
#   'pulau',
#   'timor',
#   'kampung',
#   'solor',
#   'airmata'],
#  '1018182': ['harry',
#   'potter',
#   'and',
#   'the',
#   'order',
#   'of',
#   'the',
#   'phoenix',
#   'ungkap',
#   'nyata',
#   'mrs',
#   'figg',
#   'squib',
#   'tugas',
#   'dumbledore',
#   'jaga',
#   'harry'],
#  '1018283': ['tenun',
#   'rupa',
#   'mampu',
#   'ajar',
#   'cara',
#   'turun',
#   'turun',
#   'jaga',
#   'tetap',
#   'lestari'],
#  '1018397': ['banyak',
#   'organisme',
#   'asidofilik',
#   'kembang',
#   'mekanisme',
#   'sangat',
#   'efisien',
#   'pompa',
#   'proton',
#   'keluar',
#   'ruang',
#   'intraseluler',
#   'jaga',
#   'sitoplasma',
#   'atau',
#   'hingga',
#   'dekat',
#   'ph',
#   'netral'],
#  '1018896': ['sisi',
#   'ajar',
#   'tetap',
#   'jaga',
#   'mutu',
#   'tinggi',
#   'sesuai',
#   'tuju',
#   'utama',
#   'para',
#   'diri',
#   'mana',
#   'ijazah',
#   'beri',
#   'th',
#   'bandung',
#   'tara',
#   'th',
#   'delft'],
#  '1019008': ['jadi', 'langgar', 'allah', 'dia', 'turun', 'ke', 'bumi'],
#  '1019249': ['tetapi',
#   'uap',
#   'air',
#   'lebih',
#   'banyak',
#   'bentuk',
#   'awan',
#   'lebih',
#   'banyak',
#   'akan',
#   'pantul',
#   'cahaya',
#   'matahari',
#   'ke',
#   'angkasa',
#   'luar',
#   'mana',
#   'ini',
#   'akan',
#   'turun',
#   'proses',
#   'panas',
#   'lihat',
#   'siklus',
#   'air'],
#  '1019301': ['didik',
#   'seks',
#   'komprehensif',
#   'akses',
#   'hadap',
#   'alat',
#   'kontrasepsi',
#   'efektif',
#   'turun',
#   'angka',
#   'hamil',
#   'kelompok',
#   'usia'],
#  '1019306': ['turun',
#   'suhu',
#   'udara',
#   'turun',
#   'suhu',
#   'air',
#   'ikan',
#   'jadi',
#   'stres',
#   'nafsu',
#   'makan',
#   'daya',
#   'tahan',
#   'tubuh',
#   'turun'],
#  '1019393': ['ringkas',
#   'ada',
#   'bisa',
#   'beri',
#   'rizki',
#   'sembuh',
#   'segala',
#   'macam',
#   'sakit',
#   'tolak',
#   'segala',
#   'macam',
#   'marabahaya',
#   'beri',
#   'segala',
#   'macam',
#   'manfaat',
#   'bahagia',
#   'sengsara',
#   'jadi',
#   'orang',
#   'miskin',
#   'kaya',
#   'hidup',
#   'mati',
#   'lulus',
#   'orang',
#   'segala',
#   'macam',
#   'uji',
#   'naik',
#   'turun',
#   'pangkat',
#   'jabat',
#   'orang',
#   'allah'],
#  '1019969': ['lalu',
#   'turun',
#   'eber',
#   'lahir',
#   'abraham',
#   'daud',
#   'hingga',
#   'akhir',
#   'turun',
#   'yesus'],
#  '1020277': ['ukur',
#   'ulang',
#   'kali',
#   'cepat',
#   'radial',
#   'proxima',
#   'centauri',
#   'tidak',
#   'tunjuk',
#   'geser',
#   'sebut',
#   'turun',
#   'massa',
#   'maksimum',
#   'dapat',
#   'milik',
#   'iring',
#   'proxima',
#   'centauri'],
#  '1020367': ['orang',
#   'kardinal',
#   'pilih',
#   'julius',
#   'riyadi',
#   'darmaatmadja',
#   'keith',
#   'michael',
#   'patrick',
#   'o',
#   'brien',
#   'pilih',
#   'tak',
#   'partisipasi',
#   'masingmasing',
#   'alas',
#   'sehat',
#   'pribadi',
#   'turun',
#   'jumlah',
#   'kardinal',
#   'pilih',
#   'hadir',
#   'jadi',
#   '115'],
#  '1020376': ['rintang',
#   'tengkorak',
#   'indikasi',
#   'jambul',
#   'sebut',
#   'sangat',
#   'tata',
#   'bahwa',
#   'burung',
#   'sebut',
#   'tak',
#   'kakatua',
#   'tak',
#   'kembang',
#   'turun'],
#  '1020463': ['magnesium',
#   'hingga',
#   '15',
#   '35',
#   'turun',
#   'titik',
#   'lebur',
#   'logam',
#   'padu',
#   'cukup',
#   'drastis',
#   '660',
#   'oc',
#   'hingga',
#   '450',
#   'oc'],
#  '1020646': ['effektifitas',
#   'red',
#   'yeast',
#   'rice',
#   'turun',
#   'kolesterol',
#   'uji',
#   'cara',
#   'klinis',
#   'lebih',
#   '17',
#   'riset',
#   'tiongkok'],
#  '1020736': ['roda',
#   'ke5',
#   'langsung',
#   'gerak',
#   'mesin',
#   'jalan',
#   'mobil',
#   'mulai',
#   'angkat',
#   'roda',
#   'gerak',
#   'mesin',
#   'sedikit',
#   'udara',
#   'kemudian',
#   'mesin',
#   'sudah',
#   'nyala',
#   'sopir',
#   'turun',
#   'mesin',
#   'guna',
#   'tuas',
#   'lembut',
#   'mulai',
#   'gera',
#   'maju'],
#  '1020742': ['kemudian',
#   'hari',
#   'anak',
#   'perempuan',
#   'bisri',
#   'syansuri',
#   'meni',
#   'kh',
#   'wahid',
#   'hasyim',
#   'turun',
#   'kh',
#   'abdurrahman',
#   'wahid',
#   'ir',
#   'h'],
#  '1020782': ['benar',
#   'nama',
#   'naiambaton',
#   'ibu',
#   'raja',
#   'nabolon',
#   'raja',
#   'sitempang',
#   'mana',
#   'akan',
#   'turun',
#   'marga',
#   'masuk',
#   'kelompok',
#   'parna'],
#  '1020856': ['burung',
#   'hantu',
#   'turun',
#   'serang',
#   'tikus',
#   'tanam',
#   'kelapa',
#   'sawit',
#   'muda',
#   'hingga',
#   'bawah',
#   '5',
#   'persen'],
#  '1020898': ['bakteri',
#   'resisten',
#   'hadap',
#   'antibiotik',
#   'betalaktam',
#   'milik',
#   '3',
#   'mekanisme',
#   'resistensi',
#   'destruksi',
#   'antibiotik',
#   'betalaktamase',
#   'turun',
#   'penetrasi',
#   'antibiotik',
#   'ikat',
#   'protein',
#   'transpepidase',
#   'turun',
#   'afinitas',
#   'ikat',
#   'protein',
#   'ikat',
#   'sebut',
#   'senyawa',
#   'antibiotik'],
#  '1021002': ['sejak',
#   'abad',
#   '17',
#   'awal',
#   'tari',
#   'topeng',
#   'ada',
#   'desa',
#   'beber',
#   'bawa',
#   'orang',
#   'seniman',
#   'gegesik',
#   'cirebon',
#   'nama',
#   'seti',
#   'turut',
#   'ahli',
#   'dalang',
#   'topeng',
#   'cirebon',
#   'gaya',
#   'beber',
#   'mimi',
#   'yayah',
#   'ki',
#   'dalang',
#   'kardama',
#   'pertama',
#   'kali',
#   'bawa',
#   'tari',
#   'topeng',
#   'desa',
#   'beber',
#   'jadi',
#   'tari',
#   'topeng',
#   'cirebon',
#   'gaya',
#   'beber',
#   'mimi',
#   'sonten',
#   'surawarcita',
#   'masih',
#   'asal',
#   'gegesik',
#   'sejak',
#   'turun',
#   'beberapa',
#   'generasi',
#   'seniman'],
#  '1021044': ['tingkat',
#   'magnesium',
#   'turun',
#   'kalsium',
#   'dapat',
#   'cegah',
#   'hiperkalsemia',
#   'sebab',
#   'hipokalsemia',
#   'gantung',
#   'tingkat',
#   'awal'],
#  '1021199': ['direktur',
#   'cityjet',
#   'nyata',
#   'hasil',
#   'negatif',
#   'level',
#   'operasional',
#   'jadi',
#   'masih',
#   'lanjut',
#   'kondisi',
#   'ekonomi',
#   'buruk',
#   'turun',
#   'jumlah',
#   'tumpang',
#   'kanaikan',
#   'harga',
#   'lemah',
#   'nilai',
#   'mata',
#   'uang',
#   'sangat',
#   'buruk'],
#  '1021330': ['fitoremediasi',
#   'diri',
#   'konsentrasi',
#   'polutan',
#   'tanah',
#   'kontaminasi',
#   'mitigasi',
#   'air',
#   'udara',
#   'tanam',
#   'mampu',
#   'turun',
#   'hilang',
#   'logam',
#   'pestisida',
#   'larut',
#   'bahan',
#   'ledak',
#   'minyak',
#   'mentah',
#   'turun',
#   'kontaminan',
#   'dari',
#   'bagai',
#   'media',
#   'kandung'],
#  '1021541': ['scratch',
#   'buat',
#   'buah',
#   'program',
#   'project',
#   'susun',
#   'tumpuk',
#   'balok',
#   'visual',
#   'perintah',
#   'atur',
#   'tingkah',
#   'laku',
#   'komponen',
#   'program',
#   'kenal',
#   'bagai',
#   'sprite'],
#  '1021908': ['susun',
#   'kurang',
#   'empat',
#   'buah',
#   'novel',
#   'tiga',
#   'otobiografi',
#   'hingga',
#   'wafat',
#   '1979',
#   'moskwa'],
#  '1022043': ['jiedushi',
#   'milik',
#   'kusa',
#   'eksternal',
#   'kuat',
#   'masuk',
#   'hak',
#   'susun',
#   'tentara',
#   'sendiri',
#   'tarik',
#   'pajak',
#   'usul',
#   'angkat',
#   'jabat'],
#  '1022080': ['kait',
#   'tetap',
#   'darat',
#   'eurasia',
#   'bagai',
#   'pusat',
#   'kuasa',
#   'dunia',
#   'brzezinski',
#   'susun',
#   'geostrategi',
#   'eurasia',
#   'amerika',
#   'serikat'],
#  '1022445': ['ronta',
#   'hasil',
#   'padam',
#   'kuasa',
#   'daerah',
#   'jenderal',
#   'tadi',
#   'susun',
#   'kuat',
#   'sendiri',
#   'mula',
#   'buah',
#   'rivalitas',
#   'antar',
#   'raja',
#   'perang',
#   'tanda',
#   'akhir',
#   'dinasti',
#   'han'],
#  '1022595': ['awal',
#   'periode',
#   'zaman',
#   'weda',
#   'zaman',
#   'mana',
#   'literaturliteratur',
#   'weda',
#   'tulis',
#   '1500',
#   '500',
#   'sm',
#   'adab',
#   'india',
#   'kenal',
#   'pola',
#   'ubah',
#   'musim',
#   'konstelasi',
#   'benda',
#   'langit',
#   'juga',
#   'susun',
#   'suatu',
#   'kalender',
#   'kuno',
#   'meta',
#   'ubah',
#   'musim',
#   'sebut'],
#  '1023334': ['vernon',
#   'parrington',
#   'susun',
#   'kanon',
#   'sastra',
#   'amerika',
#   'kutuk',
#   'james',
#   'telah',
#   'pisah',
#   'diri',
#   'amerika'],
#  '1023618': ['mayor',
#   'oerip',
#   'angkat',
#   'bagai',
#   'kepala',
#   'staf',
#   'umum',
#   'pangkat',
#   'letnan',
#   'jenderal',
#   'oerip',
#   'segera',
#   'susun',
#   'organisasi',
#   'markas',
#   'tinggi',
#   'tkr',
#   'mttkr',
#   'tiru',
#   'departemen',
#   'peperangan',
#   'hindia',
#   'belanda'],
#  '1023802': ['bagai',
#   'banding',
#   'ikut',
#   'nilai',
#   'tukar',
#   'mata',
#   'uang',
#   'won',
#   'hadap',
#   'dolar',
#   'as',
#   'codice',
#   '3',
#   '16',
#   'juli',
#   '2013',
#   'turut',
#   'xe',
#   'com'],
#  '1024098': ['nilai', 'teliti', 'cermin', 'proses', 'upacara', 'sendiri'],
#  '10245': ['manning',
#   'dakwa',
#   'atas',
#   '22',
#   'langgar',
#   'masuk',
#   'bantu',
#   'musuh',
#   'buat',
#   'dapat',
#   'hukum',
#   'mati'],
#  '1024726': ['ulas',
#   'di',
#   'koran',
#   'sama',
#   'sebut',
#   'meski',
#   'orang',
#   'goyang',
#   'kepala',
#   'orang',
#   'tentang',
#   'nilai',
#   'budaya',
#   'film',
#   'pribumi',
#   'film',
#   'tanda',
#   'maju',
#   'industri',
#   'film'],
#  '1025656': ['nilai',
#   'proyek',
#   'sudah',
#   'gelar',
#   'tahun',
#   '2011',
#   'raja',
#   'abdullah',
#   'capai',
#   '26',
#   '6',
#   'miliar',
#   'dolar',
#   'as'],
#  '1026845': ['tanding',
#   'catur',
#   'satu',
#   'menang',
#   'beri',
#   'nilai',
#   '1',
#   'seri',
#   'remis',
#   'kalah',
#   'oleh',
#   'nilai'],
#  '1027058': ['fungsi',
#   'inang',
#   'bagai',
#   'tata',
#   'gaul',
#   'tata',
#   'nilai',
#   'masyarakat'],
#  '1027251': ['seri',
#   'lima',
#   'harry',
#   'potter',
#   'harry',
#   'potter',
#   'orde',
#   'phoenix',
#   'harry',
#   'tahu',
#   'untuk',
#   'lanjut',
#   'kelas',
#   'newt',
#   'ramu',
#   'guru',
#   'ramu',
#   'profesor',
#   'snape',
#   'syarat',
#   'nilai',
#   'o',
#   'outstanding',
#   'kagum'],
#  '1030805': ['altman',
#   'bicara',
#   'nilai',
#   'teori',
#   'karena',
#   'maju',
#   'pikir',
#   'dengan',
#   'masuk',
#   'beda',
#   'tingkat',
#   'kombinasi',
#   'serta',
#   'proses',
#   'komunikasi',
#   'altman',
#   '2002'],
#  '1032572': ['negara',
#   'belah',
#   'utara',
#   'garis',
#   'sangat',
#   'kaya',
#   'dagang',
#   'barang',
#   'jadi',
#   'sedang',
#   'negara',
#   'belah',
#   'selatan',
#   'garis',
#   'miskin',
#   'dagang',
#   'barang',
#   'tengah',
#   'jadi',
#   'nilai',
#   'ekspor',
#   'kecil'],
#  '1034282': ['suhu',
#   'tekan',
#   'pilih',
#   'cara',
#   'bebas',
#   'harus',
#   'kutip',
#   'nilai',
#   'konstanta',
#   'loschmidt'],
#  '103565': ['mesin',
#   'guna',
#   'lama',
#   'perang',
#   'dunia',
#   'ii',
#   'tank',
#   'berat',
#   'jerman',
#   'panther',
#   'jagdpanther',
#   'tiger',
#   'ii',
#   'jagdtiger',
#   'hl230',
#   'p30',
#   'versi',
#   'lebih',
#   'baru',
#   'tiger',
#   'i',
#   'sturmtiger',
#   'hl230',
#   'p45'],
#  '1036677': ['ia',
#   'sempat',
#   'tawar',
#   'beasiswa',
#   'kuliah',
#   'imperial',
#   'college',
#   'london',
#   'jurus',
#   'ilmu',
#   'aerodinamika',
#   'nilai',
#   'matematika',
#   'fisika',
#   'lama',
#   'duduk',
#   'bangku',
#   'sekolah',
#   'bagus'],
#  '1037135': ['perintah',
#   'kurang',
#   'keluar',
#   'kenal',
#   'pajak',
#   'tambah',
#   'nilai'],
#  '1038920': ['bahkan', 'nilai', 'olga', 'jadi', 'jeblok'],
#  '1039082': ['jajang',
#   'cina',
#   'beri',
#   'buah',
#   'pusaka',
#   'suci',
#   'tak',
#   'nilai',
#   'harga',
#   'buah',
#   'fragmen',
#   'tengkorak',
#   'sakyamuni',
#   'buddha',
#   'buah',
#   'mangkuk',
#   'emis',
#   'dari',
#   'kayu',
#   'jubah',
#   'monastik',
#   'buddha',
#   '100',
#   'sarira',
#   'buddha',
#   'mutiara',
#   'manik',
#   'kristal',
#   'konon',
#   'temu',
#   'antara',
#   'abu',
#   'kremasi',
#   'guru',
#   'spiritual',
#   'buddha'],
#  '1039926': ['meski',
#   'hampir',
#   'panjang',
#   'abad',
#   'ke13',
#   'yerusalem',
#   'alami',
#   'turun',
#   'status',
#   'jadi',
#   'buah',
#   'desa',
#   'jatuh',
#   'nilai',
#   'strategis',
#   'kota',
#   'dan',
#   'gulat',
#   'internal',
#   'ayyubiyyah'],
#  '1040613': ['notasi',
#   'ilmiah',
#   'cara',
#   'tulis',
#   'nomor',
#   'akomodasi',
#   'nilai',
#   'terlalu',
#   'besar',
#   'kecil',
#   'dengan',
#   'mudah',
#   'tulis',
#   'notasi',
#   'desimal',
#   'standar'],
#  '1040718': ['tahun',
#   '1993',
#   'bangun',
#   'di',
#   'renovasi',
#   'tetap',
#   'tahan',
#   'nilai',
#   'sejarah',
#   'bentuk',
#   'asli',
#   'arsitektur',
#   'kolonial'],
#  '1040958': ['kondisi', 'nol', 'ada', 'manik', 'tempel', 'garis', 'nilai'],
#  '1043553': ['pierre',
#   'louis',
#   'dulong',
#   'lahir',
#   '12',
#   'february',
#   '1785',
#   'tinggal',
#   '19',
#   'juli',
#   '1838',
#   'orang',
#   'fisikawan',
#   'kimiawan',
#   'apoteker',
#   'perancis',
#   'sama',
#   'a',
#   't',
#   'petit',
#   'louis',
#   'dulong',
#   'cetus',
#   'hukum',
#   'dulong',
#   'petit',
#   'nyata',
#   'produk',
#   'massa',
#   'atom',
#   'panas',
#   'jenis',
#   'zat',
#   'padat',
#   'tetap'],
#  '1043721': ['ajar',
#   'alquran',
#   'kena',
#   'masalah',
#   'perang',
#   'damai',
#   'jadi',
#   'topik',
#   'diskusi',
#   'panas',
#   'beberapa',
#   'tahun',
#   'akhir'],
#  '1044626': ['lewat',
#   'bagai',
#   'timbang',
#   'gerilyawan',
#   'tibet',
#   'pindah',
#   'markas',
#   'besar',
#   'dusun',
#   'mustang',
#   'yangberlokasi',
#   'dekat',
#   'batas',
#   'nepal',
#   'musim',
#   'panas',
#   '1960',
#   'sekitar',
#   '2',
#   '000',
#   'orang',
#   'gerilyawan',
#   'bentuk',
#   'cia',
#   'jadi',
#   'tujuh',
#   'kelompok'],
#  '1045094': ['libat',
#   'hubung',
#   'asmara',
#   'panas',
#   'orang',
#   'muda',
#   'kayaraya'],
#  '1045473': ['holmqvistit',
#   'banyak',
#   'jenis',
#   'mineral',
#   'batu',
#   'tampil',
#   'ut',
#   'gruvmuseum',
#   'buka',
#   'tiap',
#   'hari',
#   'musim',
#   'panas',
#   'sore',
#   'hari'],
#  '1046057': ['musim',
#   'dingin',
#   'danau',
#   'isi',
#   'air',
#   'pada',
#   'musim',
#   'panas',
#   'air',
#   'uap',
#   'sisa',
#   'kerak',
#   'garam'],
#  '1046644': ['musim',
#   'panas',
#   '1979',
#   'rating',
#   'siar',
#   'berita',
#   'model',
#   'baru',
#   'sebut',
#   'terus',
#   'tanjak'],
#  '1046689': ['roti',
#   'bakar',
#   'panas',
#   'lebih',
#   'rangup',
#   'keras',
#   'dapat',
#   'tampung',
#   'hias',
#   'atas',
#   'lebih',
#   'baik'],
#  '1047043': ['remake',
#   'drama',
#   'televisi',
#   'jepang',
#   'my',
#   'boss',
#   'my',
#   'hero',
#   'siar',
#   'nippon',
#   'tv',
#   'musim',
#   'panas',
#   'tahun',
#   '2006'],
#  '1047117': ['musim',
#   'panas',
#   'biasa',
#   'cerah',
#   'suhu',
#   'rata',
#   '16',
#   'c',
#   '27',
#   'c',
#   'dapat',
#   'naik',
#   'setinggi',
#   '38',
#   'c',
#   'lama',
#   'gelombang',
#   'panas',
#   'sekal'],
#  '1047484': ['lama',
#   'pimpin',
#   'indonesia',
#   'menang',
#   'medali',
#   'emas',
#   'juara',
#   'dunia',
#   'guangzhou',
#   'cina',
#   'tahun',
#   '2013',
#   '2',
#   'gelar',
#   'all',
#   'england',
#   'tiap',
#   'tahun',
#   '2013',
#   '2014',
#   'juara',
#   'umum',
#   'southeast',
#   'asi',
#   'games',
#   '2013',
#   '2015',
#   '2',
#   'gelar',
#   'juara',
#   '2014',
#   'asi',
#   'games',
#   'incheon',
#   'korea',
#   'selatan',
#   '1',
#   'gelar',
#   'juara',
#   'olimpiade',
#   'musim',
#   'panas',
#   '2016',
#   'rio',
#   'de',
#   'janeiro',
#   'brasil'],
#  '1047728': ['rooney',
#   'masuk',
#   'skuad',
#   'tim',
#   'pertama',
#   'everton',
#   'kamp',
#   'latih',
#   'di',
#   'austria',
#   'musim',
#   'panas',
#   '2002',
#   'cetak',
#   'gol',
#   'pertama',
#   'tim',
#   'senior',
#   'menang',
#   '31',
#   'atas',
#   'sc',
#   'weiz',
#   'tanggal',
#   '15',
#   'juli'],
#  '1048343': ['musim',
#   'panas',
#   '1877',
#   'hidup',
#   'ganggu',
#   'adelaide',
#   'nansen',
#   'wafat',
#   'dadak'],
#  '1048400': ['seluruh',
#   'provinsi',
#   'iklim',
#   'benua',
#   'matahari',
#   'terik',
#   'kering',
#   'musim',
#   'panas',
#   'hangat',
#   'musim',
#   'dingin',
#   'relatif',
#   'dingin'],
#  '1048745': ['cokelat',
#   'panas',
#   'milik',
#   'banyak',
#   'kalori',
#   'lemak',
#   'jenuh',
#   'gula'],
#  '1048908': ['samping',
#   'ada',
#   'dudukuy',
#   'tutup',
#   'kepala',
#   'buat',
#   'tumbuh',
#   'bambu',
#   'kayu',
#   'daun',
#   'hanya',
#   'fungsi',
#   'bagai',
#   'lindung',
#   'kepala',
#   'panas',
#   'hujan'],
#  '1049083': ['buah',
#   'awan',
#   'hitam',
#   'besar',
#   'bentuk',
#   'udara',
#   'panas',
#   'atas',
#   'kobar',
#   'api'],
#  '1049120': ['versi',
#   'asli',
#   'i',
#   'am',
#   'a',
#   'rock',
#   'pertama',
#   'kali',
#   'rilis',
#   'the',
#   'paul',
#   'simon',
#   'songbook',
#   'pada',
#   'musim',
#   'panas',
#   '1965',
#   'rilis',
#   'bagai',
#   'singel',
#   'satu',
#   'album'],
#  '1049519': ['unsur',
#   'subyektif',
#   'bantu',
#   'jelas',
#   'beda',
#   'antara',
#   'bagai',
#   'kodeks',
#   'masoret',
#   'jumlah',
#   'detail',
#   'ke',
#   'bagi',
#   'kecil',
#   'meski',
#   'derajat',
#   'konformitas',
#   'tinggi'],
#  '1049578': ['perhati', 'hasil', 'bilang', 'deret', 'fibonacci', 'bawah'],
#  '1050134': ['tionghoa',
#   'kamboja',
#   'milik',
#   'pengaruh',
#   'ekonomi',
#   'kamboja',
#   'kira',
#   'milik',
#   'besar'],
#  '1050284': ['belanda',
#   'mulai',
#   'restrukturisasi',
#   'administratif',
#   'belu',
#   '191516',
#   'coba',
#   'guna',
#   'kuasa',
#   'tradisional',
#   'bagai',
#   'zelfbestuurders',
#   'raja',
#   'bawah',
#   'awas',
#   'kolonial'],
#  '1050347': ['daftar',
#   'uskup',
#   'kamboja',
#   'buah',
#   'daftar',
#   'muat',
#   'jabar',
#   'hadap',
#   'wilayah',
#   'administratif',
#   'gereja',
#   'katolik',
#   'roma',
#   'pimpin',
#   'orang',
#   'uskup',
#   'ordinaris',
#   'kamboja'],
#  '1050595': ['jadi',
#   'tanah',
#   'tuan',
#   'tanah',
#   'lah',
#   'harus',
#   'kepada',
#   'klen',
#   'marga',
#   'telah'],
#  '1050933': ['lihat',
#   'sudut',
#   'isi',
#   'pupuh',
#   'sudah',
#   'laku',
#   'sangat',
#   'rapi'],
#  '1051353': ['kampung',
#   'bagi',
#   'wilayah',
#   'administratif',
#   'guna',
#   'jumlah',
#   'kabupaten',
#   'provinsi',
#   'lampung',
#   'indonesia',
#   'bawah',
#   'camat'],
#  '1051461': ['banyak',
#   'pengawahutanan',
#   'masa',
#   'kini',
#   'jadi',
#   'seleweng',
#   'kuasa',
#   'perintah',
#   'political',
#   'corruption',
#   'kalang',
#   'lembaga',
#   'perintah',
#   'ketidakadilan',
#   'bagi',
#   'kaya',
#   'wealth',
#   'kuasa',
#   'tumbuh',
#   'duduk',
#   'ledak',
#   'duduk',
#   'overpopulation',
#   'maupun',
#   'kota',
#   'urbanization'],
#  '1051536': ['bagi',
#   'ayat',
#   'bahasa',
#   'indonesia',
#   'ayat',
#   '18',
#   'akhir',
#   'kata',
#   'yunani',
#   'apestalken',
#   'me',
#   'utus',
#   'aku',
#   'tanda',
#   'sisa',
#   'tempat',
#   'ayat',
#   '19'],
#  '1051537': ['ayat',
#   'bahasa',
#   'indonesia',
#   'ayat',
#   '19',
#   'dapat',
#   'bagi',
#   'teks',
#   'textus',
#   'receptus',
#   'tempat',
#   'ayat',
#   '18',
#   'ayat',
#   '19',
#   'pada',
#   'textus',
#   'receptus',
#   'isi',
#   'frasa',
#   'berita',
#   'tahun',
#   'rahmat',
#   'tuhan'],
#  '1051687': ['mohon',
#   'sebut',
#   'terima',
#   'ditindaklanjuti',
#   'rapat',
#   'lembaga',
#   'badan',
#   'musyawarah',
#   'desa',
#   'bamudes',
#   'hasil',
#   'mufakat',
#   'tanah',
#   'luas',
#   '800',
#   'm2',
#   'masih',
#   'upa',
#   'sawah',
#   'bias',
#   'tempat',
#   'olah',
#   'madrasah',
#   'ibtidaiyah',
#   'muhammadiyah',
#   'grogol',
#   'i',
#   'status',
#   'bagai',
#   'hak',
#   'pakai',
#   'bangun'],
#  '1051903': ['pilih',
#   'dekan',
#   'biasa',
#   'laku',
#   'rapat',
#   'senat',
#   'fakultas',
#   'dalam',
#   'tiap',
#   'universitas',
#   'beda',
#   'anggota',
#   'gantung',
#   'statuta',
#   'anggar',
#   'rumah',
#   'tangga',
#   'masingmasing'],
#  '1052696': ['21',
#   'mei',
#   '1925',
#   'usai',
#   'ikut',
#   'rapat',
#   'kampus',
#   'profesor',
#   'ueno',
#   'dadak',
#   'tinggal',
#   'dunia'],
#  '1052906': ['akhir',
#   'september',
#   '2010',
#   'bicara',
#   'rapat',
#   'umum',
#   'servicemembers',
#   'legal',
#   'defense',
#   'network',
#   '4the14k',
#   'deering',
#   'oaks',
#   'park',
#   'portland',
#   'maine'],
#  '1052988': ['brokoli',
#   'makan',
#   'kepala',
#   'bunga',
#   'warna',
#   'hijau',
#   'susun',
#   'rapat',
#   'cabang',
#   'pohon',
#   'batang',
#   'tebal'],
#  '1053040': ['gap',
#   'diri',
#   'tanggal',
#   '21',
#   'mei',
#   '1939',
#   'dalam',
#   'rapat',
#   'diri',
#   'organisasi',
#   'nasional',
#   'jakarta'],
#  '1053590': ['juga',
#   'usaha',
#   'terna',
#   'sapi',
#   'sapi',
#   'jadi',
#   'daging',
#   'sapi',
#   'potong',
#   'kebun',
#   'tebu',
#   'hasil',
#   'olah',
#   'jadi',
#   'gula',
#   'kebun',
#   'karet',
#   'lateks',
#   'jadi',
#   'kondom',
#   'sarung',
#   'tangan'],
#  '1053645': ['bulu',
#   'kucing',
#   'untuk',
#   'buat',
#   'jadi',
#   'mantel',
#   'sarung',
#   'tangan',
#   'topi',
#   'sepatu',
#   'selimut',
#   'boneka',
#   'main'],
#  '1053650': ['harga',
#   'sarung',
#   'tenun',
#   'pagatan',
#   'gantung',
#   'jenis',
#   'motif',
#   'makin',
#   'bagus',
#   'bahan',
#   'motif',
#   'makin',
#   'mahal',
#   'harga'],
#  '1053692': ['produksi', 'sarung', 'goyor', 'pusat', 'dukuh', 'wonosari'],
#  '1053724': ['lempar',
#   'fielder',
#   'pakai',
#   'seragam',
#   'biasa',
#   'dua',
#   'pukul',
#   'wicketkeeper',
#   'pakai',
#   'tambah',
#   'aksesoris',
#   'lindung',
#   'cakup',
#   'helm',
#   'sarung',
#   'tangan',
#   'bantal',
#   'kaki'],
#  '1053751': ['kulit',
#   'susut',
#   'jauh',
#   'bila',
#   'kena',
#   'api',
#   'di',
#   'sarung',
#   'tangan',
#   'balap',
#   'biasa',
#   'batas',
#   'daerah',
#   'sentuh',
#   'tangan'],
#  '1053773': ['antartindak',
#   'pilotdantampilan',
#   'manfaat',
#   'sentuh',
#   'hal',
#   'pilot',
#   'sarung',
#   'tangan',
#   'kulit',
#   'lap',
#   'sutera'],
#  '1053896': ['akhir',
#   'proses',
#   'audisi',
#   'kerja',
#   'buah',
#   'usaha',
#   'distribusi',
#   'kain',
#   'sarung',
#   'juga',
#   'jual',
#   'ayam',
#   'goreng',
#   'depan',
#   'tmp',
#   'kalibata',
#   'jakarta'],
#  '1053983': ['siapa',
#   'kerja',
#   'logam',
#   'harus',
#   'pakai',
#   'sepatu',
#   'yang',
#   'tidak',
#   'picu',
#   'percik',
#   'pakai',
#   'karet',
#   'tahan',
#   'api',
#   'sarung',
#   'tangan',
#   'karet',
#   'celemek',
#   'kaca',
#   'mata',
#   'lindung',
#   'masker',
#   'gas'],
#  '1054067': ['babs',
#   'kelinci',
#   'betina',
#   'muda',
#   'warna',
#   'pinkputih',
#   'kena',
#   'blus',
#   'kuning',
#   'rok',
#   'ungu',
#   'pita',
#   'warna',
#   'ungu',
#   'terkadang',
#   'biru',
#   'dua',
#   'ujung',
#   'telinga',
#   'terkadang',
#   'pakai',
#   'sarung',
#   'tangan',
#   'putih'],
#  '1054245': ['churchill',
#   'konservatif',
#   'percaya',
#   'posisi',
#   'inggris',
#   'bagai',
#   'kuat',
#   'dunia',
#   'gantung',
#   'langsung',
#   'imperium',
#   'hal',
#   'tentu',
#   'terus',
#   'suez',
#   'mungkin',
#   'inggris',
#   'tahan',
#   'posisi',
#   'unggul',
#   'timur',
#   'tengah',
#   'meski',
#   'hilang',
#   'india'],
#  '1054261': ['itu',
#   'ahmad',
#   'husein',
#   'bagai',
#   'ketua',
#   'dewan',
#   'banteng',
#   'ambil',
#   'alih',
#   'jabat',
#   'gubernur',
#   'sumatera',
#   'tengah',
#   'tangan',
#   'gubernur',
#   'ruslan',
#   'mulyoharjo'],
#  '1054796': ['ecek',
#   'datar',
#   'dapat',
#   'perhati',
#   'gelembung',
#   'cair',
#   'alat',
#   'ukur',
#   'ada',
#   'tengah',
#   'alat',
#   'waterpass'],
#  '1056957': ['burung',
#   'adalah',
#   'burung',
#   'tetap',
#   'australia',
#   'beberapa',
#   'pulau',
#   'kecil',
#   'indonesia',
#   'tengah',
#   'timur'],
#  '1058083': ['pscs',
#   'cilacap',
#   'musim',
#   '2015',
#   'ia',
#   'reuni',
#   'rekan',
#   'rekan',
#   'bela',
#   'tim',
#   'sepak',
#   'bola',
#   'jawa',
#   'tengah',
#   'ajang',
#   'pon',
#   'xviii',
#   'hari',
#   'nur',
#   'yulianto',
#   'fauzan',
#   'fajri',
#   'rizky',
#   'ozil',
#   'yulian'],
#  '105849': ['peristiwa',
#   'seattle',
#   '1999',
#   'rupa',
#   'ulang',
#   'revolusi',
#   'buruh',
#   'seattle',
#   'tahun',
#   '1919',
#   'jadi',
#   'awal',
#   'dunia',
#   'mulai',
#   'buka',
#   'mata',
#   'hadap',
#   'gera',
#   'sosial',
#   'baru',
#   'tolak',
#   'kapitalisme',
#   'barbar'],
#  '1060825': ['lama',
#   'puncak',
#   'khalifah',
#   'abbasiyah',
#   'delap',
#   'abad',
#   'sembilan',
#   'asia',
#   'tengah',
#   'mawannahr',
#   'alami',
#   'zaman',
#   'emas',
#   'benar'],
#  '1061295': ['curah',
#   'hujan',
#   'tahun',
#   'tinggi',
#   'kikis',
#   'lembah',
#   'dalam',
#   'tengah',
#   'gunung',
#   'ukir',
#   'jurang',
#   'air',
#   'terjun',
#   'indah'],
#  '1063116': ['mayorian',
#   'aegidius',
#   'temu',
#   'posisi',
#   'romawi',
#   'bagi',
#   'besar',
#   'masuk',
#   'wilayah',
#   'gaul',
#   'dengan',
#   'tinggal',
#   'mayor',
#   'major',
#   'tahun',
#   '461',
#   'posisi',
#   'romawi',
#   'tengah',
#   'selatan',
#   'mulai',
#   'buruk'],
#  '1065308': ['lambang',
#   'kota',
#   'jambi',
#   'bentuk',
#   'perisai',
#   'runcing',
#   'bawah',
#   'keliling',
#   'tiga',
#   'garis',
#   'warna',
#   'bagi',
#   'luar',
#   'putih',
#   'tengah',
#   'warna',
#   'hijau',
#   'bagi',
#   'luar',
#   'warna',
#   'putih'],
#  '1065574': ['cara',
#   'geografis',
#   'desa',
#   'pugeran',
#   'sangat',
#   'strategis',
#   'ingat',
#   'letak',
#   'simpang',
#   'jalan',
#   'provinsi',
#   'kabupaten',
#   'dekat',
#   'wisata',
#   'pacet',
#   'tengah',
#   'kembang',
#   'punya',
#   'potensi',
#   'tani',
#   'cukup',
#   'produktif'],
#  '1069541': ['mukim',
#   'daerah',
#   'sekarang',
#   'jadi',
#   'wilayah',
#   'tenggara',
#   'iran',
#   'barat',
#   'pakistan',
#   'mana',
#   'ada',
#   'jalur',
#   'dagang',
#   'timur',
#   'tengah',
#   'lembah',
#   'sungai',
#   'indus'],
#  '1069945': ['urus',
#   'wilayah',
#   'ppp',
#   'protes',
#   'lantar',
#   'sikap',
#   'suryadharma',
#   'anggap',
#   'leceh',
#   'usaha',
#   'tengah',
#   'bangun',
#   'kader',
#   'akar',
#   'rumput',
#   'mana',
#   'para',
#   'kader',
#   'ppp',
#   'juang',
#   'menang',
#   'ppp',
#   'suryadharma',
#   'justru',
#   'belot',
#   'partai'],
#  '1073282': ['gabung',
#   'lembaga',
#   'didik',
#   'teliti',
#   'adalah',
#   'pertama',
#   'jerman',
#   'sekaligus',
#   'rencana',
#   'jadi',
#   'model',
#   'institusi',
#   'didik',
#   'tinggi',
#   'kait',
#   'erat',
#   'dunia',
#   'akademik',
#   'riset'],
#  '1079517': ['kata',
#   'ia',
#   'pernah',
#   'tinggi',
#   'cara',
#   'akademik',
#   'selalu',
#   'pada',
#   'peringkat',
#   'lima',
#   'bawah',
#   'kelas'],
#  '1081518': ['sebab',
#   'darat',
#   'tiongkok',
#   'belah',
#   'barat',
#   'lebih',
#   'tinggi',
#   'banding',
#   'timur',
#   'sungai',
#   'besar',
#   'alir',
#   'tenggara'],
#  '1085785': ['walaupun',
#   'kelly',
#   'bukan',
#   'orang',
#   'percaya',
#   'mistis',
#   'kelly',
#   'punya',
#   'tinggi',
#   '173',
#   'cm',
#   'tetap',
#   'karena',
#   'ingin',
#   'kecewa',
#   'orang',
#   'sekitar'],
#  '1095541': ['la',
#   'bangun',
#   'macam',
#   'biara',
#   'para',
#   'darwis',
#   'guru',
#   'tinggi',
#   'madzhab',
#   'syafi',
#   'i',
#   'hanafi',
#   'buah',
#   'pustaka',
#   'observatorium',
#   'gedung',
#   'umum'],
#  '1096922': ['tambah',
#   'tinggi',
#   'laku',
#   'konstruksi',
#   'bangun',
#   'utama',
#   'menara',
#   'hanya',
#   'pada',
#   'tiang',
#   'pancar',
#   'telekomunikasi'],
#  '1101784': ['biaya',
#   'lacur',
#   'variasi',
#   'sangat',
#   'jauh',
#   'lebih',
#   'tinggi',
#   'para',
#   'lacur',
#   'umum'],
#  '112778': ['konsep',
#   'cukup',
#   'baru',
#   'bingung',
#   'analis',
#   'dan',
#   'juga',
#   'bagai',
#   'salah',
#   'satu',
#   'diri',
#   'google',
#   'sergey',
#   'brin',
#   'pada',
#   'awal',
#   'sadar',
#   'data',
#   'laku',
#   'tinggal',
#   'komputer',
#   'pribadi',
#   'dapat',
#   'akses',
#   'semua',
#   'mesin',
#   'jalan',
#   'sistem',
#   'operasi'],
#  '11352': ['tahun',
#   '1880',
#   'procter',
#   'gamble',
#   'mulai',
#   'pasar',
#   'buah',
#   'produk',
#   'baru',
#   'upa',
#   'sabun',
#   'dapat',
#   'ambang',
#   'atas',
#   'air'],
#  '115739': ['wali',
#   'kota',
#   'petaling',
#   'jaya',
#   'dato',
#   'ahmad',
#   'termizi',
#   'puteh',
#   'kini',
#   'teraju',
#   'dewan',
#   'kota',
#   'petaling',
#   'jaya',
#   'mbpj',
#   'baru',
#   'diri'],
#  '128990': ['2003',
#   'hingga',
#   '2012',
#   'tipu',
#   '5',
#   'orang',
#   'rupa',
#   'gemar',
#   'berat',
#   'super1'],
#  '129049': ['beda', 'massa', 'berat', 'perlu', 'ukur', 'presisi', 'tinggi'],
#  '129521': ['akhir',
#   'tuju',
#   'berat',
#   'hati',
#   'frederick',
#   'ii',
#   'prusia',
#   'catherine',
#   'ii',
#   'rusia',
#   'tetap',
#   'laku',
#   'atau',
#   'tuju',
#   'austria'],
#  '135525': ['galai',
#   'sejati',
#   'perdana',
#   'triakonter',
#   'cara',
#   'harfiah',
#   'arti',
#   'dayung',
#   'tiga',
#   'puluh',
#   'pentekonter',
#   'dayung',
#   'lima',
#   'puluh',
#   'kembang',
#   'rancang',
#   'galai',
#   'perdana',
#   'dan',
#   'jadi',
#   'tolok',
#   'ukur',
#   'rancang',
#   'kapal',
#   'lebih',
#   'besar',
#   'kemudian',
#   'hari'],
#  '144272': ['jalan',
#   'ridwan',
#   'rais',
#   'arah',
#   'patung',
#   'pahlawan',
#   'depan',
#   'gedung',
#   'menteri',
#   'dagang',
#   'jakarta',
#   'pusat',
#   'pernah',
#   'jadi',
#   'tragedi',
#   'celaka',
#   'besar',
#   '22',
#   'januari',
#   '2012',
#   'pukul',
#   '11',
#   '12',
#   'siang',
#   'laku',
#   'orang',
#   'wanita',
#   'nama',
#   'afriyani',
#   'susanti'],
#  '1446': ['organisasi',
#   'bentuk',
#   'koordinasi',
#   'operasi',
#   'bantu',
#   'negara',
#   'asing',
#   'laku',
#   'semua',
#   'program',
#   'aman',
#   'nonmiliter',
#   'amerika',
#   'serikat'],
#  '145972': ['panjang',
#   'total',
#   'tubuh',
#   'capai',
#   '1',
#   '5',
#   'm',
#   'warna',
#   'dasar',
#   'tubuh',
#   'kuning',
#   'cokelat',
#   'kepala',
#   'bentuk',
#   'segitiga',
#   '3',
#   'buah',
#   'bintik',
#   'besar',
#   'warna',
#   'coklat',
#   'tua'],
#  '163828': ['identitas',
#   'kelompok',
#   'jadi',
#   'debat',
#   'turki',
#   'rasa',
#   'bagi',
#   'besar',
#   'orang',
#   'muslim',
#   'trakia',
#   'barat',
#   'orang',
#   'turki',
#   'yunani',
#   'nyata',
#   'dapat',
#   'orang',
#   'pomak',
#   'orang',
#   'lokal',
#   'yang',
#   'jadi',
#   'muslim',
#   'adopsi',
#   'identitas',
#   'bahasa',
#   'turki',
#   'masa',
#   'utsmaniyah'],
#  '167681': ['besar',
#   'muslim',
#   'turki',
#   'ikut',
#   'paham',
#   'sunni',
#   'bagi',
#   'kecil',
#   'dalah',
#   'kaum',
#   'syi',
#   'ah',
#   'diri',
#   'bagai',
#   'sekte',
#   'alevi',
#   'ja',
#   'fari',
#   'alawi'],
#  '169856': ['beda',
#   'kasus',
#   'bagi',
#   'besar',
#   'sisa',
#   'janji',
#   'lama',
#   'teks',
#   'mazmur',
#   'amiatinus',
#   'umum',
#   'anggap',
#   'saksi',
#   'inferior',
#   'karya',
#   'hieronimus',
#   'versio',
#   'juxta',
#   'hebraicum',
#   'hadir',
#   'rangkai',
#   'columba',
#   'judul',
#   'mazmur',
#   'temu',
#   'cathach',
#   'st',
#   'columba',
#   'tunjuk',
#   'mazmur',
#   'irlandia',
#   'rupa',
#   'sumber',
#   'teks',
#   'beda',
#   'banyak',
#   'tempat',
#   'naskah',
#   'irlandia',
#   'baik'],
#  '1710': ['film',
#   'pertama',
#   'annaud',
#   'black',
#   'and',
#   'white',
#   'in',
#   'color',
#   '1976',
#   'raih',
#   'buah',
#   'academy',
#   'award',
#   'film',
#   'bahasa',
#   'asing',
#   'baik'],
#  '175': ['perintah',
#   'nepal',
#   'nyata',
#   '2011',
#   'jadi',
#   'tahun',
#   'pariwisata',
#   'nepal',
#   'harap',
#   'tarik',
#   'satu',
#   'juta',
#   'wisatawan',
#   'asing',
#   'negara',
#   'lama',
#   'tahun'],
#  '196633': ['letak',
#   'provinsi',
#   'polandia',
#   'besar',
#   'sejak',
#   '1999',
#   'di',
#   'provinsi',
#   'leszno',
#   '19751998'],
#  '203576': ['lis',
#   'lanjut',
#   'studi',
#   'bidang',
#   'matematika',
#   'mit',
#   'kemudian',
#   'raih',
#   'gelar',
#   'master',
#   'tahun',
#   '1949',
#   'ph',
#   'd',
#   'tahun',
#   '1950'],
#  '204070': ['konflik',
#   'akibat',
#   'beda',
#   'penting',
#   'dapat',
#   'sangkut',
#   'bidang',
#   'politik',
#   'ekonomi',
#   'sosial',
#   'budaya'],
#  '204744': ['telah',
#   'keluar',
#   'atur',
#   'larang',
#   'pegawai',
#   'negeri',
#   'sipil',
#   'pns',
#   'politik',
#   'ibu',
#   'satu',
#   'anak',
#   'akhir',
#   'lepas',
#   'karier',
#   'bidang',
#   'akademik',
#   'kiprah',
#   'dunia',
#   'politik',
#   'detik'],
#  '204998': ['elis',
#   'lulus',
#   'sekolah',
#   'didik',
#   'guru',
#   'spg',
#   'kemudian',
#   'lanjut',
#   'studi',
#   'jurus',
#   'sastra',
#   'sunda',
#   'fakultas',
#   'sastra',
#   'unpad',
#   'lalu',
#   'jalur',
#   'terima',
#   'minat',
#   'mampu',
#   'pmdk',
#   'ambil',
#   'bidang',
#   'linguistik',
#   'hasil',
#   'lulus',
#   'predikat',
#   'cum',
#   'laude',
#   'tahun',
#   '1986',
#   'skripsi',
#   'judul',
#   'bahasa',
#   'sunda',
#   'dialek',
#   'kabupaten',
#   'tasikmalaya'],
#  '206667': ['ini',
#   'aktif',
#   'giat',
#   'masyarakat',
#   'kuliah',
#   'organisasi',
#   'agus',
#   'milik',
#   'usaha',
#   'mandiri',
#   'gerak',
#   'bidang',
#   'limbah',
#   'besi',
#   'tua',
#   'dia',
#   'rintis',
#   'sama',
#   'istri',
#   'sejak',
#   '2014',
#   'cv',
#   'karunia',
#   'baja'],
#  '206701': ['1981',
#   'mulai',
#   'ajar',
#   'hukum',
#   'vrije',
#   'universiteit',
#   'amsterdam',
#   'mana',
#   'dapat',
#   'gelar',
#   'll',
#   'm',
#   'nya',
#   'bidang',
#   'filsafat',
#   'hukum',
#   '1986'],
#  '206703': ['aplikasi',
#   'umum',
#   'sinyal',
#   'video',
#   'televisi',
#   'dia',
#   'juga',
#   'aplikasi',
#   'di',
#   'dalam',
#   'bidang',
#   'teknik',
#   'saintifik',
#   'produksi',
#   'aman'],
#  '209561': ['selesai',
#   'studi',
#   'bidang',
#   'fashion',
#   'editing',
#   'guru',
#   'tinggi',
#   'kerja',
#   'bagai',
#   'editor',
#   'stylist',
#   'majalah',
#   'popeye'],
#  '210269': ['topik',
#   'kisar',
#   'banyak',
#   'bidang',
#   'ahli',
#   'cermin',
#   'di',
#   'zaman',
#   'romawi',
#   'sama',
#   'saat',
#   'ilmu',
#   'konstruksi',
#   'cakup',
#   'bidang',
#   'agam'],
#  '210579': ['up',
#   'telah',
#   'hasil',
#   '15',
#   '000',
#   'dokter',
#   '15',
#   '000',
#   'insinyur',
#   '8',
#   '000',
#   'acara',
#   '23',
#   '000',
#   'guru',
#   'ribu',
#   'lulus',
#   'bidang',
#   'ilmu',
#   'jadi',
#   'seluruh',
#   'alumni',
#   'yang',
#   'masih',
#   'hidup',
#   'jumlah',
#   '260',
#   '000',
#   'orang',
#   'seluruh',
#   'dunia'],
#  '210913': ['harga',
#   'sebut',
#   'anggap',
#   'jadi',
#   'salah',
#   'satu',
#   'harga',
#   'arsitektur',
#   'utama',
#   'dunia',
#   'sering',
#   'sebut',
#   'bagai',
#   'harga',
#   'nobel',
#   'bidang',
#   'arsitektur'],
#  '211005': ['kompetensi',
#   'ajar',
#   'maksud',
#   'mampu',
#   'kuasa',
#   'materi',
#   'bidang',
#   'studi',
#   'madu',
#   'metodologi',
#   'ajar',
#   'tepat',
#   'baik',
#   'cara',
#   'teoretik',
#   'maupun',
#   'praktik',
#   'implementasi',
#   'proses',
#   'ajar'],
#  '212580': ['buah',
#   'wawancara',
#   'rekam',
#   'mati',
#   'bourdieu',
#   'tunjuk',
#   'beberapa',
#   'buku',
#   'masuk',
#   'bidang',
#   'politik',
#   'travail',
#   'et',
#   'travaileurs',
#   '1963',
#   'les',
#   'heeritiers',
#   '1964'],
#  '212807': ['mayoritas', 'duduk', 'gerak', 'bidang', 'tani'],
#  '213145': ['rombong',
#   'orang',
#   'champa',
#   'agama',
#   'budha',
#   'kenal',
#   'piawai',
#   'bidang',
#   'seni',
#   'masuk',
#   'batik',
#   'tari',
#   'buat',
#   'hias',
#   'emas',
#   'buat',
#   'alat',
#   'kuningan',
#   'lain',
#   'bagai'],
#  '214370': ['konsep',
#   'awal',
#   'kontrol',
#   'diri',
#   'mulai',
#   'bidang',
#   'ilmu',
#   'psikologi',
#   'sejak',
#   'tahun',
#   '1977',
#   'istilah',
#   'efikasi',
#   'diri'],
#  '215347': ['pakar',
#   'bidang',
#   'geologi',
#   'sangat',
#   'hormat',
#   'dunia',
#   'internasional'],
#  '215964': ['butuh',
#   'hadap',
#   'sarjana',
#   'bidang',
#   'gizi',
#   'baik',
#   'kualitas',
#   'prima',
#   'maupun',
#   'kuantitas',
#   'lihat',
#   'cenderung',
#   'tingkat',
#   'jumlah',
#   'minat',
#   'bidang',
#   'studi',
#   'gizi',
#   'fkm',
#   'ui',
#   'terus',
#   'tingkat',
#   'tahun',
#   'tahun',
#   'bahkan',
#   'jadi',
#   'hampir',
#   '100',
#   'tahun',
#   '2007',
#   'banding',
#   'tahun'],
#  '216082': ['semenjak',
#   'huruhara',
#   'jadi',
#   'bulan',
#   'mei',
#   '1998',
#   'pasu',
#   'anti',
#   'huruhara',
#   'phh',
#   'kini',
#   'terima',
#   'latih',
#   'anti',
#   'huruhara',
#   'khusus',
#   'terus',
#   'terus',
#   'laku',
#   'baharu',
#   'bidang',
#   'materi',
#   'laksana',
#   'pasu',
#   'huruhara',
#   'phh'],
#  '217146': ['dua',
#   'bidang',
#   'geografi',
#   'manusialingkungan',
#   'ekologi',
#   'budaya',
#   'politik',
#   'teliti',
#   'risikobencana'],
#  '217264': ['1993',
#   'selesai',
#   'didik',
#   'spesialisasi',
#   'bidang',
#   'administrasi',
#   'manajemen',
#   'universitas',
#   'harvard'],
#  '218': ['banyak',
#   'orang',
#   'asing',
#   'tarik',
#   'pusat',
#   'belanja',
#   'hidup',
#   'malam'],
#  '219154': ['american',
#   'idol',
#   'musim',
#   'sembilan',
#   'rupa',
#   'lanjut',
#   'tayang',
#   'reality',
#   'show',
#   'bidang',
#   'nyanyi',
#   'selenggara',
#   'fox',
#   'sembilan',
#   'kali',
#   'sejak',
#   '12',
#   'januari',
#   '2010',
#   'akhir',
#   '26',
#   'mei',
#   '2010'],
#  '220388': ['padang',
#   'ekspres',
#   'kembang',
#   'sangat',
#   'cepat',
#   'lain',
#   'dukung',
#   'tenaga',
#   'muda',
#   'terampil',
#   'bidang',
#   'jurnalistik',
#   'strata',
#   'didik',
#   'rendah',
#   'si'],
#  '221852': ['program',
#   'studi',
#   'utama',
#   'kembang',
#   'sekolah',
#   'tinggi',
#   'bidang',
#   'ilmu',
#   'ekonomi',
#   'jurus',
#   'manajemen',
#   'akuntansi',
#   'pada',
#   'tahap',
#   'beikutnya',
#   'adalah',
#   'jurus',
#   'ilmu',
#   'ekonomi',
#   'studi',
#   'bangun'],
#  '222385': ['malah',
#   'tak',
#   'pelit',
#   'ilmu',
#   'jadi',
#   'guru',
#   'beberapa',
#   'latih',
#   'kena',
#   'bidang',
#   'komunikasi'],
#  '222699': ['bidang',
#   'layar',
#   'radar',
#   'untuk',
#   'atur',
#   'jalur',
#   'jalan',
#   'kapal',
#   'tiap',
#   'kapal',
#   'jalan',
#   'lalu',
#   'lalang',
#   'jalur',
#   'masingmasing',
#   'tidak',
#   'saling',
#   'tabrak',
#   'sekalipun',
#   'cuaca',
#   'kurang',
#   'baik',
#   'misal',
#   'cuaca',
#   'kabut'],
#  '223698': ['m66',
#   'panjang',
#   'panjang',
#   '95',
#   'ribu',
#   'tahun',
#   'cahaya',
#   'jalur',
#   'debu',
#   'colok',
#   'gugus',
#   'bintang',
#   'terang',
#   'panjang',
#   'lengan',
#   'spiral'],
#  '224411': ['juara',
#   'satu',
#   'bintang',
#   'radio',
#   'televisi',
#   'raih',
#   'festival',
#   'tahun',
#   '1983'],
#  '226018': ['daun',
#   'muda',
#   'ranting',
#   'karang',
#   'bunga',
#   'hias',
#   'rambut',
#   'bintang',
#   'rapat',
#   'pendek',
#   'warna',
#   'perak',
#   'mentega',
#   'olah',
#   'tabur',
#   'tepung'],
#  '226317': ['tahun',
#   '2011',
#   'majalah',
#   'complex',
#   'tempat',
#   'peringkat',
#   '94',
#   'daftar',
#   '100',
#   'bintang',
#   'porno',
#   'top',
#   'laris',
#   'ini'],
#  '226834': ['beberapa',
#   'bintang',
#   'main',
#   'film',
#   'antara',
#   'warner',
#   'baxter',
#   'billie',
#   'dove',
#   'douglas',
#   'fairbanks',
#   'jr',
#   'film',
#   'ambil',
#   'latar',
#   'belakang',
#   'death',
#   'valley',
#   'national',
#   'park',
#   'kota',
#   'hantu',
#   'rhyolite',
#   'nevada'],
#  '226922': ['beberapa',
#   'bintang',
#   'main',
#   'film',
#   'di',
#   'mildred',
#   'harris',
#   'clara',
#   'bow',
#   'charles',
#   'emmett',
#   'mack',
#   'tyrone',
#   'power',
#   'sr',
#   'film',
#   'rilis',
#   'tanggal',
#   '12',
#   'september',
#   '1923',
#   'sekarang',
#   'anggap',
#   'bagai',
#   'film',
#   'hilang'],
#  '227850': ['saat',
#   'sama',
#   'teliti',
#   'etnografi',
#   'pulau',
#   'caroline',
#   'mikronesia',
#   'ungkap',
#   'fakta',
#   'metode',
#   'navigasi',
#   'bintang',
#   'tradisional',
#   'sangat',
#   'banyak',
#   'hari',
#   'sana'],
#  '22934': ['adalah',
#   'asisten',
#   'centre',
#   'national',
#   'de',
#   'la',
#   'recherche',
#   'scientifique',
#   'datang',
#   'as',
#   'atas',
#   'beasiswa',
#   'rockefeller',
#   'mungkin',
#   'unjung',
#   'beberapa',
#   'guru',
#   'tinggi',
#   'sana',
#   'uppsala',
#   'oslo',
#   '19491950'],
#  '229367': ['claude',
#   'ptolemy',
#   'tempat',
#   'bintang',
#   'rasi',
#   'andromeda',
#   'di',
#   'almagest',
#   'pindah',
#   'rasi',
#   'perseus',
#   'johann',
#   'bayer',
#   'tetap',
#   'bagai',
#   'upsilon',
#   'persei',
#   'per'],
#  '229829': ['meski',
#   'tetap',
#   'bagai',
#   'alpha',
#   'magnitudo',
#   '4',
#   '32',
#   'bintang',
#   'lebih',
#   'redup',
#   'banding',
#   'beta',
#   'comae',
#   'berenices'],
#  '230194': ['omicron',
#   'geminorum',
#   'gem',
#   'geminorum',
#   'salah',
#   'satu',
#   'bintang',
#   'rasi',
#   'gemini'],
#  '230410': ['gamma',
#   'leonis',
#   'leo',
#   'leonis',
#   'bintang',
#   'ganda',
#   'rasi',
#   'leo'],
#  '230596': ['delta',
#   'librae',
#   'lib',
#   'librae',
#   'salah',
#   'satu',
#   'bintang',
#   'rasi',
#   'libra'],
#  '231189': ['lambang',
#   'turki',
#   'buah',
#   'oval',
#   'merah',
#   'kandung',
#   'buah',
#   'bulan',
#   'sabit',
#   'bintang',
#   'bendera',
#   'turki',
#   'keliling',
#   'nama',
#   'resmi',
#   'negara',
#   'dalam',
#   'bahasa',
#   'turki'],
#  '232228': ['origine',
#   'de',
#   'tous',
#   'les',
#   'cultes',
#   '1795',
#   'dupuis',
#   'identifikasi',
#   'ritus',
#   'prakristen',
#   'siria',
#   'raya',
#   'mesir',
#   'kuno',
#   'sia',
#   'bagai',
#   'wakil',
#   'lahir',
#   'dewa',
#   'orang',
#   'perawan',
#   'titik',
#   'balik',
#   'musim',
#   'dingin',
#   'argumen',
#   'ritus',
#   'sebut',
#   'dasar',
#   'naik',
#   'musim',
#   'dingin',
#   'rasi',
#   'bintang',
#   'virgo'],
#  '236872': ['teliti',
#   'tahun',
#   '2003',
#   'lapor',
#   'montmorilonit',
#   'cepat',
#   'konversi',
#   'asam',
#   'lemak',
#   'dalam',
#   'gelembung',
#   'bahwa',
#   'gelembung',
#   'bisa',
#   'bungkus',
#   'rna',
#   'lekat',
#   'tanah',
#   'liat'],
#  '237114': ['pramana',
#   'cerai',
#   'anita',
#   'bisa',
#   'rebut',
#   'pratiwi',
#   'arfian',
#   'mila',
#   'anita',
#   'tahu',
#   'niat',
#   'pramana'],
#  '240206': ['temu',
#   'unsur',
#   'nukleus',
#   'tangkap',
#   'elektron',
#   'orbit',
#   'dalam'],
#  '242752': ['maleficent',
#   'usaha',
#   'cabut',
#   'kutu',
#   'beri',
#   'tidak',
#   'karena',
#   'kata',
# ...
#   'daerah',
#   'air',
#   'terjun',
#   'grinjingan',
#   'dowo',
#   'dangat',
#   'asri',
#   'sejuk'],
#  '935688': ['pertama',
#   'bandara',
#   'baru',
#   'bangun',
#   'ramah',
#   'lingkung',
#   'mungkin',
#   'hasil',
#   'putus',
#   'bangun',
#   'buah',
#   'kereta',
#   'cepat',
#   'jalur',
#   'panjang',
#   'stasiun',
#   'pusat',
#   'oslo',
#   'tuju',
#   'bandara',
#   'hanya',
#   'membuthkan',
#   'waktu',
#   '19',
#   'menit'],
#  '936464': ['alkhansa',
#   'buah',
#   'lingkung',
#   'kota',
#   'suci',
#   'mek',
#   'provinsi',
#   'mek',
#   'tepat',
#   'belah',
#   'barat',
#   'arab',
#   'saudi'],
#  '936563': ['thaibah',
#   'buah',
#   'lingkung',
#   'kota',
#   'suci',
#   'madinah',
#   'provinsi',
#   'madinah',
#   'tepat',
#   'belah',
#   'barat',
#   'arab',
#   'saudi'],
#  '936842': ['awal',
#   'tahun',
#   '1980an',
#   'memang',
#   'banyak',
#   'lagu',
#   'tema',
#   'lingkung',
#   'muncul'],
#  '937415': ['rupa', 'mantan', 'menteri', 'lingkung', 'hidup', 'jerman'],
#  '939356': ['janji',
#   'sebut',
#   'raja',
#   'sultan',
#   'milik',
#   'status',
#   'negara',
#   'semi',
#   'merdeka',
#   'lingkung',
#   'raja',
#   'belanda'],
#  '939883': ['lingkung',
#   'bangun',
#   'tani',
#   'lbp',
#   'salah',
#   'satu',
#   'cabang',
#   'disiplin',
#   'ilmu',
#   'teknik',
#   'tani',
#   'fokus',
#   'kendali',
#   'lingkung',
#   'bangun',
#   'tani',
#   'tumbuh',
#   'produksi',
#   'tahan',
#   'mutu',
#   'hasil',
#   'tani'],
#  '940227': ['aseptic',
#   'canning',
#   'mana',
#   'bahan',
#   'kaleng',
#   'sterilisasi',
#   'cara',
#   'pisah',
#   'kemudian',
#   'proses',
#   'kaleng',
#   'laku',
#   'pada',
#   'kondisi',
#   'lingkung',
#   'steril'],
#  '941270': ['nadine',
#   'zamira',
#   'sjarief',
#   'orang',
#   'figur',
#   'publik',
#   'indonesia',
#   'laku',
#   'bisnis',
#   'lingkung',
#   'aktivis',
#   'lingkung',
#   'hidup'],
#  '941794': ['angkasa',
#   'pura',
#   'angkat',
#   'udara',
#   'palembang',
#   'sekitar',
#   'tahun',
#   '1980',
#   'tni',
#   'angkat',
#   'udara',
#   'aur',
#   'tanah',
#   'duduk',
#   'sma',
#   'negeri',
#   '13',
#   'palembang',
#   'sekarang',
#   'di',
#   'hibah',
#   'bangun',
#   'jadi',
#   'sekolah',
#   'penting',
#   'masyarakat',
#   'di',
#   'sekitar',
#   'lingkung',
#   'aur',
#   'telah',
#   'pada',
#   'tahun',
#   '1980',
#   'bangun',
#   'buah',
#   'sekolah',
#   'di',
#   'rama',
#   'smu',
#   'talang',
#   'kelapa'],
#  '942252': ['tuju',
#   'maju',
#   'kembang',
#   'sebar',
#   'luas',
#   'ilmu',
#   'tahu',
#   'teknologi',
#   'seni',
#   'ilmu',
#   'manusia',
#   'tingkat',
#   'sejahtera',
#   'duduk',
#   'sumatera',
#   'khusus',
#   'bangsa',
#   'indonesia',
#   'jalan',
#   'dinamika',
#   'masyarakat',
#   'indonesia',
#   'masyarakat',
#   'dunia',
#   'tetap',
#   'junjung',
#   'tinggi',
#   'nilai',
#   'sosial',
#   'manusia',
#   'lingkung',
#   'lalu',
#   'wahana',
#   'tridharma',
#   'guru',
#   'tinggi'],
#  '94537': ['prahara',
#   'ganti',
#   'personel',
#   'nyata',
#   'henti',
#   'situ',
#   'tiket',
#   'harus',
#   'hadap',
#   'nyata',
#   'pahit',
#   '2',
#   'orang',
#   'personel',
#   'baru',
#   'gabung',
#   'gatut',
#   'drum',
#   'joey',
#   'vokal',
#   'pilih',
#   'undur',
#   'diri'],
#  '948210': ['sumber',
#   'air',
#   'asal',
#   'mata',
#   'air',
#   'sekitar',
#   'masjid',
#   'oleh',
#   'masyarakat',
#   'sebut',
#   'bulaan'],
#  '948418': ['ompu',
#   'tuan',
#   'bur',
#   'punya',
#   '4',
#   'orang',
#   'putera',
#   'lango',
#   'raja',
#   'saing',
#   'raja',
#   'mata',
#   'raja',
#   'deak',
#   'raja',
#   'dua',
#   'puter',
#   'kawin',
#   'sihotang',
#   'marsoit',
#   'limbong',
#   'naopatpulu'],
#  '950467': ['13',
#   'september',
#   '2011',
#   'mata',
#   'buat',
#   'debut',
#   'liga',
#   'champions',
#   'uefa',
#   'chelsea',
#   'hadap',
#   'bayer',
#   'leverkusen'],
#  '951268': ['pound',
#   'sterling',
#   'cadang',
#   'mata',
#   'uang',
#   'besar',
#   'tiga',
#   'dunia',
#   'dolar',
#   'as',
#   'euro'],
#  '951413': ['meski',
#   'nikah',
#   'katherine',
#   'arthur',
#   'sempurna',
#   'katherine',
#   'sumpah',
#   'mati',
#   'ia',
#   'perawan',
#   'meni',
#   'henry',
#   'tafsir',
#   'henry',
#   'atas',
#   'alkitab',
#   'arti',
#   'nikah',
#   'adalah',
#   'dosa',
#   'mata',
#   'tuhan'],
#  '957825': ['acara',
#   '5',
#   'orang',
#   'kontestan',
#   'adu',
#   'strategi',
#   'tahu',
#   'meja',
#   'bentuk',
#   'segi',
#   'enam',
#   'heksagonal',
#   'jadi',
#   'kontestan',
#   'kuat',
#   'hak',
#   'bawa',
#   'pulang',
#   'hadiah',
#   'uang',
#   'tunai'],
#  '958240': ['penyiptaan',
#   'teleskop',
#   'optis',
#   'bawa',
#   'lompat',
#   'besar',
#   'kualitas',
#   'bulan'],
#  '960350': ['pada',
#   'film',
#   'evil',
#   'dead',
#   'ii',
#   'pergi',
#   'pacar',
#   'lagi',
#   'audio',
#   'tape',
#   'bunyi',
#   'ash',
#   'bawa',
#   'malapetaka'],
#  '961577': ['bawa', 'kaisar', 'xian', 'lari'],
#  '963387': ['total',
#   '11',
#   'kapal',
#   'transpor',
#   'ukur',
#   'besar',
#   'kerah',
#   'yamamoto',
#   'bawa',
#   'sisa',
#   '7',
#   '000',
#   'pasu',
#   'divisi',
#   'infanteri',
#   '38',
#   'amunisi',
#   'makan',
#   'alat',
#   'berat',
#   'rabaul',
#   'guadalkanal'],
#  '966840': ['air',
#   'raksa',
#   'seperti',
#   'air',
#   'kembang',
#   'beku',
#   'tidak',
#   'pecah',
#   'tabung',
#   'kaca',
#   'buat',
#   'sulit',
#   'ketika',
#   'beku'],
#  '967041': ['garner',
#   'buku',
#   'judul',
#   'frames',
#   'of',
#   'mind',
#   'teori',
#   'multiple',
#   'intelegences',
#   'tahun',
#   '1983',
#   'definisi',
#   'cerdas',
#   'bagai',
#   'mampu',
#   'pecah',
#   'suatu',
#   'masalah',
#   'suatu',
#   'cipta',
#   'suatu',
#   'produk',
#   'nila',
#   'suatu',
#   'budaya'],
#  '967178': ['rigen',
#   'prediksi',
#   'jadi',
#   'juara',
#   '3',
#   'mampu',
#   'tampil',
#   'lepas',
#   'maksimal',
#   'ia',
#   'nobat',
#   'jadi',
#   'juara',
#   'suci',
#   '5',
#   'buat',
#   'pecah',
#   'rekor',
#   'arie',
#   'abdur',
#   'bagai',
#   'wakil',
#   'indonesia',
#   'timur',
#   'pertama',
#   'hasil',
#   'juara',
#   'suci',
#   'kompas',
#   'tv'],
#  '967291': ['anak',
#   'selalu',
#   'pecah',
#   'masalah',
#   'orang',
#   'sekitar',
#   'solusi',
#   'out',
#   'of',
#   'the',
#   'box',
#   'aneh',
#   'orang',
#   'dewasa',
#   'tepat'],
#  '967555': ['sebelas',
#   'cerita',
#   'detektif',
#   'eksentrik',
#   'kenal',
#   'hercule',
#   'poirot',
#   'pecah',
#   'bagai',
#   'misteri',
#   'kait',
#   'tamak',
#   'iri',
#   'hati',
#   'balas',
#   'dendam'],
#  '967623': ['sabtu',
#   '17',
#   'november',
#   '2007',
#   'universitas',
#   'bob',
#   'jones',
#   'pecah',
#   'rekor',
#   'guinness',
#   'degan',
#   'jumlah',
#   'tidak',
#   'resmi',
#   '3',
#   '800',
#   'anggota'],
#  '967714': ['lima',
#   'belas',
#   'tahun',
#   'kemudian',
#   'kurang',
#   'lebih',
#   'tahun',
#   '1711',
#   'bupati',
#   'cianjur',
#   'aria',
#   'wira',
#   'tanu',
#   'kapal',
#   '4',
#   'kuintal',
#   'kopi',
#   'amsterdam',
#   'ekspor',
#   'kopi',
#   'perdana',
#   'sebut',
#   'pecah',
#   'rekor',
#   'harga',
#   'lelang',
#   'sana'],
#  '967780': ['logika',
#   'mulai',
#   'sejak',
#   'thales',
#   '624',
#   'sm',
#   '548',
#   'sm',
#   'filsuf',
#   'yunani',
#   'pertama',
#   'tinggal',
#   'segala',
#   'dongeng',
#   'takhayul',
#   'cerita',
#   'isap',
#   'jempol',
#   'paling',
#   'akal',
#   'budi',
#   'pecah',
#   'rahasia',
#   'alam',
#   'semesta'],
#  '967972': ['kemudian',
#   'pesawat',
#   'hasil',
#   'buat',
#   'fokker',
#   'f',
#   '18',
#   'kemudian',
#   'pecah',
#   'rekor',
#   'terbang',
#   'batavia',
#   'jakarta',
#   'sekarang',
#   'lalu',
#   'fokker',
#   'f',
#   '20',
#   'dapat',
#   'lipat',
#   'roda'],
#  '968056': ['final',
#   'nba',
#   'ray',
#   'allen',
#   'hasil',
#   'pecah',
#   'rekor',
#   'final',
#   'nba',
#   'buat',
#   'delapan',
#   'kali',
#   'tembak',
#   'tiga',
#   'angka',
#   'buat',
#   'saat',
#   'game',
#   '2'],
#  '968123': ['tahun',
#   '1991',
#   'assange',
#   'usia',
#   '20',
#   'tahun',
#   'beberapa',
#   'teman',
#   'profesi',
#   'bagai',
#   'hacker',
#   'acak',
#   'komputer',
#   'pecah',
#   'dan',
#   'pasuk',
#   'jaring',
#   'terminal',
#   'nortel',
#   'usaha',
#   'telekomunikasi',
#   'kanada'],
#  '968550': ['bagai',
#   'anak',
#   'kecil',
#   'sering',
#   'lihat',
#   'operasi',
#   'polisi',
#   'tangkap',
#   'orang',
#   'kulit',
#   'hitam',
#   'cara',
#   'ilegal',
#   'tinggal',
#   'area',
#   'sebut'],
#  '968555': ['ada',
#   'air',
#   'jernih',
#   'ular',
#   'garter',
#   'sierra',
#   'tangkap',
#   'mangsa',
#   'jauh',
#   'lebih',
#   'efektif',
#   'banding',
#   'strategi',
#   'ular',
#   'garter',
#   'yang',
#   'tangkap',
#   'mangsa',
#   'cara',
#   'acak'],
#  '968578': ['satu',
#   'versi',
#   'kata',
#   'kerja',
#   'bagai',
#   'suruh',
#   'buah',
#   'kantor',
#   'perintah',
#   'lokal',
#   'tugas',
#   'tangkap',
#   'jahat',
#   'tidak',
#   'pernah',
#   'luka',
#   'duduk',
#   'biasa'],
#  '968892': ['kepiting',
#   'famili',
#   'porcellanidae',
#   'milik',
#   'rambut',
#   'sekitar',
#   'mulut',
#   'bantu',
#   'tangkap',
#   'partikel',
#   'organik',
#   'air',
#   'yang',
#   'alir',
#   'lalu'],
#  '968988': ['tom',
#   'jarang',
#   'sekali',
#   'sukses',
#   'tangkap',
#   'jerry',
#   'utama',
#   'oleh',
#   'pandai',
#   'lincah',
#   'jerry',
#   'bodoh',
#   'tom',
#   'sendiri'],
#  '969102': ['30',
#   'polisi',
#   'mesir',
#   'tangkap',
#   '50',
#   'orang',
#   'mahasiswa',
#   'anggota',
#   'ikhwanul',
#   'muslimin',
#   'larang',
#   'perintah',
#   'mereka',
#   'sedang',
#   'libur',
#   'alexandria',
#   'pantai',
#   'utara',
#   'negara'],
#  '969114': ['jj',
#   'muncul',
#   'episode',
#   'lauren',
#   'musim',
#   'tujuh',
#   'mana',
#   'minta',
#   'untuk',
#   'bantu',
#   'bau',
#   'temu',
#   'emily',
#   'prentiss',
#   'tangkap',
#   'ian',
#   'doyle'],
#  '969437': ['kaisar', 'perintah', 'eksarka', 'ravenna', 'tangkap', 'paus'],
#  '970195': ['tahun',
#   '630',
#   'kaisar',
#   'taizong',
#   'kirim',
#   'jendral',
#   'li',
#   'jing',
#   'lawan',
#   'tujue',
#   'timur',
#   'tangkap',
#   'jiali',
#   'khan',
#   'hancur',
#   'perintah',
#   'tujue',
#   'timur'],
#  '970329': ['theodoros',
#   'bukti',
#   'kuasa',
#   'kuat',
#   'suka',
#   'perang',
#   'sangat',
#   'luas',
#   'negara',
#   'epirus',
#   'tangkap',
#   'tesalonika',
#   'tahun',
#   '1224',
#   'mana',
#   'mahkota',
#   'bagai',
#   'kaisar'],
#  '970655': ['hasil',
#   'kalah',
#   'pasu',
#   'kubarsi',
#   'tangkap',
#   'raja',
#   'maliyatkustur'],
#  '970694': ['meski',
#   'sangat',
#   'efektif',
#   'tangkap',
#   'andang',
#   'ekor',
#   'pok',
#   'mon',
#   'beberapa',
#   'pok',
#   'mon',
#   'tidak',
#   'suka',
#   'pok',
#   'ball'],
#  '970917': ['capai',
#   'lorong',
#   'bawah',
#   'tanah',
#   'sniper',
#   'wolf',
#   'sergap',
#   'mereka',
#   'luka',
#   'meryl',
#   'tangkap',
#   'snake'],
#  '971058': ['suatu',
#   'hari',
#   'tangkap',
#   'ekor',
#   'ikan',
#   'besar',
#   'sedang',
#   'hamil'],
#  '971061': ['itu',
#   'kamera',
#   'aman',
#   'tangkap',
#   'gambar',
#   'lincoln',
#   'di',
#   'rumah',
#   'sakit',
#   'segera',
#   'ia',
#   'jadi',
#   'buron'],
#  '971194': ['korawa', 'hasil', 'tangkap', 'samba', 'lalu', 'samba', 'penjara'],
#  '971488': ['tahun',
#   'ikut',
#   'matthias',
#   'tangkap',
#   'jajce',
#   'usir',
#   'bangsa',
#   'turki',
#   'serbia',
#   'utara',
#   'lembaga',
#   'banats',
#   'militer',
#   'baru',
#   'jajce',
#   'srebernik',
#   'keluar',
#   'wilayah',
#   'bosnia',
#   'asai'],
#  '971516': ['akhir',
#   'misteri',
#   'sebut',
#   'ungkap',
#   'tutur',
#   'harry',
#   'a',
#   'poeze',
#   'orang',
#   'sejarawan',
#   'belanda',
#   'sebut',
#   'yang',
#   'tangkap',
#   'tembak',
#   'mati',
#   'tan',
#   'malaka',
#   'tanggal',
#   '21',
#   'februari',
#   '1949',
#   'pasu',
#   'tni',
#   'bawah',
#   'pimpin',
#   'letda',
#   'soekotjo',
#   'batalyon',
#   'sikat',
#   'divisi',
#   'brawijaya'],
#  '971565': ['mogadorian',
#   'akhir',
#   'temu',
#   'john',
#   'manfaat',
#   'teori',
#   'konspirasi',
#   'tangkap',
#   'henri'],
#  '971717': ['legiun',
#   'hasil',
#   'tangkap',
#   'berontak',
#   'pisah',
#   'dari',
#   'tentara',
#   'utama',
#   'pasu',
#   'spartakus',
#   'gagal',
#   'bagai',
#   'kelompok',
#   'kecil',
#   'serang',
#   'legiun',
#   'dekat'],
#  '972013': ['perang',
#   'enam',
#   'hari',
#   'dorong',
#   'israel',
#   'tanggal',
#   '9',
#   'juni',
#   '1967',
#   'kuasa',
#   'suez'],
#  '972331': ['efek',
#   'dari',
#   'perang',
#   'korea',
#   'dorong',
#   'nato',
#   'kembang',
#   'struktur',
#   'militer'],
#  '972838': ['pimpin',
#   'sekolah',
#   'pkt',
#   'sejak',
#   'tahun',
#   '1993',
#   'hu',
#   'jintao',
#   'laku',
#   'ubah',
#   'dorong',
#   'diskusi',
#   'buka',
#   'bahas',
#   'masalah',
#   'reformasi'],
#  '973255': ['kabel',
#   'kena',
#   'alat',
#   'segera',
#   'picu',
#   'alat',
#   'ledak',
#   'kecil',
#   'dorong',
#   'pisau',
#   'potong',
#   'kabel'],
#  '973510': ['gelombang',
#   'timbul',
#   'cara',
#   'temporer',
#   'jadi',
#   'angin',
#   'tekan',
#   'air',
#   'jauh',
#   'darat',
#   'dorong',
#   'air',
#   'lebih',
#   'untuk',
#   'ganti'],
#  '973900': ['tuju',
#   'prosedur',
#   'adalah',
#   'biasa',
#   'serta',
#   'substansial',
#   'topik',
#   'debat',
#   'dorong',
#   'teliti',
#   'akademik',
#   'tulis',
#   'aktif',
#   'besar',
#   'siap',
#   'untuk',
#   'konferensi'],
#  '973962': ['bulan',
#   'maret',
#   '2016',
#   'pilih',
#   'super',
#   'tuesday',
#   'henti',
#   'kampanye',
#   'umum',
#   'ia',
#   'jadi',
#   'ketua',
#   'baru',
#   'my',
#   'faith',
#   'votes',
#   'buah',
#   'kelompok',
#   'dorong',
#   'orang',
#   'kristen',
#   'jalan',
#   'tugas',
#   'sipil',
#   'untuk',
#   'pilih'],
#  '974719': ['cara',
#   'historis',
#   'orang',
#   'tionghoa',
#   'beri',
#   'kontribusi',
#   'ekonomi',
#   'kota',
#   'sejak',
#   'migrasi',
#   'lama',
#   'periode',
#   'sultan',
#   'brunei',
#   'temu',
#   'bijih',
#   'antimon',
#   'juga',
#   'lama',
#   'perintah',
#   'charles',
#   'vyner',
#   'brooke',
#   'dorong',
#   'migrasi',
#   'orang',
#   'tionghoa',
#   'luar',
#   'negara',
#   'tanam',
#   'lada',
#   'hitam',
#   'serawak'],
#  '974811': ['rafi',
#   'lelaki',
#   'agak',
#   'nakal',
#   'suka',
#   'ganti',
#   'pacar',
#   'dorong',
#   'bagas',
#   'ungkap',
#   'cinta',
#   'alex',
#   'panggil',
#   'alexandria'],
#  '975672': ['okar',
#   'tegas',
#   'evolusi',
#   'tolak',
#   'tuhan',
#   'hilang',
#   'nilai',
#   'moral',
#   'dorong',
#   'material',
#   'komunisme'],
#  '975957': ['moody',
#   'jadi',
#   'dekat',
#   'brookes',
#   'kaum',
#   'dispensasionalis',
#   'dan',
#   'dorong',
#   'sebar',
#   'dispensasionalisme',
#   'tampak',
#   'tidak',
#   'pernah',
#   'ajar',
#   'nuansa',
#   'sistem',
#   'dispensasionalis'],
#  '978415': ['9',
#   'hingga',
#   'tengah',
#   'hari',
#   'punya',
#   'orang',
#   'sekretaris',
#   'studio',
#   'terima',
#   'semua',
#   'panggil',
#   'telepon'],
#  '98136': ['prestasi',
#   'jadi',
#   'winds',
#   'bagai',
#   'terima',
#   'harga',
#   'rekam',
#   'jepang',
#   'artis',
#   'datang',
#   'baru',
#   'baik',
#   'tahun',
#   '2002'],
#  '981819': ['gugur',
#   'duryodana',
#   'mahabharata',
#   'kresna',
#   'terima',
#   'kutu',
#   'ibu',
#   'duryodana',
#   'gandar'],
#  '98383': ['hidang',
#   'istimewa',
#   'pesta',
#   'malam',
#   'tahun',
#   'baru',
#   'sampanye',
#   'foie',
#   'gras'],
#  '989281': ['suruci',
#   'larang',
#   'utama',
#   'akan',
#   'nobat',
#   'bagai',
#   'raja',
#   'druwa',
#   'kurang',
#   'sayang',
#   'tak',
#   'pantas',
#   'terima',
#   'kasih',
#   'sayang',
#   'bagaimana',
#   'terima',
#   'utama'],
#  '994570': ['kandung',
#   'paba',
#   'aminobenzoic',
#   'acid',
#   'asam',
#   'ferulat',
#   'allantoin',
#   'beras',
#   'biasa',
#   'guna',
#   'bega',
#   'mutih',
#   'cerah',
#   'kulit'],
#  '994574': ['kopi',
#   'robusta',
#   'kata',
#   'bagai',
#   'kopi',
#   'kelas',
#   '2',
#   'rasa',
#   'lebih',
#   'pahit',
#   'sedikit',
#   'asam',
#   'kandung',
#   'kafeina',
#   'kadar',
#   'jauh',
#   'lebih',
#   'banyak'],
#  '995972': ['karena',
#   'perak',
#   'mudah',
#   'serap',
#   'neutron',
#   'bebas',
#   'banyak',
#   'buat',
#   'batang',
#   'kendali',
#   'untuk',
#   'atur',
#   'reaksi',
#   'fisi',
#   'nuklir',
#   'reaktor',
#   'nuklir',
#   'air',
#   'tekan',
#   'umum',
#   'bentuk',
#   'alloy',
#   'kandung',
#   '80',
#   'perak',
#   '15',
#   'indium',
#   '5',
#   'kadmium'],
#  '996060': ['banyak',
#   'senyawa',
#   'industri',
#   'penting',
#   'amonia',
#   'asam',
#   'nitrat',
#   'nitrat',
#   'organik',
#   'propelan',
#   'bahan',
#   'ledak',
#   'sianida',
#   'kandung',
#   'nitrogen'],
#  '996671': ['tanam',
#   'milik',
#   'buah',
#   'bentuk',
#   'kapsul',
#   'kandung',
#   '23',
#   'biji',
#   'kerut',
#   'bentuk',
#   'biji',
#   'tanam',
#   'adam',
#   'eva'],
#  '997586': ['luar',
#   'model',
#   'dasar',
#   'telur',
#   'goreng',
#   'antara',
#   'iris',
#   'roti',
#   'banyak',
#   'roti',
#   'lapis',
#   'biasa',
#   'kandung',
#   'variasi',
#   'cakup',
#   'telur',
#   'goreng',
#   'bacon',
#   'sosis',
#   'keju',
#   'potong',
#   'dingin',
#   'topping',
#   'untuk',
#   'hamburger'],
#  '998147': ['demikian',
#   'sejak',
#   '2000an',
#   'indonesia',
#   'kenal',
#   'pupuk',
#   'majemuk',
#   'telah',
#   'kandung',
#   'tiga',
#   'unsur',
#   'pokok',
#   'sebut'],
#  '999241': ['magma',
#   'teluk',
#   'kandung',
#   'gas',
#   'terus',
#   'larut',
#   'tekan',
#   'besar',
#   'oleh',
#   'magma',
#   'bawah'],
#  '999441': ['naratif',
#   'narrative',
#   'kandung',
#   'unsur',
#   'judul',
#   'title',
#   'orientasi',
#   'orientation',
#   'komplikasi',
#   'complication',
#   'resolusi',
#   'resolution'],
#  '999728': ['peribahasa',
#   'pepatah',
#   'ayat',
#   'kelompok',
#   'kata',
#   'punya',
#   'susun',
#   'tetap',
#   'kandung',
#   'atur',
#   'dasar',
#   'perilaku']}

# %%
file_path = "../data/training_set/double_annotator_disagree.csv"

double_annotator_disagree = preprocessing(file_path)

double_annotator_disagree
# Out:
# {'1001238': ['rencana',
#   'pulang',
#   'amerika',
#   'serikat',
#   'dalam',
#   'volume',
#   '42',
#   'temu',
#   'vermouth',
#   'lawan',
#   'conan',
#   'vermouth',
#   'janji',
#   'akan',
#   'kejar',
#   'sherry'],
#  '1001448': ['meski',
#   'mekanisme',
#   'mampu',
#   'picu',
#   'produksi',
#   'nasional',
#   'ketidakpuasan',
#   'tetap',
#   'muncul',
#   'film',
#   'buat',
#   'cara',
#   'hanya',
#   'kejar',
#   'wajib',
#   'jumlah',
#   'mutu',
#   'ragu'],
#  '1001820': ['bagai',
#   'ganti',
#   'kaum',
#   'melayu',
#   'lepas',
#   'tuan',
#   'melayu',
#   'warga',
#   'melayu',
#   'bantu',
#   'kejar',
#   'tinggal',
#   'ekonomi'],
#  '1001888': ['bulan',
#   'april',
#   '2014',
#   'deezer',
#   'umum',
#   'ceo',
#   'ini',
#   'dauchez',
#   'tinggal',
#   'usaha',
#   'bulan',
#   'september',
#   'kejar',
#   'peluang',
#   'profesional',
#   'baru'],
#  '1001962': ['toufik',
#   'boushaki',
#   'duduk',
#   'asli',
#   'aljazair',
#   'mana',
#   'kejar',
#   'studi',
#   'dasar',
#   'provinsi',
#   'boumerdes',
#   'gabung',
#   'pada',
#   'tahun',
#   '1994',
#   'kursus',
#   'teknologi'],
#  '1001987': ['marah',
#   'urak',
#   'ambil',
#   'unit',
#   'orchisnya',
#   'hancur',
#   'armada',
#   'cima',
#   'kejar',
#   'koloni',
#   'jatuh'],
#  '1002386': ['teror',
#   'terus',
#   'rebak',
#   'hati',
#   'tasya',
#   'lebih',
#   'hancur',
#   'karena',
#   'benar',
#   'sangat',
#   'cinta',
#   'arya',
#   'malah',
#   'arya',
#   'kejar',
#   'tracy'],
#  '1002645': ['desain', 'tani', 'fokus', 'kejar', 'swasembada', 'beras'],
#  '1002901': ['sisi',
#   'david',
#   'fauzy',
#   'baadillah',
#   'pernah',
#   'campak',
#   'nadia',
#   'terus',
#   'kejar',
#   'nadya',
#   'segala',
#   'cara'],
#  '1004734': ['ghaitsa', 'keluar', 'debut', 'singelnya', 'judul', 'matahari'],
#  '1008265': ['keluar',
#   'jadi',
#   'buah',
#   'antidot',
#   'dapat',
#   'lawan',
#   'racun',
#   'produksi',
#   'binatang',
#   'ular',
#   'laba',
#   'binatang',
#   'racun'],
#  '1008910': ['wakil',
#   'presiden',
#   'ri',
#   'jusuf',
#   'kalla',
#   'keluar',
#   'nyata',
#   'rupa',
#   'depan',
#   'amdal',
#   'sesuai',
#   'penting',
#   'masyarakat'],
#  '1009398': ['barrett',
#   'm99',
#   'barrett',
#   'model',
#   '99',
#   'punya',
#   'juluk',
#   'big',
#   'shot',
#   'senapan',
#   'runduk',
#   'singleshot',
#   'amunisi',
#   'masuk',
#   'ruang',
#   'tembak',
#   'satu',
#   'satu',
#   'satu',
#   'tembak',
#   'selongsong',
#   'keluar',
#   'amunisi',
#   'baru',
#   'masuk',
#   'cara',
#   'manual',
#   'bolt',
#   'bullpup',
#   'amunisi',
#   '50',
#   'bmg',
#   '12',
#   '7',
#   'x',
#   '99',
#   'mm',
#   '416',
#   'barrett',
#   'buat',
#   'barrett',
#   'firearms',
#   'company',
#   'senapan',
#   'rancang',
#   'barret',
#   'keluar',
#   'purwarupa',
#   'm98'],
#  '1009449': ['tanggal',
#   '12',
#   'desember',
#   '1945',
#   'markas',
#   'tinggi',
#   'tkr',
#   'keluar',
#   'umum',
#   'nyata',
#   'bentuk',
#   'terbang',
#   'bagai',
#   'dari',
#   'markas',
#   'besar',
#   'umum'],
#  '1009766': ['portland',
#   'main',
#   'lawan',
#   'sporting',
#   'kansas',
#   'city',
#   'babak',
#   'playoff',
#   'mls',
#   'lanjut',
#   'adu',
#   'penalti',
#   'kevin',
#   'ellis',
#   'cetak',
#   'gol',
#   'ikat',
#   'akhir',
#   'menit',
#   'akhir',
#   'atur',
#   'akhir',
#   '1',
#   '1'],
#  '1009906': ['jarak',
#   'umur',
#   'cukup',
#   'jauh',
#   '13',
#   'tahun',
#   'rupa',
#   'halang',
#   'niat',
#   'gadis',
#   'darah',
#   'bugisminang',
#   'untuk',
#   'ikat',
#   'janji',
#   'suci'],
#  '1010242': ['ternate',
#   'ikat',
#   'portugis',
#   'prospek',
#   'untung',
#   'dagang',
#   'cengkih',
#   'pihak',
#   'ternate',
#   'butuh',
#   'kuat',
#   'koalisi',
#   'kuat',
#   'kuasa',
#   'lebih',
#   'tidore',
#   'jailolo',
#   'bacan'],
#  '1010430': ['antihistaminh',
#   'kerja',
#   'ikat',
#   'reseptor',
#   'histamin',
#   'h',
#   'sel',
#   'mast',
#   'otot',
#   'polos',
#   'endotelium',
#   'dalam',
#   'tubuh',
#   'inti',
#   'tuberomammillar',
#   'otak',
#   'antihistaminh',
#   'ikat',
#   'reseptor',
#   'histamin',
#   'h',
#   'salur',
#   'cerna',
#   'atas',
#   'utama',
#   'di',
#   'lambung'],
#  '1010693': ['sandhy',
#   'dapat',
#   '119',
#   'poin',
#   'para',
#   'hakim',
#   'masih',
#   'tempat',
#   'pertama',
#   '238',
#   'poin',
#   'ikat',
#   'jamala',
#   'dapat',
#   'nilai',
#   'sempurna',
#   'hari',
#   'kompetisi'],
#  '1010738': ['alfalfa',
#   'guna',
#   'sistem',
#   'rotasi',
#   'tanam',
#   'pangan',
#   'dapat',
#   'ikat',
#   'nitrogen',
#   'baik',
#   'struktur',
#   'tanah',
#   'kontrol',
#   'gulma',
#   'tanam',
#   'ikut',
#   'akan',
#   'dibudidayakan'],
#  '1010761': ['dila',
#   'dekat',
#   'raja',
#   'kota',
#   'kepala',
#   'daerah',
#   'wali',
#   'kota',
#   'orang',
#   'filistin',
#   'kata',
#   'perempuan',
#   'coba',
#   'bujuk',
#   'untuk',
#   'tahu',
#   'kuat',
#   'besar',
#   'dengan',
#   'apakah',
#   'kami',
#   'kalah',
#   'dan',
#   'ikat',
#   'untuk',
#   'tunduk'],
#  '1010992': ['kosong',
#   'kuasa',
#   'negara',
#   'adikukasa',
#   'bukan',
#   'arti',
#   'mudah',
#   'bangsa',
#   'israel',
#   'hidup',
#   'tenang',
#   'raja',
#   'kecil',
#   'kelompok',
#   'suku',
#   'bangsa',
#   'kuat',
#   'muncul',
#   'isi',
#   'vakum',
#   'sebut'],
#  '1011016': ['usia',
#   '14',
#   'tahun',
#   'percaya',
#   'isi',
#   'sesi',
#   'jam',
#   'session',
#   'booth',
#   'rolling',
#   'stone',
#   'acara',
#   'soundrenaline',
#   '2008'],
#  '1011050': ['atur',
#   'baru',
#   'laku',
#   'konstantinus',
#   'orang',
#   'jadi',
#   'senator',
#   'baik',
#   'pilih',
#   'bagai',
#   'pretor',
#   'banyak',
#   'kasus',
#   'isi',
#   'salah',
#   'satu',
#   'fungsi',
#   'dalam',
#   'peringkat',
#   'senatorial',
#   'sejak',
#   'itu',
#   'pegang',
#   'kuasa',
#   'sungguh',
#   'status',
#   'sosial',
#   'lebur',
#   'sama',
#   'dalam',
#   'suatu',
#   'hierarki',
#   'imperial',
#   'gabung'],
#  '1011643': ['adalah',
#   'jalur',
#   'kelok',
#   'cukup',
#   'sulit',
#   'lalu',
#   'seri',
#   'ingin',
#   'tonton',
#   'luas',
#   'mungkin',
#   'meski',
#   'ada',
#   'gemar',
#   'luar',
#   'sana',
#   'sudah',
#   'senang',
#   'seri',
#   'bishonen',
#   'untuk',
#   'isi',
#   'kosong',
#   'tinggal',
#   'free'],
#  '1011756': ['telah',
#   'isi',
#   'banyak',
#   'giat',
#   'dakwah',
#   'arab',
#   'saudi',
#   'lain',
#   'ceramah',
#   'bagai',
#   'stasiun',
#   'televisi',
#   'lain',
#   'stasiun',
#   'tv',
#   'saudi',
#   'stasiun',
#   'tv',
#   'kuwait',
#   'stasiun',
#   'tv',
#   'alarabiya'],
#  '1011840': ['terkadang',
#   'kursi',
#   'isi',
#   'juri',
#   'isi',
#   'musim',
#   'beniqno',
#   'juga',
#   'juri',
#   'tamu',
#   'indonesia',
#   'dorce',
#   'gamalama',
#   'jaja',
#   'mihardja',
#   'erie',
#   'suzan',
#   'cici',
#   'paramida',
#   'iyeth',
#   'bustami',
#   'hingga',
#   'ratu',
#   'dangdut',
#   'elvy',
#   'sukaesih',
#   'konser',
#   'menang'],
#  '1012699': ['perintah',
#   'bujuk',
#   'tani',
#   'tuan',
#   'tanah',
#   'tengah',
#   'utara',
#   'rusia',
#   'isi',
#   'lahan',
#   'kosong',
#   'dengan',
#   'tanam',
#   'kentang'],
#  '1013085': ['lama',
#   'beberapa',
#   'tahun',
#   'lanjut',
#   'fukui',
#   'isi',
#   'main',
#   'bagai',
#   'peran',
#   'kecil',
#   'serial',
#   'tokusatsu',
#   'drama',
#   'film',
#   'bagai',
#   'asam',
#   'shinohara',
#   'garo',
#   'bagai',
#   'ran',
#   'uzaki',
#   'gekiyellow',
#   'serial',
#   'super',
#   'senta',
#   'juuken',
#   'senta',
#   'gekiranger'],
#  '1013479': ['isi', 'tiap', 'kulit', 'sesuai', 'baris', 'tabel'],
#  '1013613': ['turut',
#   'rencana',
#   'bintang',
#   'tamu',
#   'akan',
#   'isi',
#   'acara',
#   'afgan',
#   'wali',
#   'tra',
#   'sihombing',
#   'nidji',
#   'd',
#   'masiv',
#   'masih',
#   'banyak'],
#  '1013938': ['shogun',
#   'kadang',
#   'kala',
#   'tunjuk',
#   'orang',
#   'menteri',
#   'senior',
#   'isi',
#   'posisi',
#   'taira',
#   'tetua',
#   'nasehat'],
#  '1014207': ['orang',
#   'konsul',
#   'konsul',
#   'jenderal',
#   'pimpin',
#   'buah',
#   'konsulat',
#   'bahasa',
#   'inggris',
#   'consulate',
#   'wakil',
#   'resmi',
#   'buah',
#   'negara',
#   'tindak',
#   'bantu',
#   'lindung',
#   'warga',
#   'negara',
#   'menfasilitasi',
#   'hubung',
#   'dagang',
#   'sahabat',
#   'ini',
#   'beda',
#   'tugas',
#   'orang',
#   'konsul',
#   'orang',
#   'duta',
#   'besar',
#   'wakil',
#   'buah',
#   'negara',
#   'tugas',
#   'luar',
#   'wilayah',
#   'metropolitan',
#   'ibu',
#   'kota',
#   'buah',
#   'negara',
#   'luar',
#   'negeri',
#   'wajib',
#   'jaga',
#   'penting',
#   'negara',
#   'rakyat',
#   'ada',
#   'negara',
#   'luar',
#   'negeri',
#   'sebut'],
#  '1015833': ['istilah',
#   'latin',
#   'milites',
#   'guna',
#   'tentu',
#   'tentara',
#   'kemudian',
#   'sebut',
#   'kategori',
#   'ksatria',
#   'juang',
#   'mampu',
#   'jaga',
#   'kuda'],
#  '1016114': ['ini',
#   'buka',
#   'kasus',
#   'baru',
#   'sebut',
#   'bagai',
#   'amerika',
#   'serikat',
#   'versus',
#   'microsoft',
#   'tanya',
#   'microsoft',
#   'repot',
#   'jaga',
#   'dominasi',
#   'dalam',
#   'sistem',
#   'operasi',
#   'komputer',
#   'pribadi',
#   'kompetisi',
#   'para',
#   'saing',
#   'netscape',
#   'ibm',
#   'cara',
#   'tidak',
#   'jujur'],
#  '1017210': ['meski',
#   'spekulasi',
#   'media',
#   'konstan',
#   'jaga',
#   'hidup',
#   'pribadi',
#   'jaga',
#   'baik'],
#  '1017368': ['siapa',
#   'hemat',
#   'jaga',
#   'awqat',
#   'waktu',
#   'tidak',
#   'akan',
#   'selamat',
#   'berbagia',
#   'afat',
#   'malapetaka'],
#  '1019166': ['hasil',
#   'teliti',
#   'sebut',
#   'nyata',
#   'infus',
#   'daun',
#   'angsana',
#   '5',
#   'ml',
#   '10',
#   '20',
#   'io',
#   'cara',
#   'oral',
#   'turun',
#   'kadar',
#   'gula',
#   'darah',
#   'kelinci'],
#  '1019232': ['tiap',
#   'regu',
#   'polo',
#   'air',
#   'turun',
#   '6',
#   'main',
#   '1',
#   'jaga',
#   'gawang',
#   'total',
#   '7',
#   'orang',
#   'main',
#   'tiap',
#   'tanding',
#   '6',
#   'orang',
#   'cadang',
#   'harus',
#   'duduk',
#   'bang',
#   'cadang',
#   'dalam',
#   'lapang',
#   'tanding',
#   '1',
#   'orang',
#   'manager',
#   '1',
#   'orang',
#   'kepala',
#   'latih',
#   '1',
#   'orang',
#   'asisten',
#   'latih'],
#  '1019327': ['jurai', 'ratu', 'puncak', 'yang', 'turun', 'orang', 'abung'],
#  '1019525': ['desa',
#   'punya',
#   'jumlah',
#   'duduk',
#   'sangat',
#   'sedikit',
#   'punya',
#   'luas',
#   'wilayah',
#   'lumayan',
#   'luas',
#   'mata',
#   'cahari',
#   'duduk',
#   'tani',
#   '99',
#   'mayoritas',
#   'agama',
#   'islam',
#   'seringa',
#   'giat',
#   'agama',
#   'sufatnya',
#   'rutin',
#   'tiap',
#   'tahu',
#   'misal',
#   'ingat',
#   'maulid',
#   'nabi',
#   'bareng',
#   'khaul',
#   'wali',
#   'mbah',
#   'ahmad',
#   'mizan',
#   'rupa',
#   'leluhur',
#   'di',
#   'percaya',
#   'bagai',
#   'babat',
#   'desa',
#   'dan',
#   'merupan',
#   'sepuh',
#   'turun',
#   'silsilah',
#   'kerabat',
#   'di',
#   'desa',
#   'margotuhu',
#   'kidul'],
#  '1019572': ['korban',
#   'asal',
#   'bahasa',
#   'arab',
#   'juga',
#   'turun',
#   'kata',
#   'kurban'],
#  '1019636': ['usaha',
#   'sebut',
#   'kendali',
#   'tibsa',
#   'inversora',
#   's',
#   'a',
#   'turun',
#   'kendali',
#   'sueztractebel',
#   'oleh',
#   'techint'],
#  '1019800': ['povenmire',
#   'isi',
#   'suara',
#   'tambah',
#   'candace',
#   'adegan',
#   'mana',
#   'karakter',
#   'sebut',
#   'alami',
#   'buah',
#   'reaksi',
#   'alergi',
#   'bagai',
#   'kru',
#   'mampu',
#   'turun',
#   'suara',
#   'aktris',
#   'rutin',
#   'ashley',
#   'tisdale',
#   'sekadar'],
#  '1020484': ['suku',
#   'banjar',
#   'milik',
#   'genetik',
#   'melayu',
#   'dominan',
#   'telah',
#   'laku',
#   'migrasi',
#   'keluar',
#   'pulau',
#   'kalimantan',
#   'tahun',
#   '830',
#   'masehi',
#   '1',
#   '200',
#   'tahun',
#   'lalu',
#   'tuju',
#   'madagasikara',
#   'alias',
#   'madagaskar',
#   'turun',
#   'bangsa',
#   'malagasi'],
#  '1020559': ['acara',
#   'a',
#   'm',
#   'chicago',
#   'udara',
#   'waktu',
#   'sama',
#   'acara',
#   'phill',
#   'donahue',
#   'show',
#   'populer',
#   'tidak',
#   'butuh',
#   'waktu',
#   'lama',
#   'oprah',
#   'turun',
#   'phill',
#   'takhta'],
#  '1021072': ['gagas',
#   'sel',
#   'epitelial',
#   'turun',
#   'sifat',
#   'epitelial',
#   'dapat',
#   'sifat',
#   'mesenkimal',
#   'muncul',
#   'awal',
#   'tahun',
#   '1980',
#   'amat',
#   'laku',
#   'elizabeth',
#   'hay',
#   'embrio',
#   'anak',
#   'ayam'],
#  '1021430': ['acara',
#   'pentahbisan',
#   'sebut',
#   'kemudian',
#   'lanjut',
#   'laksana',
#   'sidang',
#   'am',
#   'sinode',
#   'pertama',
#   'gereja',
#   'protestan',
#   'indonesia',
#   'donggala',
#   'gpid',
#   'langsung',
#   'mulai',
#   'tanggal',
#   '47',
#   'april',
#   '1965',
#   'sekaligus',
#   'susun',
#   'pedoman',
#   'kerja',
#   'majelis',
#   'sinode',
#   'pilih',
#   'majelis',
#   'sinode',
#   'periode',
#   'pertama',
#   'tugas',
#   'lama',
#   '4',
#   'tahun',
#   '19651968'],
#  '1021536': ['bela',
#   'telah',
#   'habis',
#   'waktu',
#   'beberapa',
#   'bulan',
#   'serang',
#   'susun',
#   'posisi',
#   'tahan',
#   'tanam',
#   'ranjau'],
#  '1022398': ['puncak',
#   'maju',
#   'astronomi',
#   'kalender',
#   'bawah',
#   'raja',
#   'sejong',
#   'chiljeongsan',
#   'susun',
#   'hitung',
#   'program',
#   'tujuh',
#   'benda',
#   'langit',
#   'lima',
#   'planet',
#   'lihat',
#   'matahari',
#   'bulan',
#   'kembang',
#   'tahun',
#   '1442'],
#  '1022522': ['forer',
#   'susun',
#   'hasil',
#   'tes',
#   'pribadi',
#   'sebut',
#   'buku',
#   'astrologi',
#   'kalimat',
#   'guna',
#   'kalimat',
#   'sangat',
#   'umum'],
#  '1022923': ['skripsi',
#   'tuju',
#   'mahasiswa',
#   'mampu',
#   'susun',
#   'tulis',
#   'suatu',
#   'karya',
#   'ilmiah',
#   'sesuai',
#   'bidang',
#   'ilmu'],
#  '1023248': ['juga',
#   'nyata',
#   'bagai',
#   'utus',
#   'allah',
#   'sama',
#   'nabi',
#   'muhammad',
#   'susun',
#   'ayat',
#   'nyata',
#   'bagai',
#   'tanding',
#   'ayat',
#   'alquran'],
#  '1023320': ['gadamer',
#   'susun',
#   'habilitasi',
#   'nya',
#   '1929',
#   'habis',
#   'masa',
#   'awal',
#   '1930an',
#   'jadi',
#   'privatdozent',
#   'beri',
#   'kuliah',
#   'marburg',
#   'jadi',
#   'profesor',
#   'tempat',
#   'sama',
#   'tahun',
#   '1937'],
#  '1023409': ['teknik',
#   'susun',
#   'definisi',
#   'kualifikasi',
#   'dasar',
#   'macam',
#   'arti',
#   'arti',
#   'intensional',
#   'arti',
#   'ekstensional'],
#  '1023699': ['pimpin',
#   'nazi',
#   'susun',
#   'solusi',
#   'akhir',
#   'tuju',
#   'utama',
#   'yang',
#   'sebut',
#   'masalah',
#   'yahudi'],
#  '1024759': ['prof',
#   'a',
#   'hasymi',
#   'nyata',
#   'buku',
#   'sebut',
#   'karang',
#   'syekh',
#   'jalaluddin',
#   'rupa',
#   'buku',
#   'punya',
#   'suatu',
#   'nilai',
#   'tinggi',
#   'bidang',
#   'hukum',
#   'baik'],
#  '1024855': ['nilai',
#   'bunyi',
#   'asli',
#   'voiceless',
#   'bilabial',
#   'plosive',
#   'nilai',
#   'sama',
#   'banyak',
#   'bahasa',
#   'semitik',
#   'bahasa',
#   'arab',
#   'hilang',
#   'sekarang',
#   'untuk',
#   'melambang',
#   'bunyi',
#   'voiceless',
#   'labiodental',
#   'fricative'],
#  '1025466': ['tetap',
#   'jangka',
#   'panjang',
#   'lihat',
#   'depresiasi',
#   'properti',
#   'properti',
#   'hilang',
#   '64',
#   'nilai',
#   'sejak',
#   '2001',
#   'hingga',
#   'november',
#   '2008'],
#  '1025526': ['tiap',
#   'agama',
#   'milik',
#   'etika',
#   'teologis',
#   'unik',
#   'dasar',
#   'apa',
#   'yakin',
#   'jadi',
#   'sistem',
#   'nilai',
#   'anut'],
#  '1026106': ['misal', 'nilai', 'k', 'asam', 'klorida', 'hcl', '10'],
#  '1026559': ['desertasinya',
#   'judul',
#   'bahasa',
#   'isyarat',
#   'syair',
#   'arab',
#   'kaji',
#   'semiotika',
#   'karya',
#   'imam',
#   'aljahidz',
#   'nilai',
#   'akhir',
#   'camlaude'],
#  '1027032': ['makin',
#   'nila',
#   'hasil',
#   'upaya',
#   'kembang',
#   'budaya',
#   'bagi',
#   'masyarakat',
#   'makin',
#   'besar',
#   'harap',
#   'tingkat',
#   'budaya',
#   'sebut'],
#  '1030843': ['tiap',
#   'atlit',
#   'laku',
#   'lima',
#   'loncat',
#   'papan',
#   'setinggi',
#   '3',
#   'meter',
#   'tiga',
#   'atlit',
#   'total',
#   'nilai',
#   'tinggi',
#   'hak',
#   'medali',
#   'emas',
#   'perak',
#   'perunggu'],
#  '1032741': ['lebih', 'sulit', 'tentu', 'nilai', 'hadap', 'variabel'],
#  '1033439': ['nilai',
#   'sosial',
#   'buah',
#   'konsep',
#   'abstrak',
#   'diri',
#   'manusia',
#   'kena',
#   'apa',
#   'anggap',
#   'baik'],
#  '1034583': ['situasi',
#   'jadi',
#   'makin',
#   'tambah',
#   'semarak',
#   'karena',
#   'satu',
#   'tahun',
#   'selenggara',
#   'beberapa',
#   'kali',
#   'lomba',
#   'madihin',
#   'tingkat',
#   'kota',
#   'kabupaten',
#   'provinsi',
#   'hadiah',
#   'uang',
#   'nilai',
#   'juta',
#   'rupiah'],
#  '1041020': ['musim', 'baru', 'bagus', 'simpul', 'ulas', 'beri', 'nilai', 'a'],
#  '1043374': ['beda',
#   'panas',
#   'dingin',
#   'awards',
#   'anugerah',
#   'tahun',
#   'rupa',
#   'dari',
#   'lakon',
#   'opera',
#   'van',
#   'java',
#   'umum'],
#  '1043528': ['mungkin',
#   'panas',
#   'kandung',
#   'lapis',
#   'cair',
#   'diri',
#   'magma',
#   'air',
#   'amonia',
#   'antara',
#   'kerak',
#   'es',
#   'i',
#   'lapis',
#   'es',
#   'lebih',
#   'dalam',
#   'yang',
#   'diri',
#   'es',
#   'tekan',
#   'tinggi'],
#  '1044090': ['28',
#   'januari',
#   '2015',
#   'iwata',
#   'alami',
#   'panas',
#   'tinggi',
#   'serang',
#   'influenza',
#   'buah',
#   'temu',
#   'para',
#   'pegang',
#   'saham',
#   'laku'],
#  '1045062': ['cuaca',
#   'kota',
#   'chang',
#   'an',
#   'sangat',
#   'panas',
#   'musim',
#   'panas',
#   'sering',
#   'undang',
#   'putra',
#   'istana',
#   'jiucheng',
#   'bekas',
#   'istana',
#   'renshou',
#   'masa',
#   'dinasti',
#   'sui',
#   'baoji',
#   'shanxi',
#   'hindar',
#   'cuaca',
#   'sengat'],
#  '1045076': ['kemudian',
#   'tuang',
#   'vodka',
#   'dingin',
#   'dalam',
#   'cangkir',
#   'ganti',
#   'air',
#   'panas',
#   'tumpah'],
#  '1046185': ['album',
#   'isi',
#   'sembilan',
#   'lagu',
#   'enam',
#   'lagu',
#   'album',
#   'dan',
#   'tambah',
#   'tiga',
#   'lagu',
#   'baru',
#   'masuk',
#   'singel',
#   'utama',
#   'dance',
#   'the',
#   'night',
#   'away',
#   'singel',
#   'musim',
#   'panas'],
#  '1046301': ['tunas',
#   'tanam',
#   'percaya',
#   'sembuh',
#   'sakit',
#   'panas',
#   'dengan',
#   'cara',
#   'panggang',
#   'bakar',
#   'lalu',
#   'konsumsi',
#   'isi'],
#  '1046622': ['kolam', 'air', 'panas', 'ada', 'tengah', 'taman'],
#  '1047412': ['jalur',
#   'cabang',
#   'sebut',
#   'sempat',
#   'nonaktif',
#   'sejak',
#   'tahun',
#   '1972',
#   'kini',
#   'aktif',
#   'bagai',
#   'relokasi',
#   'rel',
#   'arah',
#   'barat',
#   'akibat',
#   'dari',
#   'banjir',
#   'lumpur',
#   'panas',
#   'sidoarjo'],
#  '1048106': ['kapasitas',
#   '1',
#   '904',
#   'mw',
#   'tenaga',
#   'panas',
#   'bumi',
#   'hasil',
#   'hingga',
#   '27',
#   'listrik',
#   'bangkit',
#   'filipina'],
#  '1048303': ['beberapa',
#   'kali',
#   'pensiun',
#   'putus',
#   'dari',
#   'masa',
#   'pensiun',
#   'musim',
#   'panas',
#   'tahun',
#   '2013',
#   'main',
#   'cara',
#   'eksklusif',
#   'ganda',
#   'aktif',
#   'hingga',
#   'akhir',
#   'tahun',
#   '2017',
#   'raih',
#   '9',
#   'gelar',
#   'juara',
#   'wta',
#   'tutup',
#   'karir',
#   'peringkat',
#   '1',
#   'dunia',
#   'ganda'],
#  '1048733': ['eropa',
#   'besar',
#   'jenis',
#   'cokelat',
#   'panas',
#   'buat',
#   'sangat',
#   'kental',
#   'mereka',
#   'buat',
#   'cokelat',
#   'murni'],
#  '1049523': ['beda',
#   'mesorah',
#   'babel',
#   'catat',
#   'masoret',
#   'tiberias',
#   'pernah',
#   'sebut',
#   'parashah',
#   'upaya',
#   'buat',
#   'sistematika'],
#  '1049525': ['kenal',
#   'the',
#   'jerusalem',
#   'crown',
#   'the',
#   'bible',
#   'of',
#   'the',
#   'hebrew',
#   'university',
#   'of',
#   'jerusalem',
#   '2000',
#   'mana',
#   'tipografi',
#   'tata',
#   'letak',
#   'tiru',
#   'aleppo',
#   'codex',
#   'ikut',
#   'teknik',
#   'spasi',
#   'abad',
#   'tengah',
#   'parashah',
#   'beri',
#   'baris',
#   'kosong',
#   'bagi',
#   'p',
#   'mulai',
#   's',
#   'pada',
#   'baris',
#   'baru',
#   'buah',
#   'indentasi'],
#  '1049664': ['abstrak',
#   'dasar',
#   'atas',
#   'termodinamika',
#   'bagi',
#   'dunia',
#   'jadi',
#   'sistem',
#   'batas',
#   'nyata',
#   'ideal',
#   'batas'],
#  '1049893': ['ada',
#   'damai',
#   'korawa',
#   'undang',
#   'pandawa',
#   'runding',
#   'soal',
#   'wilayah',
#   'raja'],
#  '1050107': ['sengketa',
#   'kait',
#   'barang',
#   'rampas',
#   'buat',
#   'venesia',
#   'sekutu',
#   'perancis'],
#  '1050240': ['pesawat',
#   'antariksa',
#   'milik',
#   'yang',
#   'jelas',
#   'baik',
#   'tinjau',
#   'bentuk',
#   'berat',
#   'misi',
#   'sistem',
#   'stabil'],
#  '1050250': ['undang',
#   'tang',
#   'bagi',
#   'waris',
#   'properti',
#   'jabat',
#   'kepada',
#   'terus',
#   'sah',
#   'mungkin',
#   'mobilitas',
#   'sosial',
#   'agar',
#   'keluarga',
#   'tidak',
#   'jadi',
#   'keluarga',
#   'bangsawan',
#   'lalu',
#   'primogenitur'],
#  '1050303': ['hubung',
#   'sebut',
#   'pandang',
#   'bagai',
#   'hubung',
#   'internasional',
#   'dekat',
#   'diri',
#   'tanda',
#   'bagi',
#   'sejarah',
#   'budaya',
#   'lembaga',
#   'bahasa',
#   'hubung',
#   'rakyat',
#   'rakyat',
#   'ekstensif',
#   'paham',
#   'aman',
#   'saling',
#   'tumpang',
#   'tindih',
#   'turnamen',
#   'olahraga',
#   'dagang',
#   'kerjasama',
#   'investasi'],
#  '1050370': ['tingkat',
#   'posisi',
#   'madrasah',
#   'diniyah',
#   'sebab',
#   'buah',
#   'sadar',
#   'waktu',
#   'ajar',
#   'agama',
#   'dasar',
#   'kurikulum',
#   'formal',
#   'cukup',
#   'santri',
#   'paham',
#   'ajar',
#   'agama'],
#  '1050380': ['daftar',
#   'uskup',
#   'kazakhstan',
#   'buah',
#   'daftar',
#   'muat',
#   'jabar',
#   'hadap',
#   'wilayah',
#   'administratif',
#   'gereja',
#   'katolik',
#   'roma',
#   'pimpin',
#   'orang',
#   'uskup',
#   'ordinaris',
#   'kazakhstan'],
#  '1050523': ['codex',
#   'sistem',
#   'bab',
#   'aneh',
#   'codex',
#   'vaticanus',
#   'minuscule',
#   '579'],
#  '1050903': ['bagai',
#   'gambar',
#   'lebih',
#   'jauh',
#   'tugas',
#   'lingkung',
#   'dep',
#   'put',
#   'waktu',
#   'asas',
#   'tugas',
#   'pu',
#   'serah',
#   'pada',
#   'wenang',
#   'daerah',
#   'sendiri'],
#  '1050943': ['hingga',
#   'kini',
#   'ada',
#   'sepakat',
#   'kalang',
#   'sejarawan',
#   'militer',
#   'bagi',
#   'periode',
#   'operasi',
#   'militer',
#   'era',
#   'perang',
#   'saudara',
#   'amerika'],
#  '1050961': ['definisi',
#   'nonsamoa',
#   'perang',
#   'saudara',
#   'samoa',
#   'bagai',
#   'perang',
#   'jerman',
#   'britania',
#   'raya',
#   'amerika',
#   'serikat',
#   'ujung',
#   'bagi',
#   'pulau',
#   'pada',
#   'tahun',
#   '1899'],
#  '1050962': ['akibat', 'perang', 'pada', 'tahun', '1899', 'bagi', 'pulau'],
#  '1050977': ['desa',
#   'ungasan',
#   'milik',
#   'total',
#   '13',
#   '004',
#   'jiwa',
#   '2016',
#   'bagi',
#   '6',
#   '672',
#   'laki',
#   '6',
#   '332',
#   'perempuan',
#   'sex',
#   'rasio',
#   '105'],
#  '1051021': ['danau',
#   'letak',
#   'kawasan',
#   '4',
#   'negara',
#   'burundi',
#   'republik',
#   'demokratik',
#   'kongo',
#   'drc',
#   'tanzania',
#   'zambia',
#   'wilayah',
#   'drc',
#   '45',
#   'tanzania',
#   '41',
#   'rupa',
#   'bagi',
#   'besar',
#   'wilayah',
#   'danau'],
#  '1051306': ['dasar',
#   'munisipalitas',
#   'bagi',
#   'administratif',
#   'kecil',
#   'belgia',
#   'untuk',
#   'munisipalitas',
#   'duduk',
#   'lebih',
#   '100',
#   '000',
#   'duduk',
#   'atas',
#   'dasar',
#   'insiatif',
#   'nasehat',
#   'tempat',
#   'wenang',
#   'subadministratif',
#   'munisipal',
#   'badan',
#   'pilih',
#   'bentuk'],
#  '1051631': ['camat',
#   'milik',
#   '5',
#   'lima',
#   'wilayah',
#   'semua',
#   'status',
#   'bagai',
#   'desa',
#   'rincian',
#   'jumlah',
#   'dusun',
#   'banyak',
#   '17'],
#  '1051757': ['idza',
#   'pilih',
#   'bagai',
#   'wakil',
#   'bupati',
#   'wabup',
#   'brebes',
#   'sisa',
#   'masa',
#   'jabat',
#   'peroide',
#   '2007',
#   '2012',
#   'rapat',
#   'paripurna',
#   'dprd',
#   'brebes',
#   '25',
#   'agustus',
#   '2011',
#   '42',
#   'suara',
#   'cawabup',
#   'yakni',
#   'drs'],
#  '1052084': ['sempat',
#   'adu',
#   'mulut',
#   'rapat',
#   'panitia',
#   'hak',
#   'angket',
#   'bank',
#   'century',
#   'beberapa',
#   'waktu',
#   'lalu'],
#  '1052181': ['kurang',
#   'lebih',
#   '2000',
#   'orang',
#   'naung',
#   'benteng',
#   'bayu',
#   'sangat',
#   'kuat',
#   'di',
#   'depan',
#   'pagar',
#   'buat',
#   'batang',
#   'pohon',
#   'besar',
#   'bagi',
#   'atas',
#   'buat',
#   'runcing',
#   'batang',
#   'pohon',
#   'jajar',
#   'sangat',
#   'rapat',
#   'satu',
#   'sama',
#   'yang',
#   'sebut',
#   'palisada'],
#  '1052378': ['proklamasi',
#   'ratifikasi',
#   'waktu',
#   'rapat',
#   'umum',
#   'tanggal',
#   '10',
#   'desember',
#   '1948',
#   'hasil',
#   'hitung',
#   'suara',
#   '48',
#   'tuju',
#   '0',
#   'berat',
#   '8',
#   'abstain',
#   'semua',
#   'blok',
#   'negara',
#   'soviet',
#   'afrika',
#   'selatan',
#   'arab',
#   'saudi'],
#  '1052397': ['komite',
#   'sentral',
#   'pbk',
#   'lima',
#   '19',
#   'rapat',
#   'pleno',
#   'tahun',
#   '1970',
#   'hingga',
#   '1980'],
#  '1052856': ['radiogram',
#   'isi',
#   'minta',
#   'ketua',
#   'dprd',
#   'banten',
#   'mengadendakan',
#   'tetap',
#   'jadwal',
#   'rapat',
#   'paripurna',
#   'istimewa',
#   'dprd',
#   'rangka',
#   'lantik',
#   'gubernur',
#   'wakil',
#   'gubernur',
#   'pilih'],
#  '1053080': ['gubernur',
#   'andi',
#   'pangerang',
#   'pettarani',
#   'rapat',
#   'tanggal',
#   '11',
#   'maret',
#   '1963',
#   'tunjuk',
#   'lr',
#   'aminuddin',
#   'ressang',
#   'bagai',
#   'ketua',
#   'subpanitia',
#   'kerja',
#   'bentuk',
#   'fakultas',
#   'ilmu',
#   'dan',
#   'ilmu',
#   'alam',
#   'fipia',
#   'resmi',
#   'bentuk',
#   'dasar',
#   'surat',
#   'kawat',
#   'menteri',
#   'ptip',
#   'tanggal',
#   '8',
#   'agustus',
#   '1963',
#   'no',
#   '59',
#   '1',
#   'bm',
#   'ptip',
#   '63',
#   'susul',
#   'sk',
#   'menteri',
#   'no',
#   '102',
#   'tahun',
#   '1963',
#   'laku',
#   'tanggal',
#   '17',
#   'agustus',
#   '1963'],
#  '1053172': ['dasar',
#   'hasil',
#   'rapat',
#   'pleno',
#   'buka',
#   'rekapitulasi',
#   'hitung',
#   'suara',
#   'komisi',
#   'pilih',
#   'umum',
#   'kpu',
#   'tanah',
#   'bumbu',
#   'pilkada',
#   'kabupaten',
#   'akan',
#   'laksana',
#   'putar'],
#  '1053520': ['kap',
#   'kerah',
#   'sebut',
#   'duga',
#   'bagai',
#   'daerah',
#   'rapat',
#   'awan',
#   'metana',
#   'letak',
#   'kisar',
#   'tekan',
#   '1',
#   '3',
#   '2',
#   'bar',
#   'lihat',
#   'atas'],
#  '1053553': ['sarung',
#   'tangan',
#   'lindung',
#   'tangan',
#   'belayer',
#   'aman',
#   'panjat',
#   'maupun',
#   'rapler',
#   'bahaya',
#   'gesek',
#   'telapak',
#   'tangan',
#   'tali',
#   'kam'],
#  '1053721': ['lalu',
#   'billy',
#   'ball',
#   'tunjuk',
#   'salah',
#   'satu',
#   'ahli',
#   'lempar',
#   'pistol',
#   'atas',
#   'lalu',
#   'pistol',
#   'jatuh',
#   'tepat',
#   'masuk',
#   'sarung',
#   'pistol'],
#  '1053815': ['bentuk',
#   'pisau',
#   'kecil',
#   'sarung',
#   'sarung',
#   'lepas',
#   'cahaya',
#   'mata',
#   'pisau',
#   'keluar',
#   'cahaya',
#   'dapat',
#   'buat',
#   'dunamist',
#   'transformasi'],
#  '1053913': ['segera',
#   'bendera',
#   'kibar',
#   'semua',
#   'kelewang',
#   'sangkur',
#   'sentak',
#   'sarung',
#   'dengar',
#   'ria',
#   'hurahurahura'],
#  '1053937': ['ichiro',
#   'telah',
#   'tang',
#   'harga',
#   'sarung',
#   'tangan',
#   'emas',
#   'tiap',
#   'tahun',
#   'karier',
#   'liga',
#   'mayor',
#   'telah',
#   'catat',
#   '6',
#   'kali',
#   'hitting',
#   'streak',
#   '20',
#   'kali',
#   'tanding',
#   'lebih',
#   'rekor',
#   'banyak',
#   'pukul',
#   'banyak',
#   '27',
#   'kali',
#   'tanding'],
#  '1059416': ['tengah',
#   'zaman',
#   'makin',
#   'puruk',
#   'duta',
#   'masyarakat',
#   'harap',
#   'untuk',
#   'jawab',
#   'bagai',
#   'tantang',
#   'sebut'],
#  '1062067': ['mi',
#   'dzymorze',
#   'kenal',
#   'istilah',
#   'latin',
#   'intermarium',
#   'buah',
#   'rencana',
#   'cetus',
#   'pimpin',
#   'polandia',
#   'j',
#   'zef',
#   'pi',
#   'sudski',
#   'akhir',
#   'perang',
#   'dunia',
#   'i',
#   'rencana',
#   'ingin',
#   'diri',
#   'buah',
#   'federasi',
#   'negara',
#   'eropa',
#   'tengah',
#   'timur'],
#  '1068174': ['foto',
#   'keluarga',
#   'biasa',
#   'si',
#   'tengah',
#   'yang',
#   'paling',
#   'dikit'],
#  '1073006': ['rumah',
#   'tangga',
#   'tingkat',
#   'paling',
#   'tinggi',
#   'pengaruh',
#   'naik',
#   'pajak',
#   'pajak',
#   'hasil',
#   'hadap',
#   'yang',
#   'terima',
#   'muka',
#   'laba',
#   'modal'],
#  '1078773': ['kombinasi',
#   'gunung',
#   'eropa',
#   'tinggi',
#   'langit',
#   'cerah',
#   'puncak',
#   'gunung',
#   'roque',
#   'de',
#   'los',
#   'muchachos',
#   'pulau',
#   'la',
#   'palma',
#   'cocok',
#   'teleskop',
#   'letak',
#   'sana'],
#  '1082953': ['ingin',
#   'sahrul',
#   'masuk',
#   'guru',
#   'tinggi',
#   'negeri',
#   'capai',
#   'banyak',
#   'waktu',
#   'habis',
#   'nyanyi'],
#  '1083518': ['tim',
#   'ajar',
#   'gala',
#   'ada',
#   'command',
#   'tinggi',
#   'jerman',
#   'dekat'],
#  '1083646': ['guru',
#   'tinggi',
#   'didik',
#   'akreditasi',
#   'dewan',
#   'nasional',
#   'akreditasi',
#   'didik',
#   'guru',
#   'nasional',
#   'asosiasi',
#   'psikolog',
#   'sekolah',
#   'tuju',
#   'national',
#   'association',
#   'of',
#   'sekolah',
#   'psikolog'],
#  '1085916': ['abdul',
#   'rosyad',
#   'jadi',
#   'hakim',
#   'tinggi',
#   'adil',
#   'tinggi',
#   'palu',
#   'dwiarso',
#   'budi',
#   'santiarto',
#   'promosi',
#   'jadi',
#   'hakim',
#   'tinggi',
#   'adil',
#   'tinggi',
#   'denpasar',
#   'bal',
#   'jupriyadi',
#   'jadi',
#   'ketua',
#   'adil',
#   'negeri',
#   'bandung'],
#  '1092263': ['angka',
#   'tahan',
#   'ini',
#   'tingkat',
#   'hampir',
#   'tujuh',
#   'kali',
#   'lipat',
#   'sejak',
#   '1980',
#   'tiga',
#   'kali',
#   'lipat',
#   'lebih',
#   'tinggi',
#   'angka',
#   'tahan',
#   'polandianegara',
#   'oecd',
#   'angka',
#   'tahan',
#   'tinggi'],
#  '1095307': ['b',
#   'sitanala',
#   'beberapa',
#   'tokoh',
#   'masyarakat',
#   'prakarsa',
#   'diri',
#   'suatu',
#   'lembaga',
#   'didik',
#   'tinggi',
#   'malu',
#   'wujud',
#   'aspirasi',
#   'rakyat',
#   'ingin',
#   'partisipasi',
#   'bangun',
#   'bangsa',
#   'negara',
#   'utama',
#   'bidang',
#   'didik',
#   'tinggi',
#   'kembang',
#   'llmu',
#   'tahu'],
#  '114373': ['jauh',
#   'latah',
#   'baru',
#   'temu',
#   'budaya',
#   'orang',
#   'asia',
#   'tenggara',
#   'utama',
#   'indonesia',
#   'malaysia'],
#  '118920': ['tahun',
#   '2009',
#   'majalah',
#   'juga',
#   'mulai',
#   'sebar',
#   'seluruh',
#   'dunia',
#   'di',
#   'inggris',
#   'lewat',
#   'sunday',
#   'telegraph',
#   'jerman',
#   'lewat',
#   'm',
#   'nchner',
#   'merkur',
#   'tz',
#   'frankfurter',
#   'allgemeine',
#   'zeitung',
#   'irlandia',
#   'utara',
#   'lewat',
#   'belfast',
#   'telegraph',
#   'republik',
#   'irlandia',
#   'lewat',
#   'irish',
#   'independent',
#   'selandia',
#   'baru',
#   'lewat',
#   'new',
#   'zealand',
#   'herald',
#   'afrika',
#   'selatan',
#   'lewat',
#   'the',
#   'star',
#   'daily',
#   'news',
#   'cape',
#   'argus',
#   'cape',
#   'times',
#   'pretoria',
#   'news',
#   'polandia',
#   'lewat',
#   'gazeta',
#   'wyborcza',
#   'di',
#   'kuwait',
#   'lewat',
#   'kuwait',
#   'times'],
#  '123386': ['ular', 'derik', 'baru', 'lahir', 'derik', 'dapat', 'fungsi'],
#  '126438': ['manfaat', 'alat', 'berat', 'laku', 'sejak', 'aman', 'romawi'],
#  '126652': ['tanding',
#   'usai',
#   'ikan',
#   'timbang',
#   'tahu',
#   'total',
#   'berat',
#   'ikan',
#   'besar'],
#  '126728': ['theropoda',
#   'besar',
#   'ini',
#   'burung',
#   'unta',
#   'tinggi',
#   '2',
#   '74',
#   'm',
#   'berat',
#   '63',
#   '5',
#   '145',
#   '15',
#   'kg'],
#  '127103': ['juara',
#   'tinju',
#   'kelas',
#   'berat',
#   'evander',
#   'holyfield',
#   'jadi',
#   'bintang',
#   'tamu',
#   'episode',
#   'bagai',
#   'diri',
#   'sendiri',
#   'tampil',
#   'saat',
#   'mal',
#   'bantu',
#   'latih',
#   'phineas',
#   'tanding',
#   'gulat',
#   'jempol',
#   'besar',
#   'lawan',
#   'buford'],
#  '127290': ['tanggal',
#   '1',
#   'agustus',
#   'rebut',
#   'gelar',
#   'ibf',
#   'tony',
#   'tucker',
#   'menang',
#   'angka',
#   'jadi',
#   'juara',
#   'tinju',
#   'dunia',
#   'kelas',
#   'berat',
#   'sejati'],
#  '127473': ['lsu02',
#   'buat',
#   'lap',
#   'mampu',
#   'bawa',
#   'beban',
#   'berat',
#   'maksimal',
#   'hingga',
#   '3',
#   'kg',
#   'cepat',
#   'terbang',
#   'hingga',
#   '100',
#   'km',
#   'jam'],
#  '127784': ['lalu',
#   'kenal',
#   'pribadi',
#   'jadi',
#   'dukung',
#   'berat',
#   'kubu',
#   'perancis',
#   'majelis',
#   'istana',
#   'polandia',
#   'wakil',
#   'permaisuri',
#   'marie',
#   'louise',
#   'gonzaga'],
#  '127940': ['john',
#   'arthur',
#   'jack',
#   'johnson',
#   'juluk',
#   'galveston',
#   'giant',
#   'orang',
#   'tinju',
#   'amerika',
#   'pada',
#   'puncak',
#   'era',
#   'jim',
#   'crow',
#   'jadi',
#   'juara',
#   'tinju',
#   'kelas',
#   'berat',
#   'dunia',
#   'afrika',
#   'amerika',
#   'pertama',
#   '1908',
#   '1915'],
#  '127991': ['karya',
#   'lupa',
#   'relatif',
#   'kenal',
#   'mati',
#   'pada',
#   'tahun',
#   '1960',
#   'konferensi',
#   'umum',
#   'berat',
#   'ukur',
#   'nama',
#   'unit',
#   'si',
#   'magnetik',
#   'rapat',
#   'fluks',
#   'tesla',
#   'terap',
#   'hormat'],
#  '128963': ['ikan',
#   'arapaima',
#   'tumbuh',
#   'maksimal',
#   'panjang',
#   '3',
#   'meter',
#   'berat',
#   '200',
#   'kilogram'],
#  '129215': ['negara',
#   'anggap',
#   'penuh',
#   'syarat',
#   'partisipasi',
#   'inisiatif',
#   'negara',
#   'miskin',
#   'utang',
#   'berat',
#   'tahun',
#   '2008'],
#  '129358': ['banyak',
#   'pada',
#   'american',
#   'kennel',
#   'club',
#   'untuk',
#   'berat',
#   'badan',
#   'ideal',
#   'kurang',
#   '7',
#   'lb',
#   'lebih',
#   'baik',
#   'di',
#   '4',
#   'lb',
#   '6',
#   'lb'],
#  '130223': ['anjing',
#   'milik',
#   'tinggi',
#   '58',
#   'cm',
#   'berat',
#   '17',
#   'kg',
#   'lapis',
#   'bulu',
#   'pendek',
#   'halus'],
#  '130531': ['telepon',
#   'genggam',
#   'milik',
#   'dimensi',
#   '107',
#   'x',
#   '46',
#   'x',
#   '13',
#   '8',
#   'mm',
#   'berat',
#   '80',
#   'gram'],
#  '130613': ['karbon',
#   'dioksida',
#   'lebih',
#   'berat',
#   'keluar',
#   'dorong',
#   'oksigen',
#   'keluar',
#   'mati',
#   'hampir',
#   '2000',
#   'orang'],
#  '131008': ['kurir',
#   'tokugawa',
#   'ieyasu',
#   'baru',
#   'tanggal',
#   '9',
#   'september',
#   'lambat',
#   'hidetada',
#   'anggap',
#   'bagai',
#   'salah',
#   'berat',
#   'ieyasu'],
#  '131091': ['jantan',
#   'milik',
#   'berat',
#   'rata',
#   '25',
#   'kg',
#   '5577',
#   'lb',
#   'betina',
#   'kurang',
#   'tengah',
#   'berat',
#   'sebut',
#   '11',
#   'kg',
#   '2530',
#   'lb'],
#  '131322': ['neutron',
#   'netron',
#   'partikel',
#   'subatomik',
#   'tidak',
#   'muat',
#   'netral',
#   'milik',
#   'massa',
#   '940',
#   'mev',
#   'c',
#   '1',
#   '6749',
#   '10',
#   'kg',
#   'sedikit',
#   'lebih',
#   'berat',
#   'proton'],
#  '142166': ['gurun', 'taklamakan', 'dominasi', 'besar', 'cekung'],
#  '144112': ['awal',
#   'periode',
#   'joseon',
#   'rusa',
#   'besar',
#   'jadi',
#   'patung',
#   'budha',
#   'namsan',
#   'laku',
#   'kaum',
#   'radikal',
#   'neokonfusianisme',
#   'rusak',
#   'lengan',
#   'kepala',
#   'patung'],
#  '148285': ['tampil',
#   'bagai',
#   'acara2',
#   'didik',
#   'sponsor',
#   'banyak',
#   'usaha',
#   'usaha',
#   'besar',
#   'indonesia'],
#  '150772': ['laut',
#   'kansas',
#   'huni',
#   'banyak',
#   'predator',
#   'lebih',
#   'besar',
#   'tusoteuthis',
#   'kadal',
#   'laut',
#   'raksasa',
#   'mosasaurus',
#   'tylosaurus',
#   'plesiosauria',
#   'elasmosaurus',
#   'hiu',
#   'raksasa',
#   'cretoxyrhina',
#   'squalicorax',
#   'ikan',
#   'tulang',
#   'keras',
#   'xiphactinus'],
#  '163682': ['mula',
#   'kerja',
#   'bagi',
#   'besar',
#   'batas',
#   'untuk',
#   'wilayah',
#   'amerika',
#   'utara',
#   'tahun',
#   '1874',
#   'hingga',
#   'misionari',
#   'gereja',
#   'advent',
#   'pertama',
#   'j',
#   'n',
#   'andrews',
#   'utus',
#   'swiss'],
#  '170153': ['itu',
#   'jumlah',
#   'besar',
#   'anggota',
#   'terima',
#   'medali',
#   'masuk',
#   'salah',
#   'satu',
#   'medal',
#   'of',
#   'honor',
#   '11',
#   'bintang',
#   'perak',
#   'sekitar',
#   '300',
#   'hati',
#   'ungu'],
#  '179802': ['banyak',
#   'mata',
#   'cahari',
#   'duduk',
#   'desa',
#   'tani',
#   'rantau',
#   'kota',
#   'besar'],
#  '1894': ['film',
#   'sebut',
#   'jadi',
#   'wakil',
#   'hungaria',
#   'academy',
#   'awards',
#   'ke73',
#   'academy',
#   'award',
#   'film',
#   'bahasa',
#   'asing',
#   'baik',
#   'tidak',
#   'masuk',
#   'nominasi'],
#  '197029': ['lokasi', 'tidak', 'umum', 'untuk', 'senapan', 'besar'],
#  '202859': ['tiap',
#   '42',
#   'tahun',
#   'uranus',
#   'alami',
#   'ekuinoks',
#   'bidang',
#   'khatulistiwa',
#   'silang',
#   'bumi',
#   'okultasi',
#   'satelit',
#   'uranus',
#   'mungkin',
#   'jadi'],
#  '2053': ['film',
#   'sebut',
#   'jadi',
#   'salah',
#   'satu',
#   'nominasi',
#   'film',
#   'bahasa',
#   'asing',
#   'baik',
#   'academy',
#   'awards',
#   'ke88'],
#  '212403': ['airbrush',
#   'buah',
#   'teknik',
#   'seni',
#   'rupa',
#   'guna',
#   'tekan',
#   'udara',
#   'semprot',
#   'cat',
#   'warna',
#   'bidang',
#   'kerja'],
#  '219569': ['bidang',
#   'didik',
#   'duduk',
#   'atas',
#   '5',
#   'tahun',
#   'tamat',
#   'guru',
#   'tinggi',
#   'universitas',
#   'jumlah',
#   '150',
#   'orang',
#   'akademi',
#   '31',
#   'orang',
#   'slta',
#   'derajat',
#   '606',
#   'orang',
#   'sltp',
#   'derajat',
#   '570',
#   'orang',
#   'sd',
#   'derajat',
#   '722',
#   'orang',
#   'tamat',
#   'sd',
#   '254',
#   'orang',
#   'belum',
#   'sekolah',
#   '20',
#   'orang'],
#  '220337': ['bidang',
#   'didik',
#   'lurah',
#   'limpomajang',
#   '2',
#   'unit',
#   'sekolah',
#   'dasar',
#   'sdn',
#   '53',
#   'lajarella',
#   'sdn',
#   '54',
#   'bolamallimponge'],
#  '223493': ['hasil',
#   'chris',
#   'dunia',
#   'tinju',
#   'bawa',
#   'profesi',
#   'samping',
#   'lain',
#   'bintang',
#   'iklan',
#   'bagai',
#   'produk',
#   'komentator',
#   'tinju',
#   'televisi'],
#  '224128': ['borgnine',
#   'milik',
#   'tampil',
#   'paling',
#   'banyak',
#   'jadi',
#   'bintang',
#   'tamu',
#   'enam',
#   'belas',
#   'kali'],
#  '224197': ['kampus',
#   'bukit',
#   'bintang',
#   'kosong',
#   'tahun',
#   '2000',
#   'sekolah',
#   'sebut',
#   'pindah',
#   'cheras',
#   'lalu',
#   'ubah',
#   'nama',
#   'bagai',
#   'sekolah',
#   'sri',
#   'bintang',
#   'utara'],
#  '224239': ['jabat',
#   'akhir',
#   'jenderal',
#   'bintang',
#   'ini',
#   'wakapolda',
#   'sulsel'],
#  '224599': ['bintang',
#   'milik',
#   'komponen',
#   'pasang',
#   '40',
#   'eridani',
#   'b',
#   '40',
#   'eridani',
#   'c',
#   'masingmasing',
#   'rupa',
#   'bintang',
#   'katai',
#   'magnitudo',
#   'tingkat',
#   'sembilan',
#   'kelas',
#   'da4',
#   'white',
#   'dwarf',
#   'bintang',
#   'katai',
#   'merah',
#   'magnitudo',
#   'tingkat',
#   'sebelas',
#   'red',
#   'dwarf',
#   'kelas',
#   'm4',
#   '5e'],
#  '224651': ['10',
#   'oktober',
#   '2003',
#   'sendlerowa',
#   'terima',
#   'bintang',
#   'elang',
#   'putih'],
#  '224654': ['grup',
#   'musik',
#   'bob',
#   'wills',
#   'and',
#   'his',
#   'texas',
#   'playboys',
#   'rupa',
#   'bintang',
#   'laris',
#   'genre',
#   'musik',
#   'western',
#   'swing',
#   'madu',
#   'cara',
#   'nyanyi',
#   'musik',
#   'country',
#   'teknik',
#   'steel',
#   'guitar',
#   'grup',
#   'big',
#   'band',
#   'irama',
#   'jazz'],
#  '224792': ['itu',
#   'puncak',
#   'geger',
#   'bintang',
#   'turut',
#   'legenda',
#   'sebut',
#   'geger',
#   'bintang',
#   'pada',
#   'zaman',
#   'ada',
#   'bintang',
#   'jatuh',
#   'masyarakat',
#   'jadi',
#   'panik',
#   'geger'],
#  '224970': ['juri',
#   'utama',
#   'orang',
#   'latih',
#   'vokal',
#   'indra',
#   'aziz',
#   'sukses',
#   'latih',
#   'kontestan',
#   'program',
#   'cari',
#   'bakat',
#   'indonesian',
#   'idol',
#   'idola',
#   'cilik',
#   'x',
#   'factor',
#   'indonesia',
#   'afi',
#   '2013',
#   'pakar',
#   'tari',
#   'professional',
#   'hamdi',
#   'fabas',
#   'dan',
#   'bintang',
#   'tamu',
#   'juga',
#   'jadi',
#   'juri',
#   'tamu',
#   'acara'],
#  '225401': ['bulan',
#   'mei',
#   '2011',
#   'harnois',
#   'jadi',
#   'bintang',
#   'tamu',
#   'program',
#   'drama',
#   'detektif',
#   'plisi',
#   'cbs',
#   'di',
#   'musim',
#   '1',
#   'episode',
#   '21',
#   'judul',
#   'cello',
#   'and',
#   'goodbye',
#   'muncil',
#   'bagai',
#   'morgan',
#   'brody',
#   'orang',
#   'selidik',
#   'tempat',
#   'jadi',
#   'perkara',
#   'csi',
#   'polisi',
#   'los',
#   'angles',
#   'lapd',
#   'divisi',
#   'investigasi',
#   'ilmiah'],
#  '226491': ['adalah',
#   'anak',
#   'sulung',
#   'keluarga',
#   'tampak',
#   'jadi',
#   'kaya',
#   'oga',
#   'mereka',
#   'mampu',
#   'habis',
#   'libur',
#   'musim',
#   'panas',
#   'buah',
#   'resor',
#   'bintang',
#   'lima'],
#  '227422': ['walton',
#   'harris',
#   'walker',
#   'orang',
#   'jenderal',
#   'bintang',
#   'empat',
#   'tugas',
#   'bagai',
#   'komandan',
#   'perang',
#   'dunia',
#   'i',
#   'perang',
#   'dunia',
#   'ii',
#   'perang',
#   'korea',
#   'mana',
#   'komandan',
#   'eighth',
#   'united',
#   'states',
#   'army',
#   'tewas',
#   'buah',
#   'celaka',
#   'jip'],
#  '227488': ['roy',
#   'jadi',
#   'orang',
#   'muda',
#   'tampil',
#   'sampul',
#   'majalah',
#   'cosmopolitan',
#   'china',
#   'ia',
#   'tampil',
#   'edisi',
#   'juni',
#   '2016',
#   'sama',
#   'bintang',
#   'l',
#   'o',
#   'r',
#   'd'],
#  '227582': ['bagai',
#   'bintang',
#   'tamu',
#   'libat',
#   'lain',
#   'ben',
#   'becker',
#   'martina',
#   'gedeck',
#   'corinna',
#   'harfouch',
#   'angela',
#   'winkler'],
#  '227616': ['jabat',
#   'akhir',
#   'jenderal',
#   'bintang',
#   'satu',
#   'adalah',
#   'staf',
#   'khusus',
#   'kasau'],
#  '227809': ['bukan',
#   'bintang',
#   'biasa',
#   'lebih',
#   'singkat',
#   'nama',
#   'bbb',
#   'grup',
#   'musik',
#   'besut',
#   'melly',
#   'goeslaw',
#   'tahun',
#   '2006',
#   'yang',
#   'diri',
#   'raffi',
#   'ahmad',
#   'mas',
#   'beck',
#   'laudya',
#   'cinthya',
#   'bella',
#   'ayushita',
#   'chelsea',
#   'olivia',
#   'wijaya',
#   'jakarta'],
#  '238292': ['gambar',
#   'binatang',
#   'kalimat',
#   'ucap',
#   'standar',
#   'tambah',
#   'guna',
#   'stempel',
#   'karet',
#   'aneka',
#   'warna',
#   'jual',
#   'toko',
#   'buku',
#   'stempel',
#   'sedia',
#   'kantor',
#   'pos'],
#  '238508': ['boikot', 'bisa', 'arti', 'bagai', 'tolak', 'kerja', 'sama'],
#  '239421': ['debat',
#   'mereka',
#   'sebut',
#   'bagai',
#   'yahudi',
#   'mizrahi',
#   'banyak',
#   'kelompok',
#   'mizrahi',
#   'lama',
#   'beberapa',
#   'abad',
#   'akhir',
#   'sudah',
#   'alami',
#   'proses',
#   'asimilasi',
#   'total',
#   'bagi',
#   'budaya',
#   'liturgi',
#   'sefardim'],
#  '2459': ['film',
#   'sebut',
#   'pilih',
#   'bagai',
#   'wakil',
#   'austria',
#   'film',
#   'bahasa',
#   'asing',
#   'baik',
#   'academy',
#   'awards',
#   'ke86',
#   'tidak',
#   'masuk',
#   'nominasi'],
#  '247075': ['tiga',
#   'kemudi',
#   'lari',
#   'diri',
#   'bus',
#   'tapi',
#   'satu',
#   'mud',
#   'cegah',
#   'pergi',
#   'paksa',
#   'dorong',
#   'bajak',
#   'tempat',
#   'tuju'],
#  '2547': ['subject',
#   '09',
#   'kisah',
#   'jalan',
#   'mantan',
#   'agen',
#   'rahasia',
#   'cipta',
#   'akhir',
#   'masa',
#   'perintah',
#   'presiden',
#   'soeharto',
#   'bagai',
#   'antitesis',
#   'gera',
#   'oknum',
#   'asing',
#   'daerah',
#   'nusantara'],
#  '260713': ['jadi', 'bayang', 'zaman', 'saja', 'modern', 'ujar', 'ahmadie'],
#  '269462': ['untung',
#   'kecil',
#   'distorsi',
#   'tim',
#   'transient',
#   'intermodulation',
#   'bisa',
#   'setel',
#   'bass',
#   'treble',
#   'cara',
#   'mandiri'],
#  '272983': ['dasar',
#   'hukum',
#   'atur',
#   'perintah',
#   '10',
#   'tahun',
#   '2011',
#   'tata',
#   'cara',
#   'pinjam',
#   'luar',
#   'negeri',
#   'terima',
#   'hibah',
#   'atur',
#   'ganti',
#   'pp',
#   'nomor',
#   '2',
#   'tahun',
#   '2006',
#   'tata',
#   'cara',
#   'pinjam',
#   'atau',
#   'terima',
#   'hibah',
#   'terus',
#   'pinjam',
#   'atau',
#   'hibah',
#   'luar',
#   'negeri',
#   'harus',
#   'pinjam',
#   'bank',
#   'dunia',
#   'telah',
#   'pakat',
#   'bisa',
#   'cair',
#   'lalu',
#   'surat',
#   'putus',
#   'menteri',
#   'uang'],
#  '273340': ['serta',
#   'didik',
#   'dapat',
#   'hasil',
#   'luar',
#   'biasa',
#   'dapat',
#   'beasiswa',
#   'studi',
#   'jangka',
#   'pendek',
#   'bahasa',
#   'mandarin',
#   'tiongkok'],
#  '274220': ['jawab',
#   'miss',
#   'earth',
#   '2001',
#   'yah',
#   'saja',
#   'teknologi',
#   'buat',
#   'banyak',
#   'masalah',
#   'kami',
#   'lingkung',
#   'kita',
#   'laku',
#   'untuk',
#   'buat',
#   'lebih',
#   'baik'],
#  '278844': ['lengkap',
#   'fasilitas',
#   'sebut',
#   'laksana',
#   'bangun',
#   'lingkung',
#   'tanam',
#   'pohon',
#   'rangka',
#   'hijau',
#   'banyak',
#   '114',
#   '641',
#   'batang',
#   'pohon',
#   'diri',
#   '43',
#   'macam',
#   'jenis',
#   'tanam',
#   'bangun',
#   '3',
#   'buah',
#   'danau',
#   'fungsi',
#   'bagai',
#   'resap',
#   'sekaligus',
#   'daerah',
#   'latih',
#   'wilayah',
#   'pmpp',
#   'tni',
#   '1',
#   '48',
#   'ha',
#   'bnpt',
#   '551',
#   'm2',
#   'unhan',
#   '274',
#   'm2',
#   'bangun',
#   '2',
#   'unit',
#   'wtp',
#   'water',
#   'treating',
#   'plant',
#   'olah',
#   'air',
#   'muka',
#   'jadi',
#   'air',
#   'layak',
#   'konsumsi'],
#  '280634': ['30',
#   'buah',
#   'puncak',
#   'tinggi',
#   'daecheongbong',
#   '1',
#   '708',
#   'm'],
#  '283778': ['taifun',
#   'isi',
#   '9',
#   'buah',
#   'lagu',
#   'mana',
#   'album',
#   'guna',
#   'bagai',
#   'album',
#   'iring',
#   '3',
#   'film'],
#  '313898': ['janji',
#   'hudaibiyah',
#   'pakat',
#   'henti',
#   'musuh',
#   'lama',
#   'puluh',
#   'tahun',
#   'muhammad',
#   'rencana',
#   'serang',
#   'hadap',
#   'kaum',
#   'yahudi',
#   'tepat',
#   'bulan',
#   'muharam',
#   'tahun',
#   'tujuh',
#   'hijriah'],
#  '315867': ['lama',
#   'masa',
#   'perintah',
#   'yuri',
#   'bangsa',
#   'silla',
#   'raya',
#   'suatu',
#   'hari',
#   'raya',
#   'tanggal',
#   '15',
#   'bulan',
#   'delap'],
#  '324536': ['lagu',
#   'menang',
#   'song',
#   'of',
#   'the',
#   'month',
#   'bulan',
#   'februari',
#   '2008',
#   'acra',
#   'musik',
#   'kbs',
#   'music',
#   'bank'],
#  '324595': ['buku',
#   'manji',
#   'paling',
#   'akhir',
#   'allah',
#   'liberty',
#   'and',
#   'love',
#   'rilis',
#   'bulan',
#   'juni',
#   '2011',
#   'as',
#   'kanada',
#   'negara'],
#  '326045': ['pilih',
#   'salah',
#   'satu',
#   'main',
#   'bawa',
#   'dalam',
#   'mimpi',
#   'bunga',
#   'sebut'],
#  '326663': ['bunga',
#   'muncul',
#   'cara',
#   'sama',
#   'sebut',
#   'bagai',
#   'bunga',
#   'majemuk',
#   'inflorescence'],
#  '327229': ['itu',
#   'tim',
#   'temu',
#   'jenis',
#   'anggrek',
#   'kuntum',
#   'bunga',
#   'milik',
#   '3',
#   'corak',
#   'warna',
#   'kenal',
#   'three',
#   'color',
#   'genus',
#   'belum',
#   'tahu'],
#  '327398': ['karakteristik',
#   'bunga',
#   'b',
#   'lobi',
#   'letak',
#   'labellumnya',
#   'dapat',
#   'goyang',
#   'apabila',
#   'tiup',
#   'angin'],
#  '327535': ['saing',
#   'bunga',
#   'citra',
#   'lestari',
#   'mu',
#   'jizat',
#   'allah',
#   'cici',
#   'tegal',
#   'kiamat',
#   'dekat',
#   'hanna',
#   'hasyim',
#   'rumah',
#   'kardus',
#   'vitta',
#   'mariana',
#   'masa'],
#  '327541': ['motif',
#   'motif',
#   'jambang',
#   'bunga',
#   'banyak',
#   'temu',
#   'semua',
#   'rumah',
#   'adat',
#   'banjar',
#   'misal',
#   'ukir',
#   'tataban',
#   'rumah',
#   'bubung',
#   'tinggi',
#   'kalimantan',
#   'selatan'],
#  '327633': ['peluk',
#   'bunga',
#   'matahari',
#   'bahasa',
#   'perancis',
#   'le',
#   'peintre',
#   'de',
#   'tournesols',
#   'buah',
#   'potret',
#   'vincent',
#   'van',
#   'gogh',
#   'karya',
#   'paul',
#   'gauguin',
#   'desember',
#   '1888'],
#  '327759': ['masingmasing',
#   'bunga',
#   'tampil',
#   'puncak',
#   'mekar',
#   'dengan',
#   'sangat',
#   'detail'],
#  '328185': ['karang',
#   'bunga',
#   'jantan',
#   'bentuk',
#   'bongkol',
#   'gada',
#   'gelendong'],
#  '328743': ['beda',
#   'warna',
#   'satu',
#   'yang',
#   'dilatarbelakangi',
#   'gen',
#   'misal',
#   'r',
#   'gen',
#   'bunga',
#   'warna',
#   'merah',
#   'r',
#   'gen',
#   'bunga',
#   'warna',
#   'putih',
#   'dua',
#   'silang',
#   'akan',
#   'hasil',
#   'bunga',
#   'warna',
#   'merah',
#   'muda'],
#  '331320': ['itu',
#   'bdsm',
#   'bangun',
#   'jalur',
#   'kereta',
#   'api',
#   'jombangbabat',
#   '69',
#   'km',
#   'tahun',
#   '18991902',
#   'buat',
#   'jalur',
#   'cabang',
#   'stasiun',
#   'ploso',
#   'tuju',
#   'pabrik',
#   'gula',
#   'ponen',
#   'tahun',
#   '1913',
#   '2',
#   'km'],
#  '331823': ['contoh',
#   'praktik',
#   'adalahmaskapai',
#   'indonesia',
#   'airasia',
#   'cabang',
#   'maskapai',
#   'malaysia',
#   'airasia',
#   'beli',
#   'operasi',
#   'maskapai',
#   'lokal',
#   'awair',
#   '2004',
#   'belum',
#   'akhir',
#   'ubah',
#   'nama',
#   'jadi',
#   'indonesia',
#   'airasia',
#   '2005'],
#  '332192': ['kompetisi',
#   'supergirls',
#   'wrestling',
#   'buah',
#   'cabang',
#   'extreme',
#   'canadian',
#   'championship',
#   'wrestling'],
#  '332550': ['post',
#   'jabat',
#   'bagai',
#   'ibu',
#   'kos',
#   'hormat',
#   'fraternitas',
#   'tempat',
#   'pertama',
#   'sekolah',
#   'sigma',
#   'beta',
#   'epsilon',
#   'pada',
#   'tahun',
#   '1969',
#   'jadi',
#   'the',
#   'cabang',
#   'new',
#   'york',
#   'beta',
#   'sigma',
#   'alpha',
#   'epsilon'],
#  '333314': ['beberapa',
#   'keluarga',
#   'cabang',
#   'atas',
#   'asal',
#   'trah',
#   'gentry',
#   'kuno',
#   'tiongkok',
#   'bagi',
#   'besar',
#   'turun',
#   'dagang',
#   'sukses'],
#  '336256': ['cahaya', 'cerah', 'di', 'inframerah', 'jadi', 'awal', 'april'],
#  '336450': ['kritikus',
#   'gambar',
#   'album',
#   'sebut',
#   'bagai',
#   'catat',
#   'hampir',
#   'identik',
#   'ganti',
#   'dancehall',
#   'dubpop',
#   'hiphop',
#   'cerah',
#   'orientasi',
#   'balada',
#   'dewasa'],
#  '336523': ['panjang',
#   'kumbang',
#   'sekitar',
#   '10',
#   'milimeter',
#   'warna',
#   'kuning',
#   'cerah',
#   'tubuh',
#   'oranye',
#   'lima',
#   'garis',
#   'coklat',
#   'tua',
#   'panjang',
#   'elytranya'],
#  '336546': ['orang',
#   'ahli',
#   'simpul',
#   'lawan',
#   'pandang',
#   'kultur',
#   'ada',
#   'data',
#   'tunjuk',
#   'orang',
#   'lapor',
#   'suasana',
#   'hati',
#   'lebih',
#   'baik',
#   'hari',
#   'cerah',
#   'balik'],
#  '336556': ['mary',
#   'celeste',
#   'marie',
#   'celste',
#   'kapal',
#   'tiang',
#   'jenis',
#   'angkut',
#   'kargo',
#   'tumpang',
#   'temu',
#   'samudra',
#   'atlantik',
#   'awak',
#   'abai',
#   'meski',
#   'fakta',
#   'cuaca',
#   'cerah',
#   'punya',
#   'kru',
#   'alam'],
#  '336571': ['yakin',
#   'wei',
#   'milik',
#   'prospek',
#   'cerah',
#   'bagai',
#   'pimpin',
#   'militer',
#   'handal',
#   'ia',
#   'mahir',
#   'manah',
#   'tunggang',
#   'kuda'],
#  '336608': ['kisah',
#   'catat',
#   'imam',
#   'ahmad',
#   'musnadnya',
#   'binatang',
#   'akan',
#   'pukul',
#   'hidung',
#   'orang',
#   'kafir',
#   'cincin',
#   'akan',
#   'buat',
#   'wajah',
#   'orang',
#   'iman',
#   'jadi',
#   'cerah',
#   'tongkat',
#   'ketika',
#   'makan',
#   'sama',
#   'akan',
#   'kata',
#   'satu',
#   'sama',
#   'wahai',
#   'orang',
#   'iman',
#   'wahai',
#   'orang',
#   'kafir'],
#  '336644': ['teliti',
#   'tunjuk',
#   'jumlah',
#   'tambah',
#   'biaya',
#   'rendah',
#   'mampu',
#   'cepat',
#   'sodis',
#   'yang',
#   'mungkin',
#   'buat',
#   'sodis',
#   'aditif',
#   'lebih',
#   'cepat',
#   'efektif',
#   'baik',
#   'cuaca',
#   'cerah',
#   'awan'],
#  '336671': ['karakteristik',
#   'ayam',
#   'nunukan',
#   'warna',
#   'bulu',
#   'merah',
#   'cerah',
#   'merah',
#   'kekuningkuningan'],
#  '336693': ['rupa',
#   'buah',
#   'turun',
#   'grunge',
#   'milik',
#   'karakter',
#   'khas',
#   'grunge',
#   'dengan',
#   'beberapa',
#   'beda',
#   'colok',
#   'tema',
#   'lirik',
#   'lebih',
#   'cerah',
#   'ketimbang',
#   'grunge',
#   'cenderung',
#   'kelam'],
#  '336717': ['dengar',
#   'dokter',
#   'sir',
#   'james',
#   'clark',
#   'putra',
#   'nikmat',
#   'hari',
#   'kering',
#   'cerah',
#   'jauh',
#   'timur',
#   'kastil',
#   'balmoral'],
#  '336913': ['ekor', 'hewan', 'warna', 'coklat', 'merah'],
#  '34746': ['2004',
#   'tarif',
#   'nonsubsidi',
#   'langgan',
#   '6',
#   '600',
#   'va',
#   'atas',
#   'rp',
#   '1',
#   '380',
#   'per',
#   'kilowatthour',
#   'kwh',
#   'sedang',
#   'tarif',
#   'subsidi',
#   'rp',
#   '600',
#   'per',
#   'kwh'],
#  '35599': ['tahan',
#   'sebut',
#   'laku',
#   'berkas',
#   'p21',
#   'atas',
#   'nama',
#   'lengkap'],
#  '3994': ['universitas',
#   'milik',
#   'banyak',
#   'mahasiswa',
#   'asing',
#   'seringkali',
#   'punya',
#   'kelompok',
#   'sendiri',
#   'taung',
#   'ajar',
#   'sebut'],
#  '407520': ['afdeeling',
#   'doesoenlandeenatau',
#   'tanah',
#   'dusun',
#   '18981930',
#   'bekas',
#   'buah',
#   'afdeling',
#   'karesidenan',
#   'selatan',
#   'timur',
#   'borneo',
#   'sesuai',
#   'staatblad',
#   'tahun',
#   '1898',
#   'no'],
#  '4114': ['acara',
#   'bahasa',
#   'asing',
#   'pertama',
#   'dapat',
#   'harga',
#   'dupontcolumbia',
#   'cnn',
#   'en',
#   'espanol',
#   'reporter',
#   'jorge',
#   'gestoso',
#   'tang',
#   'tongkat',
#   'perak',
#   'lapor',
#   'investigasi',
#   'desaparecidos',
#   'argentina'],
#  '4115': ['istilah',
#   'asing',
#   'dengan',
#   'cepat',
# ...
#   'ganda',
#   'buat',
#   'kayu',
#   'asal',
#   'abad',
#   'ke8',
#   'nusantara',
#   'gambar',
#   'beberapa',
#   'relief',
#   'borobudur'],
#  '930518': ['dhini',
#   'main',
#   'layar',
#   'lebar',
#   'produksi',
#   'trans',
#   'tv',
#   'judul',
#   'dunia',
#   '2006'],
#  '931683': ['siasat',
#   'atur',
#   'cara',
#   'tempuh',
#   'tun',
#   'seri',
#   'lanang',
#   'perintah',
#   'layar',
#   'samalanga',
#   'pura',
#   'pura',
#   'bagai',
#   'orang',
#   'nelayan',
#   'kumuh',
#   'ahli',
#   'lihat',
#   'bintang'],
#  '932147': ['turun',
#   'hujan',
#   'lebat',
#   'liput',
#   'bumi',
#   'empat',
#   'puluh',
#   'hari',
#   'empat',
#   'puluh',
#   'malam',
#   'lama'],
#  '932335': ['bunga',
#   'lebat',
#   'kecil',
#   'bilang',
#   '5',
#   'kelopak',
#   '4',
#   '5',
#   'mm',
#   'bundar',
#   'telur',
#   'balik',
#   'mahkota',
#   '6',
#   '9',
#   'mm',
#   'lanset',
#   'sempit',
#   'merah',
#   'jambu',
#   'kuning',
#   'pucat',
#   'ujung'],
#  '932365': ['suhu',
#   'tetap',
#   'hampir',
#   'konstan',
#   'panjang',
#   'tahun',
#   'tidak',
#   'pengaruh',
#   'hujan',
#   'lebat',
#   'angin',
#   'kencang',
#   'lama',
#   'jam',
#   'awal',
#   'pagi',
#   'dapat',
#   'bawa',
#   'suhu',
#   'turun',
#   'titik',
#   'beku',
#   'ini',
#   'sangat',
#   'jarang',
#   'jadi'],
#  '932512': ['contoh',
#   'daerah',
#   'iklim',
#   'tropis',
#   'indonesia',
#   'milik',
#   'hutan',
#   'lebat',
#   'kaya',
#   'keanekaragaman',
#   'hayati',
#   'sebut',
#   'hutan',
#   'hujan',
#   'tropis',
#   'sedang',
#   'di',
#   'daerah',
#   'subtropis',
#   'hutan',
#   'itu',
#   'jumpa'],
#  '932528': ['panjang',
#   'alir',
#   'sungai',
#   'sebut',
#   'bentang',
#   'hutan',
#   'lebat',
#   'tropis',
#   'sangat',
#   'luas',
#   'sisi',
#   'sungai',
#   'sebut'],
#  '933525': ['desa',
#   'cibeureum',
#   'rupa',
#   'desa',
#   'ada',
#   'lingkung',
#   'raja',
#   'talaga',
#   'manggung'],
#  '934110': ['tipe',
#   '518',
#   'pasang',
#   'kapal',
#   'usak',
#   'kapal',
#   'tonase',
#   'berat',
#   'angkat',
#   'laut',
#   'deteksi',
#   'pesawat',
#   'jarak',
#   'jauh',
#   'tinggi',
#   'tinggi',
#   'bising',
#   'alam',
#   'rugi',
#   'lingkung',
#   'jamming',
#   'listrik',
#   'aktif'],
#  '935548': ['hari',
#   'sama',
#   'cnblue',
#   'acara',
#   'showcase',
#   'album',
#   'be',
#   'my',
#   'cinderella',
#   'ax',
#   'hall',
#   'lingkung',
#   'gwangjangdong',
#   'seoul',
#   'korea',
#   'selatan',
#   'siar',
#   'lalu',
#   'v',
#   'app'],
#  '935708': ['lingkung',
#   'erenk',
#   'y',
#   'bostanc',
#   'suadiye',
#   'pisah',
#   'distrik',
#   'kartal',
#   'tahun',
#   'sama',
#   'akhir',
#   'gabung',
#   'distrik',
#   'kad',
#   'k',
#   'y',
#   'baru',
#   'bentuk'],
#  '935809': ['perhati',
#   'beberapa',
#   'negara',
#   'us',
#   'negara',
#   'eropa',
#   'seringkali',
#   'teknik',
#   'lingkung',
#   'letak',
#   'bawah',
#   'teknik',
#   'sipil',
#   'mana',
#   'materi',
#   'kuliah',
#   'kombinasi',
#   'bidang',
#   'sipil',
#   'gerak',
#   'bidang',
#   'lingkung'],
#  '937868': ['marida',
#   'tumbuh',
#   'besar',
#   'lingkung',
#   'dukung',
#   'minat',
#   'seni',
#   'meski',
#   'milik',
#   'batas',
#   'dengar',
#   'kondisi',
#   'sehat',
#   'rentan'],
#  '938457': ['metode',
#   'tekan',
#   'penting',
#   'sesuai',
#   'lingkung',
#   'ajar',
#   'anak',
#   'tingkat',
#   'kembang',
#   'peran',
#   'aktivitas',
#   'fisik',
#   'serap',
#   'konsep',
#   'akademis',
#   'terampil',
#   'praktik'],
#  '938741': ['demikian',
#   'simpul',
#   'istilah',
#   'kawanua',
#   'lahir',
#   'masyarakat',
#   'orang',
#   'minahasa',
#   'luar',
#   'minahasa',
#   'bagai',
#   'sebut',
#   'identitas',
#   'orang',
#   'asal',
#   'minahasa',
#   'lingkung',
#   'gaul',
#   'masyarakat',
#   'bukan',
#   'orang',
#   'minahasa',
#   'misal',
#   'di',
#   'makasar',
#   'balikpapan',
#   'surabaya',
#   'jakarta',
#   'salatiga',
#   'padang',
#   'aceh'],
#  '939383': ['beberapa',
#   'lapor',
#   'sebut',
#   'tunda',
#   'oleh',
#   'masalah',
#   'terjemah',
#   'teks',
#   'asli',
#   'bahasa',
#   'jerman',
#   'bahasa',
#   'latin',
#   'lain',
#   'kata',
#   'jadi',
#   'tikai',
#   'lingkung',
#   'vatikan',
#   'kata',
#   'tepat',
#   'dalam',
#   'dokumen'],
#  '939420': ['erti',
#   'kenal',
#   'eratosthenes',
#   'geografi',
#   'rupa',
#   'ilmu',
#   'deskripsi',
#   'manusia',
#   'lingkung',
#   'alam',
#   'wilayah',
#   'dasar',
#   'data',
#   'informasi',
#   'oleh'],
#  '939918': ['dewan',
#   'teliti',
#   'lingkung',
#   'alami',
#   'agen',
#   'utama',
#   'dana',
#   'kelola',
#   'teliti',
#   'latih',
#   'tukar',
#   'tahu',
#   'ilmu',
#   'lingkung',
#   'inggris',
#   'koordinasi',
#   'beberapa',
#   'proyek',
#   'teliti',
#   'dunia',
#   'tangan',
#   'isu',
#   'utama',
#   'ubah',
#   'iklim',
#   'pengaruh',
#   'lingkung',
#   'hadap',
#   'sehat',
#   'manusia',
#   'susun',
#   'genetik',
#   'hidup',
#   'bumi'],
#  '940271': ['sejak',
#   '1994',
#   'telah',
#   'gabung',
#   'walhi',
#   'pusat',
#   'hingga',
#   'kemudian',
#   'jadi',
#   'direktur',
#   'eksekutif',
#   'wahana',
#   'lingkung',
#   'hidup',
#   'indonesia',
#   'walhi',
#   '20052008',
#   'ganti',
#   'longgena',
#   'ginting'],
#  '940301': ['karya',
#   'penuh',
#   'tegang',
#   'latar',
#   'masa',
#   'revolusi',
#   'hidup',
#   'lingkung',
#   'militer'],
#  '940815': ['jelang',
#   'ujung',
#   'utara',
#   'phoenix',
#   'garden',
#   'taman',
#   'lingkung',
#   'jalan',
#   'duduk',
#   'tempat'],
#  '941434': ['proses',
#   'sesuai',
#   'langsung',
#   'waktu',
#   'cukup',
#   'variasi',
#   'gantung',
#   'jauh',
#   'beda',
#   'kondisi',
#   'lingkung',
#   'baru',
#   'akan',
#   'hadap',
#   'langsung',
#   'lama',
#   'beberapa',
#   'hari',
#   'hingga',
#   'beberapa',
#   'minggu'],
#  '942342': ['letak',
#   'bravia',
#   'engine',
#   'layar',
#   'tft',
#   '4',
#   'inchi',
#   'buat',
#   'mata',
#   'leluasa',
#   'pandang'],
#  '942838': ['ide',
#   'buat',
#   'aplikasi',
#   'summyl',
#   'awal',
#   'nick',
#   'd',
#   'aloisio',
#   'cari',
#   'materi',
#   'uji',
#   'mata',
#   'ajar',
#   'sejarah',
#   'bulan',
#   'april',
#   '2011'],
#  '942941': ['antibiotika',
#   'kerja',
#   'pestisida',
#   'tekan',
#   'putus',
#   'satu',
#   'mata',
#   'rantai',
#   'metabolisme',
#   'saja',
#   'target',
#   'bakteri',
#   'molekul'],
#  '943131': ['cair',
#   'infeksi',
#   'kena',
#   'mata',
#   'bisa',
#   'jadi',
#   'infeksi',
#   'mata',
#   'luar'],
#  '943866': ['iring',
#   'jalan',
#   'lewat',
#   'konvensi',
#   'ramai',
#   'lihat',
#   'umum',
#   'layar',
#   'ganti',
#   'jadi',
#   'buah',
#   'main',
#   'firstperson',
#   'shooter',
#   'lewat',
#   'mata',
#   'homer'],
#  '946089': ['beberapa',
#   'mata',
#   'milik',
#   'hingga',
#   '28',
#   '000',
#   'sensor',
#   'sebut',
#   'atur',
#   'cara',
#   'heksagonal',
#   'dapat',
#   'beri',
#   'bidang',
#   'lihat',
#   '360',
#   'penuh'],
#  '946580': ['dolar', 'mata', 'uang', 'sarawak', '1858', '1953'],
#  '949274': ['panjang', 'mata', 'pandang', 'hampar', 'abu', 'putih'],
#  '949805': ['itu',
#   'sumber',
#   'mata',
#   'air',
#   'sumber',
#   'gunung',
#   'sangat',
#   'jaga',
#   'ada',
#   'dan',
#   'lestari'],
#  '952409': ['lurah', 'sulaa', 'milik', 'mata', 'air', 'banyak'],
#  '953522': ['ideologi',
#   'soekarno',
#   'antiimperialisme',
#   'kemudian',
#   'bawa',
#   'indonesia',
#   'makin',
#   'gantung',
#   'dukung',
#   'uni',
#   'soviet',
#   'china'],
#  '954435': ['jadi',
#   'bingung',
#   'apakah',
#   'nuh',
#   'bawa',
#   'tujuh',
#   'pasang',
#   'atau',
#   'pasang',
#   'binatang',
#   'tidak',
#   'haram',
#   'dalam',
#   'bahtera'],
#  '954677': ['sancho',
#   'pergi',
#   'cordoba',
#   'bagai',
#   'duta',
#   'besar',
#   'negara',
#   'sendiri',
#   'bawa',
#   'banyak',
#   'hadiah',
#   'sang',
#   'menang',
#   'almansur'],
#  '954804': ['tari',
#   'akan',
#   'bawa',
#   'lilin',
#   'nyala',
#   'piring',
#   'pegang',
#   'tiap',
#   'telapak',
#   'tangan'],
#  '958073': ['bawa',
#   'nama',
#   'avril',
#   'tangga',
#   'lagu',
#   'dunia',
#   'duduk',
#   'posisi',
#   'top',
#   '10',
#   'beberapa',
#   'negara',
#   'dunia',
#   'duduk',
#   'posisi',
#   '22',
#   'amerika'],
#  '958437': ['orang',
#   'majus',
#   'timur',
#   'datang',
#   'betlehem',
#   'lihat',
#   'sembah',
#   'yang',
#   'lahir',
#   'bagai',
#   'raja',
#   'orang',
#   'yahudi',
#   'bawa',
#   'hadiah'],
#  '960846': ['islam',
#   'pandang',
#   'tauhid',
#   'teologi',
#   'bawa',
#   'konsekuensi',
#   'pandang',
#   'tauhid',
#   'kosmologi',
#   'pandang',
#   'tauhid',
#   'antropologi',
#   'pada',
#   'dasar',
#   'tegas',
#   'alam',
#   'semesta',
#   'kosmik',
#   'antropologi',
#   'manusia',
#   'budaya',
#   'satu',
#   'fei',
#   '13'],
#  '963127': ['meski',
#   'larang',
#   'tidak',
#   'bawa',
#   'minum',
#   'keras',
#   'tetap',
#   'ada',
#   'langgar'],
#  '963252': ['selesai',
#   'kapal',
#   'berangkat',
#   '28',
#   'oktober',
#   '1613',
#   'tuju',
#   'acapulco',
#   'meksiko',
#   'bawa',
#   '180',
#   'orang',
#   'antara',
#   '10',
#   'orang',
#   'samurai',
#   'utus',
#   'shogun',
#   'pimpin',
#   'menteri',
#   'angkat',
#   'laut',
#   'muka',
#   'shogen',
#   '12',
#   'samurai',
#   'domain',
#   'senda',
#   '120',
#   'orang',
#   'dagang',
#   'jepang',
#   'laut',
#   'layan',
#   'sekitar',
#   '40',
#   'orang',
#   'spanyol',
#   'portugis'],
#  '963426': ['beberapa',
#   'selebrasi',
#   'menang',
#   'lorenzo',
#   'musim',
#   '2010',
#   'lain',
#   'jadi',
#   'golf',
#   'astronot',
#   'bawa',
#   'maskot',
#   'mario',
#   'serial',
#   'nintendo',
#   'mario',
#   'saudara',
#   'ia',
#   'diri',
#   'bagai',
#   'juara',
#   'dunia',
#   '2010',
#   'malaysia'],
#  '966878': ['biasa',
#   'paman',
#   'pasti',
#   'marah',
#   'akan',
#   'parah',
#   'nobita',
#   'siapa',
#   'pecah',
#   'kaca',
#   'rumah',
#   'pot',
#   'tanam'],
#  '967844': ['buah',
#   'salt',
#   'dapat',
#   'bagai',
#   'dari',
#   'kunci',
#   'pecah',
#   'algoritme',
#   'kriptografi',
#   'lain'],
#  '968250': ['talas',
#   'pecah',
#   'rekor',
#   'hujan',
#   'jatuh',
#   'bandar',
#   'selatan',
#   'takachiho',
#   'miyazaki',
#   'wilayah',
#   'bulan',
#   'september',
#   '2005'],
#  '968268': ['iia',
#   'pecah',
#   'leher',
#   'bulibuli',
#   'dan',
#   'tuang',
#   'minyak',
#   'atas',
#   'kepala',
#   'yesus',
#   'lalu',
#   'minyak',
#   'kaki',
#   'yesus'],
#  '968522': ['bagai',
#   'media',
#   'iklan',
#   'konsep',
#   'aida',
#   'iklan',
#   'facebok',
#   'kata',
#   'cukup',
#   'efektif',
#   'mampu',
#   'penuh',
#   'semua',
#   'unsur',
#   'konsep',
#   'sebut',
#   'attention',
#   'perhati',
#   'mana',
#   'iklna',
#   'facebook',
#   'dapat',
#   'tangkap',
#   'perhati',
#   'khalayak',
#   'iklan',
#   'tampil',
#   'bagi',
#   'kanan',
#   'halaman',
#   'facebook',
#   'interest',
#   'minat',
#   'mana',
#   'tarik',
#   'iklan',
#   'sebut',
#   'mereka',
#   'milik',
#   'mal',
#   'tahu',
#   'lebih',
#   'jauh',
#   'kena',
#   'isi',
#   'iklan',
#   'sampai',
#   'desire',
#   'hasrat',
#   'milik',
#   'minat',
#   'makan',
#   'para',
#   'khalayak',
#   'milik',
#   'hasrat',
#   'milik',
#   'tawar',
#   'iklan',
#   'facebook',
#   'lalu',
#   'action',
#   'tindak',
#   'proses',
#   'akhir',
#   'mana',
#   'khalayak',
#   'akan',
#   'tindak',
#   'lebih',
#   'jauh',
#   'laku',
#   'yang',
#   'jadi',
#   'tuju',
#   'iklan',
#   'sebut',
#   'tindak',
#   'beli',
#   'produk',
#   'jasa',
#   'yang',
#   'tawar',
#   'lain',
#   'bagai'],
#  '968926': ['linda',
#   't',
#   'lio',
#   'samar',
#   'dapat',
#   'masuk',
#   'dalam',
#   'parade',
#   'nigel',
#   'tangkap',
#   'blu',
#   'rafael',
#   'nico',
#   'pedro'],
#  '969030': ['capit', 'kepiting', 'untuk', 'tangkap', 'makan', 'mangsa'],
#  '970068': ['murphy',
#   'sendiri',
#   'lapor',
#   'senang',
#   'interpretasi',
#   'hukum',
#   'biasa',
#   'pandang',
#   'bagai',
#   'tangkap',
#   'suci',
#   'penting',
#   'benda',
#   'mati'],
#  '970135': ['pikir',
#   'panjang',
#   'esok',
#   'hari',
#   'sidik',
#   'kpk',
#   'lalu',
#   'tangkap',
#   'andi',
#   'narogong',
#   'periksa',
#   'lebih',
#   'lanjut',
#   'lalu',
#   'surat',
#   'perintah',
#   'mula',
#   'sidi',
#   'sprindik'],
#  '970181': ['awas',
#   'arti',
#   'monitor',
#   'ubah',
#   'situasi',
#   'cara',
#   'real',
#   'time',
#   'intai',
#   'tangkap',
#   'gambar',
#   'statis',
#   'analisis'],
#  '970542': ['si',
#   'potret',
#   'dengan',
#   'mudah',
#   'tangkap',
#   'suatu',
#   'objek',
#   'harus',
#   'susah',
#   'bidik',
#   'lalu',
#   'jendela',
#   'pandang',
#   'kamera',
#   'digital',
#   'besar',
#   'memang',
#   'milik'],
#  '971017': ['tom',
#   'tangkap',
#   'tikus',
#   'sebut',
#   'marah',
#   'lalu',
#   'selip',
#   'jerry',
#   'antara',
#   'tuts',
#   'piano'],
#  '971281': ['angin',
#   'biasa',
#   'manfaat',
#   'nelayan',
#   'pulang',
#   'tangkap',
#   'ikan',
#   'laut'],
#  '971629': ['peristiwa',
#   'serang',
#   'orang',
#   'murid',
#   'yesus',
#   'kristus',
#   'hadap',
#   'salah',
#   'satu',
#   'orang',
#   'hamba',
#   'imam',
#   'besar',
#   'tangkap',
#   'yesus',
#   'taman',
#   'getsemani',
#   'catat',
#   'empat',
#   'injil'],
#  '973148': ['pogrom',
#   'antiyahudi',
#   'kaisar',
#   'rusia',
#   'tahun',
#   '1881',
#   '1884',
#   'dorong',
#   'tumbuh',
#   'identitas',
#   'orang',
#   'pandang',
#   'bagai',
#   'etnisitas',
#   'bangsa',
#   'hasil',
#   'bentuk',
#   'organisasi',
#   'pionir',
#   'hovevei',
#   'zion',
#   'publikasi',
#   'autoemancipation',
#   'karya',
#   'leon',
#   'pinsker',
#   'arus',
#   'besar',
#   'pertama',
#   'imigrasi',
#   'yahudi',
#   'palestina',
#   'cara',
#   'retrospektif',
#   'nama',
#   'aliyah',
#   'pertama'],
#  '974709': ['tenaga',
#   '2',
#   'mesin',
#   'diesel',
#   'jelajah',
#   'tenaga',
#   '8',
#   '000',
#   'bhp',
#   'cepat',
#   'jelajah',
#   '21',
#   'knot',
#   '1',
#   'boost',
#   'gas',
#   'turbine',
#   'dengan22',
#   '360',
#   'shp',
#   'sanggup',
#   'dorong',
#   'kapal',
#   'hingga',
#   'cepat',
#   '30',
#   'knot'],
#  '975226': ['cara',
#   'budidaya',
#   'makin',
#   'efisien',
#   'dorong',
#   'intensifikasi',
#   'tani'],
#  '976055': ['beberapa',
#   'beberapa',
#   'sistem',
#   'cara',
#   'adat',
#   'masih',
#   'tahan',
#   'dorong',
#   'pecah',
#   'perang',
#   'saudara',
#   'kenal',
#   'nama',
#   'perang',
#   'padri',
#   'pada',
#   'awal',
#   'kaum',
#   'padri',
#   'ulama',
#   'kaum',
#   'adat',
#   'belanda',
#   'libat',
#   'diri',
#   'dalam',
#   'peperangan',
#   'ini'],
#  '977025': ['heart',
#   'attack',
#   'terima',
#   'puji',
#   'kritis',
#   'kritikus',
#   'musik',
#   'kontemporer'],
#  '979043': ['kelahi',
#   'kelahi',
#   'ia',
#   'cara',
#   'alami',
#   'tempa',
#   'latih',
#   'jawab',
#   'tantang',
#   'hidup',
#   'keras',
#   'dari',
#   'keras',
#   'hidup',
#   'alam',
#   'sifat',
#   'fisik',
#   'sikap',
#   'mental',
#   'bina',
#   'biasa',
#   'terima',
#   'nyata',
#   'hidup',
#   'cara',
#   'realitas',
#   'rasional'],
#  '981443': ['tanggal',
#   '29',
#   'september',
#   '1999',
#   'kolonel',
#   'pnb',
#   'eris',
#   'herryanto',
#   'terima',
#   'tugas',
#   'bagai',
#   'komandan',
#   'lanud',
#   'pekanbaru'],
#  '984080': ['paus',
#   'fransiskus',
#   'terima',
#   'pensiun',
#   '16',
#   'november',
#   '2016',
#   'tunjuk',
#   'orlando',
#   'brandes',
#   'terus'],
#  '985436': ['uni',
#   'eropa',
#   'terima',
#   'hadiah',
#   'nobel',
#   'damai',
#   '2012',
#   'kontribusi',
#   'maju',
#   'damai',
#   'rekonsiliasi',
#   'demokrasi',
#   'hak',
#   'asasi',
#   'manusia',
#   'eropa'],
#  '988125': ['akhir', 'perl', 'terima', 'tawar', 'michigan'],
#  '988755': ['catat',
#   'theravadin',
#   'kena',
#   'asalusul',
#   'therav',
#   'da',
#   'sebut',
#   'alir',
#   'terima',
#   'ajar',
#   'pakat',
#   'lama',
#   'konsili',
#   'buddha',
#   'tiga',
#   'bawah',
#   'lindung',
#   'raja',
#   'asoka',
#   'india',
#   'tahun',
#   '250',
#   'sm'],
#  '989091': ['bicara',
#   'kardinal',
#   'suci',
#   'dengar',
#   'anak',
#   'muda',
#   'belum',
#   'terima',
#   'komuni',
#   'pertama',
#   'dia',
#   'siap',
#   'aloysius'],
#  '989400': ['tahun',
#   '2006',
#   'kim',
#   'namgil',
#   'putus',
#   'terima',
#   'peran',
#   'utama',
#   'dalam',
#   'buah',
#   'film',
#   'kontroversial',
#   'puji',
#   'kritis',
#   'no',
#   'regret'],
#  '990689': ['hms',
#   'hermes',
#   'yang',
#   'pertama',
#   'terima',
#   'tugas',
#   'lindung',
#   'sedang',
#   'hms',
#   'invincible',
#   'pergi',
#   'utara',
#   'ganti',
#   'laut',
#   'mesin',
#   'utama'],
#  '992286': ['waktu',
#   'tugas',
#   'kyoto',
#   'kenshin',
#   'ajar',
#   'zen',
#   'kuil',
#   'daitokuji',
#   'alir',
#   'rinzai',
#   'bawah',
#   'bimbing',
#   'biksu',
#   'tetsush',
#   's',
#   'ky',
#   'terima',
#   'nama',
#   's',
#   'shin'],
#  '992405': ['mother',
#   'fotina',
#   'jelas',
#   'sama',
#   'antara',
#   'jalan',
#   'paul',
#   'putin',
#   'masuk',
#   'muda',
#   'tuntut',
#   'kristus',
#   'ilham',
#   'roh',
#   'kudus',
#   'kelompok',
#   'juga',
#   'percaya',
#   'putin',
#   'terima',
#   'roh',
#   'kudus',
#   'jadi',
#   'presiden'],
#  '993982': ['tetapi',
#   'semua',
#   'kelompok',
#   'kiri',
#   'itu',
#   'intelektual',
#   'nasionalis',
#   'sayap',
#   'kiri',
#   'nonparlemen',
#   'tulis',
#   'george',
#   'karabelias',
#   'keras',
#   'kritik',
#   'elefantis',
#   'jumlah',
#   'orang',
#   'utama',
#   'kelompok',
#   'kiri',
#   'tentang',
#   'aku',
#   'genosida',
#   'sebut',
#   'sejarawan',
#   'revisionis',
#   'tuduh',
#   'sayap',
#   'kiri',
#   'umum',
#   'yunanai',
#   'kandung',
#   'evolusi',
#   'ideologi',
#   'meyimpang'],
#  '994825': ['hasil',
#   'teliti',
#   'jepang',
#   'ungkap',
#   'rumput',
#   'laut',
#   'masuk',
#   'wakame',
#   'kandung',
#   'zat',
#   'mineral',
#   'trim',
#   'serat',
#   'makan',
#   'asam',
#   'alginat',
#   'mampu',
#   'turun',
#   'tumbuh',
#   'sel',
#   'kankaer',
#   'tekan',
#   'darah',
#   'tinggi',
#   'tingkat',
#   'kebal',
#   'tubuh']}

# %%
file_path = "../data/training_set/single_annotator.csv"

single_annotator = preprocessing(file_path)

single_annotator
# Out:
# {'336691': ['cuaca', 'cerah', 'lazim', 'panjang', 'tahun'],
#  '336270': ['gambar',
#   'hasil',
#   'layar',
#   'cukup',
#   'cerah',
#   'milik',
#   'speaker',
#   'mampu',
#   'hasil',
#   'suara',
#   'keras',
#   'jernih'],
#  '336555': ['masa',
#   'depan',
#   'cerah',
#   'pemuda',
#   'umur',
#   '20',
#   'prancis',
#   'abad',
#   '17'],
#  '336618': ['cor',
#   'caroli',
#   'alpha',
#   'canum',
#   'venaticorum',
#   'nama',
#   'lengkap',
#   'cor',
#   'caroli',
#   'regis',
#   'martyris',
#   'bintang',
#   'paling',
#   'cerah',
#   'rasi',
#   'canes',
#   'venatici'],
#  '336613': ['sanders',
#   'lebih',
#   'suka',
#   'cat',
#   'air',
#   'lilo',
#   'maksud',
#   'tampil',
#   'warna',
#   'cerah',
#   'buku',
#   'cerita',
#   'gambar'],
#  '336406': ['ulleungdo',
#   'milik',
#   'iklim',
#   'subtropis',
#   'basah',
#   'klasifikasi',
#   'iklim',
#   'koppen',
#   'cfa',
#   'pada',
#   'musim',
#   'dingin',
#   'hujan',
#   'sangat',
#   'deras',
#   'cuaca',
#   'cerah',
#   'sangat',
#   'jarang'],
#  '336324': ['ikan',
#   'hias',
#   'mungkin',
#   'besar',
#   'sulit',
#   'tahan',
#   'hidup',
#   'alam',
#   'liar',
#   'akibat',
#   'warnawarninya',
#   'cerah',
#   'sirip',
#   'panjang'],
#  '336401': ['buah',
#   'entremet',
#   'tanda',
#   'akhir',
#   'saji',
#   'suatu',
#   'set',
#   'menu',
#   'dapat',
#   'upa',
#   'apa',
#   'mulai',
#   'frumenty',
#   'sederhana',
#   'macam',
#   'bubur',
#   'gandum',
#   'warna',
#   'cerah',
#   'bumbu',
#   'rempah'],
#  '336426': ['alangkah',
#   'lega',
#   'hati',
#   'ia',
#   'mulai',
#   'lihat',
#   'binatang',
#   'ternak',
#   'liar',
#   'atas',
#   'ladang',
#   'rumput',
#   'burung',
#   'bangan',
#   'udara',
#   'cerah'],
#  '337760': ['sisi', 'atas', 'tubuh', 'warna', 'coklat', 'tembaga', 'emas'],
#  '337381': ['hasil',
#   'uji',
#   'tunjuk',
#   'ada',
#   'beberapa',
#   'varietas',
#   'tahan',
#   'hadap',
#   'wereng',
#   'coklat',
#   'biotipe',
#   '2',
#   '3',
#   'jadi',
#   'rentan',
#   'hadap',
#   'wereng',
#   'punggung',
#   'putih'],
#  '337629': ['lucy',
#   'milik',
#   'mata',
#   'coklat',
#   'rambut',
#   'pirang',
#   'panjang',
#   'bahu',
#   'biasa',
#   'ikat',
#   'pita',
#   'bagai',
#   'warna',
#   'ekor',
#   'kuda',
#   'kecil',
#   'belah',
#   'kanan',
#   'kepala',
#   'seluruh',
#   'rambut',
#   'urai'],
#  '337446': ['punggung',
#   'badan',
#   'warna',
#   'coklat',
#   'kelabu',
#   '4',
#   'garis',
#   'hitam',
#   'panjang',
#   'anterior',
#   'badan'],
#  '338100': ['jenis',
#   'koral',
#   'seringkali',
#   'temu',
#   'karang',
#   'daging',
#   'porites',
#   'lobata',
#   'banyak',
#   'warna',
#   'ungu',
#   'coklat',
#   'kuning'],
#  '337480': ['kepala',
#   'warna',
#   'coklat',
#   'merah',
#   'garis',
#   'hitam',
#   'mata',
#   'tengkuk'],
#  '336955': ['remaja',
#   'milik',
#   'corak',
#   'coklat',
#   'bintik',
#   'kuning',
#   'coklat'],
#  '816088': ['rancang',
#   'pei',
#   'tempat',
#   'kotak',
#   'sepatu',
#   'kaku',
#   'buah',
#   'sudut',
#   'kisi',
#   'jalan'],
#  '810534': ['jalan', 'cerita', 'kostum', 'guna', 'tidak', 'sesuai', 'zaman'],
#  '809166': ['taraf',
#   'hidup',
#   'masyarakat',
#   'tingkat',
#   'dukung',
#   'buat',
#   'jalan',
#   'desa',
#   'bangun',
#   'rumah',
#   'duduk',
#   'laku',
#   'cara',
#   'gotong',
#   'royong',
#   'atur',
#   'aman',
#   'cara',
#   'sama'],
#  '811504': ['lima',
#   'jalan',
#   'tol',
#   'besar',
#   'hubung',
#   'distrik',
#   'bisnis',
#   'sentral',
#   'johor',
#   'bahru',
#   'kota',
#   'luar'],
#  '814156': ['jumlah',
#   'jalan',
#   'tempat',
#   'kota',
#   'beri',
#   'nama',
#   'ilmuwan',
#   'matematikawan',
#   'temu',
#   'dieselstrasse'],
#  '811170': ['tol',
#   'serang',
#   'panimbang',
#   'rupa',
#   'jalan',
#   'tol',
#   'hubung',
#   'serang',
#   'kawasan',
#   'ekonomi',
#   'khusus',
#   'pariwisata',
#   'tanjung',
#   'lesung',
#   'banten'],
#  '824010': ['batas',
#   'paroki',
#   'santo',
#   'petrus',
#   'lubukbaja',
#   'jalan',
#   'yos',
#   'sudarso'],
#  '819672': ['tanah',
#   'siang',
#   'rupa',
#   'jalan',
#   'buat',
#   'zaman',
#   'jajah',
#   'hindia',
#   'belanda'],
#  '817018': ['pulo',
#   'geulis',
#   'capai',
#   'jalan',
#   'kaki',
#   'lewat',
#   'jembatan',
#   'hubung',
#   'tepi',
#   'sungai',
#   'ciliwung',
#   'belah',
#   'barat',
#   'lingkung',
#   'jalan',
#   'roda'],
#  '1053941': ['main',
#   'telanjang',
#   'dada',
#   'kena',
#   'pakai',
#   'perang',
#   'lindung',
#   'paha',
#   'betis',
#   'upa',
#   'celana',
#   'panjang',
#   'warna',
#   'putih',
#   'sarung',
#   'songke',
#   'songket',
#   'khas',
#   'manggarai'],
#  '1053936': ['hela',
#   'sarung',
#   'tutup',
#   'pinggang',
#   'hingga',
#   'kaki',
#   'baju',
#   'tipis',
#   'longgar',
#   'kain',
#   'muslin',
#   'lihat',
#   'payudara',
#   'leluklekuk',
#   'dada'],
#  '1053976': ['lung', 'kenal', 'bagai', 'sarung', 'pakai', 'kena', 'pinggang'],
#  '1053713': ['kayu',
#   'mahang',
#   'damar',
#   'banyak',
#   'manfaat',
#   'paling',
#   'bagai',
#   'sarung',
#   'alat',
#   'potong',
#   'kayu',
#   'bakar'],
#  '1053857': ['anton',
#   'gabrielle',
#   'alias',
#   'the',
#   'wonderboy',
#   'robertino',
#   'sang',
#   'juara',
#   'tinju',
#   'paksa',
#   'gantung',
#   'sarung',
#   'tinju'],
#  '1054017': ['sarung',
#   'pakai',
#   'komunitas',
#   'laut',
#   'semenanjung',
#   'malaya',
#   'dekat',
#   'sumatra',
#   'jawa'],
#  '1053863': ['sedang',
#   'video',
#   'game',
#   'pokemon',
#   'emerald',
#   'tampil',
#   'nyaris',
#   'sama',
#   'di',
#   'versi',
#   'serial',
#   'tv',
#   'pokemon',
#   'diamond',
#   'and',
#   'pearl',
#   'kali',
#   'ia',
#   'pakai',
#   'kemeja',
#   'warna',
#   'orange',
#   'lengan',
#   'sedikit',
#   'ubah',
#   'sarung',
#   'tangan',
#   'ia',
#   'pakai'],
#  '1053828': ['kain',
#   'sebut',
#   'kena',
#   'bagai',
#   'sarung',
#   'setinggi',
#   'dada',
#   'bagi',
#   'bahu',
#   'tutup',
#   'taba',
#   'huku'],
#  '1053569': ['sarung',
#   'muna',
#   'rupa',
#   'kain',
#   'tenun',
#   'khas',
#   'buat',
#   'suku',
#   'muna',
#   'sulawesi',
#   'tenggara'],
#  '1053988': ['beberapa',
#   'ahli',
#   'gemar',
#   'senjata',
#   'rujuk',
#   'sarung',
#   'gladius',
#   'kata',
#   'latin',
#   'vagina'],
#  '1006405': ['isyana',
#   'keluar',
#   'semua',
#   'pikir',
#   'publik',
#   'sebut',
#   'bagai',
#   'halu',
#   'dapat',
#   'ungkap',
#   'gema'],
#  '1004587': ['majelis',
#   'umum',
#   'serikat',
#   'bangsa',
#   'keluar',
#   'bagai',
#   'resolusi',
#   'kena',
#   'masalah',
#   'yang',
#   'angkat',
#   'judul',
#   'tanya',
#   'pulau',
#   'mayotte',
#   'komoro',
#   'tahun',
#   '1995'],
#  '1008067': ['lanjut',
#   'nokia',
#   'keluar',
#   'versi',
#   'beta',
#   'nokia',
#   '770',
#   'lengkap',
#   'sistem',
#   'operasi',
#   'internet',
#   'tablet',
#   'baru',
#   'sempurna',
#   '3',
#   'juni',
#   '2006'],
#  '1004006': ['detik',
#   'akhir',
#   'jelang',
#   'laksana',
#   'hukum',
#   'mati',
#   'atas',
#   'tiga',
#   'tuduh',
#   'kasus',
#   'poso',
#   'perintah',
#   'indonesia',
#   'keluar',
#   'perintah',
#   'tunda'],
#  '1005813': ['cendekiawan',
#   'keluar',
#   'bagai',
#   'alas',
#   'kena',
#   'tiada',
#   'sebut'],
#  '1004009': ['dewan',
#   'aman',
#   'pbb',
#   'gagal',
#   'keluar',
#   'resolusi',
#   'kutuk',
#   'serang',
#   'militer',
#   'israel',
#   'hadap',
#   'pos',
#   'pbb',
#   'khiam'],
#  '724669': ['lantai',
#   'dasar',
#   'fungsi',
#   'bagai',
#   'tempat',
#   'daftar',
#   'turun',
#   'ambil',
#   'bagasi',
#   'area',
#   'publik',
#   'karyawan'],
#  '729078': ['atheist',
#   'alliance',
#   'international',
#   'mulai',
#   'kampanye',
#   'alexander',
#   'nyata',
#   'kasus',
#   'sorot',
#   'hak',
#   'dasar',
#   'bebas',
#   'ekspres',
#   'yakin',
#   'diskriminasi',
#   'hadap',
#   'para',
#   'ateis',
#   'utama',
#   'negara',
#   'islam'],
#  '726198': ['sdn',
#   'jati',
#   '07',
#   'pagi',
#   'rupa',
#   'buah',
#   'sekolah',
#   'dasar',
#   'negeri',
#   'letak',
#   'jakarta',
#   'timur',
#   'indonesia'],
#  '725396': ['sd',
#   'kartika',
#   'x',
#   '7',
#   'pagi',
#   'rupa',
#   'buah',
#   'sekolah',
#   'dasar',
#   'swasta',
#   'letak',
#   'jakarta',
#   'timur',
#   'indonesia'],
#  '727103': ['lama',
#   'perintah',
#   'kazimierz',
#   'meciptakan',
#   'buah',
#   'lambang',
#   'kenal',
#   'polandia',
#   'ia',
#   'promosi',
#   'bangsawan',
#   'darat',
#   'atas',
#   'druzyna',
#   'bagai',
#   'dasar',
#   'kuasa'],
#  '726488': ['sdn',
#   'jatinegara',
#   '13',
#   'sekolah',
#   'dasar',
#   'negeri',
#   'letak',
#   'buar',
#   'i',
#   'rt',
#   '006',
#   '08',
#   'jakarta',
#   'timur',
#   'indonesia'],
#  '722785': ['proses',
#   'selesai',
#   'konstruksi',
#   'fondasi',
#   'dasar',
#   'monumen',
#   'makan',
#   'waktu',
#   'lama',
#   '2',
#   'tahun',
#   'kerja'],
#  '728626': ['2010',
#   'deklarasi',
#   'asosiasi',
#   'ekonomi',
#   'politik',
#   'indonesia',
#   'aepi',
#   'buah',
#   'asosiasi',
#   'tuju',
#   'juang',
#   'laksana',
#   'pasal',
#   '33',
#   'undang',
#   'undang',
#   'dasar',
#   'uud',
#   '1945'],
#  '716950': ['dilthey',
#   'formulasi',
#   'metodologi',
#   'dasar',
#   'ilmu',
#   'manusia',
#   'aku',
#   'khas',
#   'sifat',
#   'verstehen'],
#  '792440': ['eksistensi',
#   'bmt',
#   'jalan',
#   'lama',
#   'tidak',
#   'sematamata',
#   'kejar',
#   'untung',
#   'dunia',
#   'tetapi',
#   'perhati',
#   'suatu',
#   'transaksi',
#   'halal',
#   'haram'],
#  '800085': ['sama',
#   'empat',
#   'murid',
#   'kyai',
#   'agung',
#   'barata',
#   'pasang',
#   'rajah',
#   'kenal',
#   'nama',
#   'tulak',
#   'balak',
#   'pasopati',
#   'harap',
#   'dukuh',
#   'alas',
#   'tuwo',
#   'jadi',
#   'dukuh',
#   'lestari',
#   'nyaman',
#   'aman',
#   'maju'],
#  '799703': ['bafo',
#   'aji',
#   'tak',
#   'suka',
#   'namun',
#   'pilih',
#   'harap',
#   'akan',
#   'datang',
#   'bantu',
#   'amerika'],
#  '800991': ['kampung',
#   'seks',
#   'rasio',
#   'besar',
#   'kampung',
#   'harap',
#   'jaya',
#   'seks',
#   'rasio',
#   '109',
#   '11',
#   'yang',
#   'rendah',
#   'kampung',
#   'demisa',
#   'sp',
#   'iii',
#   'firo',
#   'seksrasio',
#   '1'],
#  '801891': ['egoisme',
#   'rendah',
#   'taruh',
#   'percaya',
#   'buta',
#   'hadap',
#   'segala',
#   'harap',
#   'janji',
#   'muluk',
#   'tuan'],
#  '801295': ['tzu',
#   'chi',
#   'kini',
#   'pusat',
#   'hualien',
#   'taiwan',
#   'diri',
#   'master',
#   'cheng',
#   'yen',
#   'orang',
#   'biksuni',
#   '14',
#   'april',
#   '1966',
#   'dia',
#   'inspirasi',
#   'guru',
#   'sekaligus',
#   'mentor',
#   'master',
#   'yin',
#   'shun',
#   'yin',
#   'shun',
#   'dao',
#   'shi',
#   'harap',
#   'besar',
#   'ajar',
#   'buddha',
#   'demi',
#   'semua',
#   'makhluk'],
#  '800874': ['ultimatum',
#   'britania',
#   '1890',
#   'akhir',
#   'harap',
#   'portugal',
#   'capai',
#   'tuju',
#   'rusak',
#   'wibawa',
#   'monarki',
#   'portugal',
#   'kuat',
#   'gera',
#   'republikanisme'],
#  '926111': ['1519',
#   'juan',
#   'sebastian',
#   'elcano',
#   'selesai',
#   'jelajah',
#   'spanyol',
#   'magellan',
#   'layar',
#   'seluruh',
#   'dunia'],
#  '970242': ['godwin',
#   'lapor',
#   'hasil',
#   'tangkap',
#   'alfred',
#   'sendiri',
#   'telah',
#   'tipu',
#   'pura',
#   'jadi',
#   'sekutu',
#   'kemudian',
#   'serah',
#   'pasu',
#   'harold',
#   'i'],
#  '969241': ['sedang',
#   'nama',
#   'ilmiah',
#   'achantophis',
#   'asal',
#   'bahasa',
#   'greeka',
#   'achantos',
#   'duri',
#   'ophis',
#   'ular',
#   'acu',
#   'ekor',
#   'kecil',
#   'tajam',
#   'guna',
#   'bagai',
#   'umpan',
#   'tangkap',
#   'mangsa'],
#  '970010': ['meksipun',
#   'peter',
#   'csak',
#   'bebas',
#   'raja',
#   'ibunda',
#   'gutkeled',
#   'koszegi',
#   'tangkap',
#   'adik',
#   'lazlo',
#   'andras',
#   'bawa',
#   'slavonia'],
#  '1022169': ['ini',
#   'sttl',
#   'ylh',
#   'sedang',
#   'susun',
#   'borang',
#   'akreditasi',
#   'segera',
#   'sampai',
#   'badan',
#   'akreditasi',
#   'nasional',
#   'ban',
#   'evaluasi',
#   'tuju',
#   'peringkat',
#   'akreditasi',
#   'a',
#   'rupa',
#   'suatu',
#   'peringkat',
#   'akreditasi',
#   'tinggi'],
#  '1022550': ['tinggal',
#   'kabupaten',
#   'purwodadi',
#   'tuju',
#   'arah',
#   'barat',
#   'akhir',
#   'prajurit',
#   'pangeran',
#   'diponegoro',
#   'suatu',
#   'tempat',
#   'batu',
#   'sangat',
#   'strategis',
#   'sembunyi',
#   'susun',
#   'kuat',
#   'baru'],
#  '1086336': ['ion',
#   'ortonitrat',
#   'tetrahedral',
#   'panjang',
#   'ikat',
#   'no',
#   '139',
#   'pm',
#   'tiba',
#   'pendek',
#   'tunjuk',
#   'interaksi',
#   'polar',
#   'pendek',
#   'ikat',
#   'orbital',
#   'd',
#   'milik',
#   'energi',
#   'terlalu',
#   'tinggi',
#   'libat'],
#  '1095740': ['letus',
#   'lanjut',
#   'terlalu',
#   'kuat',
#   'awan',
#   'naik',
#   'hingga',
#   'tinggi',
#   'seperti',
#   'namun',
#   'tidak',
#   'cukup',
#   'tinggi',
#   'hembus',
#   'lintas',
#   'eropa'],
#  '1088526': ['rupa',
#   'orang',
#   'putri',
#   'rus',
#   'kiev',
#   'asal',
#   'dinasti',
#   'rurikid',
#   'oleh',
#   'nikah',
#   'adipati',
#   'wielkopolska',
#   'sejak',
#   'tahun',
#   '1173',
#   'adipati',
#   'tinggi',
#   'polandia'],
#  '1082208': ['haber',
#   'bosch',
#   'akhir',
#   'anugerah',
#   'harga',
#   'nobel',
#   'tahun',
#   '1918',
#   '1931',
#   'atas',
#   'karya',
#   'dalam',
#   'tanggulang',
#   'masalah',
#   'kimia',
#   'teknik',
#   'teknologi',
#   'alir',
#   'sambung',
#   'tekan',
#   'tinggi',
#   'skala',
#   'besar'],
#  '162603': ['tahun',
#   '2002',
#   'mufti',
#   'besar',
#   'arab',
#   'saudi',
#   'abdul',
#   'aziz',
#   'bin',
#   'abdullah',
#   'alu',
#   'syaikh',
#   'bahwa',
#   'islam',
#   'wajib',
#   'usaha',
#   'hormat',
#   'kontrak',
#   'dan',
#   'intimidasi',
#   'peras',
#   'ancam',
#   'kerja'],
#  '167178': ['besar',
#   'jadi',
#   'konsentrasi',
#   'negara',
#   'kembang',
#   'asia',
#   'timur',
#   'tengah',
#   'afrika',
#   'utara'],
#  '190623': ['deposit',
#   'besar',
#   'adalah',
#   'deposit',
#   'logam',
#   'golong',
#   'platina',
#   'merensky',
#   'reef',
#   'sekitar',
#   'bushveld',
#   'igneous',
#   'complex',
#   'afrika',
#   'selatan'],
#  '137157': ['kelompok',
#   'selatan',
#   'masuk',
#   'nikobar',
#   'besar',
#   '1045',
#   'km',
#   'nicobar',
#   'kecil',
#   '157',
#   'km',
#   'kondul',
#   '4',
#   'km',
#   'and',
#   'pulomilo',
#   '1',
#   'km',
#   'pulau',
#   'kecil',
#   'meroe',
#   'trak',
#   'treis',
#   'menchal',
#   'cubra',
#   'pigeon',
#   'megapod',
#   'hun'],
#  '337435': ['umum',
#   'ukur',
#   'besar',
#   '25',
#   'mm',
#   'biasa',
#   'warna',
#   'coklat',
#   'hitam'],
#  '832409': ['telah',
#   'akuisisi',
#   'saham',
#   'milik',
#   'spacetoon',
#   'net',
#   'akhir',
#   'sabtu',
#   '18',
#   'mei',
#   '2013',
#   'siar',
#   'spacetoon',
#   'jaring',
#   'terrestrial',
#   'hilang',
#   'ganti',
#   'net',
#   'mulai',
#   'siar',
#   'perdana',
#   'guna',
#   'frekuensi',
#   'milik',
#   'spacetoon',
#   'seluruh',
#   'mantan',
#   'jaring',
#   'frekuensi',
#   'spacetoon',
#   'indonesia'],
#  '839188': ['blok',
#   'acara',
#   'mulai',
#   'siar',
#   'hari',
#   'senin',
#   '17',
#   'maret',
#   '1997',
#   'awal',
#   'ganti',
#   'power',
#   'zon',
#   'inkarnasi',
#   'blok',
#   'super',
#   'adventures',
#   'yang',
#   'telah',
#   'jadi',
#   'pokok',
#   'jaring',
#   'sejak',
#   '1',
#   'oktober',
#   '1992'],
#  '837039': ['prva',
#   'prva',
#   'srpska',
#   'televizija',
#   'televisi',
#   'serbia',
#   'pertama',
#   'jaring',
#   'televisi',
#   'komersial',
#   'serbia',
#   'cakup',
#   'nasional'],
#  '835153': ['salur',
#   'rupa',
#   'jaring',
#   'televisi',
#   'satelit',
#   'berita',
#   'di',
#   'mesir',
#   'salur',
#   'satelit',
#   'arab',
#   'pertama',
#   'siar',
#   'program',
#   'bahasa',
#   'asing',
#   'inggris',
#   'perancis',
#   'ibrani'],
#  '835884': ['sel',
#   't',
#   'telah',
#   'sintesis',
#   'kelenjar',
#   'timus',
#   'sebut',
#   'sel',
#   't',
#   'cd4',
#   'naif',
#   'bahasa',
#   'inggris',
#   'naive',
#   't',
#   'cell',
#   'bawa',
#   'sirkulasi',
#   'darah',
#   'hingga',
#   'masuk',
#   'limpa',
#   'migrasi',
#   'dalam',
#   'jaring',
#   'limfatik',
#   'kemudian',
#   'migrasi',
#   'ke',
#   'dalam',
#   'sirkulasi',
#   'darah',
#   'hingga',
#   'suatu',
#   'jadi',
#   'stimulasi',
#   'antigen',
#   'dengat',
#   'ikat',
#   'molekul',
#   'mhc',
#   'kelas',
#   'ii'],
#  '964212': ['awal',
#   'tahun',
#   '2005',
#   'tim',
#   'jual',
#   'midland',
#   'group',
#   'tetap',
#   'bawa',
#   'nama',
#   'jordan',
#   'balap',
#   'akhir',
#   'musim',
#   'kemudian',
#   'ganti',
#   'nama',
#   'tim',
#   'jadi',
#   'mf1',
#   'racing',
#   'mulai',
#   'musim',
#   'balap',
#   '2006'],
#  '952828': ['tahun',
#   'ikut',
#   'lippi',
#   'angkat',
#   'bagai',
#   'latih',
#   'kepala',
#   'italia',
#   'bawa',
#   'akhir',
#   'salah',
#   'satu',
#   'periode',
#   'manajerial',
#   'paling',
#   'produktif',
#   'sejarah',
#   'juventus'],
#  '965243': ['2',
#   'november',
#   '1960',
#   'narada',
#   'maha',
#   'thera',
#   'bawa',
#   'pohon',
#   'bodhi',
#   'candi',
#   'thich',
#   'ca',
#   'phat',
#   'vietnam',
#   'selatan',
#   'buat',
#   'banyak',
#   'kunjung',
#   'negara',
#   'sebut',
#   'lama',
#   'tahun',
#   '1960an'],
#  '1010775': ['kaisar',
#   'asyur',
#   'sibuk',
#   'perang',
#   'saudara',
#   'revolusi',
#   'hadap',
#   'tahta',
#   'raja',
#   'psamtik',
#   'putus',
#   'hubung',
#   'orang',
#   'asyur',
#   'ikat',
#   'hubung',
#   'gyges',
#   'raja',
#   'lydia',
#   'sewa',
#   'tentara',
#   'bayar',
#   'caria',
#   'yunani',
#   'tahan',
#   'serang',
#   'asyur'],
#  '1010515': ['dua',
#   'saran',
#   'yang',
#   'ikat',
#   'siapa',
#   'hanya',
#   'makna',
#   'sekadar',
#   'guyon',
#   'tidak',
#   'timbul',
#   'ruwet',
#   'siapa'],
#  '1010477': ['patangatuspatangpuluh',
#   'ikang',
#   'cakakala',
#   '440',
#   's',
#   '518',
#   'm',
#   'raja',
#   'pali',
#   'ikat',
#   'sahabat',
#   'raja',
#   'cina',
#   'raja',
#   'cina'],
#  '1010291': ['literatur',
#   'fiqih',
#   'ahlalhall',
#   'wa',
#   'alaqd',
#   'orang',
#   'penuh',
#   'syarat',
#   'ikat',
#   'bubar',
#   'buat',
#   'putus'],
#  '1010239': ['pusat',
#   'hg',
#   'ikat',
#   'ikat',
#   'rangkap',
#   'tiga',
#   'cc',
#   'kemudian',
#   'serang',
#   'air'],
#  '1010165': ['asam', 'ikat', 'logam', 'racun', 'per', 'alumunium', 'danau'],
#  '1025728': ['umum', 'nilai', '9', '81', 'm', 's2', 'mudah'],
#  '1036881': ['sektor',
#   'tani',
#   'beri',
#   'kontribusi',
#   'besar',
#   '45',
#   'persen',
#   'nila',
#   'rp515',
#   '2',
#   'miliar'],
#  '1024268': ['kandung',
#   'nilai',
#   'hidup',
#   'unsur',
#   'sama',
#   'sosial',
#   'serasi',
#   'lingkung',
#   'hidup'],
#  '1033210': ['juluk',
#   'narogong',
#   'milik',
#   'usaha',
#   'konveksi',
#   'jalan',
#   'narogong',
#   'bekas',
#   'andi',
#   'tuntut',
#   'jaksa',
#   'tuntut',
#   'umum',
#   'kpk',
#   'sidang',
#   'agenda',
#   'baca',
#   'tuntut',
#   '7',
#   'desember',
#   '2017',
#   'upa',
#   'hukum',
#   'penjara',
#   'lama',
#   '8',
#   'tahun',
#   'denda',
#   'besar',
#   'rp',
#   '1',
#   'miliar',
#   'subsider',
#   '6',
#   'bulan',
#   'penjara',
#   'wajib',
#   'bayar',
#   'uang',
#   'ganti',
#   'nilai',
#   'usd',
#   '2',
#   '1',
#   'juta'],
#  '1033865': ['jenis',
#   'definisi',
#   'sebut',
#   'ipv4addr',
#   'x',
#   'tafsir',
#   'uint32',
#   'nilai',
#   'x',
#   'bagai',
#   'alamat',
#   'ip'],
#  '1029209': ['resmi',
#   'taman',
#   'bal',
#   'kemudian',
#   'ikut',
#   'wujud',
#   'taman',
#   'dunia',
#   'islam',
#   'luas',
#   '6',
#   '100',
#   'm2',
#   'nilai',
#   'total',
#   'proyek',
#   '2',
#   '3',
#   'juta',
#   'euro',
#   'di',
#   'resmi',
#   'tanggal',
#   '7',
#   'july',
#   '2005'],
#  '1026050': ['norma', 'nilai', 'kisar', '4', 'a', 'baik', '0', 'e', 'gagal'],
#  '1037159': ['tingkat',
#   'didik',
#   'tinggi',
#   'ip',
#   'hitung',
#   'bagai',
#   'rerata',
#   'norma',
#   'nilai',
#   'oleh',
#   'orang',
#   'mahasiswa',
#   'mata',
#   'kuliah',
#   'sebut',
#   'beri',
#   'bobot',
#   'angka',
#   'kredit'],
#  '826303': ['paroki',
#   'rantau',
#   'pulut',
#   'masuk',
#   'salah',
#   'satu',
#   'paroki',
#   'di',
#   'kalimantan',
#   'tengah',
#   'pusat',
#   'paroki',
#   'jarak',
#   '6',
#   'jam',
#   'jalan',
#   'darat',
#   'kota',
#   'sampit',
#   '11',
#   'jam',
#   'jalan',
#   'darat',
#   'dari',
#   'palangka',
#   'raya',
#   'via',
#   'sampit'],
#  '831228': ['diri',
#   'band',
#   'nama',
#   'jam',
#   'rock',
#   'sama',
#   'ricky',
#   'tedy',
#   'bass',
#   'budi',
#   'haryono',
#   'mantan',
#   'drumer',
#   'gigi',
#   'tiket',
#   'tak',
#   'lama',
#   'kemudian',
#   'tinggal'],
#  '827160': ['akibat',
#   'aksi',
#   'teroris',
#   'presiden',
#   'ri',
#   'tekan',
#   'amerika',
#   'ultimatum',
#   'dalam',
#   '7',
#   'kali',
#   '24',
#   'jam',
#   'perintah',
#   'ri',
#   'hasil',
#   'keluar',
#   'kelly',
#   'pulau',
#   'pasu',
#   'khusus',
#   'navy',
#   'seal',
#   'amerika',
#   'ambil',
#   'alih',
#   'serang'],
#  '826423': ['sore',
#   'hari',
#   'jam',
#   'satu',
#   'siang',
#   'atas',
#   'biasa',
#   'kutasari',
#   'pasar',
#   'tobong',
#   'akan',
#   'sulit',
#   'sekali',
#   'jumpa',
#   'kol',
#   'kuning',
#   'alternatif',
#   'akan',
#   'rogok',
#   'kocek',
#   'sekitar',
#   '3000',
#   '4000',
#   'perak',
#   'sampai',
#   'di',
#   'candinata'],
#  '828629': ['usaha',
#   'listrik',
#   'negara',
#   'nyata',
#   'listrik',
#   'pulih',
#   'bagi',
#   'besar',
#   'lombok',
#   'beberapa',
#   'jam',
#   'gempa',
#   '25',
#   'listrik',
#   'pulau',
#   'padam'],
#  '830509': ['satu',
#   'jam',
#   'adalah',
#   'film',
#   'drama',
#   'indonesia',
#   'rilis',
#   'tanggal',
#   '7',
#   'oktober',
#   '2010'],
#  '825131': ['misal',
#   'orang',
#   'tenaga',
#   'ajar',
#   'honorer',
#   'punya',
#   'beban',
#   'ajar',
#   'jam',
#   'minggu',
#   'honor',
#   'besar',
#   'rp',
#   '2',
#   '500',
#   'jam',
#   'dalam',
#   'masa',
#   'empat',
#   'minggu',
#   'bulan',
#   'hanya',
#   'dapat',
#   'honor',
#   'rp',
#   '20',
#   '000'],
#  '830715': ['wombat',
#   'kukang',
#   'koala',
#   'milik',
#   'tingkat',
#   'metabolisme',
#   'rendah',
#   'ekor',
#   'mamalia',
#   'istirahat',
#   'gerak',
#   '20',
#   'jam',
#   'hari',
#   'banyak',
#   'waktu',
#   'sebut',
#   'untuk',
#   'tidur'],
#  '825878': ['satelit',
#   'msg',
#   'diameter',
#   '3',
#   '2',
#   'm',
#   'tinggi',
#   '2',
#   '4',
#   'm',
#   'putar',
#   'lawan',
#   'arah',
#   'jarum',
#   'jam',
#   'cepat',
#   '100',
#   'rpm',
#   'tinggi',
#   '36',
#   '000',
#   'km'],
#  '827506': ['sama',
#   '1400',
#   'tawan',
#   'dapat',
#   'tugas',
#   'buka',
#   'hutan',
#   'suatu',
#   'gunung',
#   'kabut',
#   'pecah',
#   'batu',
#   'buat',
#   'barak',
#   'salur',
#   'air',
#   'listrik',
#   'bengkel',
#   'lain',
#   'lama',
#   '7',
#   'hari',
#   'minggu',
#   '14',
#   'jam',
#   'hari'],
#  '831099': ['cikelet',
#   'belah',
#   'selatan',
#   'pusat',
#   'kota',
#   'garut',
#   'biasa',
#   'sebut',
#   'garut',
#   'selatan',
#   'garsel',
#   'garsela',
#   'jarak',
#   'tempuh',
#   'waktu',
#   '3',
#   '5',
#   'jam',
#   'jalan',
#   'sekitar',
#   '88',
#   'km',
#   'garut',
#   'kota'],
#  '827345': ['luar',
#   'jam',
#   'sekolah',
#   'sebut',
#   'siswa',
#   'interaksi',
#   'keluarga',
#   'masyarakat'],
#  '825471': ['tiongkok',
#   'jam',
#   'tayang',
#   'utama',
#   'pada',
#   'pukul',
#   '19',
#   '00',
#   'hingga',
#   '22',
#   '00',
#   'biasa',
#   'sebut',
#   'bagai',
#   'golden',
#   'time'],
#  '825788': ['awal',
#   'karier',
#   'super7',
#   'james',
#   'undur',
#   'diri',
#   'ingin',
#   'fokus',
#   'sekolah',
#   'tidak',
#   'mau',
#   'ganggu',
#   'jam',
#   'sekolah'],
#  '826205': ['waktu',
#   'ajar',
#   'wajib',
#   'sebut',
#   'hari',
#   'rabu',
#   'kamis',
#   'dapat',
#   'tambah',
#   'ajar',
#   'banyak',
#   '4',
#   'jam',
#   'ajar',
#   'hingga',
#   'pukul',
#   '16',
#   '00',
#   'wib'],
#  '828699': ['meski',
#   'rupa',
#   'wilayah',
#   'huni',
#   'al',
#   'karama',
#   'kenal',
#   'dubai',
#   'bagai',
#   'pusat',
#   'furnitur',
#   'murah',
#   'jual',
#   'barang',
#   'merek',
#   'tas',
#   'tangan',
#   'jam',
#   'tangan'],
#  '831767': ['sabtu',
#   '30',
#   'juni',
#   '1923',
#   'dies',
#   'natalis',
#   'ke3',
#   'th',
#   'bandung',
#   'di',
#   'aula',
#   'barakgebouw',
#   'a',
#   'mulai',
#   'jam',
#   '10',
#   '00',
#   'iring',
#   'lagu',
#   'di',
#   'mana',
#   'hadir',
#   'majelis',
#   'kurator',
#   'direktur',
#   'didik',
#   'agama',
#   'residen',
#   'bupati',
#   'jabat',
#   'instansi',
#   'perintah',
#   'sipil',
#   'militer',
#   'kalang',
#   'swasta',
#   'undang'],
#  '831128': ['tengah', 'jam', 'kemudian', 'tidak', 'mungkir', 'mati'],
#  '827696': ['tuju',
#   'desa',
#   'sawarna',
#   'wisatawan',
#   'habis',
#   'waktu',
#   '67',
#   'jam',
#   'jalan',
#   'transportasi',
#   'pribadi',
#   '910',
#   'jam',
#   'apabila',
#   'guna',
#   'transportasi',
#   'umum'],
#  '830669': ['sinetron',
#   'tayang',
#   'ulang',
#   'antv',
#   'tiap',
#   'hari',
#   'jam',
#   '04',
#   '00',
#   'pagi',
#   'season'],
#  '827764': ['jam', 'kerja', 'antara', 'pukul', '13', 'subuh'],
#  '828344': ['matius',
#   '8',
#   '13',
#   'milik',
#   'interpolasi',
#   'tanda',
#   'tanda',
#   'bintang',
#   'ketika',
#   'perwira',
#   'kembali',
#   'rumah',
#   'jam',
#   'ia',
#   'temu',
#   'budak',
#   'baik'],
#  '830805': ['bingung',
#   'sering',
#   'muncul',
#   'ajar',
#   'efek',
#   'adalah',
#   'efek',
#   'laku',
#   'arah',
#   'a',
#   'bahwa',
#   'jam',
#   'b',
#   'detak',
#   'lebih',
#   'lambat',
#   'efek',
#   'maka',
#   'b',
#   'akan',
#   'bahwa',
#   'jam',
#   'amat',
#   'a',
#   'detak',
#   'lebih',
#   'lambat'],
#  '831749': ['kota',
#   'arah',
#   'jarum',
#   'jam',
#   'utara',
#   'bushwick',
#   'brooklyn',
#   'flatlands',
#   'gravesend',
#   'new',
#   'utrecht',
#   'flatbush',
#   'tengah'],
#  '831509': ['tanggal',
#   'pilih',
#   'tepat',
#   'aksi',
#   'rupa',
#   'laku',
#   'situs',
#   'seperti',
#   'reddit',
#   'langsung',
#   'lama',
#   '24',
#   'jam',
#   '18',
#   'januari',
#   'pukul',
#   '05',
#   '00',
#   'utc'],
#  '914085': ['ukraina',
#   'merdeka',
#   'dana',
#   'kelola',
#   'zona',
#   'awal',
#   'sangat',
#   'batas',
#   'zona',
#   'sebut',
#   'jaga',
#   'ketat',
#   'huni',
#   'huni',
#   'liar'],
#  '913962': ['puisi',
#   'buku',
#   'mati',
#   'kecil',
#   'kartosoewirjo',
#   'cipta',
#   'batas',
#   'wilayah',
#   'cukup',
#   'ketat',
#   'aspek',
#   'data',
#   'sejarah',
#   'baik',
#   'dokumentasi',
#   'foto',
#   'data',
#   'tulis',
#   'ujar',
#   'lisan'],
#  '913933': ['negosiasi',
#   'simpul',
#   'tahun',
#   '1992',
#   'ditandatanganinya',
#   'janji',
#   'ecas',
#   'dagang',
#   'pesawat',
#   'sipil',
#   'besar',
#   'tetap',
#   'disiplin',
#   'dukung',
#   'perintah',
#   'dua',
#   'sisi',
#   'atlantik',
#   'cara',
#   'signifikan',
#   'lebih',
#   'ketat',
#   'atur',
#   'organisasi',
#   'dagang',
#   'dunia',
#   'wto',
#   'relevan'],
#  '913765': ['pesawat',
#   'harus',
#   'ikut',
#   'skedul',
#   'maitenance',
#   'ketat',
#   'jamin',
#   'semua',
#   'sensor',
#   'servo',
#   'kerja',
#   'baik'],
#  '914277': ['main',
#   'dapat',
#   'lewat',
#   'tiap',
#   'garis',
#   'jaga',
#   'ketat',
#   'lawan'],
#  '914453': ['elektron',
#   'ada',
#   'padat',
#   'konduktor',
#   'sendiri',
#   'rupa',
#   'kuasipartikel',
#   'kungkung',
#   'cara',
#   'ketat',
#   'temperatur',
#   'dekat',
#   'nol',
#   'absolut',
#   'perilaku',
#   'olah',
#   'belah',
#   'lebih',
#   'jauh',
#   'jadi',
#   'kuasipartikel',
#   'spinon',
#   'holon'],
#  '914611': ['anomi',
#   'jadi',
#   'ketika',
#   'disjungsi',
#   'ketat',
#   'norma',
#   'tuju',
#   'cultural',
#   'struktur',
#   'cara',
#   'sosial',
#   'anggota',
#   'kelompok',
#   'tindak',
#   'turut',
#   'norma',
#   'tuju',
#   'sebut'],
#  '914590': ['semangat',
#   'hormat',
#   'adonai',
#   'percaya',
#   'hukum',
#   'kekal',
#   'jaga',
#   'ketat',
#   'suci',
#   'ajar'],
#  '913773': ['semua',
#   'seleksi',
#   'ketat',
#   'mulai',
#   'iq',
#   'kesemaptaan',
#   'ahli',
#   'spesialisasi',
#   'militer',
#   'butuh',
#   'sehat'],
#  '913851': ['itu', 'kepala', 'komite', 'tempat', 'awas', 'ketat', 'rakyat'],
#  '913754': ['bijak',
#   'ikonoklasme',
#   'leo',
#   'terus',
#   'konstantin',
#   'v',
#   'baru',
#   'kampanye',
#   'sembah',
#   'berhala',
#   'tahun',
#   '754',
#   'lebih',
#   'ketat',
#   'banding'],
#  '913758': ['atur',
#   'lebih',
#   'ketat',
#   'terap',
#   'negara',
#   'aju',
#   'pinjam',
#   'dmi'],
#  '914414': ['negara',
#   'sumbu',
#   'gerak',
#   'seluruh',
#   'elemen',
#   'politik',
#   'suatu',
#   'jalin',
#   'rasional',
#   'kontrol',
#   'cara',
#   'ketat',
#   'guna',
#   'instrumen',
#   'kuasa'],
#  '914150': ['turut',
#   'human',
#   'rights',
#   'watch',
#   'meski',
#   'kuba',
#   'cara',
#   'resmi',
#   'ateis',
#   '1992',
#   'ini',
#   'mungkin',
#   'peluang',
#   'lebih',
#   'besar',
#   'ekspresi',
#   'agama',
#   'jadi',
#   'tahun',
#   'mungkin',
#   'beberapa',
#   'kelompok',
#   'manusia',
#   'yang',
#   'jalan',
#   'agama',
#   'operasi',
#   'perintah',
#   'tahan',
#   'kontrol',
#   'ketat',
#   'lembaga',
#   'agama',
#   'kelompok',
#   'afiliasi',
#   'dan',
#   'anut',
#   'alir',
#   'percaya'],
#  '914370': ['demikian',
#   'sambung',
#   'ketat',
#   'gabung',
#   'sama',
#   'sitoskeleton',
#   'sel',
#   'dekat'],
#  '914228': ['jalur',
#   'rel',
#   'buat',
#   'jepang',
#   'hindar',
#   'kota',
#   'padang',
#   'samudera',
#   'hindia',
#   'jaga',
#   'ketat',
#   'kapal',
#   'perang',
#   'sekutu'],
#  '914757': ['lepas',
#   'perang',
#   'diponegoro',
#   'selesai',
#   '1830',
#   'perintah',
#   'nagari',
#   'ada',
#   'tangan',
#   'patih',
#   'dalem',
#   'kontrol',
#   'cara',
#   'ketat',
#   'sekali',
#   'belanda',
#   'cegah',
#   'jadi',
#   'ronta'],
#  '914289': ['schilling',
#   'austria',
#   'salah',
#   'satu',
#   'mata',
#   'uang',
#   'eropa',
#   'cukup',
#   'stabil',
#   'nila',
#   'tinggi',
#   'bijak',
#   'moneter',
#   'ketat',
#   'perintah',
#   'austria',
#   'bank',
#   'sentral'],
#  '913682': ['spetsnaz',
#   'milik',
#   'reputasi',
#   'segani',
#   'kalang',
#   'militer',
#   'dunia',
#   'standar',
#   'latih',
#   'golong',
#   'sangat',
#   'keras',
#   'utama',
#   'spetsnaz',
#   'militer',
#   'meski',
#   'unit',
#   'kgb',
#   'fsb',
#   'mvd',
#   'tetap',
#   'standar',
#   'golong',
#   'ketat',
#   'keras',
#   'latih',
#   'rekrut',
#   'personil'],
#  '914314': ['artikel',
#   'sebut',
#   'lapor',
#   'belum',
#   'lama',
#   'perang',
#   'dunia',
#   'ii',
#   'the',
#   'times',
#   'terap',
#   'bijak',
#   'ketat',
#   'lapor',
#   'berita',
#   'editorial',
#   'minimal',
#   'lapor',
#   'kena',
#   'holocaust'],
#  '913958': ['michael',
#   'bujuk',
#   'billy',
#   'senang',
#   'senang',
#   'dia',
#   'pakai',
#   'pakai',
#   'wanita',
#   'remeh',
#   'suatu',
#   'halang',
#   'ketat',
#   'masyarakat',
#   'kelas',
#   'kerja',
#   'expressing',
#   'yourself'],
#  '913957': ['invertasi',
#   'portfolio',
#   'sebut',
#   'cukup',
#   'ketat',
#   'dana',
#   'fbr',
#   'fokus',
#   'akre',
#   'seringkali',
#   'punya',
#   '2',
#   'hingga',
#   '3',
#   'lusin',
#   'dana',
#   'ranking',
#   '10',
#   'baik',
#   'diri',
#   '75',
#   'total',
#   'aset'],
#  '914015': ['timbang',
#   'sedang',
#   'di',
#   'tempat',
#   'lubang',
#   'gabung',
#   'bagi',
#   'skala',
#   'hasil',
#   'koneksi',
#   'bentuk',
#   'ketat',
#   'bushing',
#   'gelang'],
#  '913893': ['inisiatif',
#   'definisi',
#   'cara',
#   'ketat',
#   'karya',
#   'izin',
#   'drama',
#   'musik',
#   'tari',
#   'dan',
#   'seni',
#   'masuk',
#   'larang',
#   'langsung',
#   'karya',
#   'tidak',
#   'tuju'],
#  '913946': ['dik',
#   'dua',
#   'orang',
#   'tua',
#   'keras',
#   'disiplin',
#   'tinggi',
#   'juga',
#   'pengajaranyang',
#   'ketat',
#   'asuh',
#   'penuh',
#   'perhati',
#   'gembleng',
#   'gang',
#   'prinsip',
#   'hidup',
#   'agama',
#   'kyai',
#   'haji',
#   'sukri',
#   'sutan',
#   'hasan',
#   'halim'],
#  '943537': ['lukis',
#   'dinding',
#   'goa',
#   'di',
#   'dinding',
#   'karang',
#   'antara',
#   'yang',
#   'upa',
#   'cap',
#   'tangan',
#   'babi',
#   'rusa',
#   'burung',
#   'manusia',
#   'perahu',
#   'lambang',
#   'matahari',
#   'lukis',
#   'mata',
#   'bagai'],
#  '942696': ['mungkin',
#   'nama',
#   'narmada',
#   'untuk',
#   'nama',
#   'nama',
#   'mata',
#   'air',
#   'bentuk',
#   'beberapa',
#   'kolam',
#   'buah',
#   'sungai',
#   'tempat',
#   'sebut'],
#  '948680': ['larut',
#   'konsentrasi',
#   'tinggi',
#   'sebab',
#   'luka',
#   'mata',
#   'parah'],
#  '946210': ['apabila',
#   'ada',
#   'sinar',
#   'sumber',
#   'cahaya',
#   'pantul',
#   'suatu',
#   'benda',
#   'kemudian',
#   'tiba',
#   'mata',
#   'benda',
#   'sebut',
#   'kata',
#   'lihat'],
#  '944016': ['semua',
#   'jenis',
#   'kucing',
#   'siam',
#   'milik',
#   'pola',
#   'warna',
#   'bulu',
#   'sama',
#   'mata',
#   'warna',
#   'biru'],
#  '950617': ['ngaren',
#   'letak',
#   'sisi',
#   'utara',
#   'camat',
#   'ngadirejo',
#   'mata',
#   'cahari',
#   'duduk',
#   'dominasi',
#   'oleh',
#   'bidang',
#   'tani'],
#  '950959': ['awal',
#   'abad',
#   'ke8',
#   'sceat',
#   'rupa',
#   'mata',
#   'uang',
#   'pertama',
#   'edar'],
#  '946059': ['di',
#   'mata',
#   'gerilyawan',
#   'tiga',
#   'lebih',
#   'sikap',
#   'bagai',
#   'kepala',
#   'suku',
#   'otoriter',
#   'ketimbang',
#   'pimpin',
#   'pasu',
#   'lawan',
#   'ahli',
#   'atur',
#   'strategi',
#   'perang'],
#  '944303': ['daruma', 'jual', 'dua', 'belah', 'mata', 'belum', 'gambar'],
#  '946751': ['itu',
#   'perintah',
#   'maksud',
#   'keluar',
#   'mata',
#   'uang',
#   'baru',
#   'sebut',
#   'kenkon',
#   'tsuho',
#   'surat',
#   'perintah',
#   'itu',
#   'keluar',
#   'hingga',
#   'sekarang',
#   'surat',
#   'sebut',
#   'temu'],
#  '950581': ['moga',
#   'museum',
#   'akan',
#   'jadi',
#   'mata',
#   'air',
#   'alir',
#   'kiprah',
#   'beri',
#   'arah',
#   'ajak',
#   'bijak',
#   'tindak',
#   'kelana',
#   'temu',
#   'makna',
#   'generasi',
#   'muda',
#   'negeri'],
#  '947824': ['bahkan',
#   'mati',
#   'suami',
#   'emma',
#   'tetap',
#   'di',
#   'mata',
#   'publik',
#   'terus',
#   'partisipasi',
#   'aktif',
#   'dunia',
#   'politik'],
#  '944993': ['rona',
#   'mata',
#   'tambah',
#   'dan',
#   'dimensi',
#   'mata',
#   'orang',
#   'imbang',
#   'warna',
#   'mata',
#   'hanya',
#   'mata',
#   'tampak',
#   'lebih',
#   'tarik'],
#  '950610': ['sumber', 'air', 'minum', 'asal', 'pdam', 'mata', 'air'],
#  '951989': ['menara',
#   'masingmasing',
#   'mata',
#   'baris',
#   'ikut',
#   'sistem',
#   'sederhana',
#   'sinyal',
#   'semaphore',
#   'di',
#   'mereka'],
#  '948531': ['markah',
#   'tanah',
#   'kenal',
#   'london',
#   'lain',
#   'antara',
#   'istana',
#   'buckingham',
#   'mata',
#   'london',
#   'katedral',
#   'santo',
#   'paulus',
#   'piccadilly',
#   'circus',
#   'jembatan',
#   'menara',
#   'stadion',
#   'wembley',
#   'jembatan',
#   'london',
#   'trafalgar',
#   'square'],
#  '947560': ['bagai',
#   'tugas',
#   'imbal',
#   'tantang',
#   'sedia',
#   'mungkin',
#   'main',
#   'dapat',
#   'mata',
#   'uang',
#   'game',
#   'mungkin',
#   'main',
#   'lebih',
#   'banyak',
#   'kartu',
#   'koleksi'],
#  '943561': ['gera',
#   'lahir',
#   'semata',
#   'mata',
#   'mikat',
#   'hati',
#   'tarik',
#   'simpati',
#   'bangsa',
#   'indonesia',
#   'mau',
#   'bantu',
#   'jepang'],
#  '952202': ['saksi',
#   'mata',
#   'selamat',
#   'lapor',
#   'ia',
#   'kerja',
#   'rajin',
#   'mati',
#   'tampak',
#   'hidup',
#   'air',
#   'kapal',
#   'tenggelam'],
#  '951692': ['rupee',
#   'nama',
#   'jenis',
#   'mata',
#   'uang',
#   'guna',
#   'beberapa',
#   'negara',
#   'india',
#   'pakistan',
#   'sri',
#   'lanka',
#   'nepal',
#   'mauritius',
#   'seychelles'],
#  '943844': ['cloud', 'buat', 'mata', 'kuliah'],
#  '951931': ['wilayah',
#   'grabag',
#   'pula',
#   'buah',
#   'mata',
#   'air',
#   'besar',
#   'nama',
#   'tuk',
#   'mas',
#   'rupa',
#   'suplai',
#   'utama',
#   'air',
#   'pdam',
#   'kota',
#   'magelang'],
#  '952035': ['naginata',
#   'punya',
#   'mata',
#   'pedang',
#   'membunyai',
#   'panjang',
#   '21',
#   'cm',
#   'pasang',
#   'poros',
#   'kawat'],
#  '951476': ['sma',
#   'negeri',
#   '6',
#   'padang',
#   'rupa',
#   'salah',
#   'satu',
#   'sekolah',
#   'tengah',
#   'atas',
#   'negeri',
#   'alamat',
#   'jalan',
#   'sutan',
#   'syahrir',
#   'nomor',
#   '11',
#   'mata',
#   'air',
#   'padang',
#   'selatan',
#   'padang',
#   'sumatera',
#   'barat'],
#  '946697': ['sektor',
#   'kebun',
#   'sektor',
#   'tani',
#   'juga',
#   'jadi',
#   'mata',
#   'cahari',
#   'duduk'],
#  '965356': ['walaupun',
#   'karena',
#   'masuk',
#   'tumbuh',
#   'serbu',
#   'silang',
#   'mudah',
#   'jadi',
#   'rekombinasi',
#   'sifat',
#   'bawa',
#   'tingkat',
#   'ragam',
#   'cukup',
#   'tinggi'],
#  '954646': ['mantan',
#   'manajer',
#   'baya',
#   'pernah',
#   'skor',
#   'tahun',
#   'bawa',
#   'baya',
#   'puruk',
#   'divisi',
#   'satu'],
#  '953024': ['ini',
#   'bawa',
#   'laksana',
#   'indonesian',
#   'youth',
#   'day',
#   'pertama',
#   'selenggara',
#   'sanggau'],
#  '953012': ['tentang',
#   'diet',
#   'mas',
#   'wasisto',
#   'teman',
#   'setia',
#   'ndaru',
#   'selalu',
#   'bawa',
#   'suasana',
#   'canda'],
#  '961276': ['masuk',
#   'pikir',
#   'nasionalisme',
#   'bawa',
#   'ubah',
#   'besar',
#   'tajam',
#   'bosnia'],
#  '957412': ['sampa',
#   'kafe',
#   'taruh',
#   'surat',
#   'lamar',
#   'mahdi',
#   'tak',
#   'sengaja',
#   'tabrak',
#   'melodi',
#   'adzana',
#   'adi',
#   'bing',
#   'slamet',
#   'usaha',
#   'butik',
#   'sedang',
#   'bawa',
#   'sampel',
#   'bahan',
#   'presentasi',
#   'sama',
#   'klien',
#   'kafe',
#   'sama'],
#  '960333': ['itu',
#   'tiga',
#   'beda',
#   'utama',
#   'sangkakala',
#   'hakim',
#   'cawan',
#   'hukum',
#   'pertama',
#   'sangkakala',
#   'hakim',
#   'malapetaka',
#   'bawa',
#   'parsial',
#   'hancur',
#   'malapetaka',
#   'atas',
#   '1',
#   '3',
#   'alam',
#   'orang',
#   'cawan',
#   'hukum',
#   'serang',
#   'lebih',
#   'parah',
#   'langsung',
#   'hadap',
#   'umat',
#   'manusia',
#   'alam',
#   'bawa',
#   'lebih',
#   'banyak',
#   'kacau',
#   'bumi',
#   'sangkakala',
#   'hakim'],
#  '956531': ['pesawat',
#   'bisa',
#   'bawa',
#   'bom',
#   'konvensional',
#   'fab9000kg',
#   '19',
#   '800',
#   'lb',
#   'raksasa',
#   'tunggal',
#   'tara',
#   'rusia',
#   'bom',
#   'grand',
#   'slam',
#   'inggris',
#   'bagai',
#   'senjata',
#   'nuklir',
#   'jarak',
#   'tempuh',
#   '4',
#   '800',
#   'km',
#   '3',
#   '000',
#   'mil'],
#  '955681': ['banyak',
#   'orang',
#   'jawa',
#   'rantau',
#   'malaysia',
#   'turut',
#   'bawa',
#   'bahasa',
#   'budaya',
#   'jawa',
#   'malaysia',
#   'dapat',
#   'kawasan',
#   'mukim',
#   'yang',
#   'kenal',
#   'nama',
#   'kampung',
#   'jawa',
#   'padang',
#   'jawa'],
#  '963823': ['van',
#   'marwijk',
#   'bawa',
#   'oranje',
#   'final',
#   'piala',
#   'dunia',
#   '2010',
#   '32',
#   'tahun',
#   'prestasi',
#   'tinggi',
#   'tiga',
#   '1978',
#   '1974',
#   'mana',
#   'oranje',
#   'juluk',
#   'timnas',
#   'belanda',
#   'masuk',
#   'final',
#   'kemudian',
#   'kalah',
#   'argentina',
#   'jerman',
#   'barat'],
#  '963199': ['alas',
#   'taufan',
#   'karena',
#   'ingin',
#   'buat',
#   'kamila',
#   'bahagia',
#   'bawa',
#   'fadil',
#   'asli'],
#  '966385': ['makna',
#   'mohon',
#   'berkat',
#   'tuhan',
#   'padi',
#   'tanam',
#   'hasil',
#   'bulir',
#   'lipat',
#   'hingga',
#   'bawa',
#   'makmur',
#   'masyarakat'],
#  '958961': ['tetapi',
#   'fitzgerald',
#   'gagal',
#   'kumpul',
#   'cukup',
#   'dukung',
#   'irlandia',
#   'pada',
#   'bulan',
#   'oktober',
#   'bala',
#   'tentara',
#   'kuat',
#   '1',
#   '600',
#   'prajurit',
#   'inggris',
#   'wales',
#   'darat',
#   'irlandia',
#   'bawa',
#   'empat',
#   'senjata',
#   'kepung',
#   'modern'],
#  '954427': ['wanita', 'datang', 'bawa', 'nasi', 'tumpeng', 'leta', 'tengah'],
#  '963336': ['datang',
#   'notts',
#   'county',
#   'bawa',
#   'schmeichel',
#   'jadi',
#   'main',
#   'mahal',
#   'nilai',
#   '1',
#   'juta',
#   'pound',
#   'per',
#   'tahun'],
#  '956272': ['pulang',
#   'bawa',
#   'minum',
#   'alkohol',
#   'putar',
#   'lagu',
#   'keras',
#   'mungkin',
#   'usir',
#   'rasa',
#   'sakit'],
#  '957066': ['hancur',
#   'dapat',
#   'bagai',
#   'akibat',
#   'tempur',
#   'bawa',
#   'india',
#   'tuju',
#   'zaman',
#   'depresi',
#   'sosial',
#   'ekonomi',
#   'kaliyuga',
#   'zaman',
#   'gelap',
#   'dapat',
#   'akhir',
#   'jangka',
#   'waktu',
#   'lama'],
#  '952961': ['waktu',
#   'anak',
#   'laki',
#   'laki',
#   'vito',
#   'michael',
#   'rupa',
#   'angkat',
#   'laut',
#   'datang',
#   'bawa',
#   'kasih',
#   'kay',
#   'adams'],
#  '960301': ['merdeka',
#   'negeri',
#   'capai',
#   'nasib',
#   'bawa',
#   'untung',
#   'masingmasing'],
#  '956518': ['mah',
#   'yakin',
#   'anak',
#   'lahir',
#   'bulan',
#   'suro',
#   'di',
#   'bulan',
#   'muharam',
#   'akan',
#   'bawa',
#   'sial',
#   'anggap',
#   'bagai',
#   'anak',
#   'jin'],
#  '955254': ['bawa',
#   'konsep',
#   'trading',
#   'market',
#   'khusus',
#   'jual',
#   'fashion',
#   'show',
#   'hadir',
#   'nama',
#   'trademark',
#   'hingga',
#   'sekarang'],
#  '956360': ['cerita',
#   'film',
#   'mulai',
#   'melia',
#   'zreiq',
#   'orang',
#   'perempuan',
#   'tua',
#   'eilaboun',
#   'kata',
#   'harap',
#   'tuhan',
#   'bawa',
#   'damai',
#   'negeri',
#   'dan',
#   'wujud',
#   'masyarakat',
#   'mampu',
#   'tinggal',
#   'sama',
#   'buah',
#   'hidup',
#   'indah'],
#  '960386': ['upa',
#   'simbolik',
#   'mungkin',
#   'ambil',
#   'bahasa',
#   'alkitab',
#   'temu',
#   'maka',
#   'aku',
#   'bawa',
#   'kamu',
#   'dalam',
#   'buang',
#   'jauh',
#   'seberang',
#   'damsyik'],
#  '956779': ['kapal',
#   'milik',
#   'bobot',
#   '500',
#   'hingga',
#   '1',
#   '200',
#   'ton',
#   'mampu',
#   'bawa',
#   'hingga',
#   '36',
#   'senjata',
#   'bagai',
#   'tahan'],
#  '952958': ['beri',
#   'dispensasi',
#   'khusus',
#   'bawa',
#   'pedang',
#   'adil',
#   'sebut',
#   'benar',
#   'larang',
#   'dispensasi',
#   'tidak',
#   'beri',
#   'jabat',
#   'negeri',
#   'han',
#   'sejak',
#   'xiao',
#   'he'],
#  '997820': ['alkitab',
#   'froschauer',
#   'kandung',
#   'lebih',
#   '200',
#   'ilustrasi',
#   'jadi',
#   'buah',
#   'karya',
#   'cetak',
#   'penting',
#   'saat'],
#  '996008': ['polibutena',
#   'biasa',
#   'buat',
#   'campur',
#   'cracking',
#   'c4',
#   'stream',
#   'beri',
#   'laku',
#   'merox',
#   'hilang',
#   'belerang',
#   'amina',
#   'kandung',
#   '1butena',
#   '2butena',
#   'isobutilena'],
#  '998840': ['banyak', 'kandung', 'protein', 'asam', 'lemak', 'tak', 'jenuh'],
#  '999751': ['palu',
#   'buat',
#   'baja',
#   'cipta',
#   'bunga',
#   'api',
#   'pada',
#   'industri',
#   'tambang',
#   'batu',
#   'bara',
#   'dapat',
#   'metana',
#   'dalam',
#   'industri',
#   'lingkung',
#   'bahaya',
#   'kandung',
#   'gas',
#   'mudah',
#   'bakar',
#   'guna',
#   'palu',
#   'baja'],
#  '997545': ['es',
#   'krim',
#   'umum',
#   'kandung',
#   'lebih',
#   '50',
#   'udara',
#   'proses',
#   'adu'],
#  '995743': ['emoticons',
#   'blok',
#   'unicode',
#   'kandung',
#   'representasi',
#   'grafis',
#   'wajah',
#   'manusia',
#   'sering',
#   'kait',
#   'emotikon',
#   'klasik'],
#  '1000732': ['batang', 'banyak', 'kandung', 'silika'],
#  '995486': ['spesies', 'genus', 'kandung', 'bukan', 'telur'],
#  '997993': ['orang',
#   'mesir',
#   'lihat',
#   'proses',
#   'cipta',
#   'kandung',
#   'banyak',
#   'aspek',
#   'libat',
#   'banyak',
#   'kuat'],
#  '999198': ['lapis',
#   'kandung',
#   'buluh',
#   'darah',
#   'akar',
#   'rambut',
#   'ujung',
#   'saraf',
#   'kelenjar',
#   'keringat',
#   'kelenjar',
#   'minyak'],
#  '994929': ['minyak',
#   'jagung',
#   'kandung',
#   'ubiquinon',
#   'alfatokoferol',
#   'tinggi',
#   'gammatokoferol',
#   'tinggi',
#   'dapat',
#   'hindar',
#   'tengik',
#   'oksidatif'],
#  '998224': ['darah',
#   'sudah',
#   'kandung',
#   'oksigen',
#   'tuju',
#   'atrium',
#   'kiri',
#   'lewat',
#   'ventrikel',
#   'kiri',
#   'pompa',
#   'tuju',
#   'seluruh',
#   'tubuh',
#   'lalu',
#   'aorta',
#   'mana',
#   'oksigen',
#   'pakai',
#   'lalu',
#   'metabolisme',
#   'jadi',
#   'karbon',
#   'dioksida'],
#  '996401': ['tubuh',
#   'rupa',
#   'materi',
#   'luas',
#   'cara',
#   'spasial',
#   'sedang',
#   'budi',
#   'rupa',
#   'substansi',
#   'pikir',
#   'kandung',
#   'jiwa',
#   'rasional'],
#  '999407': ['lisosom',
#   'kandung',
#   'enzim',
#   'asam',
#   'bunuh',
#   'cerna',
#   'partikel',
#   'organisme'],
#  '995538': ['contoh',
#   'formasi',
#   'besi',
#   'sangat',
#   'lapuk',
#   'brasil',
#   'jadi',
#   'tunjuk',
#   'konsentrasi',
#   'emas',
#   'kandung',
#   'limonit',
#   'tanah'],
#  '997584': ['buku',
#   'tahun',
#   '1929',
#   'seven',
#   'hundred',
#   'sandwiches',
#   'cakup',
#   'roti',
#   'lapis',
#   'bacon',
#   'resep',
#   'sering',
#   'masuk',
#   'acar',
#   'tidak',
#   'yang',
#   'kandung',
#   'tomat'],
#  '994817': ['lanjut',
#   'plumeria',
#   'cendana',
#   'meski',
#   'bau',
#   'harum',
#   'getah',
#   'kandung',
#   'racun',
#   'dapat',
#   'timbul',
#   'rasa',
#   'gatal'],
#  '997497': ['anggap',
#   'cattell',
#   'pantas',
#   'karena',
#   'teliti',
#   'teliti',
#   'social',
#   'intelligence',
#   'anggap',
#   'ras',
#   'kandung',
#   'unsur',
#   'nazi'],
#  '999053': ['biji',
#   'milik',
#   'salut',
#   'biji',
#   'manfaat',
#   'bila',
#   'mentah',
#   'sangat',
#   'racun',
#   'kandung',
#   'asam',
#   'sianida',
#   'konsentrasi',
#   'tinggi'],
#  '996407': ['ilmenit',
#   'sangat',
#   'sering',
#   'kandung',
#   'jumlah',
#   'magnesium',
#   'mangan',
#   'rumus',
#   'kimia',
#   'penuh',
#   'fe',
#   'mg',
#   'mn',
#   'ti',
#   'ilmenit',
#   'bentuk',
#   'larut',
#   'padat',
#   'geikielit',
#   'pirofanit',
#   'rupa',
#   'dari',
#   'kelompok',
#   'larut',
#   'padat'],
#  '999448': ['indonesia',
#   'syarat',
#   'hasil',
#   'temu',
#   'akan',
#   'paten',
#   'baru',
#   'pernah',
#   'ungkap',
#   'kandung',
#   'langkah',
#   'inventif',
#   'duga',
#   'dan',
#   'dapat',
#   'terap',
#   'industri'],
#  '997333': ['tiap', 'kelopak', 'nomor', 'kandung', '2', 'orbital'],
#  '995776': ['gurmukhi',
#   'blok',
#   'unicode',
#   'kandung',
#   'karakter',
#   'bahasa',
#   'punjabi'],
#  '995216': ['organon',
#   'buah',
#   'judul',
#   'beri',
#   'karya',
#   'logika',
#   'aristoteles',
#   'kandung',
#   'arti',
#   'logika',
#   'suatu',
#   'alat',
#   'guna',
#   'oleh',
#   'tahu',
#   'filosofis',
#   'untuk',
#   'kerja',
#   'filsafat',
#   'tidak',
#   'anggap',
#   'bagai',
#   'suatu',
#   'tuju',
#   'diri',
#   'sendiri'],
#  '997876': ['ikut', 'daftar', 'makan', 'mungkin', 'kandung', 'tartrazin'],
#  '1016473': ['tentara',
#   'tengah',
#   'jaga',
#   'stasiun',
#   'membunh',
#   'sangka',
#   '3',
#   'hingga',
#   '4',
#   'tembak',
#   'dasar',
#   'terang',
#   'saksi',
#   'mata'],
#  '1014231': ['kemudian',
#   'beberapa',
#   'anak',
#   'harimau',
#   'beri',
#   'kuil',
#   'waktu',
#   'waktu',
#   'biasa',
#   'ibu',
#   'bunuh',
#   'buru',
#   'orang',
#   'singkir',
#   'harimau',
#   'hewan',
#   'pelihara',
#   'mereka',
#   'di',
#   'bawah',
#   'tekan',
#   'laku',
#   'bagai',
#   'hukum',
#   'bijak',
#   'putar',
#   'jaga',
#   'spesies',
#   'yang',
#   'lindung',
#   'jadi',
#   'lebih',
#   'ketat'],
#  '1017503': ['sandi',
#   'playfair',
#   'anggap',
#   'aman',
#   'untuk',
#   'jaga',
#   'suatu',
#   'rahasia',
#   'pesan',
#   'komputer',
#   'peranti',
#   'lunak',
#   'dapat',
#   'pecah',
#   'suatu',
#   'sandi',
#   'hitung',
#   'detik'],
#  '1017926': ['umpama',
#   'schopenhauer',
#   'gambar',
#   'kelompok',
#   'landak',
#   'perlu',
#   'saling',
#   'sentuh',
#   'buah',
#   'hangat',
#   'usaha',
#   'jaga',
#   'jarak',
#   'tidak',
#   'saling',
#   'luka',
#   'duri'],
#  '1017521': ['unjung',
#   'minta',
#   'jaga',
#   'jalan',
#   'hindar',
#   'tunjuk',
#   'makan',
#   'makan',
#   'hewan',
#   'mungkin',
#   'rebut'],
#  '1015081': ['syukur',
#   'sosok',
#   'ibnu',
#   'munzir',
#   'mampu',
#   'jaga',
#   'diri',
#   'terus',
#   'buat',
#   'sembah',
#   'baik',
#   'sulawesi',
#   'barat'],
#  '1014977': ['operasi',
#   'dynamo',
#   'selesai',
#   'hadap',
#   'masalah',
#   'besar',
#   'jaga',
#   'air',
#   'dover',
#   'invasi',
#   'jerman',
#   'invasi',
#   'telah',
#   'kira'],
#  '1017465': ['rang',
#   'sungai',
#   'kuning',
#   'guanzhong',
#   'wilayah',
#   'pinggir',
#   'chang',
#   'an',
#   'li',
#   'yuan',
#   'tugas',
#   'li',
#   'jiancheng',
#   'liu',
#   'wenjing',
#   'ke',
#   'timur',
#   'jaga',
#   'terus',
#   'tong',
#   'lumbung',
#   'yongfeng',
#   'atas',
#   'segala',
#   'mungkin',
#   'datang',
#   'bala',
#   'bantu',
#   'sui',
#   'ibukota',
#   'timur',
#   'luoyang'],
#  '1018077': ['beberapa',
#   'ajar',
#   'terang',
#   'proklamasi',
#   'pribadi',
#   'gung',
#   'ye',
#   'bagai',
#   'buddha',
#   'bagai',
#   'upaya',
#   'kukuh',
#   'kuasa',
#   'rupa',
#   'anggota',
#   'raja',
#   'silla',
#   'milik',
#   'pengaruh',
#   'atas',
#   'tuan',
#   'tanah',
#   'dagang',
#   'lokal',
#   'jadi',
#   'ia',
#   'usaha',
#   'guna',
#   'kuasa',
#   'agama',
#   'jaga',
#   'perintah',
#   'bukti',
#   'efektif'],
#  '1018480': ['beberapa',
#   'jenis',
#   'bakteri',
#   'hidup',
#   'salur',
#   'cerna',
#   'tidak',
#   'serap',
#   'nutrisi',
#   'juga',
#   'peran',
#   'dalam',
#   'jaga',
#   'sehat',
#   'salur',
#   'cerna',
#   'tingkat',
#   'imunitas',
#   'tubuh'],
#  '1016675': ['ratu',
#   'dasyu',
#   'tolak',
#   'jaga',
#   'puru',
#   'usaha',
#   'bawa',
#   'ke',
#   'raja',
#   'paurav'],
#  '1018771': ['salah',
#   'satu',
#   'peran',
#   'penting',
#   'bhinneka',
#   'tunggal',
#   'ika',
#   'hidup',
#   'warga',
#   'indonesia',
#   'jaga',
#   'satu',
#   'negara',
#   'republik',
#   'indonesia'],
#  '1015860': ['aleksander',
#   'cepat',
#   'hukum',
#   'mati',
#   'karena',
#   'benar',
#   'tugas',
#   'jaga',
#   'makam',
#   'koresh',
#   'sebut',
#   'sangat',
#   'hormat',
#   'aleksander'],
#  '1015805': ['fenomena',
#   'sebut',
#   'serat',
#   'birefringence',
#   'dapat',
#   'netral',
#   'jaga',
#   'polarisasi',
#   'serat',
#   'optik'],
#  '1017175': ['tetap',
#   'perhati',
#   'detail',
#   'jalan',
#   'tugas',
#   'resmi',
#   'bagai',
#   'kaisar',
#   'walaupun',
#   'seringkali',
#   'antusias',
#   'ia',
#   'lagi',
#   'laku',
#   'campur',
#   'tangan',
#   'cara',
#   'langsung',
#   'jaga',
#   'stabilitas',
#   'negara'],
#  '1017414': ['orang',
#   'ilmuwan',
#   'pakai',
#   'baju',
#   'kriogenik',
#   'jaga',
#   'suhu',
#   'tubuh',
#   'tetap',
#   'rendah'],
#  '1018355': ['tiga',
#   'divisi',
#   'rsi',
#   'italia',
#   '2',
#   'littorio',
#   'divisi',
#   'infanteri',
#   'ke3',
#   'italia',
#   'san',
#   'marco',
#   'marine',
#   'divisi',
#   '4',
#   'italia',
#   'monte',
#   'rosa',
#   'alpine',
#   'divisi',
#   'alokasi',
#   'lxxxxvii',
#   'liguria',
#   'tentara',
#   'bawah',
#   'graziani',
#   'tempat',
#   'jaga',
#   'sisi',
#   'barat',
#   'garis',
#   'gothic',
#   'hadap',
#   'perancis'],
#  '1016614': ['kondisi',
#   'ada',
#   'biasa',
#   'capai',
#   'jaga',
#   'suhu',
#   'reaksi',
#   'tetap',
#   'medium',
#   'dengan',
#   'kuat',
#   'ionik',
#   'relatif',
#   'tinggi',
#   'bagai',
#   'larut'],
#  '1014535': ['banyak',
#   'fakta',
#   'arah',
#   'suatu',
#   'duga',
#   'priory',
#   'of',
#   'sion',
#   'rupa',
#   'buah',
#   'organisasi',
#   'jaga',
#   'ketat',
#   'rahasia',
#   'sejarah',
#   'kristiani',
#   'turut',
#   'versi',
#   'beda',
#   'kitab',
#   'injil',
#   'edar',
#   'masyarakat'],
#  '1015246': ['sebut',
#   'suatu',
#   'bentuk',
#   'brutal',
#   'polisi',
#   'buat',
#   'korban',
#   'ada',
#   'tak',
#   'daya',
#   'lempar',
#   'sana',
#   'kemari',
#   'dalam',
#   'mobil',
#   'akibat',
#   'cara',
#   'kemudi',
#   'menghentakhentak',
#   'sengaja',
#   'korban',
#   'dapat',
#   'jaga',
#   'diri',
#   'aman',
#   'kekang'],
#  '1016956': ['ceret',
#   'surya',
#   'teknologi',
#   'tabung',
#   'surya',
#   'kedap',
#   'udara',
#   'fasilitas',
#   'kedap',
#   'udara',
#   'dapat',
#   'jaga',
#   'air',
#   'sudah',
#   'panas',
#   'tetap',
#   'panas',
#   'panjang',
#   'malam'],
#  '1016134': ['aman',
#   'poso',
#   'turut',
#   'bukan',
#   'andil',
#   'kandidat',
#   'tahana',
#   'tetapi',
#   'lalu',
#   'upaya',
#   'perintah',
#   'pusat',
#   'aparat',
#   'aman',
#   'jaga',
#   'aman',
#   'tertib'],
#  '1018094': ['latih',
#   'liput',
#   'lengkap',
#   'falconry',
#   'kerudung',
#   'rufter',
#   'ikat',
#   'kaki',
#   'jesses',
#   'jaga',
#   'burung',
#   'tetap',
#   'dalam',
#   'kendali'],
#  '1017921': ['perang',
#   'libat',
#   'bagai',
#   'diadokhoi',
#   'tuju',
#   'utama',
#   'plotemaios',
#   'jaga',
#   'aman',
#   'mesir',
#   'kemudian',
#   'kuasa',
#   'daerah',
#   'sekitar',
#   'mesir',
#   'lain',
#   'kyrenaika',
#   'siprus',
#   'suriah',
#   'masuk',
#   'provinsi',
#   'yudea'],
#  '1015878': ['sejak',
#   'permafrost',
#   'cair',
#   'perlahanlahan',
#   'sedia',
#   'mantap',
#   'sumber',
#   'air',
#   'letus',
#   'jaga',
#   'air',
#   'magma',
#   'terlalu',
#   'rendah'],
#  '71739': ['sudah',
#   'lihat',
#   'negara',
#   'eropa',
#   'badan',
#   'wakil',
#   'parlementaire',
#   'demokratie'],
#  '71318': ['survei',
#   'bom',
#   'strategis',
#   'amerika',
#   'serikat',
#   'buah',
#   'badan',
#   'pakar',
#   'tugas',
#   'buat',
#   'jelas',
#   'dampak',
#   'bom',
#   'strategis',
#   'inggrisamerika',
#   'jerman',
#   'nazi',
#   'teater',
#   'eropa',
#   'perang',
#   'dunia',
#   'ii'],
#  '74694': ['hanoch',
#   'salah',
#   'orang',
#   'orang',
#   'sargon',
#   'klaim',
#   'badan',
#   'spock',
#   'cocok',
#   'fisiologi',
#   'aliennya',
#   'rupa',
#   'hibrid',
#   'manusiavulcan'],
#  '76411': ['anto',
#   'milik',
#   'tinggi',
#   'badan',
#   '170',
#   'cm',
#   'berat',
# ...
#   'bawa',
#   'informasi',
#   'asam',
#   'nukleat',
#   'liposom',
#   'akan',
#   'alami',
#   'seleksi',
#   'alam',
#   'tentu',
#   'umur',
#   'mampu',
#   'reproduksi'],
#  '963118': ['karena',
#   'ibu',
#   'saudara',
#   'rasa',
#   'antuk',
#   'lelah',
#   'bima',
#   'bawa',
#   'sekaligus',
#   'kuat',
#   'dahsyat'],
#  '966525': ['hasil',
#   'bawa',
#   'bola',
#   'lewat',
#   'garis',
#   'gol',
#   'lawan',
#   'sentuh',
#   'bola',
#   'tanah',
#   'tim',
#   'sebut',
#   'cetak',
#   '5',
#   'poin'],
#  '954202': ['hasil',
#   'baik',
#   'dia',
#   'bawa',
#   'tim',
#   'pada',
#   'piala',
#   'dunia',
#   'fifa',
#   '1998'],
#  '959077': ['hadap',
#   'jalan',
#   'jauh',
#   'bawa',
#   'bencana',
#   'anatolia',
#   'bulan',
#   'ikut',
#   'bagi',
#   'besar',
#   'tentara',
#   'hancur'],
#  '964636': ['utus',
#   'bawa',
#   'surat',
#   'sebut',
#   'konstantinopel',
#   'langsung',
#   'penjara',
#   'mereka',
#   'tiba',
#   'dipaks',
#   'terima',
#   'komuni',
#   'acacius',
#   'bagai',
#   'dari',
#   'liturgi',
#   'dasar',
#   'petrus',
#   'peter',
#   'mongus',
#   'kaum',
#   'monofisitis',
#   'nama',
#   'diptikha'],
#  '954877': ['ini',
#   'beri',
#   'serang',
#   'mampu',
#   'bawa',
#   'otoritas',
#   'blockchain',
#   'asli',
#   'tanya',
#   'cipta',
#   'yatim',
#   'blok',
#   'blockchain'],
#  '955887': ['putus',
#   'pergi',
#   'amerika',
#   'selatan',
#   'malam',
#   'kelulus',
#   'bawa',
#   'tabung',
#   'pribadi',
#   '9000',
#   'swiss',
#   'francs',
#   'sumbang',
#   'para',
#   'tetangga',
#   'pontresina',
#   'engadine',
#   'valley'],
#  '956800': ['masuk',
#   'goib',
#   'ian',
#   'bawa',
#   'banyak',
#   'pengaruh',
#   'band',
#   'khusus',
#   'segi',
#   'musikalitas'],
#  '957746': ['maret',
#   'healy',
#   'coba',
#   'bawa',
#   'masalah',
#   'ke',
#   'adil',
#   'tolak',
#   'punya',
#   'bukti',
#   'cukup',
#   'buat',
#   'mereka',
#   'usaha',
#   'untuk',
#   'cari',
#   'film',
#   'sebut'],
#  '966160': ['kemudian',
#   'segera',
#   'tahu',
#   'dua',
#   'pintu',
#   'tumpang',
#   'sangat',
#   'sesuai',
#   'pesawat',
#   'pesawat',
#   'akan',
#   'bawa',
#   '19',
#   'tumpang'],
#  '964686': ['tinggal',
#   'suami',
#   'dyah',
#   'lembu',
#   'tal',
#   'bawa',
#   'raden',
#   'wijaya',
#   'pergi',
#   'paku'],
#  '955316': ['orang',
#   'induk',
#   'bawa',
#   '1',
#   'hingga',
#   '10',
#   'telur',
#   'rata',
#   'hiu',
#   'bawa',
#   '7',
#   'butir',
#   'telur'],
#  '182290': ['ketua',
#   'mk',
#   'pertama',
#   'prof',
#   'dr',
#   'jimly',
#   'asshiddiqie',
#   's',
#   'h',
#   'guru',
#   'besar',
#   'hukum',
#   'tata',
#   'negara',
#   'universitas',
#   'indonesia',
#   'lahir',
#   '17',
#   'april',
#   '1956',
#   'pilih',
#   'rapat',
#   'internal',
#   'antar',
#   'anggota',
#   'hakim',
#   'mahkamah',
#   'konstitusi',
#   'tanggal',
#   '19',
#   'agustus',
#   '2003'],
#  '180012': ['sejak',
#   'juni',
#   '2006',
#   'versi',
#   'linux',
#   'sedia',
#   'unduh',
#   'gratis',
#   'bagi',
#   'besar',
#   'sistem',
#   'operasi',
#   'linux'],
#  '146348': ['sungai',
#   'cukup',
#   'besar',
#   'sungai',
#   'repahamba',
#   'yang',
#   'alir',
#   'dukuh',
#   'kaliputih',
#   'dukuh',
#   'repahamba',
#   'desa',
#   'kenteng'],
#  '134914': ['pisau',
#   'survival',
#   'sebut',
#   'bagai',
#   'pisau',
#   'langsung',
#   'hidup',
#   'arti',
#   'pisau',
#   'buat',
#   'tuju',
#   'tahan',
#   'hidup',
#   'lingkung',
#   'hutan',
#   'belantara',
#   'biasa',
#   'situasi',
#   'darurat',
#   'apabila',
#   'guna',
#   'telah',
#   'hilang',
#   'besar',
#   'alat',
#   'utama'],
#  '193588': ['jadwal',
#   'salur',
#   'cakup',
#   'besar',
#   'dokumenter',
#   'lokal',
#   'impor',
#   'produksi',
#   'studio',
#   'didik'],
#  '178376': ['jelang',
#   'akhir',
#   'perintah',
#   'tzimiskes',
#   'lambat',
#   'rencana',
#   'ekang',
#   'kuat',
#   'milik',
#   'tanah',
#   'besar',
#   'mati',
#   'datang',
#   'segera',
#   'dia',
#   'bicara',
#   'mereka',
#   'desasdesus',
#   'dia',
#   'racun',
#   'basileios',
#   'lekapenos',
#   'telah',
#   'akuisisi',
#   'kebun',
#   'besar',
#   'cara',
#   'ilegal'],
#  '192237': ['salah',
#   'satu',
#   'mesin',
#   'cari',
#   'pertama',
#   'sekarang',
#   'kembang',
#   'jadi',
#   'usaha',
#   'komersial',
#   'cukup',
#   'besar',
#   'lycos',
#   'mulai',
#   'carnegie',
#   'mellon',
#   'university',
#   'bagai',
#   'proyek',
#   'riset',
#   'tahun',
#   '1994'],
#  '174012': ['masyarakat',
#   'mumun',
#   'awal',
#   'sifat',
#   'egaliter',
#   'status',
#   'sama',
#   'lanjut',
#   'mulai',
#   'muncul',
#   'saing',
#   'sosial',
#   'pimpin',
#   'besar'],
#  '141421': ['isi',
#   '25',
#   'kamar',
#   'ruang',
#   'temu',
#   'ruang',
#   'cerdas',
#   'kuliah',
#   'pustaka',
#   'ruang',
#   'makan',
#   'ruang',
#   'keluarga',
#   'salon',
#   'besar',
#   'buah',
#   'klinik',
#   'medis'],
#  '170818': ['iron',
#   'giant',
#   'muncul',
#   'ciri',
#   'khas',
#   'tinggi',
#   'armor',
#   'luar',
#   'biasa',
#   'besar',
#   'punya',
#   'pedang',
#   'besar'],
#  '184395': ['von',
#   'neumann',
#   'abadi',
#   'nama',
#   'bagai',
#   'arsitektur',
#   'von',
#   'neumann',
#   'arsitektur',
#   'komputer',
#   'banyak',
#   'di',
#   'besar',
#   'sistem',
#   'komputer',
#   'non',
#   'paralel',
#   'dia',
#   'pertama',
#   'kali',
#   'publikasi',
#   'konsep',
#   'sebut'],
#  '140523': ['besar',
#   'debat',
#   'bahas',
#   'ide',
#   'internasional',
#   'globalisasi',
#   'tampak',
#   'dengan',
#   'daulat',
#   'westfalen',
#   'lihat',
#   'jumlah',
#   'interpretasi'],
#  '138292': ['alam',
#   'tetzel',
#   'bagai',
#   'orang',
#   'khotbah',
#   'indulgensi',
#   'utama',
#   'tahun',
#   '1503',
#   '1510',
#   'tunjuk',
#   'bagai',
#   'komisioner',
#   'umum',
#   'albrecht',
#   'von',
#   'brandenburg',
#   'uskup',
#   'agung',
#   'mainz',
#   'perlu',
#   'beri',
#   'kontribusi',
#   'cukup',
#   'besar',
#   'bangun',
#   'basilika',
#   'st',
#   'petrus',
#   'roma',
#   'kendati',
#   'sangat',
#   'wajib',
#   'bayar',
#   'akumulasi',
#   'manfaat',
#   'besar',
#   'telah',
#   'terima'],
#  '181060': ['guna',
#   'katalis',
#   'modern',
#   'reaksi',
#   'dapat',
#   'milik',
#   'rendemen',
#   'yield',
#   'lebih',
#   'besar',
#   '95'],
#  '156113': ['besar',
#   'wilyah',
#   'ukraina',
#   'diri',
#   'datar',
#   'tinggi',
#   'rata',
#   '175',
#   'meter',
#   '574',
#   'kaki',
#   'atas',
#   'muka',
#   'laut',
#   'keliling',
#   'gunung',
#   'bagi',
#   'barat',
#   'selatan',
#   'jauh'],
#  '142575': ['jejak',
#   'material',
#   'temu',
#   'trinity',
#   'site',
#   'sekarang',
#   'walaupun',
#   'besar',
#   'wilayah',
#   'keruk',
#   'timbun',
#   'united',
#   'states',
#   'atomic',
#   'energy',
#   'commission',
#   'tahun',
#   '1953'],
#  '184112': ['itu',
#   'yakin',
#   'cara',
#   'luas',
#   'es',
#   'ancam',
#   'kecil',
#   'kapal',
#   'besar',
#   'kapten',
#   'smith',
#   'sendiri',
#   'kata',
#   'ia',
#   'bisa',
#   'bayang',
#   'kondisi',
#   'apa',
#   'akan',
#   'akibat',
#   'kapal',
#   'tenggelam'],
#  '147429': ['ada',
#   'perang',
#   'besar',
#   'hindia',
#   'belanda',
#   'britania',
#   'kenal',
#   'nama',
#   'perang',
#   'jawa',
#   'britaniabelanda',
#   'begitu',
#   'untung',
#   'gera',
#   'juang',
#   'bukti',
#   'temu',
#   'gagal',
#   'bagus',
#   'rangin',
#   'para',
#   'ikut',
#   'tangkap',
#   'perintah',
#   'britania',
#   'tanggal',
#   '27',
#   'juni',
#   '1812',
#   'desa',
#   'panongan',
#   'hukum',
#   'mati',
#   'desa',
#   'karangsembung',
#   'rupa',
#   'tempat',
#   'penyebrangan',
#   'ramai',
#   'yang',
#   'hubung',
#   'sisi',
#   'barat',
#   'timur',
#   'sungai',
#   'cimanuk',
#   'tanggal',
#   '12',
#   'juli',
#   '1812'],
#  '187003': ['itu',
#   'sikap',
#   'beda',
#   'cara',
#   'substansial',
#   'hadap',
#   'sikap',
#   'afirmatif',
#   'orang',
#   'amerikaafrika',
#   'program',
#   'ini',
#   'tingkat',
#   'lebih',
#   'besar',
#   'banding',
#   'orang',
#   'kulit',
#   'putih'],
#  '135639': ['besar', 'duduk', 'desa', 'tan', 'dagang'],
#  '142990': ['meski',
#   'besar',
#   'negara',
#   'asia',
#   'milik',
#   'bijak',
#   'fiskal',
#   'bagus',
#   'dana',
#   'moneter',
#   'internasional',
#   'imf',
#   'turun',
#   'tangan',
#   'lalu',
#   'program',
#   'nila',
#   '40',
#   'miliar',
#   'stabil',
#   'mata',
#   'uang',
#   'korea',
#   'selatan',
#   'thailand',
#   'indonesia',
#   'negara',
#   'dampak',
#   'parah',
#   'krisis'],
#  '151031': ['access',
#   'software',
#   'jual',
#   'microsoft',
#   'tahun',
#   '1999',
#   'carver',
#   'beri',
#   'sangon',
#   'besar',
#   'beberapa',
#   'karyawannya',
#   'uang',
#   'pribadi'],
#  '182684': ['hingga',
#   'abad',
#   'ke19',
#   'besar',
#   'urus',
#   'perintah',
#   'daerah',
#   'kelola',
#   'hakim',
#   'tinggi',
#   'kota',
#   'akhir',
#   'akhir',
#   'tahun',
#   '1846'],
#  '328281': ['tari',
#   'tari',
#   'kipas',
#   'hias',
#   'bunga',
#   'peony',
#   'kena',
#   'hanbok',
#   'warna',
#   'colok'],
#  '328717': ['itu',
#   'umar',
#   'minta',
#   'bantu',
#   'ibu',
#   'bunga',
#   'denny',
#   'jangan',
#   'kawin',
#   'bunga'],
#  '326786': ['buah',
#   'sajak',
#   'sederhana',
#   'atas',
#   'lukis',
#   'gantung',
#   'depan',
#   'rangkai',
#   'bunga',
#   'tanam'],
#  '327170': ['hal',
#   'hilang',
#   'bunga',
#   'dapat',
#   'tidak',
#   'perlu',
#   'milik',
#   'orang',
#   'islam',
#   'sokong',
#   'distribusi',
#   'sejahtera'],
#  '327800': ['bagai',
#   'dosen',
#   'teliti',
#   'bidang',
#   'sastra',
#   'tulis',
#   'himpun',
#   'beberapa',
#   'karya',
#   'buku',
#   'bunga',
#   'rampai',
#   'kenang',
#   'prof',
#   'kuntowijoyo',
#   'terbit',
#   'fakultas',
#   'ilmu',
#   'budaya',
#   'ugm',
#   'prosiding',
#   'acern',
#   'university',
#   'bangsa',
#   'malaysia',
#   'konferensi',
#   'internasional',
#   'linguistik',
#   'universitas',
#   'airlangga',
#   'seminar',
#   'internasional',
#   'riksa',
#   'x',
#   'universitas',
#   'didik',
#   'indonesia',
#   'bagai',
#   'karya'],
#  '326696': ['bunga',
#   'aksiler',
#   'terminal',
#   'semu',
#   'bentuk',
#   'malai',
#   'bunga',
#   'punya',
#   'mahkota',
#   'bunga',
#   'benang',
#   'sari',
#   'jumlah',
#   '58',
#   'putik',
#   'jumlah',
#   '2',
#   '3',
#   'merus'],
#  '328723': ['tanda', 'pangkat', 'pakai', 'satu', 'bunga', 'sudut', 'lima'],
#  '328684': ['bagai',
#   'cure',
#   'blossom',
#   'rambut',
#   'merah',
#   'gelap',
#   'ubah',
#   'jadi',
#   'merah',
#   'muda',
#   'warna',
#   'tema',
#   'merah',
#   'muda',
#   'simbol',
#   'bunga',
#   'bunga',
#   'sakura'],
#  '328453': ['sedang',
#   'motif',
#   'utama',
#   'motif',
#   'bunga',
#   'biduk',
#   'motif',
#   'bunga',
#   'oteh',
#   'motif',
#   'bunga',
#   'payi',
#   'motif',
#   'bunga',
#   'inton',
#   'motif',
#   'bunga',
#   'kipas',
#   'motif',
#   'kemplang',
#   'motif',
#   'jelujur',
#   'motif',
#   'bunga',
#   'kecubung'],
#  '326053': ['tim',
#   'buat',
#   'beberapa',
#   'purwarupa',
#   'masuk',
#   'fokus',
#   'ide',
#   'tumbuh',
#   'bunga',
#   'dasar',
#   'sadar',
#   'manusia'],
#  '329309': ['umum', 'pola', 'geometri', 'rumit', 'rancang', 'bunga', 'lap'],
#  '328271': ['media',
#   'massa',
#   'putri',
#   'ana',
#   'juluk',
#   'bagai',
#   'putri',
#   'rakyat',
#   'dengan',
#   'rakyat',
#   'britania',
#   'raya',
#   'curah',
#   'sedih',
#   'dalam',
#   'siar',
#   'berita',
#   'bagai',
#   'karang',
#   'bunga',
#   'pajang',
#   'banyak',
#   'istana',
#   'buckingham',
#   'istana',
#   'kensington',
#   'pintu',
#   'masuk',
#   'utama',
#   'kompleks',
#   'atur',
#   'ulang'],
#  '326256': ['kala',
#   'sri',
#   'baginda',
#   'buru',
#   'tengah',
#   'hutan',
#   'lihat',
#   'bunga',
#   'aneka',
#   'warna',
#   'harum',
#   'semerbak',
#   'bau',
#   'sangat',
#   'sentuh',
#   'inti',
#   'asa',
#   'bangkit',
#   'nafsu',
#   'birah'],
#  '325814': ['desain',
#   'kasot',
#   'manek',
#   'tradisional',
#   'sering',
#   'milik',
#   'bentuk',
#   'bunga',
#   'eropa',
#   'warna',
#   'pengaruh',
#   'porselin',
#   'sarung',
#   'batik',
#   'ana'],
#  '326023': ['hasil', 'buah', 'bunga', 'yang', 'sebut', 'biji', 'kopi'],
#  '327298': ['fondasi',
#   'patung',
#   'bentuk',
#   'bunga',
#   'lotus',
#   'milik',
#   'luas',
#   '600',
#   'meter',
#   'persegi',
#   'mancakup',
#   'buah',
#   'ruang',
#   'kontemplasi',
#   'mana',
#   'unjung',
#   'istirahat',
#   'dengar',
#   'musik',
#   'baca',
#   'dapat',
#   'video',
#   'cd',
#   'buku',
#   'materi',
#   'ajar',
#   'patung',
#   'bagai',
#   'informasi',
#   'kena',
#   'pikir',
#   'timur',
#   'tampil',
#   'loket',
#   'informasi'],
#  '327050': ['cicil',
#   'suku',
#   'bunga',
#   '10',
#   '27',
#   'tahun',
#   'sisa',
#   'besar',
#   '4',
#   '470',
#   'usd'],
#  '327773': ['arti',
#   'lebih',
#   'luas',
#   'mimikri',
#   'agresif',
#   'cakup',
#   'bagai',
#   'jenis',
#   'muslihat',
#   'saat',
#   'bunga',
#   'anggrek',
#   'daya',
#   'serangga',
#   'jantan',
#   'rupa',
#   'betina',
#   'tampak',
#   'siap',
#   'reproduksi',
#   'lihat',
#   'pseudokopulasi',
#   'di',
#   'artikel',
#   'istilah',
#   'mimikri',
#   'agresif',
#   'acu',
#   'tipu',
#   'buat',
#   'korban',
#   'mangsa',
#   'predator'],
#  '798964': ['alun',
#   'dulu',
#   'tulis',
#   'aloenaloen',
#   'aloonaloon',
#   'rupa',
#   'suatu',
#   'lapang',
#   'buka',
#   'luas',
#   'umput',
#   'keliling',
#   'jalan',
#   'dapat',
#   'giat',
#   'masyarakat',
#   'agam',
#   'buat',
#   'fatahillah',
#   'turut',
#   'van',
#   'romondt',
#   'haryoto',
#   '1986',
#   '386',
#   'dasar',
#   'alun',
#   'rupa',
#   'halaman',
#   'depan',
#   'rumah',
#   'dalam',
#   'ukur',
#   'lebih',
#   'besar'],
#  '797332': ['prosesi',
#   'pawai',
#   'keliling',
#   'halaman',
#   'keraton',
#   'lama',
#   'satu',
#   'kali',
#   'kemudian',
#   'iring',
#   'pasuk',
#   'halaman',
#   'keraton'],
#  '797653': ['salah',
#   'satu',
#   'bidang',
#   'beberapa',
#   'bidang',
#   'kontroversial',
#   'kaji',
#   'kodeks',
#   'dresden',
#   'masuk',
#   'dalam',
#   'kait',
#   'interpretasi',
#   'tabel',
#   'air',
#   'halaman',
#   '74'],
#  '796888': ['tungkaran',
#   'paseban',
#   'halaman',
#   'buka',
#   'pekarang',
#   'rumah',
#   'banjar',
#   'masuk',
#   'wilayah',
#   'rumah',
#   'umum',
#   'main',
#   'anak',
#   'desa',
#   'untuk',
#   'jamu',
#   'selamat',
#   'dengan',
#   'bebas',
#   'permisi',
#   'tiap',
#   'orang',
#   'lalu',
#   'lalang',
#   'dalam'],
#  '795711': ['webgl',
#   'integrasi',
#   'sepenuh',
#   'semua',
#   'standar',
#   'web',
#   'browser',
#   'mungkin',
#   'cepat',
#   'gpu',
#   'fisika',
#   'olah',
#   'gambar',
#   'efek',
#   'bagai',
#   'dari',
#   'kanvas',
#   'halaman',
#   'web'],
#  '797503': ['estienne',
#   'masuk',
#   'pinggir',
#   'halaman',
#   'varian',
#   'baca',
#   '15',
#   'naskah',
#   'yunani',
#   'banyak',
#   'baca',
#   'poliglot',
#   'complutensian',
#   'complutensian',
#   'polyglot'],
#  '797176': ['ruang',
#   'museum',
#   'bangun',
#   'lantai',
#   '3',
#   'mana',
#   'sesuai',
#   'konsep',
#   'triangga',
#   'tiga',
#   'dari',
#   'tubuh',
#   'manusia',
#   'kepala',
#   'badan',
#   'anggota',
#   'gerak',
#   'tri',
#   'mandalla',
#   'tiga',
#   'halaman',
#   'jeroan',
#   'jaba',
#   'tengah',
#   'jaba',
#   'sisi',
#   'halaman',
#   'tengah',
#   'luar',
#   'tri',
#   'loka',
#   'konsep',
#   'alam',
#   'semesta',
#   'bagi',
#   'atas',
#   'bhur',
#   'bwah',
#   'swah',
#   'alam',
#   'bawah',
#   'tengah',
#   'atas'],
#  '796099': ['cerita',
#   'pernah',
#   'muat',
#   'halaman',
#   'tambah',
#   'surat',
#   'kabar',
#   'terbit',
#   'belgia',
#   'kurun',
#   'waktu',
#   '10',
#   'januari',
#   '1929',
#   'hingga',
#   '8',
#   'mei',
#   '1930',
#   'baru',
#   'buku',
#   'bentuk',
#   'album',
#   'komik',
#   'pertama',
#   'kali',
#   'tahun',
#   '1930'],
#  '797435': ['undang',
#   'setebal',
#   '90',
#   'halaman',
#   'sebut',
#   'atur',
#   'hukum',
#   'kena',
#   'hadap',
#   'orang',
#   'melayu',
#   'bangsa',
#   'yang',
#   'hubung',
#   'orang',
#   'melayu',
#   'siak',
#   'bagaimana',
#   'tegak',
#   'hukum',
#   'lalu',
#   'proses',
#   'adil',
#   'sultan',
#   'adil',
#   'belanda'],
#  '799257': ['lepas',
#   'tembak',
#   'bas',
#   'kali',
#   'udara',
#   'halaman',
#   'markas',
#   'di',
#   'jalan',
#   'kemiri',
#   'sentani',
#   'bagai',
#   'tindak',
#   'lanjut',
#   'tiga',
#   'orang',
#   'perwira',
#   'yonif',
#   '751',
#   'copot',
#   'jabat'],
#  '796991': ['28',
#   'januari',
#   '2008',
#   'pukul',
#   '9',
#   'malam',
#   'panic',
#   'at',
#   'the',
#   'disco',
#   'rilis',
#   'nine',
#   'in',
#   'the',
#   'afternoon',
#   'lalu',
#   'halaman',
#   'myspace',
#   'grup'],
#  '798755': ['deepdyve', 'tampil', 'halaman', 'pertama', 'tiap', 'artikel'],
#  '798786': ['kata',
#   'fardhu',
#   'kifayah',
#   'al',
#   'imam',
#   'asy',
#   'syafi',
#   'i',
#   'abu',
#   'hanifah',
#   'bagaimana',
#   'sebut',
#   'ibnu',
#   'habirah',
#   'kitab',
#   'al',
#   'ifshah',
#   'jilid',
#   '1',
#   'halaman',
#   '142'],
#  '796310': ['novel',
#   'setebal',
#   '123',
#   'halaman',
#   'kali',
#   'pertama',
#   'terbit',
#   'terbit',
#   'jalasutra',
#   'tahun',
#   '2006'],
#  '797753': ['buah',
#   'foto',
#   'atas',
#   'reine',
#   'gunung',
#   'reinebringen',
#   'guna',
#   'halaman',
#   'depan',
#   'beberapa',
#   'brosur',
#   'buku',
#   'turis'],
#  '796133': ['depan',
#   'gedung',
#   'utama',
#   'halaman',
#   'istana',
#   'buah',
#   'monumen',
#   'batu',
#   'andesit',
#   'setinggi',
#   '3',
#   '5',
#   'meter',
#   'sebut',
#   'dagoba',
#   'asal',
#   'desa',
#   'cupuwatu',
#   'dekat',
#   'candi',
#   'prambanan'],
#  '798196': ['pabrik',
#   'mitsuoka',
#   'motors',
#   'letak',
#   'prefektur',
#   'kampung',
#   'halaman',
#   'takita',
#   'toyama'],
#  '798921': ['united',
#   'states',
#   'of',
#   'eurasia',
#   'awal',
#   'anggap',
#   'gemar',
#   'muse',
#   'bagai',
#   'singel',
#   'pertama',
#   'rilis',
#   'muse',
#   'ungkap',
#   'lalu',
#   'halaman',
#   'twitter',
#   'bahwa',
#   'benar',
#   'uprising'],
#  ...}

# %%
file_path = "../data/training_set/triple_annotator_agree.csv"

triple_annotator_agree = preprocessing(file_path)

triple_annotator_agree
# Out:
# {'1000034': ['jepang',
#   'manga',
#   'biasa',
#   'serial',
#   'majalah',
#   'manga',
#   'besar',
#   'sering',
#   'kandung',
#   'banyak',
#   'cerita',
#   'masingmasing',
#   'saji',
#   'satu',
#   'episode',
#   'kemudian',
#   'lanjut',
#   'edisi',
#   'ikut'],
#  '1000129': ['surah',
#   'nama',
#   'maryam',
#   'surat',
#   'kandung',
#   'kisah',
#   'maryam',
#   'maria',
#   'agama',
#   'kristen',
#   'ibu',
#   'nabi',
#   'isa',
#   'as'],
#  '1000476': ['rebus',
#   'waterzooi',
#   'hachee',
#   'rebus',
#   'bawang',
#   'bombay',
#   'daging',
#   'sapi',
#   'kuah',
#   'daging',
#   'kental',
#   'kandung',
#   'banyak',
#   'rasa',
#   'butuh',
#   'beberapa',
#   'jam',
#   'saji'],
#  '1000486': ['muka',
#   'daun',
#   'kandung',
#   'lapis',
#   'lilin',
#   'air',
#   'jatuh',
#   'muka',
#   'daun',
#   'bentuk',
#   'butir',
#   'air'],
#  '1000511': ['picu',
#   'paling',
#   'umum',
#   'lain',
#   'alergen',
#   'rokok',
#   'tembakau',
#   'lain',
#   'polusi',
#   'udara',
#   'hambat',
#   'beta',
#   'non',
#   'selektif',
#   'makan',
#   'kandung',
#   'sulfit'],
#  '1000812': ['hagar',
#   'kandung',
#   'anak',
#   'abram',
#   'jadi',
#   'sombong',
#   'rendah',
#   'sara'],
#  '1001105': ['pasu',
#   'awang',
#   'tak',
#   'mampu',
#   'kejar',
#   'ira',
#   'purnama',
#   'tewas'],
#  '1001112': ['konflik',
#   'pusat',
#   'dasar',
#   'alam',
#   'mantan',
#   'polisi',
#   'chicago',
#   'chuck',
#   'adamson',
#   'kejar',
#   'tahun',
#   '1960an',
#   'kriminal',
#   'nama',
#   'mccauley',
#   'siapa',
#   'karakter',
#   'de',
#   'niro',
#   'nama'],
#  '1001164': ['srikandi',
#   'janji',
#   'temu',
#   'prabakusuma',
#   'arjuna',
#   'ia',
#   'mau',
#   'bantu',
#   'kejar',
#   'sekaligus',
#   'tangkap',
#   'curi',
#   'jamus',
#   'kalimasada'],
#  '1001333': ['hill',
#   'daftar',
#   'columbia',
#   'university',
#   '1993',
#   'aktif',
#   'lama',
#   'hampir',
#   'satu',
#   'tahun',
#   'penuh',
#   'keluar',
#   'kejar',
#   'karier',
#   'dunia',
#   'hibur'],
#  '1001347': ['tengah',
#   'sulit',
#   'dahlan',
#   'juang',
#   'jaga',
#   'adik',
#   'kejar',
#   'mimpi'],
#  '1001696': ['video',
#   'sebut',
#   'tampil',
#   'klip',
#   'orang',
#   'anak',
#   'laki',
#   'sedang',
#   'main',
#   'bola',
#   'basket',
#   'kemudian',
#   'kejar',
#   'kupukupu'],
#  '1002333': ['miller',
#   'kejar',
#   'wild',
#   'dog',
#   'akhir',
#   'akhir',
#   'buah',
#   'jembatan',
#   'luar',
#   'kastil'],
#  '1002554': ['kemudian',
#   'dua',
#   'sedot',
#   'gas',
#   'siphon',
#   'mobil',
#   'polisi',
#   'lalu',
#   'kejar',
#   'cody',
#   'saudara',
#   'laju',
#   'jual',
#   'hardware',
#   'juga',
#   'temu',
#   'orang',
#   'montir',
#   'tidak',
#   'kooperatif',
#   'ingin',
#   'peras',
#   'us',
#   '500',
#   'tambal',
#   'radiator',
#   'mereka'],
#  '1002585': ['agen',
#   'winstead',
#   'hurt',
#   'don',
#   'frye',
#   'lari',
#   'kejar',
#   'dillinger',
#   'hamilton',
#   'tengah',
#   'pohon',
#   'turut',
#   'baku',
#   'tembak'],
#  '1002705': ['tanggal',
#   '12',
#   'november',
#   'tentara',
#   'amerika',
#   'hasil',
#   'kejar',
#   'bunuh',
#   'semua',
#   'tentara',
#   'jepang',
#   'sisa',
#   'kantong',
#   'lawan'],
#  '1002835': ['hampir',
#   'tinggal',
#   'saing',
#   'berat',
#   'serbia',
#   'georgia',
#   'tuan',
#   'rumah',
#   'belarusia',
#   'rusia',
#   'armenia',
#   'terus',
#   'kejar',
#   'voting',
#   'hingga',
#   'suatu',
#   'skor',
#   'sama',
#   'georgia'],
#  '1002905': ['farrel', 'bram', 'usaha', 'kejar', 'mischa'],
#  '1003239': ['pada',
#   'waktu',
#   'belum',
#   'jadi',
#   'pisah',
#   'administratif',
#   'gubernur',
#   'jenderal',
#   'keluar',
#   'surat',
#   'putus',
#   'khusus',
#   'batal',
#   'atur',
#   'am',
#   'gereja',
#   'protestan',
#   'jauh',
#   'sangkut',
#   'minahasa'],
#  '1003602': ['tanggal',
#   '23',
#   'maret',
#   '1946',
#   'tentara',
#   'sekutu',
#   'keluar',
#   'ultimatum',
#   'ke2'],
#  '1003912': ['bulan',
#   'mei',
#   '1946',
#   'project',
#   'rand',
#   'keluar',
#   'desain',
#   'preliminari',
#   'experimen',
#   'wahana',
#   'angkasa',
#   'dari',
#   'dunia',
#   'nyata',
#   'buah',
#   'kendara',
#   'satelit',
#   'isi',
#   'instrumentasi',
#   'tepat',
#   'harap',
#   'jadi',
#   'alat',
#   'ilmu',
#   'canggih',
#   'abad',
#   'duapuluh'],
#  '1004296': ['the',
#   'misfits',
#   'terima',
#   'tawar',
#   'dan',
#   'putus',
#   'kerja',
#   'rekam',
#   'belum',
#   'slash',
#   'records',
#   'keluar',
#   'album'],
#  '1004440': ['keluar',
#   'kartu',
#   'kita',
#   'mana',
#   'sesuai',
#   'tera',
#   'pojok',
#   'kiri',
#   'atas',
#   'kartu',
#   'misal',
#   'tera',
#   '5',
#   'kita',
#   'harus',
#   'korban',
#   '5',
#   'mana'],
#  '1004753': ['akhir',
#   'gubernur',
#   'dki',
#   'jakarta',
#   'bapak',
#   'wiyogo',
#   'atmodarminto',
#   'keluar',
#   'surat',
#   'izin',
#   'bangun',
#   'gereja',
#   'nomor',
#   '612',
#   '1',
#   '857',
#   '1',
#   'tanggal',
#   '27',
#   'januari',
#   '1987'],
#  '1004898': ['telah', 'keluar', 'puluh', 'album', 'rohani'],
#  '1004921': ['adil',
#   'korea',
#   'selatan',
#   'terima',
#   'klaim',
#   'dan',
#   'putus',
#   'dorong',
#   'komisi',
#   'dagang',
#   'adil',
#   'negara',
#   'keluar',
#   'model',
#   'kontrak',
#   'baik',
#   'situasi',
#   'boyband'],
#  '1005109': ['tak',
#   'lama',
#   'itu',
#   'kaisar',
#   'keluar',
#   'buah',
#   'edik',
#   'antikatolik',
#   'sebab',
#   'aniaya',
#   'jadi'],
#  '1005298': ['asosiasi',
#   'islam',
#   'china',
#   'keluar',
#   'pesan',
#   'semua',
#   'muslim',
#   'china',
#   'asosiasi',
#   'islam',
#   'china',
#   'selamat',
#   'nasional',
#   'lama',
#   'bulan',
#   'ramadhan',
#   '1940'],
#  '1005471': ['dengar',
#   'suara',
#   'jun',
#   'lebih',
#   'banyak',
#   'takumi',
#   'izin',
#   'jun',
#   'keluar',
#   'semua',
#   'marah',
#   'rasa',
#   'frustasinya',
#   'hingga',
#   'jun',
#   'rasa',
#   'puas'],
#  '1005946': ['sukses',
#   'main',
#   'nobunaga',
#   's',
#   'ambition',
#   'guna',
#   'latar',
#   'belakang',
#   'sejarah',
#   'jepang',
#   'tahun',
#   '1983',
#   'koe',
#   'keluar',
#   'beberapa',
#   'main',
#   'hubung',
#   'sejarah',
#   'mulai',
#   'romance',
#   'of',
#   'three',
#   'kingdom',
#   'latar',
#   'belakang',
#   'sejarah',
#   'tiongkok',
#   'suikoden',
#   'juga',
#   'sejarah',
#   'tiongkok',
#   'uncharted',
#   'waters',
#   'yang',
#   'bersetting',
#   'portugal'],
#  '1006024': ['dupa', 'keluar', 'asap', 'bakar'],
#  '1006074': ['henry',
#   'yule',
#   'keluar',
#   'beberapa',
#   'jelas',
#   'nama',
#   'negosiator',
#   'bizantium',
#   'yenyo',
#   'bangsawan',
#   'john',
#   'pitzigaudes',
#   'sebut',
#   'sumber',
#   'tiongkok',
#   'orang',
#   'duta',
#   'tidak',
#   'sebut',
#   'nama',
#   'catat',
#   'edward',
#   'gibbon',
#   'orang',
#   'pria',
#   'kirim',
#   'damaskus',
#   'beri',
#   'buah',
#   'bingkis',
#   'umayyah',
#   'beberapa',
#   'tahun',
#   'kemudian',
#   'tingkat',
#   'tuntut',
#   'upati',
#   'hadap',
#   'bizantium'],
#  '1006897': ['mahkamah',
#   'konstitusi',
#   'italia',
#   'keluar',
#   'putus',
#   'maret',
#   '1964'],
#  '1007897': ['tanggal',
#   '4',
#   'maret',
#   '2009',
#   'mahkamah',
#   'pidana',
#   'internasional',
#   'icc',
#   'keluar',
#   'surat',
#   'perintah',
#   'tangkap',
#   'hadap',
#   'presiden',
#   'sudan',
#   'omar',
#   'albashir',
#   'atas',
#   'tuduh',
#   'bagai',
#   'tindak',
#   'laku',
#   'wilayah',
#   'darfur'],
#  '1007903': ['gunung', 'pernah', 'keluar', 'letus', 'kecil', 'tahun', '1789'],
#  '1009104': ['masalah',
#   'utama',
#   'mereka',
#   'hadap',
#   'keluar',
#   'kecil',
#   'tiap',
#   'sidik',
#   'jari',
#   'juga',
#   'banding',
#   'cocok',
#   'juga',
#   'cari',
#   'daftar',
#   'kecil',
#   'daftar',
#   'besar',
#   'sidik',
#   'jari'],
#  '1009443': ['simpati',
#   'publik',
#   'dukung',
#   'aktivis',
#   'freedom',
#   'rides',
#   'akhir',
#   'buat',
#   'perintah',
#   'kennedy',
#   'minta',
#   'interstate',
#   'commerce',
#   'commission',
#   'icc',
#   'keluar',
#   'perintah',
#   'desegregasi',
#   'baru'],
#  '1009516': ['ham',
#   'keluar',
#   'perintah',
#   'semua',
#   'orang',
#   'lutut',
#   'sujud',
#   'tiap',
#   'kali',
#   'lewat'],
#  '1009711': ['tahun',
#   '2008',
#   'sanny',
#   'sama',
#   '3',
#   'rekan',
#   'pernah',
#   'bentuk',
#   'grup',
#   'musik',
#   'yaitu',
#   'forward',
#   'band',
#   'keluar',
#   'album',
#   'indie'],
#  '1010004': ['psis',
#   'semarang',
#   'jadi',
#   'klub',
#   'profesional',
#   'pertama',
#   'dwi',
#   'candra',
#   'resmi',
#   'ikat',
#   'kontrak',
#   'awal',
#   'juni',
#   '2016'],
#  '1010054': ['turut',
#   'komite',
#   'selenggara',
#   'tuju',
#   'konferensi',
#   'tahun',
#   '2015',
#   'adalah',
#   'capai',
#   'suatu',
#   'sepakat',
#   'iklim',
#   'ikat',
#   'universal',
#   'semua',
#   'negara',
#   'dunia',
#   'anda',
#   'capai',
#   'jadi',
#   'sepakat',
#   'pertama',
#   'kali',
#   'lama',
#   'lebih',
#   '20',
#   'tahun',
#   'bagai',
#   'runding',
#   'pbb'],
#  '1010142': ['darat',
#   'istana',
#   'kaisar',
#   'mana',
#   'wang',
#   'usul',
#   'bunuh',
#   'ratu',
#   'tao',
#   'tieh',
#   'ikat',
#   'bahan',
#   'ledak',
#   'tao',
#   'tieh',
#   'tangkap',
#   'beri',
#   'daging',
#   'kirim',
#   'bagai',
#   'makan',
#   'ratu',
#   'tao',
#   'tieh'],
#  '1010280': ['atur',
#   'main',
#   'sebut',
#   'norma',
#   'kaidah',
#   'jadi',
#   'lebih',
#   'konkret',
#   'sifat',
#   'ikat',
#   'perlu',
#   'lembaga',
#   'institusi'],
#  '1010281': ['hasil', 'survei', 'tidak', 'ikat', 'cara', 'hukum'],
#  '1010378': ['lembaga',
#   'dapat',
#   'keluar',
#   'rekomendasi',
#   'opini',
#   'hanya',
#   'nonmengikat',
#   'deklarasi'],
#  '1010435': ['meski',
#   'sekarang',
#   'beda',
#   'dalam',
#   'antara',
#   'denominasi',
#   'yahudi',
#   'yuda',
#   'rabinik',
#   'hubung',
#   'kuat',
#   'ikat',
#   'halakha',
#   'hukum',
#   'agama',
#   'yahudi',
#   'mau',
#   'tantang',
#   'interpretasi',
#   'belum',
#   'semua',
#   'ikut',
#   'identifikasi',
#   'diri',
#   'bagai',
#   'asal',
#   'tradisi',
#   'hukum',
#   'lisan',
#   'metode',
#   'analisis',
#   'rabi'],
#  '1010454': ['konsulat',
#   'dewan',
#   'legislatif',
#   'wakil',
#   'rakyat',
#   'semua',
#   'satu',
#   'dewan',
#   'negara',
#   'dapat',
#   'jadi',
#   'opsional',
#   'tidak',
#   'ikat',
#   'raja'],
#  '1010626': ['hubung', 'makin', 'akrab', 'ikat', 'tali', 'tunang', 'sama'],
#  '1010789': ['dewa',
#   'para',
#   'asura',
#   'ikat',
#   'gunung',
#   'sebut',
#   'naga',
#   'wasuki',
#   'putar',
#   'gunung',
#   'sebut'],
#  '1010831': ['sistem',
#   'tidak',
#   'aku',
#   'wibawa',
#   'sidang',
#   'misal',
#   'sidang',
#   'sinode',
#   'ikat',
#   'buat',
#   'putus',
#   'final'],
#  '1010839': ['velcro',
#   'peranti',
#   'populer',
#   'ikat',
#   'sisi',
#   'kain',
#   'pertama',
#   'kali',
#   'cipta',
#   'tahun',
#   '1948',
#   'insinyur',
#   'listrik',
#   'nama',
#   'george',
#   'de',
#   'mestral'],
#  '1010851': ['unsur',
#   'negara',
#   'hukum',
#   'pertama',
#   'hubung',
#   'perintah',
#   'perintah',
#   'dasar',
#   'kuasa',
#   'dasar',
#   'suatu',
#   'norma',
#   'objektif',
#   'yang',
#   'juga',
#   'ikat',
#   'pihak',
#   'yang',
#   'perintah',
#   'dua',
#   'norma',
#   'objektif',
#   'harus',
#   'penuh',
#   'syarat',
#   'tidak',
#   'cara',
#   'formal',
#   'dapat',
#   'tahan',
#   'hadap',
#   'idea',
#   'hukum'],
#  '1010888': ['iket', 'kandung', 'makna', 'ikat', 'kepala'],
#  '1011394': ['tiba',
#   'stasiun',
#   'medan',
#   'loko',
#   'tarik',
#   'lepas',
#   'rangkai',
#   'kereta',
#   'langsung',
#   'tuju',
#   'dipo',
#   'lokomotif',
#   'medan',
#   'ecek',
#   'kondisi',
#   'loko',
#   'isi',
#   'bahan',
#   'bakar',
#   'nama',
#   'high',
#   'speed',
#   'diesel',
#   'hsd'],
#  '1011525': ['wakil', 'partai', 'gerindra', 'isi', 'kursi', 'banyak'],
#  '1011782': ['isi',
#   'hari',
#   'ambil',
#   'ajar',
#   'piano',
#   'kenang',
#   'mendiang',
#   'istri',
#   'jarang',
#   'susun',
#   'buku',
#   'baru'],
#  '1011792': ['rencana',
#   'peran',
#   'bagai',
#   'doug',
#   'the',
#   'thug',
#   'glatt',
#   'sekuel',
#   'datang',
#   'dia',
#   'akan',
#   'isi',
#   'suara',
#   'karakter',
#   'crash',
#   'ice',
#   'age',
#   '5',
#   'rencana',
#   'akan',
#   'rilis',
#   '2016',
#   'datang'],
#  '1011833': ['laksamana',
#   'cheng',
#   'ho',
#   'mula',
#   'labuh',
#   'quanzhou',
#   'isi',
#   'kargo',
#   'armada',
#   'sebut',
#   'porselen',
#   'barang'],
#  '1011852': ['paksa', 'meni', 'isi', 'dunia', 'manusia'],
#  '1012083': ['seri',
#   'ponsel',
#   'infinix',
#   'masuk',
#   'kategori',
#   'kelas',
#   'tengah',
#   'seri',
#   'note',
#   'milik',
#   'ciri',
#   'khas',
#   'desain',
#   'bongsor',
#   'baterai',
#   'kapasitas',
#   'besar',
#   'milik',
#   'fitur',
#   'mampu',
#   'isi',
#   'ulang',
#   'daya',
#   'cepat'],
#  '1012237': ['saat',
#   'isi',
#   'bensin',
#   'sabine',
#   'lihat',
#   'berita',
#   'orang',
#   'buron',
#   'anak',
#   'hilang'],
#  '1012706': ['monster',
#   'yamaha',
#   'tech',
#   '3',
#   'sangat',
#   'senang',
#   'potensi',
#   'menandatangani',
#   'hafizh',
#   'isi',
#   'kursi',
#   'jonas',
#   'folger',
#   'musim',
#   '2018'],
#  '1012765': ['isi',
#   'hari',
#   'tekun',
#   'kerja',
#   'bagai',
#   'tani',
#   'kopi',
#   'desa',
#   'baturetno',
#   'camat',
#   'dampit',
#   'kabupaten',
#   'malang'],
#  '1012786': ['qatar',
#   'airways',
#   'isi',
#   'a319lr',
#   'tempat',
#   'duduk',
#   'standars',
#   'jumlah',
#   '110',
#   'kursi'],
#  '1012839': ['pencar',
#   'jadi',
#   'ke',
#   'arah',
#   'guam',
#   'rota',
#   'isi',
#   'bahan',
#   'bakar'],
#  '1013047': ['usai',
#   'tualang',
#   'amerika',
#   'cruyff',
#   'ke',
#   'ajax',
#   'sedia',
#   'isi',
#   'posisi',
#   'nasihat',
#   'teknik',
#   'latih',
#   'leo',
#   'beenhaker'],
#  '1013560': ['kam',
#   'terima',
#   'itu',
#   'ia',
#   'langsung',
#   'isi',
#   'kosong',
#   'pendeta',
#   'sejak',
#   '1800',
#   'akibat',
#   'tinggal',
#   'pendeta',
#   'kalang',
#   'veerenidge',
#   'oostindische',
#   'compagnie',
#   'voc'],
#  '1013870': ['tak',
#   'bukti',
#   'latar',
#   'belakang',
#   'pribadi',
#   'para',
#   'jabat',
#   'sebut',
#   'meski',
#   'pilih',
#   'anggota',
#   'sama',
#   'aristokratik',
#   'philoi',
#   'hetairoi',
#   'isi',
#   'kosong',
#   'para',
#   'perwira',
#   'tentara'],
#  '1014013': ['film',
#   'yang',
#   'hampir',
#   '100',
#   '500',
#   '000',
#   'fokus',
#   'manajer',
#   'bandara',
#   'usaha',
#   'jaga',
#   'bandara',
#   'buka',
#   'lama',
#   'badai',
#   'salju',
#   'bomber',
#   'bunuh',
#   'diri',
#   'rencana',
#   'ledak',
#   'buah',
#   'pesawat',
#   'boeing',
#   '707',
#   'terbang'],
#  '1014018': ['armada',
#   'baru',
#   'tiba',
#   'laut',
#   'marmara',
#   'jaga',
#   'jarak',
#   'armada',
#   'bizantium',
#   'labuh',
#   'pesisir',
#   'asia'],
#  '1014219': ['sulit', 'jaga', 'lancar', 'cash', 'flow'],
#  '1014613': ['kendali',
#   'kuat',
#   'atas',
#   'laut',
#   'merah',
#   'suleiman',
#   'hasil',
#   'aman',
#   'jalur',
#   'dagang',
#   'india',
#   'dahulu',
#   'asai',
#   'portugal',
#   'jaga',
#   'dagang',
#   'india',
#   'lama',
#   'abad',
#   'ke16'],
#  '1014733': ['kala',
#   'jaga',
#   'sakit',
#   'jantung',
#   'kambuh',
#   'saskia',
#   'malah',
#   'urus',
#   'braga',
#   'fero',
#   'walandouw',
#   'buruh',
#   'pabrik',
#   'baru',
#   'bawa',
#   'banyak',
#   'masalah'],
#  '1014871': ['alur',
#   'waris',
#   'rantau',
#   'pergi',
#   'luar',
#   'desa',
#   'biasa',
#   'tetap',
#   'jaga',
#   'kerabat',
#   'dengan',
#   'temu',
#   'rutin'],
#  '1015470': ['guna',
#   'bagai',
#   'aditif',
#   'makan',
#   'humektan',
#   'punya',
#   'efek',
#   'jaga',
#   'bahan',
#   'pangan',
#   'tetap',
#   'lembap'],
#  '1015525': ['adalah',
#   'motor',
#   'elektromagnetik',
#   'kendali',
#   'komputer',
#   'beri',
#   'suspensi',
#   'lembut',
#   'pada',
#   'yang',
#   'sama',
#   'jaga',
#   'tinggi',
#   'kendara',
#   'cara',
#   'aktif'],
#  '1016613': ['hse',
#   'alumni',
#   'club',
#   'tuju',
#   'jaga',
#   'hubung',
#   'alumni',
#   'beri',
#   'dukung',
#   'karier'],
#  '1016754': ['itu',
#   'harap',
#   'masyarakat',
#   'jaga',
#   'ruang',
#   'keluarga',
#   'doktrin',
#   'terorisme'],
#  '101698': ['kardinal',
#   'minta',
#   'transfer',
#   'gereja',
#   'tituler',
#   'baru',
#   'buah',
#   'konsistori',
#   'itu',
#   'kardinal',
#   'deakon',
#   'ambil',
#   'opsi',
#   'jadi',
#   'kardinal',
#   'imam',
#   'biasa',
#   'puluh',
#   'tahun',
#   'kardinal',
#   'pilih',
#   'transfer',
#   'kedeakonan',
#   'ke',
#   'gelar',
#   'lowong',
#   'kedeakonannya',
#   'angkat',
#   'status',
#   'pro',
#   'hac',
#   'vice',
#   'khusus',
#   'buah',
#   'titel'],
#  '1017199': ['perangkat',
#   'android',
#   'umum',
#   'tenaga',
#   'baterai',
#   'android',
#   'rancang',
#   'kelola',
#   'memori',
#   'ram',
#   'jaga',
#   'konsumsi',
#   'daya',
#   'minimal',
#   'beda',
#   'sistem',
#   'operasi',
#   'desktop',
#   'bisa',
#   'hubung',
#   'sumber',
#   'daya',
#   'listrik',
#   'tak',
#   'batas'],
#  '1017285': ['mampu',
#   'tangan',
#   'arus',
#   'mesfet',
#   'baik',
#   'gerbang',
#   'panjang',
#   'samping',
#   'jaga',
#   'daerah',
#   'aktif',
#   'tetap',
#   'konstan',
#   'batas',
#   'geser',
#   'fase',
#   'panjang',
#   'gerbang',
#   'efek',
#   'jalur',
#   'transmisi'],
#  '1017406': ['wajib',
#   'dari',
#   'menteri',
#   'tani',
#   'beberapa',
#   'negara',
#   'jaga',
#   'langsung',
#   'lingkung',
#   'hidup'],
#  '1017682': ['peran',
#   'satyaki',
#   'tampak',
#   'tonjol',
#   'hari',
#   'ke14',
#   'ia',
#   'tugas',
#   'arjuna',
#   'jaga',
#   'yudistira',
#   'serang',
#   'drona'],
#  '1018227': ['orang',
#   'betawi',
#   'sangat',
#   'jaga',
#   'nilai',
#   'agama',
#   'cermin',
#   'ajar',
#   'orangtua',
#   'utama',
#   'agama',
#   'islam',
#   'anak'],
#  '1018464': ['tahun',
#   '1409',
#   'marguerite',
#   'de',
#   'tri',
#   'cucu',
#   'arnaud',
#   'jadi',
#   'istri',
#   'george',
#   'de',
#   'castellane',
#   'dengan',
#   'bawa',
#   'wilayah',
#   'montmeyan',
#   'keluarga',
#   'castellane',
#   'jaga',
#   'daerah',
#   'lama',
#   'lebih',
#   'tiga',
#   'abad'],
#  '1019067': ['tahu',
#   'langgar',
#   'yan',
#   'luo',
#   'wang',
#   'hukum',
#   'niu',
#   'tou',
#   'ma',
#   'mi',
#   'hukum',
#   'pukul',
#   'ubah',
#   'kepala',
#   'manusia',
#   'jadi',
#   'kerbau',
#   'kuda',
#   'turun',
#   'pangkat',
#   'di',
#   'bawah',
#   'hakim',
#   'cui'],
#  '1019113': ['tahun',
#   '1972',
#   'nascar',
#   'tahap',
#   'buat',
#   'buah',
#   'atur',
#   'turun',
#   'pindah',
#   'mesin',
#   'maksimum',
#   '429',
#   'kubik',
#   'inci',
#   '7',
#   '0',
#   'liter',
#   '358',
#   'kubik',
#   'inci',
#   '5',
#   '8',
#   'liter',
#   'jadi',
#   'standar',
#   'sekarang'],
#  '1019233': ['perlu',
#   'olah',
#   'citra',
#   'meski',
#   'format',
#   'png',
#   'jadi',
#   'alternatif',
#   'lama',
#   'proses',
#   'olah',
#   'citra',
#   'format',
#   'selain',
#   'hilang',
#   'citra',
#   'sedang',
#   'olah',
#   'simpan',
#   'ulang',
#   'ulang',
#   'dari',
#   'citra',
#   'akan',
#   'turun',
#   'kualitas',
#   'citra',
#   'format',
#   'jpeg',
#   'jadi',
#   'pilih',
#   'lebih',
#   'baik'],
#  '1019241': ['langkah',
#   'ambil',
#   'turun',
#   'harga',
#   'minyak',
#   'dunia',
#   'cenderung',
#   'lonjak'],
#  '1019350': ['faktor',
#   'turun',
#   'kontraktilitas',
#   'milik',
#   'aksi',
#   'inotropik',
#   'negatif'],
#  '1019464': ['bagai',
#   'suatu',
#   'kelompok',
#   'antihipertensi',
#   'untuk',
#   'turun',
#   'tekan',
#   'darah',
#   'tingkat',
#   'normal',
#   '90',
#   'mmhg',
#   'diastolik',
#   'sampai',
#   'tingkat',
#   'palig',
#   'rendah',
#   'dapat',
#   'toleransi'],
#  '1019792': ['turut',
#   'sumner',
#   'musik',
#   'sangat',
#   'keras',
#   'berat',
#   'kami',
#   'rasa',
#   'martin',
#   'turun',
#   'lebih',
#   'rendah',
#   'utama',
#   'gitar'],
#  '1019990': ['hancur',
#   'habitat',
#   'gilir',
#   'turun',
#   'tingkat',
#   'keanekaragaman',
#   'hayati',
#   'pengaruh',
#   'bukan',
#   'lestari',
#   'hutan',
#   'primer',
#   'sendiri',
#   'juga',
#   'spesies',
#   'asli',
#   'hidup',
#   'gantung',
#   'pada',
#   'lingkung',
#   'sedia',
#   'hutan',
#   'primer'],
#  '1020045': ['gabung',
#   'kontrasepsi',
#   'suntik',
#   'tiga',
#   'cycloprovera',
#   'direformulasi',
#   'tahun',
#   '1980',
#   'turun',
#   'dosis',
#   'ganti',
#   'nama',
#   'cyclofem',
#   'sebut',
#   'lunelle'],
#  '1020256': ['b',
#   's',
#   'haldane',
#   'turun',
#   'sama',
#   'kinetik',
#   'saat',
#   'masih',
#   'banyak',
#   'anggap',
#   'bagai',
#   'titik',
#   'awal',
#   'model',
#   'aktivitas',
#   'enzimatik'],
#  '1020882': ['peristiwa',
#   'akhir',
#   'ikut',
#   'turun',
#   'populer',
#   'gera',
#   'kiri',
#   'jepang'],
#  '1021126': ['mati',
#   'raja',
#   'arnulf',
#   'paus',
#   'akhir',
#   'kirim',
#   'wali',
#   'tahbis',
#   'uskup',
#   'agung',
#   'moravia',
#   'raya',
#   '3',
#   'uskup',
#   'tahun',
#   '899',
#   'turun',
#   'pengaruh',
#   'utama',
#   'klerus',
#   'bayern'],
#  '1021284': ['awal',
#   'perintah',
#   'jalan',
#   'bijak',
#   'positif',
#   'turun',
#   'pajak',
#   'kuat',
#   'raja',
#   'ini',
#   'sebentar',
#   'tak',
#   'lama',
#   'kemudian',
#   'kuasa',
#   'pemerintahaan',
#   'jatuh',
#   'tangan',
#   'kasim'],
#  '1021324': ['kennedy',
#   'siap',
#   'turun',
#   'garda',
#   'nasional',
#   'alabama',
#   'bila',
#   'perlu'],
#  '1021394': ['sebab',
#   'saing',
#   'sekitar',
#   'sebab',
#   'hasil',
#   'lebih',
#   'turut',
#   'turun',
#   'biaya',
#   'beli',
#   'bahan',
#   'mentah'],
#  '1021416': ['kaji',
#   'sebut',
#   'bentuk',
#   'suatu',
#   'kelompok',
#   'kerja',
#   'cara',
#   'rutin',
#   'laku',
#   'kaji',
#   'lanjut',
#   'susun',
#   'rencana',
#   'bentuk',
#   'suatu',
#   'pusat',
#   'studi',
#   'kota'],
#  '1021461': ['dong',
#   'zhuo',
#   'pindah',
#   'ibukota',
#   'chang',
#   'an',
#   'menteri',
#   'negeri',
#   'wang',
#   'yun',
#   'mulai',
#   'susun',
#   'rencana',
#   'bunuh',
#   'dong',
#   'zhuo',
#   'guna',
#   'diao',
#   'chan'],
#  '1021597': ['kardinal',
#   'boromeus',
#   'ungkap',
#   'apabila',
#   'don',
#   'nicola',
#   'orang',
#   'komponis',
#   'gaya',
#   'lebih',
#   'kromatis',
#   'di',
#   'mil',
#   'ia',
#   'susun',
#   'suatu',
#   'komposisi',
#   'misa',
#   'dua',
#   'dapat',
#   'banding',
#   'hal',
#   'jelas',
#   'tekstual'],
#  '1021685': ['telah', 'susun', 'jumlah', 'program', 'akan', 'laku'],
#  '1021690': ['50',
#   'tahun',
#   '1993',
#   'bentuk',
#   'komisi',
#   'nasional',
#   'hak',
#   'asasi',
#   'manusia',
#   'komnas',
#   'ham',
#   'pada',
#   'yang',
#   'sama',
#   'tunjuk',
#   'pensiun',
#   'ketua',
#   'mahkamah',
#   'agung',
#   'ri',
#   'ali',
#   'said',
#   'susun',
#   'komisi',
#   'sebut',
#   'pilih',
#   'anggota'],
#  '1021862': ['maharsi',
#   'visvamitra',
#   'rsirsi',
#   'lain',
#   'susun',
#   'sastra',
#   'dhanurveda',
#   'daam',
#   '4',
#   'bab'],
#  '1021881': ['lapor',
#   'ubah',
#   'saldo',
#   'anggar',
#   'lebih',
#   'sal',
#   'saji',
#   'informasi',
#   'naik',
#   'turun',
#   'sal',
#   'tahun',
#   'lapor',
#   'banding',
#   'tahun',
#   'saji',
#   'bendahara',
#   'umum',
#   'negara',
#   'dan',
#   'entitas',
#   'lapor',
#   'susun',
#   'lapor',
#   'uang',
#   'konsolidasi'],
#  '1021962': ['adapun',
#   'rangka',
#   'jalan',
#   'perintah',
#   'daerah',
#   'duduk',
#   'kaigun',
#   'susun',
#   'perintah'],
#  '1021997': ['8',
#   'april',
#   '2007',
#   'keluarga',
#   'kung',
#   'umum',
#   'mereka',
#   'susun',
#   'buah',
#   'daftar',
#   '45',
#   'nama',
#   'akan',
#   'jadi',
#   'anggota',
#   'komite',
#   'makam',
#   'nina',
#   'wang'],
#  '1022085': ['tiga',
#   'bulan',
#   'depan',
#   'minta',
#   'bupati',
#   'wakil',
#   'bupati',
#   'susun',
#   'rencana',
#   'bangun',
#   'jangka',
#   'tengah',
#   'rpjm',
#   'kabupaten',
#   'aceh',
#   'utara'],
#  '1022467': ['biro',
#   'hasil',
#   'susun',
#   'rencana',
#   'bangun',
#   'lima',
#   'tahun',
#   'rplt',
#   'rencana',
#   'laksana',
#   'tahun',
#   '19561961',
#   'tuju',
#   'dpr',
#   'tanggal',
#   '11',
#   'november',
#   '1958'],
#  '1022476': ['mula',
#   'gratisagen',
#   'biasa',
#   'bayar',
#   'susun',
#   'main',
#   'hampir',
#   'semua',
#   'mereka',
#   'menandatangani',
#   'yang',
#   'tentu',
#   'rookie',
#   'minimum',
#   'bonus',
#   'penandatanganan'],
#  '1022738': ['jiang',
#   'wei',
#   'balik',
#   'komplot',
#   'liu',
#   'shan',
#   'susun',
#   'rencana',
#   'kelabu',
#   'zhong',
#   'hui',
#   'laku',
#   'ronta',
#   'akan',
#   'lemah',
#   'pasu',
#   'wei'],
#  '1022955': ['atom',
#   'atom',
#   'susun',
#   'zat',
#   'padat',
#   'vibrasi',
#   'hadap',
#   'posisi',
#   'keseimbanganya',
#   'kisi',
#   'kisi',
#   'kristal',
#   'ikut',
#   'vibrasi'],
#  '1023203': ['beberapa',
#   'tentang',
#   'gagal',
#   'sartono',
#   'susun',
#   'kabinet',
#   'waktu'],
#  '1023313': ['pindah',
#   'bus',
#   'tahun',
#   '1991',
#   'tinggal',
#   'sana',
#   'sma',
#   'mana',
#   'pertama',
#   'mulai',
#   'susun',
#   'lagu'],
#  '1023489': ['tahun',
#   '2002',
#   'perintah',
#   'kota',
#   'magelang',
#   'susun',
#   'master',
#   'plan',
#   'alun',
#   'kota',
#   'magelang',
#   'kemudian',
#   'jadi',
#   'bagai',
#   'dasar',
#   'giat',
#   'renovasi',
#   'alun'],
#  '1023652': ['mikat',
#   'inwook',
#   'kamp',
#   'susun',
#   'rencana',
#   'biaya',
#   'pompa',
#   'uang',
#   'ayah',
#   'investasi',
#   'eksternal'],
#  '1026068': ['portal',
#   'buat',
#   'sedia',
#   'informasi',
#   'harga',
#   'pangan',
#   'kini',
#   'cara',
#   'akurat',
#   'seluruh',
#   'pasar',
#   'tradisional',
#   'jawa',
#   'barat',
#   'bagai',
#   'upaya',
#   'jaga',
#   'daya',
#   'beli',
#   'masyarakat',
#   'tingkat',
#   'nilai',
#   'tambah',
#   'tani',
#   'stabilitas',
#   'harga',
#   'pangan',
#   'baik',
#   'manajemen',
#   'kendali',
#   'inflasi',
#   'jawa',
#   'barat'],
#  '1027256': ['anomali',
#   'gravitasi',
#   'beda',
#   'gravitasi',
#   'observasi',
#   'nilai',
#   'prediksi',
#   'model'],
#  '1028330': ['chen',
#   'anak',
#   'ayah',
#   'baca',
#   'karya',
#   'sastra',
#   'kabar',
#   'bantu',
#   'pikir',
#   'putra',
#   'hadap',
#   'nilai',
#   'demokrasi',
#   'dan',
#   'bebas'],
#  '1028771': ['tumbuh',
#   'lerak',
#   'bentuk',
#   'pohon',
#   'rata',
#   'milik',
#   'tinggi',
#   '10m',
#   'walaupun',
#   'capai',
#   '42',
#   'meter',
#   'diameter',
#   '1m',
#   'pohon',
#   'lerak',
#   'besar',
#   'kualitas',
#   'kayu',
#   'tara',
#   'kayu',
#   'jati',
#   'banyak',
#   'tebang',
#   'milik',
#   'nilai',
#   'ekonomis'],
#  '1028797': ['komika',
#   'hasil',
#   'kumpul',
#   'nilai',
#   'tinggi',
#   'tiga',
#   'putar',
#   'sebut',
#   'nobat',
#   'bagai',
#   'juara',
#   'stand',
#   'up',
#   'comedy',
#   'indonesia'],
#  '1029290': ['nilai',
#   'moral',
#   'tindak',
#   'dapat',
#   'simpul',
#   'analis',
#   'tindak',
#   'dasar',
#   'akar',
#   'jahat',
#   'tidak'],
#  '103103': ['oleh',
#   'ini',
#   'hancur',
#   'tank',
#   'model',
#   'baru',
#   'meriam',
#   '88',
#   'mm',
#   'mulai',
#   'produksi'],
#  '1035379': ['kesah',
#   'kkl',
#   'kelas',
#   'xii',
#   'jadi',
#   'kekl',
#   'malam',
#   'pisah',
#   'hadir',
#   'para',
#   'orangtua',
#   'murid',
#   'guru',
#   'umum',
#   'juara',
#   'nilai',
#   'un',
#   'acara',
#   'sebut'],
#  '1037678': ['tnbnw',
#   'milik',
#   'nilai',
#   'jasa',
#   'lingkung',
#   'wisata',
#   'manfaat',
#   'air',
#   'manfaat',
#   'masyarakat',
#   'kawasan'],
#  '1038466': ['akhir',
#   'perintah',
#   'utama',
#   'pertanggungjawabannya',
#   'tolak',
#   'mpr',
#   'nilai',
#   'tukar',
#   'rupiah',
#   'roket',
#   'naik',
#   'pada',
#   'level',
#   'rp',
#   '6500',
#   'per',
#   'dolar',
#   'as',
#   'nilai',
#   'tidak',
#   'pernah',
#   'capai',
#   'di',
#   'era',
#   'perintah',
#   'lanjut'],
#  '1041243': ['sedang',
#   'sumbu',
#   'horisontal',
#   'lihat',
#   'bagi',
#   'ruang',
#   'rumah',
#   'tidak',
#   'sekat',
#   'saling',
#   'satu',
#   'satu',
#   'rumah',
#   'rumah',
#   'belah',
#   'ini',
#   'kandung',
#   'nilai',
#   'manusia',
#   'tinggi'],
#  '1041533': ['lanjut',
#   'batas',
#   'kontrol',
#   'atas',
#   'ucl',
#   'upper',
#   'control',
#   'limit',
#   'batas',
#   'kontrol',
#   'bawah',
#   'lcl',
#   'lower',
#   'contro',
#   'limit',
#   'nilai',
#   'individual',
#   'hitung',
#   'tambah',
#   'kurang',
#   '2',
#   '66',
#   'kali',
#   'rata',
#   'moving',
#   'range',
#   'hadap',
#   'rata',
#   'nilai',
#   'inidividual'],
#  '1041634': ['variabel',
#   'acak',
#   'x',
#   't',
#   'risi',
#   'nilai',
#   'buah',
#   'variabel',
#   'sembunyi',
#   'saat',
#   't',
#   'variabel',
#   'acak',
#   'y',
#   't',
#   'risi',
#   'nilai',
#   'buah',
#   'variabel',
#   'dapat',
#   'tidak',
#   'sembunyi',
#   'saat',
#   't',
#   'anak',
#   'panah',
#   'tunjuk',
#   'gantung',
#   'kondisional'],
#  '1042335': ['musim',
#   'panas',
#   '655',
#   'wu',
#   'dakwa',
#   'permaisuri',
#   'wang',
#   'ibu',
#   'orang',
#   'wanita',
#   'keluarga',
#   'liu',
#   'atas',
#   'duga',
#   'laku',
#   'sihir'],
#  '1042598': ['rilis',
#   'album',
#   'pertama',
#   'dan',
#   'beberapa',
#   'promo',
#   'intens',
#   'auryn',
#   'jadi',
#   'salah',
#   'satu',
#   'artis',
#   'spanyol',
#   'milik',
#   'jadwal',
#   'konser',
#   'banyak',
#   'musim',
#   'panas',
#   '2012',
#   'total',
#   '80',
#   'jadwal',
#   'tahun'],
#  '1043386': ['povenmire',
#   'marsh',
#   'serial',
#   'sebut',
#   'cermin',
#   'kenang',
#   'masa',
#   'kecil',
#   'sendiri',
#   'kencan',
#   'lama',
#   'musim',
#   'panas',
#   'senang',
#   'gali',
#   'parit',
#   'bangun',
#   'terowongan',
#   'benteng',
#   'rumah',
#   'pohon'],
#  '1043464': ['musim',
#   'panas',
#   '2003',
#   'kristin',
#   'kreuk',
#   'tampil',
#   'cemerlang',
#   'jadi',
#   'bintang',
#   'utama',
#   'film',
#   'layar',
#   'lebar',
#   'pertama',
#   'eurotrip',
#   '2004',
#   'juga',
#   'bintang',
#   'lain',
#   'scott',
#   'mechlowicz',
#   'michelle',
#   'trachtenberg'],
#  '104562': ['gauguin',
#   'langsung',
#   'memberitahukan',
#   'theo',
#   'kena',
#   'peristiwa',
#   'padahal',
#   'theo',
#   'baru',
#   'lamar',
#   'saudara',
#   'perempuan',
#   'andries',
#   'bonger',
#   'teman',
#   'lama',
#   'theo',
#   'nama',
#   'johanna',
#   'tanggal',
#   '24',
#   'desember'],
#  '1045721': ['lalu',
#   'analisis',
#   'hadap',
#   'sebut',
#   'tahu',
#   'posisi',
#   'matahari',
#   'benam',
#   'titik',
#   'balik',
#   'musim',
#   'panas',
#   'posisi',
#   'matahari',
#   'terbit',
#   'saat',
#   'titik',
#   'ekuinoks',
#   'segar',
#   'patung',
#   'sphinx',
#   'ada',
#   'dalam',
#   'kompleks',
#   'piramida'],
#  '1046175': ['lima',
#   'musim',
#   'moldova',
#   'krkoti',
#   'ke',
#   'zeta',
#   'musim',
#   'panas',
#   '2016',
#   'kerja',
#   'cukup',
#   'solid',
#   'cetak',
#   '4',
#   'gol',
#   '15',
#   'tampil',
#   'lama',
#   'paruh',
#   'pertama',
#   'musim',
#   '201617',
#   'liga',
#   'pertama',
#   'montenegro'],
#  '1046307': ['pattaya',
#   'milik',
#   'iklim',
#   'tropis',
#   'kering',
#   'basah',
#   'bagi',
#   'jadi',
#   'musim',
#   'ikut',
#   'panas',
#   'kering',
#   'desember',
#   'hingga',
#   'februari',
#   'panas',
#   'lembat',
#   'maret',
#   'april',
#   'panas',
#   'hujan',
#   'mei',
#   'hingga',
#   'november'],
#  '1047051': ['troy',
#   'rencana',
#   'cari',
#   'kerja',
#   'musim',
#   'panas',
#   'kumpul',
#   'uang',
#   'buat',
#   'kuliah'],
#  '1047160': ['konveksi',
#   'termal',
#   'jadi',
#   'panas',
#   'alir',
#   'lalu',
#   'medium',
#   'serta',
#   'pindah',
#   'molekul',
#   'susun',
#   'material',
#   'sebut'],
#  '1048552': ['chevron',
#   'indoasia',
#   'business',
#   'unit',
#   'cakup',
#   'bisnis',
#   'minyak',
#   'gas',
#   'diri',
#   'cico',
#   'chevron',
#   'pacific',
#   'indonesia',
#   'chevron',
#   'makassar',
#   'ltd',
#   'bisnis',
#   'panas',
#   'bumi',
#   'diri',
#   'chevron',
#   'geothermal',
#   'indonesia',
#   'chevron',
#   'geothermal',
#   'salak',
#   'mandau',
#   'cipta',
#   'tenaga',
#   'nusantara',
#   'chevron',
#   'geothermal',
#   'phillipines'],
#  '1049081': ['lewat',
#   'musim',
#   'panas',
#   'panjang',
#   'tahun',
#   '1664',
#   '1665',
#   'london',
#   'landa',
#   'kering',
#   'luar',
#   'biasa',
#   'sejak',
#   'bulan',
#   'november',
#   '1665'],
#  '1049996': ['abad',
#   'ke1',
#   'm',
#   'filo',
#   'aleksandria',
#   'bahas',
#   'kitab',
#   'suci',
#   'tidak',
#   'sebut',
#   'kena',
#   'alkitab',
#   'sebut',
#   'jadi',
#   'tiga',
#   'meski',
#   'de',
#   'vita',
#   'contemplativa',
#   'karya',
#   'abad',
#   'ke19',
#   'ragu',
#   'arang',
#   'nyata',
#   'bagi',
#   'iii',
#   '25',
#   'ajar',
#   'hukum',
#   'firman',
#   'kudus',
#   'allah',
#   'ucap',
#   'para',
#   'nabi',
#   'suci',
#   'himne',
#   'mazmur',
#   'segala',
#   'jenis',
#   'lain',
#   'akal',
#   'budi',
#   'yang',
#   'dari',
#   'tahu',
#   'saleh',
#   'tingkat',
#   'bawa',
#   'sempurna'],
#  '1051375': ['kota',
#   'waitakere',
#   'bagi',
#   'administratif',
#   'auckland',
#   'barat',
#   'selandia',
#   'baru'],
#  '1051625': ['bagi', 'wilayah', 'moro', 'ternate', 'bagi', 'besar'],
#  '1051749': ['rapat',
#   'pimpin',
#   'abri',
#   'tahun',
#   '2000',
#   'pakat',
#   'hapus',
#   'doktrin',
#   'yang',
#   'mulai',
#   'milu',
#   '2004',
#   'harap',
#   'selesai',
#   'milu',
#   '2009'],
#  '1051840': ['ojong', 'rapat', 'yayasan', 'tanggal', '3', 'juli', '1959'],
#  '1051848': ['bagai',
#   'presiden',
#   'konfederasi',
#   'leuthard',
#   'pimpin',
#   'rapat',
#   'dewan',
#   'federal',
#   'laksana',
#   'fungsi',
#   'wakil',
#   'biasa',
#   'tangan',
#   'orang',
#   'kepala',
#   'negara',
#   'negara',
#   'demokrasi',
#   'meski',
#   'swiss',
#   'dewan',
#   'federal',
#   'cara',
#   'seluruh',
#   'anggap',
#   'bagai',
#   'kepala',
#   'negara'],
#  '1052246': ['banyak',
#   'ilmuwan',
#   'sekarang',
#   'istilah',
#   'antroposen',
#   'masuk',
#   'geological',
#   'society',
#   'of',
#   'america',
#   'rapat',
#   'tahun',
#   'tahun',
#   '2011',
#   'beri',
#   'judul',
#   'archean',
#   'to',
#   'anthropocene',
#   'the',
#   'past',
#   'is',
#   'the',
#   'key',
#   'to',
#   'the',
#   'future'],
#  '1052333': ['beberapa',
#   'jual',
#   'jamu',
#   'tambah',
#   'bahan',
#   'yang',
#   'biasa',
#   'dalam',
#   'ramu',
#   'jamu',
#   'putih',
#   'jamu',
#   'sari',
#   'rapat',
#   'buah',
#   'delima',
#   'buah',
#   'pinang',
#   'kunci',
#   'pepet',
#   'maja'],
#  '1052415': ['itu',
#   'gubernur',
#   'jenderal',
#   'selenggara',
#   'rapat',
#   'majelis',
#   'konstituante',
#   'bulan',
#   'mei',
#   '1955',
#   'susun',
#   'kesah',
#   'konstitusi',
#   'pakistan',
#   'pada',
#   '29',
#   'februari',
#   '1956'],
#  '1052700': ['cisco',
#   'telepresence',
#   'guna',
#   'presentasi',
#   'kecil',
#   'rapat',
#   'negosiasi',
#   'interview',
#   'lain',
#   'bagai'],
#  '1052846': ['tumbuh',
#   'suka',
#   'tempat',
#   'panas',
#   'upa',
#   'perdu',
#   'panjat',
#   'tinggi',
#   'batang',
#   '2',
#   '5',
#   'm',
#   'batang',
#   'besar',
#   'jari',
#   'kelingking',
#   'bintil',
#   'rapat',
#   'rasa',
#   'pahit',
#   'sirih'],
#  '1052936': ['lanjut',
#   'serta',
#   'rapat',
#   'panggil',
#   'seluruh',
#   'balap',
#   'presentasi',
#   'rencana',
#   'atas'],
#  '1053076': ['dua',
#   'sayap',
#   'dapat',
#   'hall',
#   'cukup',
#   'besar',
#   'ukur',
#   '50',
#   'x',
#   '40',
#   'meter',
#   '8',
#   'kali',
#   'ruang',
#   'rapat',
#   'senat',
#   'rektorat',
#   'biasa',
#   'pakai',
#   'mahasiswa',
#   'unsri'],
#  '1053571': ['pakai',
#   'sarung',
#   'atur',
#   'tentu',
#   'bagai',
#   'beda',
#   'golong',
#   'bangsawan',
#   'rakyat',
#   'jelata'],
#  '1053574': ['juga',
#   'larang',
#   'biasa',
#   'kunyah',
#   'pinang',
#   'wanita',
#   'eropa',
#   'anjur',
#   'sarung',
#   'kalang'],
#  '1053602': ['pajak',
#   'yang',
#   'nama',
#   'wulusau',
#   'upa',
#   'uang',
#   'barang',
#   'beras',
#   'kain',
#   'putih',
#   'sarung',
#   'terus'],
#  '1053636': ['peri',
#   'rumah',
#   'pakai',
#   'pakai',
#   'sarung',
#   'bantal',
#   'serbet',
#   'teh',
#   'mereka',
#   'izin',
#   'milik',
#   'pakai'],
#  '1053651': ['busana',
#   'pengantin',
#   'laki',
#   'masa',
#   'awal',
#   'diri',
#   'atas',
#   'macam',
#   'sarung',
#   'kain',
#   'tenun',
#   'tangan',
#   'dhoti',
#   'selendang',
#   'tutup',
#   'bahu',
#   'saputangan',
#   'merah',
#   'kepala',
#   'leis'],
#  '1053673': ['adalah',
#   'landak',
#   'antropomorfik',
#   'biru',
#   'mata',
#   'hijau',
#   'kena',
#   'sarung',
#   'tangan',
#   'putih',
#   'sepatu',
#   'merah',
#   'putih'],
#  '1053701': ['iaido',
#   'kait',
#   'kendali',
#   'gera',
#   'tarik',
#   'pedang',
#   'cara',
#   'halus',
#   'sarung',
#   'pedang',
#   'juga',
#   'sebut',
#   'untuk',
#   'serang',
#   'dan',
#   'potong',
#   'lawan'],
#  '1053729': ['seluruh',
#   'kiper',
#   'pakai',
#   'sarung',
#   'tangan',
#   'desain',
#   'khusus',
#   'tangkap',
#   'bola',
#   'lindung',
#   'jari',
#   'tangan',
#   'cedera'],
#  '1053769': ['indonesia',
#   'sarung',
#   'identik',
#   'giat',
#   'agama',
#   'sholat',
#   'longyi',
#   'rupa',
#   'pakai',
#   'hari',
#   'bahkan',
#   'resmi',
#   'di',
#   'myanmar'],
#  '1053778': ['hanya',
#   'dar',
#   'alat',
#   'transformasi',
#   'crossz',
#   'magma',
#   'knuckle',
#   'lepas',
#   'build',
#   'driver',
#   'pasang',
#   'tangan',
#   'kanan',
#   'layak',
#   'sarung',
#   'tinju',
#   'logam',
#   'hasil',
#   'pukul',
#   'kuat',
#   'sembur',
#   'api',
#   'magma',
#   'sangat',
#   'panas',
#   'dapat',
#   'bakar',
#   'lawan'],
#  '1053784': ['buah',
#   'rantai',
#   'buat',
#   'perak',
#   'kuningan',
#   'hubung',
#   'sarung',
#   'pichangatti',
#   'bagai',
#   'implement',
#   'guna',
#   'bagai',
#   'tusuk',
#   'gigi',
#   'pinset',
#   'bersih',
#   'telinga',
#   'tusuk',
#   'artikel',
#   'bersih',
#   'kuku'],
#  '1053789': ['duduk',
#   'abbas',
#   'makin',
#   'lama',
#   'makin',
#   'hampir',
#   'duduk',
#   'uskup',
#   'tanpa',
#   'hirau',
#   'larang',
#   'konsili',
#   'awal',
#   'protes',
#   'st',
#   'bernardus',
#   'pihak',
#   'mereka',
#   'mulai',
#   'adopsi',
#   'insignia',
#   'episkopal',
#   'mitra',
#   'cincin',
#   'sarung',
#   'tangan',
#   'kasut'],
#  '1053816': ['sarung',
#   'tangan',
#   'masker',
#   'tahan',
#   'api',
#   'sama',
#   'respirator',
#   'perlu',
#   'anjur',
#   'hindar',
#   'masalah',
#   'sehat',
#   'kerja',
#   'papar',
#   'xilena'],
#  '1053827': ['pakai',
#   'batik',
#   'los',
#   'pasar',
#   'barat',
#   'tawar',
#   'baju',
#   'surjan',
#   'blangkon',
#   'sarung',
#   'tenun',
#   'maupun',
#   'batik'],
#  '1053835': ['algojo',
#   'hendak',
#   'pakai',
#   'smock',
#   'lindung',
#   'sarung',
#   'tangan',
#   'cermin',
#   'mata',
#   'takut',
#   'daging',
#   'darah',
#   'pesa',
#   'hiv',
#   'kena'],
#  '1053840': ['kemudian',
#   'ken',
#   'arok',
#   'uji',
#   'keris',
#   'sebut',
#   'akhir',
#   'keris',
#   'sebut',
#   'tusuk',
#   'mpu',
#   'gandring',
#   'konon',
#   'turut',
#   'tepat',
#   'janji',
#   'sarung',
#   'keris',
#   'belum',
#   'selesai',
#   'buat',
#   'lebih',
#   'bahkan',
#   'kata',
#   'uji',
#   'mampu',
#   'keris',
#   'sebut',
#   'lawan',
#   'kuat',
#   'supranatural',
#   'si',
#   'buat',
#   'keris',
#   'justru',
#   'simpan',
#   'keris',
#   'untuk',
#   'tambah',
#   'mampu'],
#  '1053846': ['tampil',
#   'unik',
#   'kena',
#   'sarung',
#   'baju',
#   'gombrong',
#   'panggung',
#   'jadi',
#   'salah',
#   'satu',
#   'daya',
#   'tarik'],
#  '1053872': ['ikut',
#   'baur',
#   'masyarakat',
#   'singaraja',
#   'selalu',
#   'kena',
#   'sarung',
#   'jarang',
#   'pakai',
#   'baju'],
#  '1053910': ['kisah',
#   'jual',
#   'orang',
#   'pria',
#   'jaja',
#   'nasi',
#   'sebut',
#   'cara',
#   'keliling',
#   'pakai',
#   'sarung'],
#  '1053933': ['renang',
#   'boleh',
#   'pakai',
#   'alat',
#   'pakai',
#   'renang',
#   'dapat',
#   'pengaruh',
#   'cepat',
#   'daya',
#   'apung',
#   'tahan',
#   'lama',
#   'lomba',
#   'misal',
#   'sarung',
#   'tangan',
#   'selaput',
#   'kaki',
#   'katak',
#   'sirip',
#   'bagai'],
#  '1053947': ['masjid',
#   'kenal',
#   'unik',
#   'milik',
#   'atur',
#   'adat',
#   'tegas',
#   'larang',
#   'pakai',
#   'sarung',
#   'wajib',
#   'kena',
#   'celana',
#   'panjang',
#   'para',
#   'jamaah',
#   'wajib',
#   'pakai',
#   'tutup',
#   'kepala',
#   'kopiah',
#   'larang',
#   'perempuan',
#   'ibadah',
#   'masjid'],
#  '1053957': ['walaupun',
#   'sushi',
#   'toko',
#   'swalayan',
#   'jepang',
#   'umum',
#   'buat',
#   'pakai',
#   'sarung',
#   'tangan'],
#  '1053960': ['akhir',
#   'tapa',
#   'lambu',
#   'mangkurat',
#   'temu',
#   'buah',
#   'buih',
#   'besar',
#   'dalam',
#   'dengar',
#   'suara',
#   'minta',
#   'lambu',
#   'mangkurat',
#   'sedia',
#   'kain',
#   'sarung',
#   'tenun',
#   '40',
#   'orang',
#   'gadis',
#   'perahu',
#   'indah',
#   'bawa',
#   'gadis',
#   'jelita',
#   'sebut',
#   'istana'],
#  '1053971': ['tangan',
#   'kiri',
#   'selalu',
#   'bungkus',
#   'sarung',
#   'tangan',
#   'hitam'],
#  '1053985': ['warna',
#   'suka',
#   'warna',
#   'merah',
#   'sama',
#   'rambut',
#   'mata',
#   'sarung',
#   'tangan',
#   'baju',
#   'tentu',
#   'mobil'],
#  '1053997': ['produk',
#   'hasil',
#   'satu',
#   'buah',
#   'sarung',
#   'makan',
#   'waktu',
#   '15',
#   'hari'],
#  '1053999': ['hela',
#   'sarung',
#   'hasil',
#   'rajin',
#   'biasa',
#   'milik',
#   'lebar',
#   '80',
#   'centimeter',
#   'panjang',
#   '2',
#   'meter'],
#  '1054005': ['mana',
#   'saat',
#   'dr',
#   'mohammad',
#   'hatta',
#   'jabat',
#   'bagai',
#   'wakil',
#   'presiden',
#   'indonesia',
#   'saat',
#   'kunjung',
#   'samarinda',
#   'oleh',
#   'koperasi',
#   'ruwi',
#   'rukun',
#   'wanita',
#   'indonesia',
#   'cabang',
#   'samarinda',
#   'serah',
#   'sarung',
#   'samarinda',
#   'corak',
#   'kamummu',
#   'moh'],
#  '1054011': ['adalah',
#   'arti',
#   'dasar',
#   'sarung',
#   'laku',
#   'indonesia',
#   'tempat',
#   'kawasan'],
#  '1054038': ['5',
#   'lembar',
#   'tapih',
#   'khas',
#   'bugis',
#   '5',
#   'lembar',
#   'sarung',
#   'songket',
#   'khusus',
#   'upacara'],
#  '1054048': ['kebaya',
#   'jawa',
#   'sekarang',
#   'catat',
#   'thomas',
#   'stamford',
#   'bingley',
#   'raffles',
#   '1817',
#   'bagai',
#   'sutra',
#   'brokat',
#   'beludru',
#   'buka',
#   'pusat',
#   'blus',
#   'ikat',
#   'bros',
#   'bukan',
#   'tombol',
#   'tombollubang',
#   'atas',
#   'batang',
#   'tubuh',
#   'bungkus',
#   'kemben',
#   'yang',
#   'kain',
#   'pisah',
#   'bungkus',
#   'kain',
#   'beberapa',
#   'meter',
#   'panjang',
#   'keliru',
#   'beri',
#   'istilah',
#   'sarung',
#   'inggris',
#   'sarung',
#   'aksen',
#   'malaysia',
#   'sarung',
#   'jahit',
#   'bentuk',
#   'tabung',
#   'pakai',
#   'barat'],
#  '1054049': ['kena',
#   'sarung',
#   'sepatu',
#   'cantik',
#   'manik',
#   'sebut',
#   'kasut',
#   'manek'],
#  '1054089': ['miss',
#   'world',
#   'beach',
#   'fashion',
#   '2013',
#   'final',
#   'kualifikasi',
#   'umum',
#   '9',
#   'september',
#   'presentasi',
#   'sarung',
#   'bal',
#   'westin',
#   'resort',
#   'nusa'],
#  '1054633': ['perlu',
#   'tahu',
#   'dalam',
#   'kalender',
#   'hijriyah',
#   'buah',
#   'hari',
#   'awal',
#   'sejak',
#   'benam',
#   'matahari',
#   'waktu',
#   'tempat',
#   'bukan',
#   'tengah',
#   'malam'],
#  '1059369': ['jumlah',
#   'duduk',
#   'taksir',
#   'banyak',
#   'lebih',
#   '255',
#   'juta',
#   'jiwa',
#   'jadi',
#   'negara',
#   'bagai',
#   'negara',
#   'duduk',
#   'besar',
#   'empat',
#   'dunia',
#   'berkat',
#   'tumbuh',
#   'kelas',
#   'tengah',
#   'tumbuh',
#   'terbang',
#   'tarif',
#   'rendah',
#   'dasawarsa',
#   'akhir',
#   'indonesia',
#   'cara',
#   'luas',
#   'anggap',
#   'bagai',
#   'pasar',
#   'terbang',
#   'tengah',
#   'tumbuh'],
#  '1059835': ['saran',
#   'claire',
#   'bennet',
#   'angela',
#   'turun',
#   'tengah',
#   'jalan',
#   'tidak',
#   'turut',
#   'tangkap'],
#  '1060022': ['tabrak',
#   'akibat',
#   'arthur',
#   'jatuh',
#   'satu',
#   'tas',
#   'isi',
#   'ramu',
#   'sihir',
#   'tengah',
#   'ambil',
#   'botol',
#   'jatuh',
#   'salah',
#   'satu',
#   'mereka',
#   'sengaja',
#   'tukar',
#   'botol',
#   'sebut',
#   'kaleng',
#   'soda',
#   'masaharu'],
#  '1060275': ['sejak',
#   '29',
#   'desember',
#   '2015',
#   'salur',
#   'peace',
#   'tv',
#   'chinese',
#   'tayang',
#   'seluruh',
#   'dunia',
#   'utama',
#   'asia',
#   'timur',
#   'tengah',
#   'australia'],
#  '1060414': ['adalah',
#   'rupa',
#   'orang',
#   'wartawan',
#   'tabloid',
#   'mistis',
#   'tengah',
#   'tugas',
#   'liput',
#   'piramida',
#   'gunung',
#   'padang',
#   'mana',
#   'tuntut',
#   'diri',
#   'kerja',
#   'sama',
#   'paranormal',
#   'guntur',
#   'samudra',
#   'dwi',
#   'sasono',
#   'ungkap',
#   'misteri',
#   'piramida',
#   'gunung',
#   'padang'],
#  '1061298': ['tahun',
#   '1983',
#   'tiba',
#   'muncul',
#   'kasus',
#   'jawa',
#   'tengah',
#   'tular',
#   'mana'],
#  '1062204': ['tanjung',
#   'rupa',
#   'ujung',
#   'paling',
#   'selatan',
#   'pengunungan',
#   'tengah',
#   'bagi',
#   'taman',
#   'nasional',
#   'kenting'],
#  '1064949': ['kereta',
#   'api',
#   'ini',
#   'jadi',
#   'satu',
#   'kereta',
#   'api',
#   'operasi',
#   'jakarta',
#   'jawa',
#   'tengah',
#   'rute',
#   'lintas',
#   'bandung',
#   'tidak',
#   'lintas',
#   'cirebon'],
#  '1065727': ['sang',
#   'main',
#   'kontrol',
#   'buah',
#   'pesawat',
#   'luar',
#   'angkasa',
#   'tengah',
#   'kumpul',
#   'asteroid',
#   'beberapa',
#   'piring',
#   'terbang'],
#  '1067112': ['hal',
#   'geografi',
#   'wilayah',
#   'duduk',
#   'latvia',
#   'yang',
#   'tengah',
#   'tiga',
#   'negara',
#   'baltik',
#   'estonia',
#   'latvia',
#   'lithuania'],
#  '1067285': ['muara',
#   'pagatan',
#   'tengah',
#   'desa',
#   'letak',
#   'camat',
#   'kus',
#   'hilir',
#   'kabupaten',
#   'tanah',
#   'bumbu',
#   'provinsi',
#   'kalimantan',
#   'selatan',
#   'indonesia'],
#  '1067609': ['seperti',
#   'candi',
#   'gaya',
#   'jawa',
#   'tengah',
#   'tubuh',
#   'candi',
#   'atap',
#   'batu',
#   'temu'],
#  '1067632': ['tengah',
#   'negara',
#   'ini',
#   'letak',
#   'central',
#   'valley',
#   'buah',
#   'lembah',
#   'besar',
#   'subur',
#   'batas',
#   'baris',
#   'gunung',
#   'pesisir',
#   'barat',
#   'sierra',
#   'nevada',
#   'granit',
#   'timur',
#   'cascade',
#   'range',
#   'gunung',
#   'rap',
#   'utara',
#   'gunung',
#   'tehachapi',
#   'selatan'],
#  '1067870': ['awal',
#   'abad',
#   'ke15',
#   'conquistador',
#   'spanyol',
#   'layar',
#   'amerika',
#   'tengah',
#   'pulau',
#   'karibia',
#   'itu',
#   'kenal',
#   'bagai',
#   'koloni',
#   'spanyol',
#   'baru'],
#  '1068367': ['kini',
#   'percy',
#   'teman',
#   'sama',
#   'para',
#   'buru',
#   'artemis',
#   'milik',
#   'waktu',
#   'satu',
#   'minggu',
#   'cari',
#   'dewi',
#   'culik',
#   'pecah',
#   'misteri',
#   'monster',
#   'tengah',
#   'buru'],
#  '1068509': ['cimahi',
#   'tengah',
#   'buah',
#   'camat',
#   'kota',
#   'cimahi',
#   'provinsi',
#   'jawa',
#   'barat',
#   'indonesia'],
#  '1068554': ['temu',
#   'prasasti',
#   'tunjuk',
#   'kawasan',
#   'pantai',
#   'utara',
#   'jawa',
#   'tengah',
#   'kembang',
#   'raja',
#   'corak',
#   'hindu',
#   'siwais'],
#  '1069005': ['53',
#   'persen',
#   'tetap',
#   'amerika',
#   'serikat',
#   'selatan',
#   '40',
#   'persen',
#   'tetap',
#   'timur',
#   'laut',
#   'utara',
#   'tengah',
#   '7',
#   'persen',
#   'barat'],
#  '1069806': ['tulis',
#   'tepat',
#   'lariang',
#   'bangngi',
#   'dalam',
#   'bahasa',
#   'makassar',
#   'arti',
#   'kabur',
#   'tengah',
#   'malam'],
#  '1070655': ['ini',
#   'federasi',
#   'sepakbola',
#   'asean',
#   'fifa',
#   'tengah',
#   'timbang',
#   'rencana',
#   'sebut'],
#  '1072446': ['buah',
#   'pepaya',
#   'kandung',
#   'vitamin',
#   'c',
#   'tinggi',
#   'bantu',
#   'tingkat',
#   'daya',
#   'tahan',
#   'tubuh'],
#  '1073038': ['garis',
#   'fungsi',
#   'bagai',
#   'batas',
#   'ruang',
#   'jarak',
#   'bebas',
#   'minimum',
#   'bidang',
#   'luar',
#   'suatu',
#   'massa',
#   'bangun',
#   'hadap',
#   'lahan',
#   'asai',
#   'batas',
#   'tepi',
#   'sungai',
#   'pantai',
#   'massa',
#   'bangun',
#   'lain',
#   'rencana',
#   'salur',
#   'jaring',
#   'tegang',
#   'tinggi',
#   'listrik',
#   'jaring',
#   'pipa',
#   'gas',
#   'bagai'],
#  '1073440': ['hook',
#   'teknik',
#   'sangat',
#   'efektif',
#   'bila',
#   'main',
#   'jaga',
#   'orang',
#   'lebih',
#   'tinggi',
#   'main'],
#  '1075144': ['awal',
#   'temu',
#   'daguerreotype',
#   'tahun',
#   '1839',
#   'kamera',
#   'desain',
#   'tidak',
#   'lengkap',
#   'rana',
#   'tidak',
#   'butuh',
#   'sensitivitas',
#   'tinggi',
#   'proses',
#   'kimiawi'],
#  '1076330': ['senjata',
#   'akan',
#   'masuk',
#   'rudal',
#   'kh25',
#   'toko',
#   'pada',
#   'kapasitas',
#   'pesawat',
#   'tinggi',
#   'total',
#   'enam',
#   'bawah',
#   'sayap',
#   'cantel',
#   'warload',
#   'gabung',
#   'hingga',
#   '3000',
#   'kg'],
#  '1077930': ['masuk',
#   'kategori',
#   'iucn',
#   'red',
#   'list',
#   'alami',
#   'risiko',
#   'punah',
#   'tinggi',
#   'alam',
#   'waktu',
#   'dekat'],
#  '1086132': ['leleh',
#   'zncl',
#   'milik',
#   'viskositas',
#   'tinggi',
#   'titik',
#   'leleh',
#   'konduktivitas',
#   'listrik',
#   'relatif',
#   'rendah',
#   'tingkat',
#   'cara',
#   'nyata',
#   'hadap',
#   'suhu'],
#  '1087697': ['geografi',
#   'skotlandia',
#   'tradisional',
#   'datar',
#   'tinggi',
#   'acu',
#   'wilayah',
#   'skotlandia',
#   'belah',
#   'utara',
#   'barat',
#   'sesar',
#   'batas',
#   'datar',
#   'tinggi',
#   'lintas',
#   'darat',
#   'skotlandia',
#   'garis',
#   'hampir',
#   'lurus',
#   'helensburgh',
#   'stonehaven'],
#  '108883': ['livery',
#   'ka',
#   'jayabaya',
#   'nanti',
#   'guna',
#   'seluruh',
#   'kereta',
#   'api',
#   'indonesia',
#   'semua',
#   'kelas',
#   'satu',
#   'satu',
#   'kereta',
#   'jalan',
#   'pelihara',
#   'akhir',
#   'pa',
#   'balai',
#   'yasa',
#   'maupun',
#   'datang',
#   'kereta',
#   'baru',
#   'pt',
#   'inka',
#   'meski',
#   'livery',
#   'khusus',
#   'kereta',
#   'sendiri',
#   'aneh',
#   'bila',
#   'lihat',
#   'warna',
#   'pintu'],
#  '1092796': ['tingkat',
#   'partisipasi',
#   'ini',
#   'relatif',
#   'tinggi',
#   'walaupun',
#   'bisa',
#   'maksimal',
#   'ingat',
#   'cukup',
#   'sedia',
#   'fasilitas',
#   'sehat',
#   'upa',
#   'buah',
#   'puskesmas',
#   'bantu',
#   'desa',
#   'kloposawit'],
#  '1097596': ['herleva',
#   'legenda',
#   'lanjut',
#   'lihat',
#   'adipati',
#   'atas',
#   'benteng',
#   'naik',
#   'rok',
#   'mungkin',
#   'lebih',
#   'tinggi',
#   'sedikit',
#   'biasa',
#   'tarik',
#   'perhati',
#   'sang',
#   'adipati'],
#  '1100785': ['neurosifilis',
#   'akibat',
#   'penetrasi',
#   'lemah',
#   'penisilin',
#   'g',
#   'dalam',
#   'sistem',
#   'saraf',
#   'pusat',
#   'yang',
#   'kena',
#   'dampak',
#   'rekomendasi',
#   'beri',
#   'penisilin',
#   'intravena',
#   'dosis',
#   'tinggi',
#   'minimal',
#   '10',
#   'hari'],
#  '112454': ['cabang',
#   'lompat',
#   'ski',
#   'bahkan',
#   'baru',
#   'di',
#   'holmenkollen',
#   'tahun',
#   '1933'],
#  '118669': ['beberapa',
#   'teknik',
#   'baru',
#   'gera',
#   'mata',
#   'desensitisasi',
#   'olah',
#   'eye',
#   'movement',
#   'desensitization',
#   'and',
#   'reprocessing',
#   'emdr',
#   'bukti',
#   'efektif'],
#  '120122': ['lanjut',
#   'angkat',
#   'puteranya',
#   'bagai',
#   'ganti',
#   'kelak',
#   'gelar',
#   'sultan',
#   'sulaiman',
#   'saidullah',
#   'ii',
#   'saat',
#   'baru',
#   'usia',
#   '6',
#   'tahun',
#   '1767'],
#  '121137': ['tujuh',
#   'puluh',
#   'murid',
#   'murid',
#   'yesus',
#   'kristus',
#   'mula',
#   'catat',
#   'injil',
#   'lukas',
#   'janji',
#   'baru',
#   'alkitab',
#   'kristen'],
#  '121747': ['flea',
#   'acuh',
#   'tak',
#   'acuh',
#   'jual',
#   'album',
#   'rendah',
#   'dia',
#   'baru',
#   'lamar',
#   'pacaranya',
#   'loesha',
#   'zeviar',
#   'saat',
#   'sedang',
#   'hamil',
#   'anak'],
#  '1219': ['banyak',
#   'usaha',
#   'perban',
#   'baik',
#   'lokal',
#   'maupun',
#   'asing',
#   'buka',
#   'cabang',
#   'kelapa',
#   'gading'],
#  '123401': ['sejak',
#   'tahun',
#   '2013',
#   'jalur',
#   'nambo',
#   'mulai',
#   'aktif',
#   'ka',
#   'angkut',
#   'semen',
#   'krl',
#   'commuter',
#   'line',
#   'baru',
#   'ada',
#   'sejak',
#   'tahun',
#   '2015'],
#  '123556': ['lima',
#   'kabupaten',
#   'sebut',
#   'kabupaten',
#   'keerom',
#   'gunung',
#   'bintang',
#   'boven',
#   'goel',
#   'rupa',
#   'kabupaten',
#   'baru',
#   'hasil',
#   'mekar'],
#  '13163': ['2017',
#   'bawa',
#   'proyek',
#   'dokumenter',
#   'musik',
#   'sedang',
#   'kembang',
#   'pilih',
#   'jadi',
#   'satu',
#   '12',
#   'sutradara',
#   'dokumenter',
#   'dunia',
#   'ajar',
#   'american',
#   'film',
#   'showcase',
#   '2017',
#   'selenggara',
#   'atas',
#   'mitra',
#   'biro',
#   'didik',
#   'budaya',
#   'departemen',
#   'luar',
#   'negeri',
#   'amerika',
#   'university',
#   'of',
#   'southern',
#   'california',
#   'cinematic',
#   'arts',
#   'asosiasi',
#   'dokumenter',
#   'international',
#   'film',
#   'independen',
#   'amerika'],
#  '13527': ['tonkatsu',
#   'kadang',
#   'saji',
#   'telur',
#   'atas',
#   'mangkuk',
#   'isi',
#   'nasi',
#   'bagai',
#   'katsudon'],
#  '135812': ['atas',
#   'hasil',
#   'rendah',
#   'tingkat',
#   'anggur',
#   'sebut',
#   'canberra',
#   'milik',
#   'disposabel',
#   'tinggi',
#   'banding',
#   'kota',
#   'besar',
#   'di',
#   'australia'],
#  '136807': ['pamer',
#   'dunia',
#   '1888',
#   'rupa',
#   'salah',
#   'satu',
#   'acara',
#   'besar',
#   'masa',
#   'di',
#   'barcelona',
#   'jadi',
#   'yang',
#   'penting',
#   'sejarah',
#   'alir',
#   'modernisme'],
#  '14039': ['encarta',
#   'luncur',
#   'tahun',
#   '1993',
#   'microsoft',
#   'hak',
#   'nonekslusif',
#   'atas',
# ...
#   'lain',
#   'oleh',
#   'faktor',
#   'bawa'],
#  '967745': ['rekor',
#   '100',
#   'meter',
#   'olimpiade',
#   'bejiing',
#   'sebut',
#   'sendiri',
#   'pecah',
#   'rekor',
#   'ia',
#   'pegang',
#   '9',
#   '72',
#   'detik',
#   'yang',
#   'cipta',
#   'juara',
#   'reebok',
#   'new',
#   'york',
#   '31',
#   'mei',
#   '2008'],
#  '967782': ['24',
#   'maret',
#   '2005',
#   'departemen',
#   'energi',
#   'as',
#   'umum',
#   'blue',
#   'gene',
#   'l',
#   'pecah',
#   'rekor',
#   'komputer',
#   'cepat',
#   'capai',
#   '135',
#   '5',
#   'tflops'],
#  '967796': ['karnivor',
#   'milik',
#   'sistem',
#   'cerna',
#   'pendek',
#   'mereka',
#   'harus',
#   'pecah',
#   'selulosa',
#   'bagaimana',
#   'temu',
#   'tumbuh'],
#  '967831': ['orang',
#   'ahli',
#   'epigrafi',
#   'butuh',
#   'pecah',
#   'buah',
#   'catat',
#   'sejarah',
#   'tulis',
#   'masyarakat',
#   'masa',
#   'lampau',
#   'dapat',
#   'erti',
#   'masyarakat',
#   'ini'],
#  '967925': ['rogers',
#   'pecah',
#   'rekor',
#   'usia',
#   '26',
#   'tahun',
#   'hank',
#   'snow',
#   'usia',
#   '59',
#   'tahun',
#   '11',
#   'minggu',
#   'lagu',
#   'hello',
#   'love',
#   'di',
#   'urut',
#   'nomor',
#   'satu'],
#  '967952': ['guiding',
#   'light',
#   'kenal',
#   'bagai',
#   'the',
#   'guiding',
#   'light',
#   'tahun',
#   '1975',
#   'hanya',
#   'gl',
#   'drama',
#   'pecah',
#   'guinness',
#   'world',
#   'records',
#   'bagai',
#   'sinetron',
#   'panjang',
#   'pernah'],
#  '967959': ['beda',
#   'utama',
#   'pada',
#   'manfaat',
#   'jenis',
#   'kapang',
#   'koji',
#   'guna',
#   'pecah',
#   'pati'],
#  '968160': ['aljabar',
#   'abstrak',
#   'kembang',
#   'abad',
#   'ke19',
#   'asal',
#   'tari',
#   'pecah',
#   'sama',
#   'awal',
#   'fokus',
#   'apa',
#   'sekarang',
#   'sebut',
#   'teori',
#   'galois',
#   'pada',
#   'masalah',
#   'konstruktibilitas'],
#  '968211': ['pecah', 'rekor', 'pegang', 'alves', 'magno'],
#  '968304': ['de',
#   'ruyter',
#   'paksa',
#   'pecah',
#   'beberapa',
#   'genteng',
#   'atap',
#   'dapat',
#   'masuk',
#   'dalam',
#   'gereja',
#   'keluar',
#   'pintu',
#   'gereja',
#   'sebut'],
#  '968318': ['lin',
#   'selesai',
#   'karier',
#   'sekolah',
#   'tinggi',
#   'bagai',
#   'main',
#   'pertama',
#   'sejarah',
#   'ivy',
#   'league',
#   'pecah',
#   'rekor',
#   'paling',
#   'sedikit',
#   '1',
#   '450',
#   'points',
#   'benar',
#   '1',
#   '483',
#   '450',
#   'rebound',
#   '487',
#   '400',
#   'assist',
#   '406',
#   '200',
#   'steals',
#   '225'],
#  '969201': ['pernah',
#   'kerja',
#   'akuarium',
#   'tinggal',
#   'jadi',
#   'orang',
#   'polisi',
#   'sumpah',
#   'buka',
#   'kasus',
#   'mati',
#   'adik',
#   'tangkap',
#   'si',
#   'bunuh'],
#  '969255': ['pernah',
#   'suatu',
#   'hongwu',
#   'tangkap',
#   'beberapa',
#   'orang',
#   'buat',
#   'tekateki',
#   'hina',
#   'permaisuri',
#   'ma',
#   'bemaksud',
#   'hukum',
#   'mati',
#   'namun',
#   'sang',
#   'permaisuri',
#   'beri',
#   'ampun',
#   'mereka',
#   'hongwu',
#   'bebas'],
#  '969804': ['liu',
#   'hilang',
#   'beberapa',
#   'wilayah',
#   'telah',
#   'caplok',
#   'li',
#   'shimin',
#   'sama',
#   'pasu',
#   'tiba',
#   'ia',
#   'hasil',
#   'tangkap',
#   'bunuh',
#   'orang',
#   'jenderal',
#   'tang',
#   'luo',
#   'shixin'],
#  '970596': ['polisi',
#   'new',
#   'york',
#   'ins',
#   'jaga',
#   'pantai',
#   'polisi',
#   'thailand',
#   'hong',
#   'kong',
#   'interpol',
#   'bekerjasama',
#   'tangkap',
#   'laku'],
#  '970822': ['yan',
#   'fei',
#   'lolos',
#   'jebak',
#   'jala',
#   'racun',
#   'usaha',
#   'tangkap',
#   'hao',
#   'zhang',
#   'ting',
#   'gagal',
#   'sedang',
#   'tu',
#   'fung',
#   'san',
#   'hasil',
#   'tunduk',
#   'bo',
#   'jing',
#   'lei',
#   'cepat'],
#  '971008': ['beberapa',
#   'stasiun',
#   'radio',
#   'amatir',
#   'catat',
#   'sinyal',
#   'elf',
#   'malah',
#   'lebih',
#   'rendah',
#   'antena',
#   'buat',
#   'sendiri',
#   'lebih',
#   'besar',
#   'main',
#   'pada',
#   'cepat',
#   'lebih',
#   'tinggi',
#   'tangkap',
#   'fluktuasi',
#   'alam',
#   'ladang',
#   'elektromagnetik',
#   'bumi'],
#  '971298': ['hidrogen',
#   'sangat',
#   'mudah',
#   'hilang',
#   'tangkap',
#   'buah',
#   'elektron',
#   'oleh',
#   'itu',
#   'cara',
#   'kimia',
#   'masuk',
#   'dalam',
#   'golong',
#   'sekaligus',
#   'unsur',
#   'golong',
#   '1',
#   '17'],
#  '971892': ['mulai',
#   'tahun',
#   '1960',
#   'buah',
#   'revolusi',
#   'kognitif',
#   'teliti',
#   'manusia',
#   'cara',
#   'tahap',
#   'dorong',
#   'transformasi',
#   'sama',
#   'teliti',
#   'hewan'],
#  '971949': ['naik',
#   'kate',
#   'middleton',
#   'jadi',
#   'putri',
#   'raja',
#   'britania',
#   'selenggara',
#   'olimpiade',
#   'london',
#   '2012',
#   'kata',
#   'bagai',
#   'faktor',
#   'dorong',
#   'london',
#   'jadi',
#   'kota',
#   'mode',
#   'dunia'],
#  '971967': ['catat',
#   'kitab',
#   'ezra',
#   'pasal',
#   '5',
#   '2',
#   'yesua',
#   'masuk',
#   'pimpin',
#   'dorong',
#   'bangun',
#   'bait',
#   'suci'],
#  '972015': ['mari',
#   'saling',
#   'perhati',
#   'kita',
#   'saling',
#   'dorong',
#   'kasih',
#   'dalam',
#   'kerja',
#   'baik'],
#  '972069': ['nyata',
#   'begitu',
#   'sakit',
#   'hingga',
#   'dorong',
#   'salah',
#   'satu',
#   'mereka',
#   'akhir',
#   'hidup'],
#  '972083': ['kota',
#   'milik',
#   'kembang',
#   'cepat',
#   'dapat',
#   'labuh',
#   'laut',
#   'dorong',
#   'cepat',
#   'bangun'],
#  '972133': ['tahun',
#   '1960an',
#   'perintah',
#   'usaha',
#   'dorong',
#   'keluarga',
#   'milik',
#   'turun',
#   'banyak',
#   'mungkin',
#   'dasar',
#   'percaya',
#   'mao',
#   'tingkat',
#   'populasi',
#   'duduk',
#   'pengaruh',
#   'tumbuh',
#   'buah',
#   'negara',
#   'mao',
#   'cegah',
#   'program',
#   'keluarga',
#   'rencana',
#   'tiongkok'],
#  '972771': ['enzim',
#   'bagai',
#   'katalis',
#   'reaksi',
#   'sipf',
#   'guna',
#   'logam',
#   'transisi',
#   'tindak',
#   'bagai',
#   'katalis',
#   'dorong',
#   'bentuk',
#   'peptida',
#   'kondisi',
#   'larut',
#   'nacl',
#   'konsentrasi',
#   'tinggi',
#   'tembaga',
#   'ii',
#   'mana',
#   'tunjuk',
#   'aktivitas',
#   'katalitik',
#   'tinggi'],
#  '973077': ['dorong', 'dengar', 'terima', 'ampun', 'tawar', 'lalu', 'kristus'],
#  '973242': ['pilih',
#   'jadi',
#   'paus',
#   'leo',
#   'xiii',
#   'kerja',
#   'dorong',
#   'paham',
#   'gereja',
#   'dunia',
#   'modern'],
#  '973690': ['kuasa',
#   'muwahidun',
#   'dorong',
#   'kembang',
#   'seni',
#   'tulis',
#   'hasil',
#   'antara',
#   'ibnu',
#   'tufail',
#   'ibnu',
#   'araby',
#   'ibnu',
#   'rusyd'],
#  '973756': ['kantong',
#   'udara',
#   'kemudi',
#   'kembang',
#   'cepat',
#   'dorong',
#   'kepala',
#   'tuju',
#   'pipa',
#   'sebut'],
#  '973781': ['dalam',
#   'rangkai',
#   'rumit',
#   'manuver',
#   'kontramanuver',
#   'jepang',
#   'dorong',
#   'armada',
#   'rusia',
#   'tempur',
#   'port',
#   'arthur',
#   'tahun',
#   '1905'],
#  '973863': ['ian',
#   'marah',
#   'kejut',
#   'wendy',
#   'lalu',
#   'geser',
#   'buah',
#   'kotak',
#   'sebab',
#   'beberapa',
#   'paku',
#   'jatuh',
#   'erin',
#   'ambil',
#   'tongkat',
#   'magnet',
#   'bersih',
#   'paku',
#   'sebut',
#   'dorong',
#   'tongkat',
#   'magnet',
#   'sis',
#   'lemari',
#   'malah',
#   'dorong',
#   'rantai',
#   'besi',
#   'bawah',
#   'buat',
#   'mesin',
#   'derek',
#   'mati',
#   'jadi',
#   'hidup'],
#  '974059': ['september',
#   '2000',
#   'departemen',
#   'luar',
#   'negeri',
#   'dagang',
#   'australia',
#   'rilis',
#   'tentang',
#   'file',
#   'rahasia',
#   'tunjuk',
#   'komentar',
#   'perintah',
#   'buruh',
#   'whitlam',
#   'mungkin',
#   'dorong',
#   'rezim',
#   'suharto',
#   'serang',
#   'timor',
#   'timur'],
#  '974140': ['kemudian',
#   'jadi',
#   'patriarkh',
#   'yunani',
#   'aleksandria',
#   'bagai',
#   'kirilos',
#   'iii',
#   'patriarkh',
#   'ekumenikal',
#   'konstantinopel',
#   'bagai',
#   'kirilos',
#   'i',
#   'lucaris',
#   'dorong',
#   'reformasi',
#   'gereja',
#   'ortodoks',
#   'timur',
#   'jalan',
#   'protestan',
#   'kalvinis'],
#  '974278': ['tuju',
#   'iredentisme',
#   'italia',
#   'sedikit',
#   'pengaruh',
#   'korsika',
#   'baru',
#   'masa',
#   'perintah',
#   'fasis',
#   'benito',
#   'mussolini',
#   'organisasi',
#   'pertama',
#   'cara',
#   'kuat',
#   'dorong',
#   'satu',
#   'pulau',
#   'sebut',
#   'raja',
#   'italia',
#   'diri'],
#  '974333': ['wujud',
#   'ini',
#   'butuh',
#   'investasi',
#   'bidang',
#   'infrastruktur',
#   'didik',
#   'kualitas',
#   'tinggi',
#   'dorong',
#   'kreativitas',
#   'terobos',
#   'bidang',
#   'sains',
#   'teknologi'],
#  '974573': ['lebih',
#   'dorong',
#   'pasu',
#   'mikhael',
#   'perintah',
#   'putra',
#   'muda',
#   'theophilos',
#   'pimpin',
#   'prosesi',
#   'panjang',
#   'dinding',
#   'bawa',
#   'potong',
#   'salib',
#   'sejati',
#   'mantel',
#   'perawan',
#   'maria',
#   'standar',
#   'besar',
#   'kibar',
#   'atas',
#   'gereja',
#   'st',
#   'maria',
#   'blachernae',
#   'pandang',
#   'penuh',
#   'pasu'],
#  '974930': ['kembang',
#   'amsterdam',
#   'bagai',
#   'salah',
#   'satu',
#   'pusat',
#   'dagang',
#   'eropa',
#   'tahun',
#   '1580an',
#   'dorong',
#   'belanda',
#   'luas',
#   'jaring',
#   'dagang',
#   'keluar',
#   'eropa',
#   'utara',
#   'utama',
#   'mediterania',
#   'levant'],
#  '974959': ['upaya',
#   'nazi',
#   'dorong',
#   'emigrasi',
#   'yahudi',
#   'jerman',
#   'kurang',
#   'hasil',
#   'gagas',
#   'deportasi',
#   'orang',
#   'yahudi',
#   'madagaskar',
#   'angkat',
#   'oleh',
#   'perintah',
#   'nazi',
#   'tahun',
#   '1940'],
#  '975442': ['contoh',
#   'promosi',
#   'bahan',
#   'bakar',
#   'nabati',
#   'perintah',
#   'bagai',
#   'upaya',
#   'atas',
#   'panas',
#   'global',
#   'justru',
#   'dorong',
#   'jadi',
#   'gundul',
#   'hutan',
#   'beberapa',
#   'wilayah'],
#  '975801': ['cara',
#   'pribadi',
#   'hitler',
#   'dorong',
#   'teman',
#   'dekat',
#   'tidak',
#   'rokok',
#   'harga',
#   'orang',
#   'henti',
#   'rokok'],
#  '975892': ['komunikasi',
#   'pasar',
#   'kontribusi',
#   'ekuitas',
#   'merek',
#   'tanam',
#   'merek',
#   'ingat',
#   'cipta',
#   'citra',
#   'merek',
#   'dorong',
#   'jual',
#   'bahkan',
#   'pengaruh',
#   'nilai',
#   'pegang',
#   'saham'],
#  '975926': ['inti',
#   'gera',
#   'bangsa',
#   'bagai',
#   'negara',
#   'sebut',
#   'dorong',
#   'negara',
#   'masuk',
#   'indonesia',
#   'laku',
#   'yang',
#   'sama',
#   'lawan',
#   'jajah',
#   'kolonialisme',
#   'negara'],
#  '976338': ['damai', 'pbb', 'aktif', 'dorong', 'lucut', 'senjata'],
#  '978854': ['botol',
#   'kaca',
#   'romawi',
#   'isi',
#   'balsem',
#   'campur',
#   'minyak',
#   'suci',
#   'duga',
#   'bawa',
#   'ekor',
#   'merpati',
#   'roh',
#   'kudus',
#   'monarki',
#   'perancis',
#   'aku',
#   'terima',
#   'kuasa',
#   'atas',
#   'karunia'],
#  '985392': ['beberapa',
#   'negara',
#   'hukum',
#   'umum',
#   'britania',
#   'raya',
#   'irlandia',
#   'australia',
#   'kanada',
#   'sidi',
#   'publik',
#   'beda',
#   'royal',
#   'commission',
#   'mana',
#   'sidi',
#   'publik',
#   'terima',
#   'bukti',
#   'ada',
#   'dengar',
#   'forum',
#   'lebih',
#   'umum',
#   'peristiwa',
#   'lebih',
#   'spesifik'],
#  '986403': ['tahun',
#   '1958',
#   'monshizadeh',
#   'terima',
#   '7',
#   '000',
#   'savak',
#   'berangkat',
#   'amerika',
#   'serikat'],
#  '986862': ['bila',
#   'ubah',
#   'putus',
#   'laku',
#   'perlu',
#   'laksana',
#   'lalu',
#   'masa',
#   'simulcast',
#   'masa',
#   'mana',
#   'masyarakat',
#   'mampu',
#   'beli',
#   'pesawat',
#   'terima',
#   'digital',
#   'pesawat',
#   'terima',
#   'analog',
#   'milik',
#   'tetap',
#   'pakai',
#   'terima',
#   'siar',
#   'analog',
#   'pancar',
#   'tv',
#   'siar',
#   'siar',
#   'tv',
#   'digital'],
#  '986890': ['perangkat',
#   'lunak',
#   'untuk',
#   'guna',
#   'pribadi',
#   'mungkin',
#   'untuk',
#   'integrasi',
#   'smartphone',
#   '10',
#   'akun',
#   'surate',
#   'bas',
#   'post',
#   'office',
#   'protocol',
#   'pop3',
#   'internet',
#   'message',
#   'access',
#   'protocol',
#   'imap',
#   'terima',
#   'kirim',
#   'pesan',
#   'instan',
#   'akses',
#   'internet'],
#  '989875': ['john',
#   'akhir',
#   'terima',
#   'william',
#   'tokoh',
#   'adalah',
#   'halusinasi'],
#  '989944': ['adapun',
#   'alas',
#   'tahu',
#   'cara',
#   'namun',
#   'duga',
#   'telah',
#   'terima',
#   'suap'],
#  '990524': ['juli',
#   '2008',
#   'pluna',
#   'terima',
#   'pesawat',
#   'lima',
#   'total',
#   '7',
#   'pesan'],
#  '992709': ['atrium',
#   'fungsi',
#   'bagai',
#   'ruang',
#   'resepsi',
#   'tempat',
#   'paterfamilias',
#   'kepala',
#   'rumah',
#   'tangga',
#   'jumpa',
#   'tamu',
#   'tiap',
#   'pagi',
#   'mulai',
#   'kalang',
#   'keluarga',
#   'kaya',
#   'hingga',
#   'keluarga',
#   'miskin',
#   'terima',
#   'bantu',
#   'amal'],
#  '993076': ['tahun',
#   '1970',
#   'terima',
#   'beasiswa',
#   'militer',
#   'untuk',
#   'ajar',
#   'tank',
#   'mesir',
#   'lama',
#   'enam',
#   'tahun'],
#  '993657': ['ada',
#   'inti',
#   'stabil',
#   'alam',
#   'kandung',
#   '8',
#   'nukleon',
#   'dapat',
#   'bottleneck',
#   'henti',
#   'proses',
#   'nukleosintesis',
#   'sampai',
#   'sini'],
#  '994040': ['target',
#   'utama',
#   'misi',
#   'adalah',
#   'europa',
#   'duga',
#   'milik',
#   'samudra',
#   'bawah',
#   'muka',
#   'mungkin',
#   'kandung',
#   'hidup'],
#  '994086': ['18',
#   'januari',
#   '2007',
#   'sanger',
#   'umum',
#   'proyek',
#   'akan',
#   'bagai',
#   'eksperimen',
#   'kandung',
#   'artikel',
#   'telah',
#   'akan',
#   'segera',
#   'kerja',
#   'para',
#   'kontributor',
#   'citizendium',
#   'ketimbang',
#   'sekadar',
#   'jadi',
#   'kopi',
#   'lengkap',
#   'artikel',
#   'wikipedia'],
#  '994244': ['band',
#   'kenal',
#   'genre',
#   'metalcore',
#   'debut',
#   'sounding',
#   'the',
#   'seventh',
#   'trumpet',
#   'kandung',
#   'banyak',
#   'vokal',
#   'scream'],
#  '994350': ['lebih',
#   '3000',
#   'buku',
#   'judul',
#   'kandung',
#   'kata',
#   'pemimipin',
#   'leader'],
#  '995462': ['satelit',
#   'jenis',
#   'juga',
#   'monitor',
#   'ubah',
#   'iklim',
#   'teliti',
#   'ekologis',
#   'lidi',
#   'lokasi',
#   'darat',
#   'kandung',
#   'mineral',
#   'minyak'],
#  '995744': ['enclosed',
#   'alphanumeric',
#   'supplement',
#   'blok',
#   'unicode',
#   'kandung',
#   'karakter',
#   'abjad',
#   'latin',
#   'kurung',
#   'lingkar',
#   'oval',
#   'persegi',
#   'bagai',
#   'perlu'],
#  '995799': ['khmer',
#   'blok',
#   'unicode',
#   'kandung',
#   'karakter',
#   'tulis',
#   'bahasa',
#   'khmer',
#   'kamboja'],
#  '996044': ['softlens',
#   'lensa',
#   'kontak',
#   'buah',
#   'alat',
#   'guna',
#   'bantu',
#   'lihat',
#   'bagai',
#   'ganti',
#   'kacamata',
#   'softlens',
#   'biasa',
#   'pasang',
#   'kornea',
#   'mata',
#   'buat',
#   'plastik',
#   'kandung',
#   'air'],
#  '996346': ['daun',
#   'kubis',
#   'kandung',
#   'kelompok',
#   'glukosinolat',
#   'sebab',
#   'rasa',
#   'pahit'],
#  '996484': ['banyak',
#   'seni',
#   'beladiri',
#   'kandung',
#   'latih',
#   'gumul',
#   'walaupun',
#   'tekan',
#   'variasi'],
#  '996509': ['pusat',
#   'germinal',
#   'pertama',
#   'kali',
#   'definisi',
#   'walther',
#   'flemming',
#   'tahun',
#   '1884',
#   'bagai',
#   'mikroanatomi',
#   'beda',
#   'organ',
#   'limfoid',
#   'sekunder',
#   'kandung',
#   'sel',
#   'belah'],
#  '996885': ['buah', 'kandung', 'banyak', 'vitamin', 'c', 'tanin'],
#  '996944': ['akibat',
#   'koh',
#   'biasa',
#   'kandung',
#   'bagai',
#   'jumlah',
#   'air',
#   'karbonat',
#   'lihat',
#   'bawah'],
#  '996966': ['senyawa',
#   'kandung',
#   'lebih',
#   'satu',
#   'jenis',
#   'halogen',
#   'mungkin'],
#  '996975': ['samping',
#   'kandung',
#   'air',
#   'liur',
#   'komodo',
#   'milik',
#   'aneka',
#   'bakteri',
#   'mati',
#   'dalam',
#   'lebih',
#   '28',
#   'bakteri',
#   'gramnegatif',
#   '29',
#   'grampositif',
#   'isolasi',
#   'air',
#   'liur'],
#  '997027': ['20',
#   'pasien',
#   'tangan',
#   'dapson',
#   'derita',
#   'hemolisis',
#   'efek',
#   'samping',
#   'lebih',
#   'umum',
#   'parah',
#   'mereka',
#   'defisiensi',
#   'glukosa6fosfat',
#   'dehidrogenase',
#   'akhir',
#   'lapdap',
#   'kombinasi',
#   'antimalaria',
#   'kandung',
#   'dapson',
#   'tarik',
#   'guna',
#   'klinis'],
#  '997491': ['lokasi',
#   'taj',
#   'kandung',
#   'beberapa',
#   'kubur',
#   'di',
#   'paviliun',
#   'timur',
#   'selatan'],
#  '997936': ['beberapa',
#   'kombinasi',
#   'vaksin',
#   'vaksin',
#   'tetanus',
#   'vaksin',
#   'seperti',
#   'dtap',
#   'tdap',
#   'kandung',
#   'vaksin',
#   'difteri',
#   'tetanus',
#   'pertusis',
#   'dt',
#   'td',
#   'kandung',
#   'vaksin',
#   'difteri',
#   'tetanus'],
#  '998087': ['kasus',
#   'implan',
#   'kandung',
#   'perangkat',
#   'elektronik',
#   'jantung',
#   'buat'],
#  '998233': ['samping',
#   'singel',
#   'sebut',
#   'isi',
#   'lagu',
#   'album',
#   'kenal',
#   'lebih',
#   'kelam',
#   'kandung',
#   'lebih',
#   'banyak',
#   'konten',
#   'dewasa',
#   'banding',
#   'album'],
#  '998640': ['seluruh',
#   'alam',
#   'semesta',
#   'kandung',
#   'diri',
#   'allah',
#   'allah',
#   'satu',
#   'wujud',
#   'nyata',
#   'alam',
#   'semesta',
#   'bayang'],
#  '998683': ['molekul', 'kandung', '4n', 'elektron', 'pi', 'antiaromatik'],
#  '998844': ['kira',
#   'salar',
#   'de',
#   'uyuni',
#   'kandung',
#   '10',
#   'miliar',
#   'ton',
#   'garam',
#   'kurang',
#   'sekitar',
#   '25',
#   '000',
#   'ton',
#   'garam',
#   'tiap',
#   'tahun'],
#  '999059': ['injil',
#   'ada',
#   'ini',
#   'kandung',
#   'firman',
#   'allah',
#   'riwayat',
#   'isa',
#   'semua',
#   'tulis',
#   'generasi',
#   'isa'],
#  '999349': ['itu',
#   'episode',
#   'kandung',
#   'satu',
#   'tunjuk',
#   'dalam',
#   'bahasa',
#   'bunga'],
#  '999660': ['teliti',
#   'kembang',
#   'galur',
#   'semanggi',
#   'yang',
#   'kandung',
#   'sedikit',
#   'kumarin',
#   'galur',
#   'yang',
#   'kandung',
#   'kumarin',
#   'bentuk',
#   'ikat']}

# %%
file_path = "../data/training_set/triple_annotator_disagree.csv"

triple_annotator_disagree = preprocessing(file_path)

triple_annotator_disagree
# Out:
# {'1000113': ['kena',
#   'sendang',
#   'mata',
#   'air',
#   'tawar',
#   'duduk',
#   'tempat',
#   'nama',
#   'sendang',
#   'mberan',
#   'arti',
#   'sumber',
#   'tahu',
#   'sedang',
#   'sendang',
#   'mata',
#   'air',
#   'kandung',
#   'belerang',
#   'nama',
#   'sendang',
#   'gong',
#   'dulu',
#   'jaman',
#   'nenek',
#   'moyang',
#   'sumber',
#   'tutup',
#   'gong'],
#  '1000354': ['osmofili',
#   'ragi',
#   'salah',
#   'satu',
#   'organisme',
#   'sebab',
#   'busuk',
#   'bagai',
#   'hasil',
#   'olah',
#   'industri',
#   'gula',
#   'makan',
#   'kandung',
#   'zat',
#   'manis'],
#  '1000621': ['temu',
#   'jill',
#   'bandara',
#   'tinggal',
#   'jakarta',
#   'sama',
#   'jill',
#   'kini',
#   'sedang',
#   'hamil',
#   'kandung',
#   'anak',
#   'dan',
#   'terbang',
#   'eropa'],
#  '1001117': ['mr',
#   'frank',
#   'churchill',
#   'putra',
#   'mr',
#   'weston',
#   'nikah',
#   'adalah',
#   'orang',
#   'pemuda',
#   'ramah',
#   'atur',
#   'suka',
#   'semua',
#   'orang',
#   'mr',
#   'knightley',
#   'anggap',
#   'cukup',
#   'dewasa',
#   'walaupun',
#   'kecembuannya',
#   'frank',
#   'karena',
#   'kejar',
#   'emma'],
#  '1001733': ['itu',
#   'bagai',
#   'hukum',
#   'orion',
#   'selalu',
#   'kejar',
#   'peliades',
#   'tidak',
#   'dapat',
#   'dan',
#   'selalu',
#   'kejar',
#   'kalajengking',
#   'zodiak',
#   'scorpio'],
#  '1001766': ['lulus',
#   'institut',
#   'dongah',
#   'media',
#   'seni',
#   'jurus',
#   'applied',
#   'music',
#   'ikut',
#   'audisi',
#   'woollim',
#   'entertainment',
#   'kejar',
#   'karier',
#   'bagai',
#   'nyanyi',
#   'solo',
#   'terima',
#   'woollim',
#   'sama',
#   '2',
#   'agens',
#   'salah',
#   'satu',
#   'jadi',
#   'yg',
#   'entertainment'],
#  '1002152': ['beberapa',
#   'waktu',
#   'alih',
#   'mumbai',
#   'kejar',
#   'karier',
#   'bidang',
#   'modeling'],
#  '1002209': ['sokrates',
#   'aku',
#   'mereka',
#   'bahas',
#   'ini',
#   'motif',
#   'ban',
#   'kritias',
#   'periksa',
#   'diri',
#   'sendiri',
#   'dia',
#   'kejar',
#   'argumen',
#   'sebut',
#   'penting',
#   'sendiri',
#   '166c',
#   'd'],
#  '1002271': ['turut',
#   'akun',
#   'pertama',
#   'toma',
#   'pertama',
#   'kali',
#   'muncul',
#   'tahun',
#   '803',
#   'sama',
#   'vardanis',
#   'tourkos',
#   'kejar',
#   'karier',
#   'militer',
#   'luncur',
#   'ronta',
#   'akhir',
#   'tahun',
#   '820'],
#  '1002454': ['ini',
#   'cukup',
#   'memprihatikan',
#   'mereka',
#   'kejar',
#   'gaji',
#   'besar',
#   'timbang',
#   'risiko',
#   'buah',
#   'ironi',
#   'lebih',
#   'memprihatikan',
#   'banyak',
#   'tki',
#   'tkw',
#   'asal',
#   'desa',
#   'clumprit',
#   'rupa',
#   'lulus',
#   'guru',
#   'tinggi',
#   'sektor',
#   'tani',
#   'kerja',
#   'generasi',
#   'tua',
#   'buruh',
#   'tani',
#   'datang',
#   'desa',
#   'tetangga'],
#  '1002566': ['kejar', 'nami', 'desa', 'kokoyashi'],
#  '1003958': ['dagang',
#   'sultan',
#   'pasai',
#   'keluar',
#   'koin',
#   'emas',
#   'bagai',
#   'alat',
#   'transaksi',
#   'masyarakat',
#   'mata',
#   'uang',
#   'sebut',
#   'deureuham'],
#  '1003963': ['visa',
#   'keluar',
#   'kartu',
#   'panjang',
#   'kredit',
#   'tetap',
#   'tarif',
#   'biaya',
#   'konsumen',
#   'balik',
#   'visa',
#   'sedia',
#   'lembaga',
#   'uang',
#   'produk',
#   'bayar',
#   'merek',
#   'visa',
#   'kemudian',
#   'guna',
#   'tawar',
#   'program',
#   'kredit',
#   'debit',
#   'prabayar',
#   'akses',
#   'tunai',
#   'langgan'],
#  '1004109': ['gera',
#   'mulai',
#   'keluar',
#   'bijak',
#   'wajib',
#   'ajar',
#   'pns',
#   'sana',
#   'kena',
#   'seragam',
#   'batik',
#   'gebleg',
#   'renteng',
#   'batik',
#   'khas',
#   'kulonprogo',
#   'hari'],
#  '1004651': ['stalin',
#   'keluar',
#   'perintah',
#   'gko',
#   'no',
#   '5859ss',
#   'isi',
#   'pindah',
#   'orang',
#   'tatar',
#   'krimea'],
#  '1004781': ['pimpin',
#   'tanding',
#   'trinidad',
#   'tobago',
#   'lawan',
#   'swedia',
#   'keluar',
#   'kartu',
#   'merah',
#   'pertama',
#   'turnamen',
#   'kepada',
#   'main',
#   'trinidad',
#   'tobago',
#   'avery',
#   'john'],
#  '1004932': ['ahli',
#   'sihir',
#   'firaun',
#   'masingmasing',
#   'keluar',
#   'ajaib',
#   'antara',
#   'lempar',
#   'tali',
#   'lalu',
#   'jadi',
#   'ular'],
#  '1006399': ['usaha',
#   'anggap',
#   'bagai',
#   'usaha',
#   'multinasional',
#   'pertama',
#   'dunia',
#   'sekaligus',
#   'rupa',
#   'usaha',
#   'pertama',
#   'keluar',
#   'sistem',
#   'saham'],
#  '1006400': ['kalman',
#   'keluar',
#   'jumlah',
#   'putus',
#   'undang',
#   'pisah',
#   'capitula',
#   'de',
#   'iudeis',
#   'atur',
#   'posisi',
#   'orang',
#   'yahudi',
#   'hongaria'],
#  '1006454': ['saat',
#   'burung',
#   'jenjang',
#   'tanya',
#   'hadiah',
#   'serigala',
#   'jawab',
#   'kamu',
#   'tempat',
#   'kepala',
#   'dalam',
#   'mulut',
#   'serigala',
#   'keluar',
#   'dengan',
#   'selamat',
#   'yang',
#   'jadi',
#   'hadiah'],
#  '1006483': ['26',
#   'desember',
#   '1995',
#   'presiden',
#   'soeharto',
#   'keluar',
#   'keppres',
#   'no',
#   '82',
#   'kena',
#   'proyek',
#   'kembang',
#   'lahan',
#   'gambut',
#   'plg',
#   'satu',
#   'juta',
#   'hektar',
#   'kalimantan',
#   'tengah'],
#  '1006784': ['tahun',
#   '1871',
#   'perintah',
#   'kota',
#   'banjarmasin',
#   'keluar',
#   'segel',
#   'izin',
#   'buat',
#   'rumah',
#   'bubung',
#   'tinggi',
#   'kampung',
#   'sungai',
#   'jingah',
#   'rupa',
#   'rumah',
#   'tua',
#   'pernah',
#   'keluar',
#   'segel'],
#  '1006993': ['tahun',
#   '1993',
#   'parlemen',
#   'belgia',
#   'keluar',
#   'undang',
#   'yurisdiksi',
#   'universal',
#   'izin',
#   'adil',
#   'belgia',
#   'hakim',
#   'yang',
#   'laku',
#   'jahat',
#   'perang',
#   'jahat',
#   'hadap',
#   'manusia',
#   'genosida'],
#  '1007800': ['ketika',
#   'son',
#   'goku',
#   'mulai',
#   'pojok',
#   'akhir',
#   'gohan',
#   'masih',
#   'usia',
#   '4',
#   'tahun',
#   'marah',
#   'keluar',
#   'seluruh',
#   'tenaga',
#   'angka',
#   'scouter',
#   'tunjuk',
#   'ranga',
#   'atas',
#   '1000'],
#  '1007814': ['banyak',
#   'mungkin',
#   'pertanggungjawabkanlah',
#   'hidup',
#   'kini',
#   'arsyil',
#   'hasil',
#   'karya',
#   'dunia',
#   'tulis',
#   'keluar',
#   '2',
#   'buku',
#   'motivasi',
#   'kena',
#   'hidup'],
#  '1007834': ['sukses',
#   'keluar',
#   'single',
#   'damai',
#   'wayang',
#   'rilis',
#   'single',
#   'pada',
#   'tahun',
#   '2015'],
#  '1008802': ['tahun',
#   '749',
#   'thelbald',
#   'keluar',
#   'carter',
#   'bebas',
#   'wilayah',
#   'eklesiologi',
#   'semua',
#   'wajib',
#   'butuh',
#   'bangun',
#   'benteng',
#   'jembatan',
#   'wajib',
#   'letak',
#   'atas',
#   'semua',
#   'orang',
#   'bagai',
#   'dari',
#   'trinoda',
#   'necessitas'],
#  '1008953': ['sejak', 'bentuk', 'telah', 'keluar', '4', 'album'],
#  '1009294': ['musa',
#   'esok',
#   'hari',
#   'masuk',
#   'dalam',
#   'kemah',
#   'hukum',
#   'maka',
#   'tampak',
#   'tongkat',
#   'harun',
#   'turun',
#   'lewi',
#   'tunas',
#   'keluar',
#   'kuntum',
#   'kembang',
#   'bunga',
#   'buah',
#   'buah',
#   'badam'],
#  '1009468': ['bulan',
#   'september',
#   '2010',
#   'keluar',
#   'cd',
#   'dvd',
#   'rekam',
#   'cara',
#   'langsung',
#   'teatro',
#   'lope',
#   'de',
#   'vega',
#   'sevilla',
#   'raya',
#   '15',
#   'tahun',
#   'karier',
#   'bagai',
#   'nyanyi'],
#  '1009772': ['pasang',
#   'mudamudi',
#   'galela',
#   'tobelo',
#   'yang',
#   'datang',
#   'telaga',
#   'untuk',
#   'saling',
#   'ikat',
#   'janji'],
#  '1009810': ['banyak', 'biasa', 'bagai', 'cara', 'ikat', 'tzitzit'],
#  '1009833': ['akar',
#   'baik',
#   'dapat',
#   'ikat',
#   'nitrogen',
#   'mampu',
#   'bantu',
#   'baik',
#   'subur',
#   'tanah'],
#  '1009871': ['belum',
#   'tempur',
#   'kata',
#   'yudistira',
#   'diri',
#   'budak',
#   'kaya',
#   'dengan',
#   'kaya',
#   'korawa',
#   'ikat',
#   'bisma'],
#  '1009951': ['kelompok',
#   'bakteri',
#   'biasa',
#   'simbiosis',
#   'tanam',
#   'kacang',
#   'polong',
#   'bentuk',
#   'suatu',
#   'simbiosis',
#   'mutualisme',
#   'upa',
#   'nodul',
#   'bintil',
#   'akar',
#   'ikat',
#   'nitrogen',
#   'bebas',
#   'udara',
#   'pada',
#   'umum',
#   'dapat',
#   'cara',
#   'langsung',
#   'banyak',
#   'organisme'],
#  '1009988': ['hidroksamat',
#   'telah',
#   'pakai',
#   'transpor',
#   'luar',
#   'sel',
#   'ikat',
#   'ion',
#   'logam',
#   'besi'],
#  '1010027': ['peter',
#   'tenda',
#   'doyle',
#   'temu',
#   'sylar',
#   'ikat',
#   'mampu',
#   'telekinesis',
#   'tubuh',
#   'doyle'],
#  '1010123': ['karena',
#   'pendek',
#   'rantai',
#   'hidrofobik',
#   'akibat',
#   'poliena',
#   'ikat',
#   'kolesterol',
#   'toksik',
#   'hewan'],
#  '1010145': ['lain',
#   'masuk',
#   'sejarah',
#   'budaya',
#   'juga',
#   'ikat',
#   'kroasia',
#   'slovenia',
#   'eropa',
#   'tengah',
#   'daerah',
#   'laut',
#   'tengah',
#   'lebih',
#   'mereka',
#   'ikat',
#   'bal'],
#  '1010162': ['binding',
#   'domain',
#   'ortosterik',
#   'milik',
#   'homologi',
#   'tinggi',
#   'tiap',
#   'subtipenya',
#   'ini',
#   'buat',
#   'sulit',
#   'dapat',
#   'agonis',
#   'antagonis',
#   'dapat',
#   'ikat',
#   'sutipe'],
#  '1010240': ['bagai',
#   'glukokortikoid',
#   'struktur',
#   'lipofilik',
#   'prednisolon',
#   'mungkin',
#   'mudah',
#   'lewat',
#   'membran',
#   'sel',
#   'kemudian',
#   'ikat',
#   'masingmasing',
#   'reseptor',
#   'glukokortikoid',
#   'gcr',
#   'letak',
#   'sitoplasma'],
#  '1010272': ['sumpah',
#   'setia',
#   'atas',
#   'sedia',
#   'jadi',
#   'tani',
#   'budak',
#   'hanya',
#   'ikat',
#   'diri',
#   'tetapi',
#   'turun'],
#  '1010295': ['fokus',
#   'utama',
#   'novel',
#   'adalah',
#   'cerita',
#   'dalam',
#   'dunia',
#   'alternatif',
#   'amerika',
#   'serikat',
#   'mana',
#   'bisnis',
#   'swasta',
#   'derita',
#   'bagai',
#   'akibat',
#   'hukum',
#   'undang',
#   'terlalu',
#   'ikat',
#   'kaku'],
#  '1010340': ['hasil',
#   'tunjuk',
#   'reaksi',
#   'enzimatik',
#   'perilaku',
#   'cara',
#   'langgar',
#   'sama',
#   'michaelismenten',
#   'klasik',
#   'bahwa',
#   'peran',
#   'tidak',
#   'ikat',
#   'katalisis',
#   'enzimatik',
#   'harus',
#   'cara',
#   'eksperimental'],
#  '1010401': ['biaya',
#   'musdes',
#   'desa',
#   'bisa',
#   'asal',
#   'agam',
#   'sumber',
#   'lain',
#   'hibah',
#   'sumbang',
#   'tidak',
#   'ikat',
#   'dari',
#   'pihak',
#   'tiga'],
#  '1010433': ['pyqt',
#   'lintas',
#   'platform',
#   'gui',
#   'perangkat',
#   'qt',
#   'ikat',
#   'python',
#   'implementasi',
#   'bagai',
#   'plugin'],
#  '1010444': ['rasa', 'tantang', 'tino', 'ikat', 'tangan', 'arie'],
#  '1010448': ['memorandum',
#   'of',
#   'understanding',
#   'tak',
#   'ikat',
#   'ditandatangani',
#   'april',
#   '2006',
#   'beri',
#   'konsesi',
#   'operasi',
#   'jaring',
#   'kcr',
#   'mtrcl',
#   'lama',
#   '50',
#   'tahun'],
#  '1010569': ['ini',
#   'cantum',
#   'amar',
#   'putus',
#   'tetapi',
#   'dissenting',
#   'opinion',
#   'akan',
#   'jadi',
#   'buah',
#   'preseden',
#   'ikat',
#   'jadi',
#   'dari',
#   'putus',
#   'hakim'],
#  '1010611': ['gera',
#   'lopor',
#   'habib',
#   'ali',
#   'nyata',
#   'mampu',
#   'ikat',
#   'jumlah',
#   'besar',
#   'muka',
#   'islam',
#   'bagai',
#   'latar',
#   'belakang',
#   'beda',
#   'dalam',
#   'satu',
#   'shaf',
#   'lurus',
#   'panjang',
#   'sama',
#   'tanggap',
#   'buah',
#   'isu',
#   'internasional',
#   'satu',
#   'suara',
#   'bulat',
#   'tidak',
#   'pecah'],
#  '1010625': ['energi',
#   'sebut',
#   'lanjut',
#   'untuk',
#   'ikat',
#   'senyawa',
#   'sederhana',
#   'sebut',
#   'jadi',
#   'senyawa',
#   'lebih',
#   'kompleks'],
#  '1010665': ['lektin',
#   'protein',
#   'ikat',
#   'sel',
#   'tubuh',
#   'glikoprotein',
#   'glikolipid',
#   'ekspresi',
#   'muka',
#   'sel',
#   'khusus',
#   'molekul',
#   'glukosa',
#   'milik',
#   'mampu',
#   'buat',
#   'sel',
#   'sebut',
#   'gumpal'],
#  '1010684': ['hg',
#   'senyawa',
#   'anorganik',
#   'ikat',
#   'karbon',
#   'bentuk',
#   'senyawa',
#   'organomerkuri'],
#  '1010702': ['eaat5', 'ikat', 'dlg4', 'domain', 'pdz'],
#  '1010757': ['thomas',
#   'buka',
#   'pintu',
#   'kemudi',
#   'mobil',
#   'dan',
#   'angela',
#   'tusuk',
#   'mata',
#   'pulpen',
#   'lalu',
#   'ikat',
#   'thomas',
#   'mobil'],
#  '1010768': ['hemoglobin',
#   'ikat',
#   'ubah',
#   'warna',
#   'merah',
#   'biru',
#   'jadi',
#   'merah',
#   'cerah'],
#  '1011047': ['isi',
#   'kosong',
#   'sintang',
#   'mgr',
#   'agus',
#   'tugas',
#   'jadi',
#   'administrator',
#   'apostolik',
#   'tahbis',
#   'ganti',
#   'sintang',
#   'mgr',
#   'samuel',
#   'oton',
#   'sidin',
#   'o',
#   'f',
#   'm',
#   'cap'],
#  '1011107': ['aplikasi',
#   'bimatri',
#   'rilis',
#   '3',
#   'indonesia',
#   'aplikasi',
#   'teknologi',
#   'informasi',
#   'komunikasi',
#   'tuju',
#   'mudah',
#   'operator',
#   'seluler',
#   'tri',
#   'tahu',
#   'isi',
#   'ulang',
#   'pulsa',
#   'tri'],
#  '1011318': ['ikut',
#   'audisi',
#   'isi',
#   'salah',
#   'satu',
#   'program',
#   'komedi',
#   'jawa',
#   'pos',
#   'media',
#   'televisi',
#   'jtv',
#   'menang',
#   'bagai',
#   'juara',
#   'pertama',
#   'kondisi',
#   'uang',
#   'akbar',
#   'mulai',
#   'tingkat',
#   'sedikit'],
#  '1011468': ['mereka',
#   'senang',
#   'musso',
#   'pakai',
#   'isi',
#   'suara',
#   'karakter',
#   'jeremy',
#   'johnson',
#   'meski',
#   'musso',
#   'isi',
#   'suara',
#   'karakter',
#   'utama',
#   'peran',
#   'baru',
#   'mungkin',
#   'dapat',
#   'bicara',
#   'lebih',
#   'banyak'],
#  '1011471': ['aktivitas',
#   'hari',
#   'lebih',
#   'banyak',
#   'penuh',
#   'undang',
#   'isi',
#   'seminar',
#   'ceramah',
#   'samping',
#   'tulis',
#   'novel',
#   'jadi',
#   'kerja',
#   'utama',
#   'sekal',
#   'tulis',
#   'skenario',
#   'sinetron',
#   'untuk',
#   'sinemart',
#   'buah',
#   'rumah',
#   'produksi',
#   'taung',
#   'karya',
#   'dunia',
#   'film',
#   'sinetron'],
#  '1011673': ['adit',
#   'sanggar',
#   'ananda',
#   'jadi',
#   'pionir',
#   'sanggar',
#   'anak',
#   'paling',
#   'aktif',
#   'buat',
#   'isi',
#   'bagai',
#   'tayang',
#   'televisi',
#   'mulai',
#   'iklan',
#   'tv',
#   'media',
#   'cetak',
#   'sinetron',
#   'drama',
#   'misteri',
#   'laga',
#   'komedi'],
#  '1011779': ['sering',
#   'isi',
#   'acara',
#   'open',
#   'mic',
#   'ada',
#   'komunitas',
#   'maupun',
#   'penuh',
#   'undang',
#   'komunitas',
#   'stand',
#   'up',
#   'indo',
#   'se',
#   'jabodetabek',
#   'tampil',
#   'ber',
#   'stand',
#   'up',
#   'comedy',
#   'nama',
#   'dicky',
#   'bagai',
#   'komika',
#   'mulai',
#   'kenal',
#   'akhir',
#   '2014'],
#  '1011819': ['bukti',
#   'jadi',
#   'orang',
#   'dosen',
#   'pulung',
#   'isi',
#   'waktu',
#   'senggang',
#   'jadi',
#   'orang',
#   'comic',
#   'laksana',
#   'stand',
#   'up',
#   'comedy'],
#  '1011881': ['sekolah',
#   'bagai',
#   'selenggara',
#   'didik',
#   'tengah',
#   'juru',
#   'bagai',
#   'harap',
#   'perintah',
#   'masyarakat',
#   'upaya',
#   'tekad',
#   'hasil',
#   'tenaga',
#   'kerja',
#   'tingkat',
#   'tengah',
#   'isi',
#   'lapang',
#   'kerja',
#   'sedia',
#   'tingkat',
#   'regional',
#   'nasional',
#   'internasional'],
#  '1011989': ['sama',
#   'menteri',
#   'tani',
#   'estanislau',
#   'da',
#   'silva',
#   'nama',
#   'usul',
#   'fretilin',
#   'isi',
#   'posisi',
#   'perdana',
#   'menteri'],
#  '1012307': ['demikian',
#   'irna',
#   'sempat',
#   'tulis',
#   'bahkan',
#   'terjemah',
#   'isi',
#   'lembar',
#   'ilmu',
#   'tahu',
#   'anak',
#   'tabloid',
#   'nova'],
#  '1012364': ['pertama',
#   'kali',
#   'diri',
#   'percaya',
#   'isi',
#   'suara',
#   'tokoh',
#   'peran',
#   'utama',
#   'bagai',
#   'haruka',
#   'anime',
#   'kurogane',
#   'communication'],
#  '1012453': ['musim',
#   'pertama',
#   'suara',
#   'isi',
#   'lacey',
#   'chabert',
#   'kemudian',
#   'ganti',
#   'mila',
#   'kunis',
#   'sejak',
#   'musim',
#   'walaupun',
#   'chabert',
#   'sempat',
#   'isi',
#   'suara',
#   'meg',
#   'episode',
#   'yug',
#   'ylimaf',
#   'back',
#   'to',
#   'the',
#   'pilot'],
#  '1012565': ['kenal',
#   'isi',
#   'bagai',
#   'acara',
#   'televisi',
#   'indonesia',
#   'jadi',
#   'salah',
#   'satu',
#   'per',
#   'film',
#   'setan',
#   'facebook'],
#  '1012604': ['luar',
#   'jalan',
#   'giat',
#   'bagai',
#   'motivator',
#   'adam',
#   'khoo',
#   'model',
#   'freelance',
#   'alya',
#   'senang',
#   'isi',
#   'waktu',
#   'luang',
#   'luk'],
#  '1012627': ['wakil', 'partai', 'satu', 'bangun', 'isi', 'kursi', 'banyak'],
#  '1012634': ['hari',
#   'sama',
#   'agens',
#   'south',
#   'club',
#   'unggah',
#   'video',
#   'nyata',
#   'telah',
#   'milik',
#   'main',
#   'bas',
#   'baru',
#   'isi',
#   'posisi',
#   'luang',
#   'sebut'],
#  '1012650': ['sejak',
#   'itu',
#   'jelas',
#   'plantae',
#   'bagaimana',
#   'definisi',
#   'awal',
#   'cakup',
#   'beberapa',
#   'kelompok',
#   'tidak',
#   'kait',
#   'beberapa',
#   'kelompok',
#   'jamur',
#   'ganggang',
#   'tidak',
#   'kait',
#   'pindah',
#   'isi',
#   'raja',
#   'baru'],
#  '1013187': ['linkin',
#   'park',
#   'sedang',
#   'kerja',
#   'proyek',
#   'isi',
#   'soundtrack',
#   'film',
#   'datang',
#   'sebut',
#   'mall',
#   'sutradara',
#   'joe',
#   'hahn'],
#  '1013270': ['isi',
#   'suara',
#   'tokoh',
#   'aang',
#   'serial',
#   'animasi',
#   'avatar',
#   'the',
#   'legend',
#   'of',
#   'aang'],
#  '1013376': ['situ',
#   'budjana',
#   'armand',
#   'ajak',
#   'thomas',
#   'kembali',
#   'isi',
#   'main',
#   'bass',
#   'album',
#   'baru',
#   'gigi',
#   'baik',
#   '1999'],
#  '1013446': ['buat',
#   'benda',
#   'apung',
#   'udara',
#   'harus',
#   'lebih',
#   'ringan',
#   'volume',
#   'sama',
#   'udara',
#   'isi',
#   'balon',
#   'dengan',
#   'udara',
#   'tidak',
#   'terlalu',
#   'padat',
#   'udara',
#   'sekitar'],
#  '1013457': ['itu',
#   'tahun',
#   '1952',
#   'maskapai',
#   'juga',
#   'laku',
#   'beli',
#   'banyak',
#   '5',
#   'armada',
#   'douglas',
#   'dc4',
#   'nanti',
#   'isi',
#   'jalur',
#   'timur',
#   'tengah',
#   'awal',
#   'operasional',
#   'tuju',
#   'amman',
#   'jordania'],
#  '1013701': ['yo',
#   'and',
#   'i',
#   'inspirasi',
#   'hubung',
#   'gaga',
#   'pacar',
#   'gaga',
#   'l',
#   'c',
#   'carl',
#   'buah',
#   'lagu',
#   'tempo',
#   'lambat',
#   'isi',
#   'suara',
#   'gitar',
#   'elektrik',
#   'piano',
#   'gaga',
#   'lange',
#   'isi',
#   'background',
#   'vocal'],
#  '1013900': ['autoloader',
#   'atas',
#   'masalah',
#   'susah',
#   'isi',
#   'amunisi',
#   'sering',
#   'muncul',
#   'tank',
#   'isi',
#   'manusia'],
#  '1014040': ['itu',
#   'jaga',
#   'jaga',
#   'kualitas',
#   'uang',
#   'rupiah',
#   'kondisi',
#   'layak',
#   'edar',
#   'masyarakat',
#   'bank',
#   'indonesia',
#   'laku',
#   'giat',
#   'musnah',
#   'uang'],
#  '1014133': ['susu',
#   'kerbau',
#   'perah',
#   'lebih',
#   'puting',
#   'susu',
#   'bersih',
#   'air',
#   'hangat',
#   'ini',
#   'maksud',
#   'jaga',
#   'kerbersihan',
#   'susu',
#   'rangsang',
#   'puting',
#   'susu'],
#  '1014440': ['usta',
#   'e',
#   'anggap',
#   'islam',
#   'bosniak',
#   'bagai',
#   'agama',
#   'jaga',
#   'murni',
#   'darah',
#   'kroasia'],
#  '1014533': ['direktur',
#   'dokumentasi',
#   'snte',
#   'st',
#   'phane',
#   'dieu',
#   'komentar',
#   'januari',
#   '2005',
#   'ini',
#   'tuju',
#   'jaga',
#   'komersial',
#   'gambar',
#   'tidak',
#   'dalam',
#   'cara',
#   'tidak',
#   'tuju'],
#  '1014570': ['jaga',
#   'sehat',
#   'ternak',
#   'kabupaten',
#   'bintan',
#   '5',
#   'orang',
#   'dokter',
#   'hewan',
#   'bantu',
#   'beberapa',
#   'paramedis',
#   'veteriner',
#   'tunjang',
#   '2',
#   'buah',
#   'sarana',
#   'pos',
#   'sehat',
#   'hewan',
#   'poskeswan',
#   'lokasi',
#   'desa',
#   'sri',
#   'bintan',
#   'desa',
#   'ekang',
#   'anculai',
#   'camat',
#   'teluk',
#   'bong',
#   'poskeswan',
#   'kabupaten',
#   'bintan',
#   'dapat',
#   'rumah',
#   'potong',
#   'hewan',
#   'unggas',
#   'rphu',
#   'lokasi',
#   'camat',
#   'bintan',
#   'utara'],
#  '1014651': ['komisioner',
#   'labuh',
#   'atur',
#   'hilir',
#   'arun',
#   'arundel',
#   'laut',
#   'tahun',
#   '1732',
#   'beberapa',
#   'tingkat',
#   'laku',
#   'jaga',
#   'kawasan',
#   'muara',
#   'bebas',
#   'endap',
#   'dukung',
#   'buah',
#   'undang',
#   'tahun',
#   '1793'],
#  '1014811': ['pendeta',
#   'laku',
#   'konseling',
#   'pastoral',
#   'wajib',
#   'jaga',
#   'rahasia',
#   'jemaat',
#   'laku',
#   'cakap',
#   'konseling',
#   'pastoral'],
#  '1015084': ['keluarga',
#   'besar',
#   'vakum',
#   'jaga',
#   'jarak',
#   'kuasa',
#   'lama',
#   'masa',
#   'pakubuwana',
#   'vii',
#   'viii'],
#  '1015303': ['hal', 'buat', 'djing', 'tie', 'jaga', 'aman', 'duduk'],
#  '1015546': ['bijak',
#   'tahan',
#   'nasional',
#   'tuju',
#   'jaga',
#   'merdeka',
#   'kuasa',
#   'republik',
#   'makedonia',
#   'atas',
#   'lahan',
#   'angkasa',
#   'ada',
#   'daerah',
#   'republik',
#   'makedonia'],
#  '1015603': ['teks',
#   'lama',
#   '1853',
#   'liput',
#   'tuju',
#   'jaga',
#   'hubung',
#   'pasif',
#   'suku',
#   'indian',
#   'promosi',
#   'konversi',
#   'ke',
#   'katolik',
#   'hapus',
#   'reformasi',
#   'sebut'],
#  '1015740': ['tempur',
#   'asfeld',
#   '552',
#   'bunuh',
#   'turismodus',
#   'putra',
#   'raja',
#   'gepid',
#   'turisindus',
#   'dalam',
#   'menang',
#   'akibat',
#   'ikut',
#   'campur',
#   'kaisar',
#   'yustitianus',
#   'jaga',
#   'imbang',
#   'antara',
#   'saing',
#   'kuat',
#   'regional'],
#  '1016219': ['sunil',
#   'kata',
#   'abdi',
#   'setan',
#   'garap',
#   'mulai',
#   'ide',
#   'cerita',
#   'naskah',
#   'hingga',
#   'sutradara',
#   'joko',
#   'anwar',
#   'butuh',
#   'lebih',
#   'banyak',
#   'anggar',
#   'banding',
#   'film',
#   'horor',
#   'biasa',
#   'tekad',
#   'jaga',
#   'nuansa',
#   'era',
#   '1980an',
#   'pada',
#   'film',
#   'asli'],
#  '1016269': ['tuju',
#   'tidak',
#   'untuk',
#   'tahan',
#   'kota',
#   'untuk',
#   'jaga',
#   'istana',
#   'sendiri',
#   'letak',
#   'dekat',
#   'gunung',
#   'sion'],
#  '1016459': ['hagrid',
#   'tolak',
#   'percaya',
#   'snape',
#   'tanggung',
#   'jawab',
#   'atas',
#   'bahaya',
#   'harry',
#   'ceplos',
#   'dia',
#   'beli',
#   'anjing',
#   'kepala',
#   'tiga',
#   'bahwa',
#   'monster',
#   'jaga',
#   'rahasia',
#   'punya',
#   'professor',
#   'dumbledore',
#   'orang',
#   'nama',
#   'nicolas',
#   'flamel'],
#  '1016463': ['sebab',
#   'bagi',
#   'orang',
#   'krowe',
#   'sangat',
#   'penting',
#   'jaga',
#   'hubung',
#   'roh',
#   'halus',
#   'sebut'],
#  '1016961': ['satyaka',
#   'libat',
#   'perang',
#   'baratayuda',
#   'tugas',
#   'ayah',
#   'jaga',
#   'baladewa',
#   'sedang',
#   'tapa'],
#  '1017097': ['samping',
#   'balast',
#   'jaga',
#   'rel',
#   'tetap',
#   'tempat',
#   'apabila',
#   'kereta',
#   'api',
#   'jalan',
#   'di',
#   'atas'],
#  '1017149': ['visi',
#   'wujud',
#   'generasi',
#   'masadepan',
#   'cerdas',
#   'beril',
#   'kreatif',
#   'produktif',
#   'mandiri',
#   'maju',
#   'akhlak',
#   'mulia',
#   'ramah',
#   'daulat',
#   'adab',
#   'sejahtera',
#   'peduli',
#   'adil',
#   'makmur',
#   'cinta',
#   'tanah',
#   'air',
#   'bangsa',
#   'turut',
#   'jaga',
#   'utuh',
#   'nkri',
#   'pancasila',
#   'uud',
#   '1945',
#   'haluan',
#   'islam',
#   'ahlussunnah',
#   'wal',
#   'jama',
#   'ah',
#   'garis',
#   'jam',
#   'yah',
#   'nahdlatul',
#   'ulama',
#   'nu',
#   'islam',
#   'rahmat',
#   'lil',
#   'alamien'],
#  '1017213': ['wilkataksini',
#   'raksasa',
#   'sangat',
#   'besar',
#   'jaga',
#   'pantai',
#   'alengka'],
#  '1017401': ['kumpul',
#   'di',
#   'tengah',
#   'inap',
#   'mereka',
#   'dapat',
#   'fakta',
#   'kejut',
#   'migi',
#   'hilang',
#   'padahal',
#   'sadha',
#   'jaga',
#   'pintu',
#   'kamar',
#   'tidak',
#   'lihat',
#   'orang',
#   'masuk',
#   'maupun',
#   'keluar',
#   'sang',
#   'paranormal',
#   'kata',
#   'migi',
#   'bawa',
#   'dunia',
#   'roh',
#   'halus'],
#  '1017568': ['awal',
#   'kenal',
#   'yonko',
#   'diri',
#   'shanks',
#   'whitebeard',
#   'kaido',
#   'big',
#   'mom',
#   'hasil',
#   'bentuk',
#   'imbang',
#   'kuasa',
#   'solid',
#   'sama',
#   'shichibukai',
#   'angkat',
#   'laut',
#   'jaga',
#   'damai',
#   'dunia'],
#  '1018004': ['fobetor',
#   'cipta',
#   'pasang',
#   'monster',
#   'jaga',
#   'gerbang',
#   'dunia',
#   'mimpi',
#   'susup'],
#  '1018577': ['tugas', 'jaga', 'area', 'pasifik'],
#  '1019424': ['konsumsi',
#   'minyak',
#   'jagung',
#   'efektif',
#   'turun',
#   'kadar',
#   'kolesterol',
#   'darah'],
#  '1019685': ['kemudian',
#   'bharata',
#   'takluk',
#   'darat',
#   'india',
#   'kuno',
#   'bharatawarsha',
#   'turun',
#   'kuru',
#   'turun',
#   'wangsa',
#   'rawa',
#   'korawa'],
#  '1020863': ['runding',
#   'ploegman',
#   'tolak',
#   'turun',
#   'bendera',
#   'belanda',
#   'tolak',
#   'aku',
#   'daulat',
#   'indonesia'],
#  '1021143': ['sapu',
#   'lumpur',
#   'turun',
#   'sisi',
#   'curam',
#   'gunung',
#   'rap',
#   'komposit',
#   'milik',
#   'kuat',
#   'cepat',
#   'rata',
#   'kubur',
#   'segala',
#   'di',
#   'jalan'],
#  '1021368': ['lapis',
#   'baja',
#   'canggih',
#   'tingkat',
#   'survivabilitas',
#   'tank',
#   'telah',
#   'turun',
#   'tingkat',
#   'mati',
#   'awak'],
#  '1021424': ['awal',
#   '1980an',
#   'cara',
#   'eksplisit',
#   'dukung',
#   'upaya',
#   'tiongkok',
#   'sejarawan',
#   'asing',
#   'harrison',
#   'salisbury',
#   'susun',
#   'suatu',
#   'berita',
#   'long',
#   'march',
#   'laku',
#   'wawancara',
#   'ekstensif',
#   'hidup',
#   'panjang',
#   'maret'],
#  '1021781': ['sana',
#   'tunjuk',
#   'susun',
#   'notasi',
#   'seragam',
#   'karawitan',
#   'mantap',
#   'utuh',
#   'praktis',
#   'mudah',
#   'ajar'],
#  '1021860': ['bakteri',
#   'nitrifikasi',
#   'kelompok',
#   'bakteri',
#   'mampu',
#   'susun',
#   'senyawa',
#   'nitrat',
#   'senyawa',
#   'amonia',
#   'pada',
#   'umum',
#   'langsung',
#   'cara',
#   'aerob',
#   'dalam',
#   'tanah'],
#  '1021967': ['crowther',
#   'mulai',
#   'terjemah',
#   'alkitab',
#   'dalam',
#   'bahasa',
#   'yoruba',
#   'susun',
#   'kamus',
#   'yoruba'],
#  '1022026': ['itu',
#   'tyler',
#   'susun',
#   'musik',
#   'serial',
#   'children',
#   'of',
#   'dune',
#   'dalam',
#   'waktu',
#   'satu',
#   'bulan',
#   'tepat',
#   'karya',
#   'darkness',
#   'falls'],
#  '1022363': ['bila',
#   'coba',
#   'terap',
#   'ilmu',
#   'coba',
#   'susun',
#   'beda',
#   'sosial',
#   'sebut',
#   'runtuh',
#   'semua'],
#  '1022414': ['mevlut',
#   'cavusoglu',
#   'susun',
#   'organisasi',
#   'buah',
#   'temu',
#   'akbar',
#   'orasi',
#   'referendum',
#   'konstitusional',
#   'turki',
#   '2017',
#   'mana',
#   'imigran',
#   'ada',
#   'belanda',
#   'pilih'],
#  '1022444': ['zhang',
#   'jiao',
#   'orang',
#   'pimpin',
#   'alir',
#   'agama',
#   'taipingdao',
#   'iring',
#   'tambah',
#   'ikut',
#   'alir',
#   'ratus',
#   'ribu',
#   'umat',
#   'kemudian',
#   'susun',
#   'rencana',
#   'ronta',
#   'hadap',
#   'kaisar',
#   'memang',
#   'lemah'],
#  '1022580': ['konstitusionalisme',
#   'dasar',
#   'gagas',
#   'ide',
#   'daulat',
#   'hukum',
#   'lahir',
#   'konsensus',
#   'libat',
#   'seluruh',
#   'rakyat',
#   'wakil',
#   'rakyat',
#   'susun',
#   'konstitusi',
#   'jadi',
#   'landas',
#   'hidup',
#   'negara'],
#  '1022584': ['konon',
#   'sang',
#   'arsitek',
#   'abdul',
#   'wahid',
#   'el',
#   'wakil',
#   'inspirasi',
#   'hidup',
#   'masyarakat',
#   'tekad',
#   'keras',
#   'disiplin',
#   'bangun',
#   'susun',
#   'rancang',
#   'masjid',
#   'bir',
#   'ali',
#   'yang',
#   'gagah'],
#  '1022645': ['akhir',
#   'konferensi',
#   'susun',
#   'deklarasi',
#   'pbb',
#   'buat',
#   'sekutu',
#   'damai',
#   'musuh',
#   'untuk',
#   'sumber',
#   'daya',
#   'penuh',
#   'menang'],
#  '1022708': ['kiai',
#   'nawawi',
#   'emban',
#   'tugas',
#   'susun',
#   'kitab',
#   'aqidah',
#   'ahmad',
#   'rifai',
#   'fiqih',
#   'muhammad',
#   'khallil',
#   'susun',
#   'tasawuf'],
#  '1022742': ['golong', 'susun', 'banyak', 'minyak', 'atsiri'],
#  '1022826': ['dr',
#   'de',
#   'casparis',
#   'kemudian',
#   'susun',
#   'teori',
#   'telah',
#   'jadi',
#   'perang',
#   'saudara',
#   'rebut',
#   'takhta',
#   'tinggal',
#   'samaratungga',
#   'balaputradewa',
#   'lawan',
#   'pramodawardhani'],
#  '1022827': ['dasar',
#   'alam',
#   'bagai',
#   'orang',
#   'kulit',
#   'hitam',
#   'minoritaire',
#   'dalam',
#   'masyarakat',
#   'perancis',
#   'susun',
#   'buku',
#   'judul',
#   'kulit',
#   'hitam',
#   'topeng',
#   'putih',
#   'mal',
#   'peru',
#   'terbit',
#   'tahun',
#   '1952'],
#  '1022849': ['harmoni',
#   'musik',
#   'barat',
#   'salah',
#   'satu',
#   'teori',
#   'musik',
#   'ajar',
#   'bagaimana',
#   'susun',
#   'suatu',
#   'rangkai',
#   'akordakord',
#   'musik',
#   'sebut',
#   'enak',
#   'dengar',
#   'selaras'],
#  '1022930': ['cetak',
#   'praktik',
#   'buang',
#   'huruf',
#   'u',
#   'colour',
#   'honour',
#   'laku',
#   'susun',
#   'huruf',
#   'hemat',
#   'waktu',
#   'waktu',
#   'kerja',
#   'susun',
#   'huruf',
#   'timah',
#   'kerja',
#   'manual'],
#  '1023132': ['tahun',
#   '1947',
#   'negara',
#   'adopsi',
#   'statuta',
#   'westminster',
#   'tegas',
#   'parlemen',
#   'britania',
#   'dapat',
#   'susun',
#   'undang',
#   'selandia',
#   'baru',
#   'tuju',
#   'selandia',
#   'baru'],
#  '1023461': ['turut',
#   'mayo',
#   'clinic',
#   '95',
#   'insiden',
#   'leceh',
#   'seksual',
#   'hadap',
#   'anak',
#   'usia',
#   '12',
#   'lebih',
#   'muda',
#   'laku',
#   'laku',
#   'penuh',
#   'kriteria',
#   'diagnostik',
#   'pedofilia',
#   'bahwa',
#   'orang',
#   'sebut',
#   'susun',
#   '65',
#   'laku',
#   'aniaya',
#   'anak'],
#  '1023497': ['awal',
#   'tahun',
#   '2000',
#   'jonny',
#   'greenwood',
#   'satu',
#   'anggota',
#   'radiohead',
#   'latih',
#   'teori',
#   'musik',
#   'susun',
#   'aransemen',
#   'musik',
#   'gesek',
#   'how',
#   'to',
#   'disappear',
#   'completely',
#   'ia',
#   'rekam',
#   'sama',
#   'orchestra',
#   'of',
#   'st',
#   'john',
#   's',
#   'dorchester',
#   'abbey'],
#  '1023517': ['schuschnigg',
#   'coba',
#   'kendali',
#   'atas',
#   'itu',
#   'susun',
#   'plebisit',
#   'selenggara',
#   '13',
#   'maret'],
#  '102363': ['beri', 'gelar', 'ksatria', 'hormat', 'tahun', 'baru', '2008'],
#  '1025417': ['tingkat',
#   'yang',
#   'layak',
#   'buah',
#   'waralaba',
#   'minimum',
#   '15',
#   'persen',
#   'nilai'],
#  '1027031': ['batik',
#   'rajin',
#   'milik',
#   'nilai',
#   'seni',
#   'tinggi',
#   'telah',
#   'jadi',
#   'dari',
#   'budaya',
#   'indonesia',
#   'khusus',
#   'jawa',
#   'sejak',
#   'lama'],
#  '1029974': ['kumpul',
#   'pasang',
#   'nilai',
#   'vektor',
#   'eigen',
#   'suatu',
#   'matriks',
#   'ukur',
#   'n',
#   'x',
#   'n',
#   'sebut',
#   'sistem',
#   'eigen',
#   'matriks',
#   'sebut'],
#  '1030212': ['ide',
#   'buat',
#   'tazo',
#   'mirip',
#   'pog',
#   'mirip',
#   'tazo',
#   'bentuk',
#   'tutup',
#   'botol',
#   'kemas',
#   'mana',
#   'tiap',
#   'tazo',
#   'milik',
#   'nilai',
#   'sendiri',
#   'main',
#   'tang',
#   'tazo',
#   'main'],
#  '103225': ['topik',
#   'angkat',
#   'karya',
#   'menang',
#   'guna',
#   'teknologi',
#   'baru',
#   'mungkin',
#   'interaksi',
#   'cipta',
#   'audiens',
#   'segala',
#   'umur',
#   'latar',
#   'belakang',
#   'nasionalitas'],
#  '1032284': ['milik',
#   'nilai',
#   'bagai',
#   'bahan',
#   'kimia',
#   'baik',
#   'bagai',
#   'bahan',
#   'baku',
#   'kaya',
#   'proses',
#   'bagai',
#   'produk',
#   'akhir',
#   'untuk',
#   'guna',
#   'tentu',
#   'balik',
#   'milik',
#   'nilai',
#   'bagai',
#   'bahan',
#   'bakar',
#   'sederhana'],
#  '1033924': ['nilai',
#   'kartu',
#   'individu',
#   'untuk',
#   'peringkat',
#   'tangan',
#   'ada',
#   'kategori',
#   'peringkat',
#   'sama'],
#  '1038272': ['tahun',
#   '2007',
#   'anugerah',
#   'harga',
#   'sastra',
#   'belanda',
#   'tolak',
#   'nilai',
#   'anggap',
#   'rendah',
#   '16',
#   '000',
#   'kata',
#   'olah',
#   'baru',
#   'sekarang'],
#  '1038785': ['ini',
#   'masuk',
#   'buah',
#   'hangar',
#   'luas',
#   'enam',
#   'pesawat',
#   'nila',
#   'nok',
#   '100',
#   'juta'],
#  '1042144': ['perotti',
#   'gabung',
#   'sevilla',
#   'musim',
#   'panas',
#   'tahun',
#   '2007'],
#  '1043997': ['beberapa',
#   'alir',
#   'panas',
#   'tutup',
#   'es',
#   'air',
#   'kemudian',
#   'panas',
#   'ubah',
#   'jadi',
#   'uap',
#   'cipta',
#   'kawah',
#   'lebar',
#   '20',
#   'meter',
#   'kirim',
#   'abu',
#   '2',
#   '000',
#   'meter',
#   'udara'],
#  '1044570': ['contoh',
#   'sama',
#   'basal',
#   'basanit',
#   'produksi',
#   'vulkan',
#   'titik',
#   'panas',
#   'pulau',
#   'hawa',
#   'komoro'],
#  '1044821': ['karena',
#   'belum',
#   'pakai',
#   'baik',
#   'kantong',
#   'teh',
#   'rendam',
#   'air',
#   'panas',
#   'sebentar',
#   'dan',
#   'buang',
#   'air',
#   'pertama'],
#  '1044879': ['olimpiade',
#   'musim',
#   'panas',
#   '2016',
#   'menang',
#   'medali',
#   'perunggu',
#   'kategori',
#   '58',
#   'kg',
#   'jadi',
#   'gulat',
#   'putri',
#   'india',
#   'pertama',
#   'menang',
#   'buah',
#   'medali',
#   'olimpiade',
#   'raih',
#   'medali',
#   'olimpiade',
#   'perempuan',
#   'empat',
#   'negara',
#   'sebut'],
#  '1046047': ['anggar',
#   'diutakatik',
#   'debat',
#   'langsung',
#   'panas',
#   'warna',
#   'aksi',
#   'walkout',
#   'beberapa',
#   'anggota',
#   'dprd'],
#  '1047477': ['negara',
#   'iklim',
#   'dwa',
#   'musim',
#   'panas',
#   'hangat',
#   'musim',
#   'dingin',
#   'kering'],
#  '1048792': ['kawasan',
#   'pernah',
#   'jadi',
#   'medan',
#   'tempur',
#   'sebut',
#   'tempur',
#   'musim',
#   'panas',
#   'osaka'],
#  '1048917': ['gas',
#   'panas',
#   'hasil',
#   'bakar',
#   'punya',
#   'volume',
#   'jauh',
#   'lebih',
#   'besar',
#   'volume',
#   'bahan',
#   'bakar',
#   'asli',
#   'akan',
#   'tingkat',
#   'tekan',
#   'ruang',
#   'bakar',
#   'volume',
#   'batas'],
#  '1049349': ['bagi',
#   'prancis',
#   'jadi',
#   'komune',
#   '1790',
#   'lama',
#   'revolusi',
#   'prancis',
#   'tahun',
#   '1834',
#   'paris',
#   'kota',
#   'tengah',
#   'ukur',
#   'sekarang',
#   'tahun',
#   '1860',
#   'kota',
#   'aneksasi',
#   'komune',
#   'beberapa',
#   'antara',
#   'bentuk',
#   'peta',
#   'administratif',
#   'baru',
#   'upa',
#   'puluh',
#   'arondisemen',
#   'kotamadya',
#   'tingkat',
#   'kabupaten',
#   'masih',
#   'diri',
#   'hingga',
#   'sekarang'],
#  '1049426': ['bagi',
#   'raja',
#   'franka',
#   'limburg',
#   'sekarang',
#   'jadi',
#   'milik',
#   'sisa',
#   'belanda',
#   'waktu',
#   'baru',
#   'kaisar',
#   'romawi',
#   'suci'],
#  '1049428': ['aritmetika',
#   'cepat',
#   'suatu',
#   'mampu',
#   'hitung',
#   'operasi',
#   'aritmetika',
#   'jumlah',
#   'kurang',
#   'kali',
#   'bagi',
#   'cepat',
#   'bantu',
#   'kalkulator',
#   'bahkan',
#   'bilang',
#   'nilai',
#   'cukup',
#   'besar'],
#  '1049645': ['bulan',
#   'november',
#   '1997',
#   'ikut',
#   'hadir',
#   'undi',
#   'grup',
#   'piala',
#   'dunia',
#   '1998',
#   'kota',
#   'marseille'],
#  '1049710': ['kena',
#   'hal',
#   'sebut',
#   'atas',
#   'sesuai',
#   'timbang',
#   'mahkamah',
#   'agung',
#   'surat',
#   'nomor',
#   'ma',
#   'pa',
#   '121',
#   'ix',
#   '1976',
#   'tanggal',
#   '23',
#   'september',
#   '1976',
#   'untuk',
#   'lancar',
#   'laksana',
#   'tugas',
#   'bina',
#   'adil',
#   'agama',
#   'jawa',
#   'madura',
#   'pandang',
#   'perlu',
#   'bagi',
#   'tugas',
#   'baru',
#   'cara',
#   'administratif',
#   'bentuk',
#   'cabang',
#   'mahkamah',
#   'islam',
#   'tinggi',
#   'bandung',
#   'surabaya'],
#  '1049788': ['putus',
#   'bagi',
#   'wilayah',
#   'bagi',
#   'wilayah',
#   'serah',
#   'ki',
#   'prawiro',
#   'sumo'],
#  '1049986': ['tctp',
#   'beri',
#   'dukung',
#   'perintah',
#   'daerah',
#   'dukung',
#   'kolaborasi',
#   'antarsektoral',
#   'program',
#   'sehat',
#   'ibu',
#   'anak',
#   'lalu',
#   'terbit',
#   'bagi',
#   'buku',
#   'pegang',
#   'ibu',
#   'anak',
#   'gelar',
#   'padang',
#   '29',
#   'juni6',
#   'juli',
#   '2009'],
#  '1050023': ['karena',
#   'bagi',
#   'tugas',
#   'tanggung',
#   'jawab',
#   'wenang',
#   'jadwal',
#   'tugas',
#   'tata',
#   'kerja',
#   'lain',
#   'masuk',
#   'sistem',
#   'kelola',
#   'didik',
#   'ajar',
#   'perlu',
#   'paham',
#   'pakat',
#   'patuh',
#   'sama'],
#  '1050068': ['county',
#   'hohenzollernhechingen',
#   'diri',
#   'tahun',
#   '1576',
#   'zollern',
#   'rupa',
#   'bagi',
#   'dari',
#   'kaisar',
#   'romawi',
#   'suci'],
#  '1050073': ['april',
#   '2017',
#   'kelompok',
#   'buat',
#   'bijak',
#   'eropa',
#   'diskus',
#   'tentu',
#   'apa',
#   'harus',
#   'buat',
#   'kena',
#   'kursi',
#   'kosong',
#   'sebut',
#   'salah',
#   'satu',
#   'opsi',
#   'dukung',
#   'gianni',
#   'pittella',
#   'emmanuel',
#   'macron',
#   'isi',
#   '73',
#   'kursi',
#   'sebut',
#   'daftar',
#   'konstituen',
#   'seluruh',
#   'eropa',
#   'opsi',
#   'adalah',
#   'tiada',
#   'kursi',
#   'sebut',
#   'atur',
#   'bagi',
#   'beberapa',
#   'seluruh',
#   'kursi',
#   'ada',
#   'parlemen',
#   'untuk',
#   'kurang',
#   'ketidaksetaraan',
#   'representasi',
#   'parlemen'],
#  '1050226': ['sejarahwan',
#   'hongaria',
#   'gyula',
#   'krist',
#   '97',
#   'kata',
#   'bagi',
#   'kadipaten',
#   'zaman',
#   'b',
#   '8ela',
#   'mungkin'],
#  '1050350': ['daftar',
#   'uskup',
#   'sri',
#   'lanka',
#   'maladewa',
#   'buah',
#   'daftar',
#   'muat',
#   'jabar',
#   'hadap',
#   'wilayah',
#   'administratif',
#   'gereja',
#   'katolik',
#   'roma',
#   'pimpin',
#   'orang',
#   'uskup',
#   'ordinaris',
#   'sri',
#   'lanka',
#   'maladewa'],
#  '1050826': ['jadwal', 'masih', 'jelas', 'proyek', 'tunda'],
#  '1050879': ['traktat',
#   'wilayah',
#   'bagi',
#   'wilayah',
#   'jerman',
#   'italia',
#   'beberapa',
#   'negara',
#   'sementara',
#   'swiss',
#   'dapat',
#   'merdeka'],
#  '1051008': ['sejak',
#   'selenggara',
#   'musim',
#   'liga',
#   'indonesia',
#   'lagi',
#   'sistem',
#   'wilayah',
#   'barat',
#   'wilayah',
#   'timur',
#   'sistem',
#   'knockout',
#   'stage',
#   'empat',
#   'final',
#   'semifinal',
#   'final'],
#  '1051015': ['hal',
#   'cara',
#   'untung',
#   'rugi',
#   'janji',
#   'sekutu',
#   'baik',
#   'sebut',
#   'atur',
#   'dalam',
#   'janji',
#   'diri',
#   'sekutu'],
#  '1051358': ['pertama',
#   'kali',
#   'sebut',
#   'bagai',
#   'satrap',
#   'daerah',
#   'hydaspes',
#   'naskah',
#   'babilonia',
#   '323',
#   'sm'],
#  '1051375': ['kota',
#   'waitakere',
#   'bagi',
#   'administratif',
#   'auckland',
#   'barat',
#   'selandia',
#   'baru'],
#  '1051976': ['rapat',
#   'mulai',
#   'pun',
#   'diolok2',
#   'tsuchikage',
#   'oonoki',
#   'ia',
#   'pantas',
#   'gelar',
#   'kage',
#   'ia',
#   'terlalu',
#   'muda',
#   'dapat',
#   'gelar',
#   'sebut'],
#  '1051994': ['a',
#   'bila',
#   'q',
#   'rapat',
#   'muat',
#   'listrik',
#   'muka',
#   'luas',
#   'sudut',
#   'juga'],
#  '1052012': ['cara',
#   'umum',
#   'proses',
#   'olah',
#   'kecap',
#   'ikan',
#   'dengan',
#   'garam',
#   'ikan',
#   'telah',
#   'halus',
#   'kemudian',
#   'simpan',
#   'wadah',
#   'tutup',
#   'rapat',
#   'lama',
#   '3',
#   'beberapa',
#   'bulan'],
#  '1052047': ['ruu',
#   'abpn',
#   '2015',
#   'presiden',
#   'susilo',
#   'bambang',
#   'yudhoyono',
#   'rapat',
#   'paripurna',
#   'dprri',
#   'tanggal',
#   '15',
#   'agustus',
#   '2014',
#   'tuju',
#   'oleh',
#   'dpr',
#   'tanggal',
#   '29',
#   'september',
#   '2014'],
#  '1052075': ['rapat',
#   'tugas',
#   'polisi',
#   'selesai',
#   'fadli',
#   'zon',
#   'nyata',
#   'polisi',
#   'kerja',
#   'bagaimana',
#   'mesti'],
#  '1052129': ['lantik',
#   'gubernur',
#   'zaini',
#   'abdullah',
#   '6',
#   'agustus',
#   '2012',
#   'sesuai',
#   'surat',
#   'putus',
#   'menteri',
#   'negeri',
#   'nomor',
#   '132',
#   '11505',
#   'nomor',
#   '132',
#   '11505',
#   'tahun',
#   '2012',
#   'buah',
#   'rapat',
#   'paripurna',
#   'istimewa',
#   'dprk',
#   'tempat'],
#  '1052160': ['lapang',
#   'ingat',
#   'pada',
#   'peristiwa',
#   'rapat',
#   'raksasa',
#   'rakyat',
#   'jakarta',
#   'jadi',
#   'lapang',
#   'ikada'],
#  '1052210': ['lalu',
#   'rapat',
#   'internal',
#   'komisi',
#   'pilih',
#   'umum',
#   'daerah',
#   'kabupaten',
#   'grobogan',
#   '16',
#   'januari',
#   '2011',
#   'resmi',
#   'tetap',
#   'hasil',
#   'pilkada',
#   'grobogan',
#   '2011',
#   'pasang',
#   'bambang',
#   'pudjionoicek',
#   'baskoro',
#   'baik',
#   'bagai',
#   'pasang',
#   'raih',
#   'suara',
#   'banyak'],
#  '1052367': ['tentang',
#   'bolpoin',
#   'karet',
#   'sealant',
#   'nya',
#   'ekstra',
#   'keras',
#   'rapat',
#   'tahan',
#   'tinta',
#   'tak',
#   'sedot',
#   'tekan',
#   'vakum'],
#  '1052425': ['puluh',
#   'negara',
#   'rencana',
#   'temu',
#   'para',
#   'mitra',
#   'usai',
#   'rapat',
#   'menteri',
#   'uang',
#   'batal',
#   'resmi',
#   'janji',
#   'multilateral',
#   'tunda',
#   'akibat',
#   'krisis',
#   'politik',
#   'thailand'],
#  '1052447': ['kasus',
#   'mula',
#   'mereka',
#   'diberitahukan',
#   'rapat',
#   'panjang',
#   'hgb',
#   'itc',
#   'mangga',
#   'bulan',
#   'agustus',
#   '2006',
#   'status',
#   'tanah',
#   'sama',
#   'itcmangga',
#   'yang',
#   'diperjualbelikan',
#   'pt',
#   'duta',
#   'pertiwi',
#   'tbk',
#   'tahun',
#   '1992',
#   'status',
#   'atas',
#   'tanah',
#   'sama',
#   'hgb',
#   'yang',
#   'tera',
#   'di',
#   'dalam',
#   'tiap',
#   'sertifikat',
#   'milik',
#   'lama',
#   'benar',
#   'hgb',
#   'atas',
#   'hpl',
#   'pemprov',
#   'dki'],
#  '1052539': ['lalu',
#   'rapat',
#   'majelis',
#   'madrasah',
#   'pimpin',
#   'arsyid',
#   'tola',
#   'b',
#   'sc',
#   'pakat',
#   'drs',
#   'suardi',
#   'bagai',
#   'kepala',
#   'man',
#   '1',
#   'palu',
#   'masa',
#   'bakti',
#   '2001',
#   '2004'],
#  '1052555': ['september',
#   '2007',
#   'institute',
#   'of',
#   'medicine',
#   'selenggara',
#   'workshop',
#   'judul',
#   'the',
#   'development',
#   'of',
#   'dris',
#   '19942004',
#   'lessons',
#   'learned',
#   'and',
#   'new',
#   'challenges',
#   'rapat',
#   'sebut',
#   'beberapa',
#   'bicara',
#   'nyata',
#   'asupan',
#   'diet',
#   'rekomendasi',
#   'dietary',
#   'recommended',
#   'intakes',
#   'dri',
#   'ini',
#   'besar',
#   'dasar',
#   'tingkat',
#   'rendah',
#   'piramida',
#   'mutu',
#   'bukti',
#   'hanya',
#   'dasar',
#   'opini',
#   'bukan',
#   'dasar',
#   'uji',
#   'klinis',
#   'kendali',
#   'acak'],
#  '1052637': ['ikosahedron',
#   'milik',
#   'lima',
#   'wajah',
#   'segitiga',
#   'sama',
#   'sisi',
#   'rapat',
#   'tiap',
#   'simpul'],
#  '1052717': ['musim',
#   'gugur',
#   '654',
#   'rapat',
#   'kaisar',
#   'kaisar',
#   'panggil',
#   'zhangsun',
#   'li',
#   'ji',
#   'li',
#   'shiji',
#   'telah',
#   'ganti',
#   'nama',
#   'hindar',
#   'tabu',
#   'nama',
#   'mirip',
#   'kaisar',
#   'taizong',
#   'li',
#   'shimin',
#   'chu',
#   'yu',
#   'zhining',
#   'istana'],
#  '1052832': ['upacara',
#   'tutup',
#   'kongres',
#   'rapat',
#   'besar',
#   'umum',
#   'tamansiswa',
#   'pertama',
#   'yogyakarta',
#   '13',
#   'agustus',
#   '1930',
#   'ki',
#   'sarmidi',
#   'mangunsarkoro',
#   'sama',
#   'ki',
#   'sadikin',
#   'ki',
#   's',
#   'djojoprajitno',
#   'ki',
#   'poeger',
#   'ki',
#   'kadiroen',
#   'ki',
#   'safioedin',
#   'soerjopoetro',
#   'atas',
#   'nama',
#   'satu',
#   'tamansiswa',
#   'seluruh',
#   'indonesia',
#   'menandatangani',
#   'terang',
#   'terima',
#   'serah',
#   'piagam',
#   'satu',
#   'janji',
#   'diri',
#   'tangan',
#   'ki',
#   'hadjar',
#   'dewantara',
#   'ki',
#   'tjokrodirjo',
#   'ki',
#   'pronowidigdo',
#   'wujud',
#   'usaha',
#   'didik',
#   'alas',
#   'hidup',
#   'hidup',
#   'bangsa',
#   'nama',
#   'tamansiswa',
#   'diri',
#   '3',
#   'juli',
#   '1922',
#   'yogyakarta'],
#  '1052836': ['olbricht',
#   'lalu',
#   'tunjuk',
#   'stauffenberg',
#   'kenal',
#   'rapat',
#   'komite',
#   'rahasia',
#   'hadir',
#   'ludwig',
#   'beck',
#   'dr',
#   'carl',
#   'goerdeler',
#   'erwin',
#   'von',
#   'witzleben'],
#  '1052840': ['celaka',
#   'tas',
#   'pindah',
#   'salah',
#   'satu',
#   'anggota',
#   'rapat',
#   'kaki',
#   'meja'],
#  '1053034': ['21',
#   'desember',
#   '1948',
#   'empat',
#   'menteri',
#   'sebut',
#   'rapat',
#   'hasil',
#   'seluruh',
#   'gubernur',
#   'militer',
#   'i',
#   'ii',
#   'iii',
#   'seluruh',
#   'gubernur',
#   'sipil',
#   'residen',
#   'jawa',
#   'perintah',
#   'pusat',
#   'serah',
#   'kepada',
#   '3',
#   'orang',
#   'menteri',
#   'menteri',
#   'negeri',
#   'menteri',
#   'hakim',
#   'menteri',
#   'hubung'],
#  '1053110': ['pasu',
#   'rasulullah',
#   'saw',
#   'kepung',
#   'dengan',
#   'rapat',
#   'lama',
#   '15',
#   'hari',
#   'bulan',
#   'syawal',
#   'hingga',
#   'awal',
#   'dzulqaidah',
#   'tahun',
#   '2',
#   'hijriah'],
#  '1053113': ['seperti',
#   'artis',
#   'sandra',
#   'masuk',
#   'selebritis',
#   'tutup',
#   'rapat',
#   'kisah',
#   'cinta'],
#  '1053132': ['panitia',
#   'angket',
#   'dpr',
#   'lapor',
#   'laksana',
#   'tugas',
#   'rapat',
#   'paripurna',
#   'dpr',
#   'paling',
#   'lama',
#   'enam',
#   'puluh',
#   'hari',
#   'sejak',
#   'bentuk',
#   'panitia',
#   'angket'],
#  '1053145': ['atom',
#   'rupa',
#   'satu',
#   'kecil',
#   'dapat',
#   'urai',
#   'suatu',
#   'unsur',
#   'masih',
#   'tahan',
#   'sifat',
#   'bentuk',
#   'inti',
#   'rapat',
#   'muat',
#   'positif',
#   'keliling',
#   'suatu',
#   'sistem',
#   'elektron'],
#  '1053295': ['tanggal',
#   '24',
#   'november',
#   '2007',
#   'tempat',
#   'hotel',
#   'alila',
#   'selenggara',
#   'rapat',
#   'koordinator',
#   'angkat',
#   'alumni',
#   'sekolah',
#   'pa',
#   'hoa',
#   'sekolah',
#   'jpp',
#   'sma',
#   'negeri',
#   '19'],
#  '1053370': ['bentuk',
#   'ayam',
#   'buat',
#   'jarang',
#   'tidak',
#   'rapat',
#   'air',
#   'kotor',
#   'mudah',
#   'buang'],
#  '1053441': ['subang',
#   'aju',
#   'hasil',
#   'putus',
#   'rapat',
#   'paripurna',
#   'menteri',
#   'negeri',
#   'indonesia',
#   'lalu',
#   'gubernur',
#   'jawa',
#   'barat',
#   'lantik',
#   'ojang',
#   'bagai',
#   'bupati',
#   'subang'],
#  '1053446': ['dpd',
#   'diikutsertakan',
#   'bahas',
#   'ruu',
#   'sesuai',
#   'wenang',
#   'rapat',
#   'komisi',
#   'panitia',
#   'alat',
#   'lengkap',
#   'dpr',
#   'khusus',
#   'tangan',
#   'bidang',
#   'legislasi'],
#  '1053448': ['putus',
#   'majelis',
#   'musyawarat',
#   'rakyat',
#   'atas',
#   'usul',
#   'henti',
#   'presiden',
#   'atau',
#   'wakil',
#   'presiden',
#   'ambil',
#   'rapat',
#   'paripurna',
#   'majelis',
#   'musyawarat',
#   'rakyat',
#   'hadir',
#   'kurang',
#   '3',
#   '4',
#   'jumlah',
#   'anggota',
#   'tuju',
#   'sekurangkurangnya',
#   '2',
#   '3',
#   'jumlah',
#   'anggota',
#   'hadir',
#   'presiden',
#   'atau',
#   'wakil',
#   'presiden',
#   'beri',
#   'sempat',
#   'jelas',
#   'rapat',
#   'paripurna',
#   'majelis',
#   'musyawarat',
#   'rakyat'],
#  '1053487': ['tanggal',
#   '1',
#   'juli',
#   '1959',
#   'tempat',
#   'gedung',
#   'wilis',
#   'patih',
#   'yogyakarta',
#   'rapat',
#   'pleno',
#   'lima'],
#  '1053499': ['pohon',
#   'tumbuh',
#   'rapat',
#   'julang',
#   'tinggi',
#   'lantai',
#   'hutan',
#   'banyak',
#   'tumbuh',
#   'tumbuh',
#   'perdu'],
#  '1053544': ['fruity',
#   'top',
#   'buah',
#   'atas',
#   'tim',
#   'kena',
#   'sarung',
#   'harus',
#   'susun',
#   'bagai',
#   'buah',
#   'susun',
#   'untuk',
#   'sembah',
#   'adat',
#   'bal',
#   'sebut',
#   'gebogan'],
#  '1053725': ['adalah',
#   'satu',
#   'fielder',
#   'boleh',
#   'sarung',
#   'tangan',
#   'bantal',
#   'kaki'],
#  '1053734': ['lumas',
#   'bas',
#   'minyak',
#   'lemah',
#   'lateks',
#   'kurang',
#   'efektif',
#   'kondom',
#   'sarung',
#   'tangan',
#   'lateks',
#   'bendung',
#   'gigi'],
#  '1053877': ['daerah',
#   'banjar',
#   'kalimantan',
#   'selatan',
#   'sabuk',
#   'sarung',
#   'kena',
#   'posisi',
#   'juntai',
#   'atas',
#   'lutut'],
#  '1053961': ['arya',
#   'penangsang',
#   'sigap',
#   'sangkut',
#   'burai',
#   'usus',
#   'pada',
#   'wrangka',
#   'sarunghulu',
#   'keris',
#   'selip',
#   'pinggang',
#   'terus',
#   'tempur'],
#  '1053984': ['yumoto',
#   'tari',
#   'wanita',
#   'kena',
#   'furisode',
#   'warna',
#   'biru',
#   'terang',
#   'sarung',
#   'tangan',
#   'panjang',
#   'teko',
#   'hanagasa',
#   'tutup',
#   'kepala',
#   'hias',
#   'bunga',
#   'peony'],
#  '1054056': ['atraksi',
#   'mekepung',
#   'sawah',
#   'kembang',
#   'tahun',
#   '1930',
#   'sais',
#   'berpakain',
#   'ala',
#   'prajurit',
#   'raja',
#   'bal',
#   'zaman',
#   'dulu',
#   'pakai',
#   'destar',
#   'selendang',
#   'selempod',
#   'celana',
#   'panjang',
#   'alas',
#   'kaki',
#   'pinggang',
#   'selip',
#   'bilah',
#   'pedang',
#   'pakai',
#   'sarung',
#   'poleng',
#   'warna',
#   'hitam',
#   'putih'],
#  '1055413': ['bagi',
#   'negara',
#   'nama',
#   'tengah',
#   'sebut',
#   'nama',
#   'beri',
#   'atau',
#   'nama',
#   'beri',
#   'tiga'],
#  '1056933': ['ps',
#   'bpd',
#   'jateng',
#   'singkat',
#   'satu',
#   'sepak',
#   'bola',
#   'bank',
#   'kredit',
#   'daerah',
#   'jawa',
#   'tengah',
#   'rupa',
#   'klub',
#   'diri',
#   'jadi',
#   'wakil',
#   'jawa',
#   'tengah',
#   'kompetisi',
#   'galatama'],
#  '1057909': ['ajar',
#   'sejarah',
#   'timur',
#   'tengah',
#   'modern',
#   'universitas',
#   'amsterdam',
#   '1970',
#   '75',
#   'jadi',
#   'sekretaris',
#   'pertama',
#   'duta',
#   'besar',
#   'beirut',
#   'urus',
#   'lebanon',
#   'jordan',
#   'siprus',
#   '1980',
#   '83',
#   'charg',
#   'd',
#   'affaires',
#   'belanda',
#   'tripoli',
#   'libya',
#   '1983',
#   '85',
#   'deputi',
#   'direktur',
#   'urus',
#   'afrika',
#   'timur',
#   'tengah',
#   'menteri',
#   'urus',
#   'luar',
#   'negeri',
#   'belanda',
#   '1985',
#   '88'],
#  '1058172': ['teater',
#   'lingkar',
#   'laku',
#   'kerjasama',
#   'stasiun',
#   'tvri',
#   'jawa',
#   'tengah',
#   'siar',
#   'mentas',
#   'usung',
#   'lakon',
#   'mudah',
#   'cerna',
#   'pirsa',
#   'televisi',
#   'dengan',
#   'acara',
#   'tajuk',
#   'guyon',
#   'mathon',
#   'sindir',
#   'tidak',
#   'timbul',
#   'sakit',
#   'hati',
#   'orang'],
#  '1058716': ['dewan',
#   'wakil',
#   'rakyat',
#   'daerah',
#   'jawa',
#   'tengah',
#   'buah',
#   'lembaga',
#   'legislatif',
#   'unikameral',
#   'indonesia'],
#  '1059324': ['proses',
#   'sedimentasi',
#   'terus',
#   'terus',
#   'akan',
#   'bentuk',
#   'suatu',
#   'gosong',
#   'tengah',
#   'muara',
#   'kemudian',
#   'alir',
#   'sungai',
#   'belah',
#   'jadi',
#   'di',
#   'muara'],
#  '1060379': ['tengah',
#   'sibuk',
#   'bagai',
#   'mangkubumi',
#   'raja',
#   'kalinyamat',
#   'jepara',
#   'patih',
#   'sungging',
#   'badar',
#   'duwung',
#   'sering',
#   'ukir',
#   'atas',
#   'batu',
#   'khusus',
#   'datang',
#   'negeri',
#   'tiongkok'],
#  '1060680': ['sejak',
#   'itu',
#   'banyak',
#   'emigran',
#   'ukraina',
#   'kembali',
#   'ukraina',
#   'khusus',
#   'asia',
#   'tengah',
#   'siberia'],
#  '1061390': ['martin',
#   'ziguele',
#   'ialah',
#   'orang',
#   'politikus',
#   'republik',
#   'afrika',
#   'tengah',
#   'jadi',
#   'perdana',
#   'menteri',
#   'republik',
#   'afrika',
#   'tengah',
#   'tahun',
#   '2001',
#   'hingga',
#   '2003'],
#  '1063077': ['reichskommissariat',
#   'turkestan',
#   'eja',
#   'turkistan',
#   'singkat',
#   'rkt',
#   'reichskommissariat',
#   'jerman',
#   'nazi',
#   'usul',
#   'diri',
#   'republik',
#   'asia',
#   'tengah',
#   'uni',
#   'soviet',
#   'masa',
#   'perang',
#   'dunia',
#   'ii'],
#  '1063733': ['cara',
#   'administratif',
#   'sungai',
#   'ada',
#   'tiga',
#   'kabupaten',
#   'kabupaten',
#   'malaka',
#   'kabupaten',
#   'timor',
#   'tengah',
#   'utara',
#   'kabupaten',
#   'timor',
#   'tengah',
#   'selatan',
#   'provinsi',
#   'nusa',
#   'tenggara',
#   'timur',
#   'indonesia'],
#  '106508': ['semua',
#   'sebut',
#   'tolak',
#   'atas',
#   'selibat',
#   'kaum',
#   'rohaniwan',
#   'akhir',
#   'tolak',
#   'atas',
#   'doktrin',
#   'di',
#   'banyak',
#   'kalang',
#   'protestan',
#   'pandang',
#   'kata',
#   'saudara',
#   'yesus',
#   'janji',
#   'baru',
#   'bagai',
#   'anak',
#   'kandung',
#   'maria',
#   'akibat',
#   'sulit',
#   'jawab',
#   'tanya',
#   'yesus',
#   'serah',
#   'ibu',
#   'murid',
#   'kasih',
#   'yohanes',
#   '19',
#   '2627',
#   'asumsi',
#   'ibu',
#   'milik',
#   'anak',
#   'kandung'],
#  '1066315': ['tengah',
#   'giat',
#   'promosi',
#   'album',
#   'studio',
#   'grup',
#   'juga',
#   'partisipasi',
#   'smtown',
#   'live',
#   '10',
#   'world',
#   'tour',
#   'sama',
#   'rekan',
#   'satu',
#   'label',
#   'mereka',
#   'di',
#   's',
#   'm'],
#  '1067049': ['14',
#   'maret',
#   '2004',
#   'aristide',
#   'tinggal',
#   'republik',
#   'afrika',
#   'tengah',
#   'berangkat',
#   'jamaika',
#   'timbul',
#   'cemas',
#   'pihak',
#   'perintah',
#   'prancis',
#   'amerika',
#   'rasa',
#   'hadir',
#   'daerah',
#   'akan',
#   'ketidakstabilan',
#   'haiti'],
#  '1067954': ['upaya',
#   'jepang',
#   'luas',
#   'perimeter',
#   'tahan',
#   'di',
#   'samudra',
#   'pasifik',
#   'selatan',
#   'tengah',
#   'gagal',
#   'tempur',
#   'laut',
#   'karang',
#   'mei',
#   '1942',
#   'tempur',
#   'midway',
#   'juni',
#   '1942'],
#  '1067981': ['buah',
#   'upaya',
#   'pisah',
#   'bangun',
#   'pangkal',
#   'militer',
#   'pulau',
#   'solomon',
#   'tengah',
#   'akomodasi',
#   'konvoi',
#   'kapal',
#   'tongkang',
#   'guadalkanal',
#   'gagal',
#   'akibat',
#   'hancur',
#   'serang',
#   'udara',
#   'sekutu'],
#  '1068591': ['naik',
#   'takhta',
#   'kuasa',
#   'adiwijaya',
#   'cakup',
#   'wilayah',
#   'jawa',
#   'tengah',
#   'karena',
#   'tinggal',
#   'trenggana',
#   'banyak',
#   'daerah',
#   'bawah',
#   'demak',
#   'lepas',
#   'diri'],
#  '1071465': ['tengah',
#   'benteng',
#   'kursi',
#   'batu',
#   'kata',
#   'jadi',
#   'tempat',
#   'prajurit',
#   'temu',
#   'makan'],
#  '1071835': ['biasa',
#   'gelar',
#   'masjid',
#   'tengah',
#   'sepi',
#   'lepas',
#   'shalat',
#   'ashar',
#   'isya',
#   'shubuh',
#   'bab',
#   'al',
#   'umrah'],
# ...
#   'baur',
#   'orang'],
#  '965537': ['kereta',
#   'api',
#   'hanya',
#   'jalan',
#   'satu',
#   'kali',
#   'hari',
#   'hanya',
#   'jam',
#   '14',
#   '16',
#   'sore',
#   'bojonegoro',
#   'biasa',
#   'bawa',
#   '4',
#   'gerbong',
#   'tawang',
#   'jaya',
#   'tarik',
#   'loko',
#   'cc201'],
#  '966307': ['debut',
#   'nya',
#   'nba',
#   'hasil',
#   'bawa',
#   'tim',
#   'raih',
#   'menang',
#   'lalu',
#   'orlando',
#   'magic',
#   'skor',
#   '10086'],
#  '966741': ['ubah',
#   'sistem',
#   'taruh',
#   'suatu',
#   'benda',
#   'dalam',
#   'koper',
#   'dalang',
#   'parto',
#   'beri',
#   'tunjuk',
#   'cara',
#   'jawab',
#   'dengan',
#   'bawa',
#   'barang',
#   'sebut',
#   'acara',
#   'langsung',
#   'batas',
#   'waktu',
#   'hingga',
#   'jam',
#   '4',
#   'pagi'],
#  '966968': ['salyut', 'pecah', 'beberapa', 'rekor', 'spaceflight'],
#  '966988': ['negara',
#   'asal',
#   'wings',
#   'jual',
#   'banyak',
#   '681',
#   '924',
#   'album',
#   'bulan',
#   'pertama',
#   'pecah',
#   'rekor',
#   'jual',
#   'album',
#   'tinggi',
#   'bulan',
#   'pertama',
#   'panjang',
#   'sejarah',
#   'gaon',
#   'music',
#   'chart',
#   'jadi',
#   'album',
#   'jual',
#   'banyak',
#   'turut',
#   'versi',
#   'gaon'],
#  '967015': ['tahun',
#   '1995',
#   '1996',
#   'graf',
#   'juara',
#   'seri',
#   'grand',
#   'slam',
#   'perancis',
#   'wimbledon',
#   'amerika',
#   'raih',
#   'gelar',
#   'wta',
#   '100',
#   'wimbledon',
#   '1996',
#   'banyak',
#   'keitga',
#   'era',
#   'buka',
#   'paut',
#   'navratilova',
#   '167',
#   'gelar',
#   'evert',
#   '154',
#   'gelar',
#   'tanggal',
#   '13',
#   'mei',
#   '1996',
#   'ukir',
#   'sejarah',
#   'lama',
#   '332',
#   'minggu',
#   'bagai',
#   'no',
#   '1',
#   'main',
#   'dunia',
#   'pecah',
#   'rekor',
#   'martina',
#   'navratilova',
#   '331',
#   'minggu',
#   'jadi',
#   'no',
#   '1',
#   'pegang',
#   'no',
#   '1',
#   'peringkat',
#   'total',
#   'lama',
#   '377',
#   'minggu',
#   'nonberturutturut',
#   'geser',
#   'no',
#   '2',
#   '31',
#   'maret',
#   '1997',
#   'martina',
#   'hingis',
#   'jadi',
#   'no',
#   '1',
#   'steffi',
#   'graf',
#   'lengkap',
#   'juara',
#   'grand',
#   'slam',
#   'jadi',
#   '22',
#   'banyak',
#   'era',
#   'tenis',
#   'buka',
#   'dua',
#   'banyak',
#   'panjang',
#   'masa',
#   'tenis',
#   'australia',
#   'margareth',
#   'smith',
#   'court',
#   'pegang',
#   '24',
#   'gelar',
#   '31',
#   'final',
#   'grand',
#   'slam',
#   'kalah',
#   'navratilova',
#   '34',
#   'final',
#   'grand',
#   'slam',
#   'evert',
#   '32',
#   'final',
#   'grand',
#   'slam'],
#  '967031': ['sepakat',
#   'kristologis',
#   'baru',
#   'dengan',
#   'gereja',
#   'katolik',
#   'roma',
#   'beberapa',
#   'gereja',
#   'ortodoks',
#   'pecah',
#   'debat',
#   'cara',
#   'permanen',
#   'buka',
#   'jalan',
#   'satu'],
#  '967043': ['suluh',
#   'tani',
#   'suatu',
#   'usaha',
#   'upaya',
#   'ubah',
#   'perilaku',
#   'tani',
#   'keluarga',
#   'mereka',
#   'tahu',
#   'punya',
#   'mau',
#   'mampu',
#   'pecah',
#   'masalah',
#   'sendiri',
#   'usaha',
#   'giat',
#   'tingkat',
#   'hasil',
#   'usaha',
#   'tingkat',
#   'hidup'],
#  '967097': ['sherlock',
#   'holmes',
#   'benedict',
#   'cumberbatch',
#   'jadi',
#   'detektif',
#   'pecah',
#   'bagai',
#   'misteri',
#   'zaman',
#   'modern',
#   'london'],
#  '967225': ['bagai',
#   'cetus',
#   'giat',
#   'tari',
#   'tebe',
#   'pecah',
#   'rekor',
#   'muri',
#   'bank',
#   'indonesia',
#   'naek',
#   'tigor',
#   'sinaga',
#   'kata',
#   'kampanye',
#   'gera',
#   'cinta',
#   'rupiah',
#   'beri',
#   'semangat',
#   'masyarakat',
#   'cinta',
#   'rupiah',
#   'selalu',
#   'rupiah',
#   'bertansaksi',
#   'cara',
#   'khusus',
#   'masyarakat',
#   'ada',
#   'daerah',
#   'batas',
#   'timor',
#   'leste'],
#  '967458': ['bukti',
#   'beberapa',
#   'terbit',
#   'buku',
#   'bahas',
#   'bilang',
#   'ini',
#   'raya',
#   'hari',
#   'pi',
#   'berita',
#   'luas',
#   'manakala',
#   'hitung',
#   'digit',
#   'hasil',
#   'pecah',
#   'rekor',
#   'hitung'],
#  '967495': ['film',
#   'inini',
#   'cerita',
#   'orang',
#   'detektif',
#   'terlalu',
#   'semangat',
#   'lebih',
#   'berat',
#   'badan',
#   'cha',
#   'cheolsoo',
#   'pergi',
#   'samar',
#   'bagai',
#   'orang',
#   'model',
#   'pecah',
#   'suatu',
#   'kasus'],
#  '967592': ['jepang',
#   'kirim',
#   'pesan',
#   'amerika',
#   'serikat',
#   'duta',
#   'besar',
#   'washington',
#   'namun',
#   'masalah',
#   'duta',
#   'urai',
#   'kode',
#   'pesan',
#   'sangat',
#   'panjang',
#   'tingkat',
#   'aman',
#   'tinggi',
#   'beri',
#   'maklumat',
#   'sebut',
#   'arti',
#   'hanya',
#   'personel',
#   'izin',
#   'sangat',
#   'tinggi',
#   'bisa',
#   'pecah',
#   'kode',
#   'lambat',
#   'proses',
#   'pesan',
#   'sebut',
#   'menteri',
#   'luar',
#   'negeri',
#   'as',
#   'sampai',
#   'telah',
#   'serang',
#   'pearl',
#   'harbor'],
#  '967611': ['relevansi',
#   'sini',
#   'kandung',
#   'erti',
#   'hukum',
#   'bisa',
#   'pecah',
#   'suatu',
#   'soal',
#   'suatu',
#   'realitas',
#   'baru',
#   'masyarakat'],
#  '967713': ['john',
#   'harrison',
#   '24',
#   'maret',
#   '1776',
#   'orang',
#   'tukang',
#   'kayu',
#   'buat',
#   'jam',
#   'otodidak',
#   'asal',
#   'inggris',
#   'cipta',
#   'kronometer',
#   'laut',
#   'buah',
#   'alat',
#   'pecah',
#   'masalah',
#   'hitung',
#   'lintang',
#   'di',
#   'laut'],
#  '967731': ['walaupun',
#   'milik',
#   'supercomputer',
#   'kapasitas',
#   'sangat',
#   'tinggi',
#   'apa',
#   'sudah',
#   'ini',
#   'rasa',
#   'tetap',
#   'kurang',
#   'mereka',
#   'usaha',
#   'pecah',
#   'masalah',
#   'lebih',
#   'besar'],
#  '967777': ['walaupun',
#   'algorism',
#   'nya',
#   'alkhawarizmi',
#   'rujuk',
#   'bagai',
#   'atur',
#   'laku',
#   'aritmetika',
#   'bilang',
#   'hinduarab',
#   'solusi',
#   'sistematis',
#   'sama',
#   'kuadrat',
#   'formal',
#   'nanti',
#   'jadi',
#   'algoritme',
#   'modern',
#   'mulai',
#   'usaha',
#   'pecah',
#   'masalah',
#   'putus',
#   'entscheidungsproblem',
#   'aju',
#   'david',
#   'hilbert',
#   'tahun',
#   '1928'],
#  '967838': ['estetisasi',
#   'politisasi',
#   'estetika',
#   'cabang',
#   'studi',
#   'filosofi',
#   'sifat',
#   'nilai',
#   'indah',
#   'seni',
#   'moral',
#   'metode',
#   'propaganda',
#   'upa',
#   'upaya',
#   'paksa',
#   'simbol',
#   'estetis'],
#  '968183': ['8',
#   'juli',
#   '2014',
#   'klose',
#   'pecah',
#   'rekor',
#   '16',
#   'gol',
#   'piala',
#   'dunia',
#   'menit',
#   'ke23',
#   'tanding',
#   'semi',
#   'final',
#   'kontra',
#   'brazil',
#   'juga',
#   'rupa',
#   'gol',
#   'di',
#   'piala',
#   'dunia',
#   '2014'],
#  '968218': ['tanggal',
#   '3',
#   'november',
#   '2008',
#   'the',
#   'wall',
#   'street',
#   'journal',
#   'pecah',
#   'kisah',
#   'berangkat',
#   'tony',
#   'apple'],
#  '971335': ['biasa', 'cara', 'cara', 'teknis', 'khusus', 'tangkap', 'ikan'],
#  '972319': ['serangkain',
#   'erti',
#   'ahli',
#   'atas',
#   'dapat',
#   'simpul',
#   'motivasi',
#   'sesuatu',
#   'alas',
#   'dorong',
#   'orang',
#   'laku',
#   'selesai',
#   'henti',
#   'suatu',
#   'aktifitas',
#   'capai',
#   'tuju',
#   'yang',
#   'dari',
#   'motivasi',
#   'sebut'],
#  '972517': ['hill',
#   'menghimbau',
#   'pimpin',
#   'gereja',
#   'tobat',
#   'dorong',
#   'massa',
#   'tidak',
#   'cari',
#   'berkat',
#   'manusia',
#   'dari',
#   'allah'],
#  '972915': ['dorong',
#   'hal',
#   'paksa',
#   'praktisi',
#   'kontrol',
#   'boneka',
#   'lalu',
#   'sikap',
#   'baik'],
#  '973173': ['juga',
#   'usaha',
#   'luas',
#   'basis',
#   'dukung',
#   'nguy',
#   'n',
#   'selatan',
#   'angkat',
#   'mantan',
#   'berontak',
#   'bandit',
#   'para',
#   'ungsi',
#   'tiongkok',
#   'baru',
#   'tiba',
#   'lari',
#   'diri',
#   'tanah',
#   'air',
#   'telah',
#   'jatuh',
#   'dinasti',
#   'ming',
#   'duduk',
#   'pos',
#   'administratif',
#   'penuh',
#   'syarat',
#   'dorong',
#   'partisipasi',
#   'integrasi',
#   'mereka',
#   'ke',
#   'masyarakat'],
#  '973313': ['perang',
#   'arus',
#   'pulang',
#   'tentara',
#   'imigrasi',
#   'massal',
#   'tingkah',
#   'laku',
#   'makin',
#   'bebas',
#   'faktor',
#   'dorong',
#   'muncul',
#   'gera',
#   'summer',
#   'of',
#   'love',
#   'hak',
#   'asasi',
#   'gay'],
#  '974016': ['phebe',
#   'suka',
#   'main',
#   'cinta',
#   'silvius',
#   'dorong',
#   'silvius',
#   'kata',
#   'ia',
#   'ikut'],
#  '974232': ['inses',
#   'ada',
#   'akan',
#   'dorong',
#   'pria',
#   'pergi',
#   'cari',
#   'wanita',
#   'luar',
#   'lingkar',
#   'kerabat',
#   'mereka',
#   'balik'],
#  '974241': ['william',
#   'randolph',
#   'hearst',
#   'seringkali',
#   'sebut',
#   'dorong',
#   'perang',
#   'spanyol',
#   'amerika',
#   'serikat',
#   'atas',
#   'alas'],
#  '974345': ['tahun',
#   '1918',
#   'tentara',
#   'serbia',
#   'dorong',
#   'kuat',
#   'tengah',
#   'keluar',
#   'kosovo'],
#  '974887': ['perilaku',
#   'tunjuk',
#   'rupa',
#   'perilaku',
#   'tari',
#   'heteroseksual',
#   'antara',
#   'satu',
#   'jantan',
#   'letak',
#   'belalai',
#   'punggu',
#   'jantan',
#   'lalu',
#   'dorong',
#   'gading',
#   'depan',
#   'ketika',
#   'ekor',
#   'jantan',
#   'tunggang',
#   'betina'],
#  '975189': ['sama',
#   'karya',
#   'leo',
#   'masa',
#   'pimpin',
#   'bagai',
#   'paus',
#   'panjang',
#   '1878',
#   '1903',
#   'salah',
#   'satu',
#   'akibat',
#   'dalam',
#   'dorong',
#   'gereja',
#   'katolik',
#   'dan',
#   'hierarkhinya',
#   'dalma',
#   'dunia',
#   'modern'],
#  '975360': ['kiprah',
#   'stieb',
#   'aku',
#   'masyarakat',
#   'luas',
#   'dorong',
#   'yayasan',
#   'kembang',
#   'beberapa',
#   'sekolah',
#   'tinggi'],
#  '975578': ['johan',
#   'wilhelm',
#   'van',
#   'lansberge',
#   'kunjung',
#   'aceh',
#   'jumlah',
#   'kuasa',
#   'tetua',
#   'tiba',
#   'kutaraja',
#   'beri',
#   'hormat',
#   'gubernur',
#   'pidato',
#   'dorong',
#   'kerja',
#   'sama',
#   'cipta',
#   'aman',
#   'dalam',
#   'perintah',
#   'belanda',
#   'janji',
#   'renovasi',
#   'masjid',
#   'raya'],
#  '976237': ['salah',
#   'buru',
#   'lepas',
#   'posting',
#   'hina',
#   'dorong',
#   'untuk',
#   'pergi',
#   'offline'],
#  '976404': ['astori',
#   'main',
#   'debut',
#   'tim',
#   'nasional',
#   'tanding',
#   'sahabat',
#   'lawan',
#   'tanggal',
#   '29',
#   'maret',
#   '2011',
#   'mana',
#   'masuk',
#   'ganti',
#   'georgio',
#   'chiellini',
#   'oleh',
#   'kartu',
#   'merah',
#   'terima',
#   'kali',
#   'kartu',
#   'kuning'],
#  '976656': ['terima',
#   'didik',
#   'awal',
#   'king',
#   's',
#   'school',
#   'kemudian',
#   'sambung',
#   'university',
#   'nottingham',
#   'bidang',
#   'undang'],
#  '976771': ['ada',
#   'diri',
#   'sendiri',
#   'pour',
#   'soi',
#   'keputusasaan',
#   'rangkul',
#   'bebas',
#   'laku',
#   'tindak',
#   'arti',
#   'terima',
#   'sepenuh',
#   'akibat',
#   'muncul'],
#  '977353': ['anime',
#   'manga',
#   'mode',
#   'film',
#   'susastra',
#   'main',
#   'video',
#   'musik',
#   'jepang',
#   'terima',
#   'sambut',
#   'hangat',
#   'seluruh',
#   'dunia',
#   'utama',
#   'negara',
#   'asia',
#   'lain'],
#  '977839': ['perintah',
#   'kolonial',
#   'terus',
#   'desak',
#   'terima',
#   'posisi',
#   'tapi',
#   'dengan',
#   'tegas',
#   'tolak'],
#  '978217': ['tahun',
#   '1964',
#   'terima',
#   'duduk',
#   'staf',
#   'ajar',
#   'coll',
#   'ge',
#   'de',
#   'france'],
#  '979363': ['halaman',
#   'informasi',
#   'milik',
#   'alamat',
#   'data',
#   'teleteks',
#   'tuju',
#   'dekoder',
#   'dalam',
#   'terima',
#   'halaman',
#   'apa',
#   'baris',
#   'apa',
#   'alamat',
#   'minta'],
#  '980672': ['3',
#   'november',
#   '1189',
#   'yoritomo',
#   'terima',
#   'surat',
#   'istana',
#   'isi',
#   'puji',
#   'atas',
#   'sukses',
#   'takluk',
#   'sh'],
#  '981309': ['1906',
#   'sommerfeld',
#   'terima',
#   'angkat',
#   'm',
#   'nchen',
#   'debije',
#   'angkat',
#   'bagai',
#   'asisten'],
#  '981767': ['jarak',
#   'cukup',
#   'jauh',
#   'markas',
#   'wang',
#   'turun',
#   'kuda',
#   'bungkuk',
#   'lalu',
#   'teriak',
#   'kea',
#   'rah',
#   'wang',
#   'adipati',
#   'mulia',
#   'memang',
#   'telah',
#   'terima',
#   'hormat',
#   'kami',
#   'wajib',
#   'balas',
#   'budi',
#   'anda'],
#  '982338': ['perata',
#   'sebut',
#   'mungkin',
#   'lebih',
#   'banyak',
#   'omatidia',
#   'terima',
#   'cahaya',
#   'suatu',
#   'tempat',
#   'oleh',
#   'itu',
#   'milik',
#   'resolusi',
#   'lebih',
#   'tinggi'],
#  '982373': ['film',
#   'terima',
#   'tanggap',
#   'positif',
#   'kritikus',
#   'maupun',
#   'tonton',
#   'telah',
#   'raih',
#   'besar',
#   '1',
#   '2',
#   'miliar',
#   'seluruh',
#   'dunia',
#   'jadi',
#   'film',
#   'dapat',
#   'kotor',
#   'tinggi',
#   'tahun',
#   '2017',
#   'peringkat',
#   'puluh',
#   'dapat',
#   'kotor',
#   'tinggi',
#   'panjang',
#   'masa'],
#  '982856': ['akashi',
#   'ungkap',
#   'rasa',
#   'terima',
#   'kasih',
#   'midorima',
#   'seperti',
#   'main',
#   'debar',
#   'minta',
#   'maaf',
#   'nyata',
#   'ia',
#   'dapat',
#   'terima',
#   'jabat',
#   'tangan',
#   'nya'],
#  '985019': ['kazimierz',
#   'i',
#   'terima',
#   'kuyavia',
#   'ayahanda',
#   'tahun',
#   '1233'],
#  '985210': ['satu',
#   'minggu',
#   'bagi',
#   'terbit',
#   'majalah',
#   'tintin',
#   'herg',
#   'terima',
#   'buah',
#   'surat',
#   'orang',
#   'ayah',
#   'anak',
#   'lelaki',
#   'gemar',
#   'berat',
#   'tualang',
#   'tintin',
#   'juga',
#   'alami',
#   'sakit',
#   'tuberkulosis',
#   'cukup',
#   'akut',
#   'serang',
#   'paru'],
#  '986365': ['tahun',
#   '19761980',
#   'tunjuk',
#   'bagai',
#   'duta',
#   'besar',
#   'indonesia',
#   'meksiko',
#   'terima',
#   'medali',
#   'hormat',
#   'aguila',
#   'azteca',
#   'primera',
#   'banda',
#   'perintah',
#   'meksiko',
#   'di',
#   'tahun',
#   '1980'],
#  '986935': ['lagu',
#   'terima',
#   'academy',
#   'award',
#   'for',
#   'best',
#   'original',
#   'song',
#   'tahun',
#   '1956'],
#  '988987': ['seluruh',
#   'negara',
#   'terima',
#   'konvensi',
#   'kait',
#   'status',
#   'ungsi',
#   'pbb',
#   'wajib',
#   'izin',
#   'orang',
#   'benar',
#   'kualifikasi',
#   'datang',
#   'negeri'],
#  '989383': ['independent',
#   'film',
#   'award',
#   'film',
#   'terima',
#   'lima',
#   'nominasi',
#   'menang',
#   'aktris',
#   'baik',
#   'shareefa',
#   'daanish'],
#  '990974': ['tahun',
#   '922',
#   'dirk',
#   'hadir',
#   'buah',
#   'tempat',
#   'sebut',
#   'bladella',
#   'sekarang',
#   'bladel',
#   'ekstrem',
#   'selatan',
#   'provinsi',
#   'belanda',
#   'noord',
#   'brabant',
#   'mana',
#   'terima',
#   'wilayah',
#   'di',
#   'buah',
#   'tempat',
#   'sebut',
#   'egmond',
#   'raja',
#   'franka',
#   'barat',
#   'charles',
#   'sederhana'],
#  '991126': ['bandara',
#   'terima',
#   'tebang',
#   'amerika',
#   'serikat',
#   'kanada',
#   'eropa'],
#  '991165': ['beberapa', 'hari', 'kemudian', 'terima', 'surat', 'ny', 'maut'],
#  '991227': ['makhluk', 'hidup', 'terima', 'berkat', 'tuhan'],
#  '991642': ['tahun',
#   '1425',
#   'tunjuk',
#   'bagai',
#   'gubernur',
#   'languedoc',
#   'terima',
#   'raja',
#   'vicomt',
#   'de',
#   'lautrec'],
#  '991666': ['meski',
#   'terima',
#   'tawar',
#   'ajax',
#   'amsterdam',
#   'arsenal',
#   'gourcuff',
#   'putus',
#   'tetap',
#   'tahan',
#   'rennes',
#   'ia',
#   'resmi',
#   'jadi',
#   'main',
#   'profesional',
#   'tahun',
#   '2003'],
#  '991753': ['jurisdiksi',
#   'hukum',
#   'umum',
#   'lebih',
#   'sedia',
#   'terima',
#   'milik',
#   'usaha',
#   'hak',
#   'cipta',
#   'dalam',
#   'karya',
#   'prinsip',
#   'amerika',
#   'serikat',
#   'sewa'],
#  '992082': ['terima',
#   'gelar',
#   'sarjana',
#   '1967',
#   'caltech',
#   'mana',
#   'jadi',
#   'murid',
#   'richard',
#   'feynman'],
#  '992103': ['tahun',
#   '1182',
#   'terima',
#   'diakonat',
#   'tangan',
#   'sepupu',
#   'uskup',
#   'agung',
#   'salzburg',
#   'adalbert',
#   'iii'],
#  '992628': ['tahun',
#   'sama',
#   'christine',
#   'terima',
#   'harga',
#   'fiapf',
#   'capai',
#   'luar',
#   'biasa',
#   'banding',
#   'harga',
#   'sebut',
#   'viagra',
#   'kata',
#   'hal',
#   'buat',
#   'kuat',
#   'muas',
#   'tonton'],
#  '993456': ['beda',
#   'dukung',
#   'kreasionisme',
#   'bumi',
#   'lama',
#   'percaya',
#   'kitab',
#   'jadi',
#   'tafsir',
#   'cara',
#   'kias',
#   'terima',
#   'umur',
#   'bumi',
#   'alam',
#   'semesta',
#   'turut',
#   'kira',
#   'ilmiah',
#   'ini'],
#  '99428': ['minta',
#   'populer',
#   'janji',
#   'baru',
#   'yunani',
#   'dorong',
#   'banyak',
#   'terbit',
#   'edisi',
#   'sah',
#   'tidak',
#   'sah',
#   'awal',
#   'abad',
#   'ke16',
#   'hampir',
#   'semua',
#   'dasar',
#   'karya',
#   'erasmus',
#   'masuk',
#   'jumlah',
#   'baca',
#   'khas',
#   'meski',
#   'biasa',
#   'ada',
#   'jumlah',
#   'ubah',
#   'kecil',
#   'sendiri'],
#  '996057': ['hampir',
#   'tak',
#   'hingga',
#   'jumlah',
#   'senyawa',
#   'kandung',
#   'karbon',
#   'mampu',
#   'karbon',
#   'bentuk',
#   'rantai',
#   'c',
#   'c',
#   'panjang',
#   'stabil'],
#  '996118': ['banyak',
#   'tempat',
#   'cr',
#   'iii',
#   'spesies',
#   'dominan',
#   'di',
#   'beberapa',
#   'daerah',
#   'air',
#   'tanah',
#   'kandung',
#   '39',
#   'g',
#   'liter',
#   'total',
#   'kromium',
#   'dengan',
#   '30',
#   'g',
#   'liter',
#   'cr',
#   'vi'],
#  '997966': ['dokumentasi',
#   'catat',
#   'audit',
#   'kandung',
#   'informasi',
#   'kena',
#   'jenis',
#   'event',
#   'waktu',
#   'event',
#   'tempat',
#   'event',
#   'hasil',
#   'event',
#   'sebut',
#   'tiap',
#   'identitas',
#   'yang',
#   'kait'],
#  '99881': ['hubung',
#   'bilateral',
#   'negeri',
#   'benar',
#   'jalin',
#   'tahun',
#   '1950',
#   'batas',
#   'komunikasi',
#   'dua',
#   'negara',
#   'buat',
#   'kerja',
#   'sama',
#   'beberapa',
#   'bidang',
#   'penting',
#   'dagang',
#   'baru',
#   'jalan',
#   'tahun',
#   '1961',
#   'akhir',
#   'pimpin',
#   'presiden',
#   'soekarno'],
#  '999036': ['pertama',
#   'letak',
#   'bagi',
#   'atas',
#   'rupa',
#   'kolam',
#   'air',
#   'panas',
#   'g',
#   'kandung',
#   'belerang']}
